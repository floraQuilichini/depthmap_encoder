# %%
import numpy as np
import torch
import torch.nn as nn
import pandas as pd
from skimage import io, transform
import torch.autograd as ag
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from PIL import Image
import os
from scipy import signal
from sklearn.metrics import mean_squared_error
from torch.autograd import Variable
import time
from functools import reduce

torch.set_printoptions(precision=6)

# %%
class ImageDataset(Dataset):

    def __init__(self, root_dir, transform=None):
        """
        Args:
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        path, dirs, files = next(os.walk(self.root_dir))
        file_count = len(files)
        return file_count

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        path, dirs, files = next(os.walk(self.root_dir))
        img_name = os.path.join(self.root_dir, files[idx])
        image = io.imread(img_name)

        if self.transform:
            image = self.transform(image)

        return image


class RandomCrop(object):
    """Crop randomly the image

    Args:
        output_size (tuple or int): Desired output size. If int, square crop
            is made.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            assert len(output_size) == 2
            self.output_size = output_size

    def __call__(self, image):

        h, w = image.shape[:2]
        new_h, new_w = self.output_size

        top = np.random.randint(0, h - new_h)
        left = np.random.randint(0, w - new_w)

        image = image[top: top + new_h,
                      left: left + new_w]


        return image
    

class ToTensor(object):
    """Convert ndarrays in images to Tensors."""

    def __call__(self, images):

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        images = images.transpose((2, 0, 1))
        return torch.from_numpy(images)

    
def show_image_batch(images_batch):
    """Show image for a batch of samples."""
    batch_size = len(images_batch)
    grid = utils.make_grid(images_batch)
    plt.imshow(grid.numpy().transpose((1, 2, 0)))

    plt.title('Batch from dataloader')
    
    
    
    
# Load training dataset

#mirror_padding_transform = transforms.Compose([transforms.ToPILImage(), transforms.Pad(padding=12, padding_mode='reflect'), transforms.ToTensor()])
transformed_dataset = ImageDataset(root_dir='./data/flickr/', 
                                           transform=transforms.Compose([
                                            RandomCrop(128), ToTensor()])
                                  )
print(transformed_dataset[1].size())
dataloader = DataLoader(transformed_dataset, batch_size=22, shuffle=True, num_workers=0)

for i_batch, batch_images in enumerate(dataloader):
    print(i_batch, batch_images.size())

    # observe 4th batch and stop.
    if i_batch == 2:
        plt.figure()
        show_image_batch(batch_images)
        plt.axis('off')
        plt.ioff()
        plt.show()
        break

"""
transform = transforms.Compose([
    transforms.Pad(12, padding_mode='reflect'),
    transforms.ToTensor()])

trainset = torchvision.datasets.Flickr8k(root='./data/flickr', ann_file = './data/flickr/file.csv', transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=2)
"""
# Out:
# torch.Size([3, 128, 128])
# 0 torch.Size([22, 3, 128, 128])
# 1 torch.Size([22, 3, 128, 128])
# 2 torch.Size([22, 3, 128, 128])
# "\ntransform = transforms.Compose([\n    transforms.Pad(12, padding_mode='reflect'),\n    transforms.ToTensor()])\n\ntrainset = torchvision.datasets.Flickr8k(root='./data/flickr', ann_file = './data/flickr/file.csv', transform=transform)\ntrainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=2)\n"

# %%
#Define additionnnal functions
def periodic_shuffling(T, C):
    T_copy = T.clone()
    batch_size = T.size()[0]
    H = T.size()[2]
    W = T.size()[3]
    T = T.view(batch_size, C, H*2, W*2)
    """
    for k in range(C):
        for i in range(2*H):
            for j in range(2*W):
                T[:, k, i, j] = T_copy[:, C*((j&1)<<1)+C*(i&1)+k, i>>1, j>>1]
    """
                
    T[:, :, ::2, ::2] = T_copy[:, 0:C, :, :]
    T[:, :, 1::2, ::2] = T_copy[:, C:2*C, :, :]
    T[:, :, ::2, 1::2] = T_copy[:, 2*C:3*C, :, :]
    T[:, :, 1::2, 1::2] = T_copy[:, 3*C:4*C, :, :]

    return T
    
    
def mirror_padding(x, padding_size):
    up_line = x[:, :, 0:padding_size, :].flip(2)
    left_col = x[:, :, :, 0:padding_size].flip(3)
    right_col = x[:, :, :, -padding_size:].flip(3)
    bottom_line = x[:, :, -padding_size:, :].flip(2)
    left_up_corner = left_col[:, :, 0:padding_size, :].flip(2)
    right_up_corner = right_col[:, :, 0:padding_size, :].flip(2)
    left_bottom_corner = left_col[:, :, -padding_size:, :].flip(2)
    right_bottom_corner = right_col[:, :, -padding_size:, :].flip(2)

    x_mirror_pad = torch.cat((torch.cat((left_up_corner, up_line, right_up_corner), 3), torch.cat((left_col, x, right_col), 3), torch.cat((left_bottom_corner, bottom_line, right_bottom_corner), 3)), 2)
    return x_mirror_pad
    

def normalize_input(x):
    mean_channels = torch.mean(1.0*x, [2,3])
    mean_channels_images = (mean_channels.repeat_interleave(x.size()[2]*x.size()[3])).view(x.size()[0], x.size()[1], x.size()[2], x.size()[3])
    x_centered = x - mean_channels_images
    max_value = torch.max(x)
    min_value = torch.min(x)
    radius = max(max_value, abs(min_value))
    x_centered_normalized = x_centered/radius
    return x_centered_normalized, radius, mean_channels
    
def denormalize_output(x, radius, mean_channels):
    x_denormalized = x*radius
    mean_channels_images = (mean_channels.repeat_interleave(x.size()[2]*x.size()[3])).view(x.size()[0], x.size()[1], x.size()[2], x.size()[3])
    x_denormalized_centered = x_denormalized + mean_channels_images
    return x_denormalized_centered



def compute_gsm(x, var, phi, nScale):
    gsm = 0.0
    
    phi = torch.abs(phi)
    var = torch.abs(var)
    phi_s_sum = torch.sum(phi, 0).unsqueeze(0)
    phi_norm = phi/phi_s_sum
    
    for s in range(nScale):
        var_s = var[s, :].view(1, -1, 1, 1)
        phi_s = phi_norm[s, :].view(1, -1, 1, 1)
        gaussian = phi_s*(1.0/(torch.sqrt(2*np.pi*var_s)))*torch.exp(-0.5*(x**2/var_s))
        gsm += gaussian
    return gsm


def sum_gsm(x, var, phi, nScale):
    gsm = 0.0
    
    phi = torch.abs(phi)
    var = torch.abs(var)
    phi_s_sum = torch.sum(phi, 0).unsqueeze(0)
    phi_norm = phi/phi_s_sum
    
    for s in range(nScale):
        var_s = var[s, :].view(1, -1, 1, 1)
        phi_s = phi_norm[s, :].view(1, -1, 1, 1)
        gaussian = phi_s*(1.0/(torch.sqrt(2*np.pi*var_s)))*torch.exp(-0.5*(x**2/var_s))
        gsm += gaussian
    #gsm_sum = (torch.log2(gsm)).sum()
    gsm_sum = gsm.sum()
    return gsm_sum
    
    
    """
    batch_size = x.size(0)
    h = x.size(-1)
    w = x.size(-2)
    #print("input : ", input)
    coeff = torch.sqrt(1.0 / (2 * np.pi * var))
    #print("coeff : ", coeff)
    x_resized = x.repeat((nScale, 1, 1, 1, 1))
    #print("input : ", input_resized)
    exponent = (-0.5*(x_resized ** 2)/var.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w))
    #print("exponent : ", exponent)
    coeffs_resized = coeff.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
    #print("coeffs : ", coeffs_resized)
    gaussian = coeffs_resized * torch.exp(exponent)
    #print("gaussian : ", gaussian)
    phi_resized = phi.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
    phi_gaussian = phi_resized*gaussian
    sum_phi_gaussian = phi_gaussian.sum(dim=0)
    #print("sum over scales : ", sum_phi_gaussian)
    result = -torch.log2(sum_phi_gaussian).sum()

    return result
    """
    
def compute_mask(nb_ones, dims):
    mask = torch.zeros(dims)
    indices = np.arange(nb_ones)
    mask_flatten = mask.view(-1, 1, 1, 1)
    mask_flatten[indices] = 1
    mask_reshaped = mask_flatten.view(dims)
    return mask_reshaped


def entropy_rate(x_quantized, phi, var):
    u = torch.arange(-0.5, 0.5+0.01, 0.01).cuda()        
    gsm_sum = torch.zeros(len(u)).cuda()
    for i in range(len(u)):
        x = x_quantized + u[i]
        gsm_sum_i = sum_gsm(x, var, phi, 6)
        gsm_sum[i] = gsm_sum_i

    integral_u = torch.trapz(gsm_sum, u)
    #print("gsm sum : ", gsm_sum)
    #print("integral over u : ", integral_u)
    entropy = -torch.log2(integral_u)
    
    return entropy



def mean_bit_per_px(x_quantized, phi, var):
    u = torch.arange(-0.5, 0.5+0.05, 0.05).cuda()   
    gsm_stacked = []
    #u_stacked = []
    for i in range(len(u)):
        x = x_quantized + u[i]
        gsm = compute_gsm(x, var, phi, 6)
        gsm_stacked.append(gsm)
        #u_stacked.append(torch.ones(gsm.size()).cuda()*u[i])
    
    gsms = torch.stack(gsm_stacked, dim=0)
    #us = torch.stack(u_stacked, dim=0)
    integral_u = torch.trapz(gsms, dx=0.05, dim=0)
    nb_bits = (-torch.log2(torch.clamp(integral_u, min=np.exp(-10**2), max=1))).sum()
    if nb_bits < 0:
        #print("integral u : ", integral_u)
        print("nb_bits : ", nb_bits)
    return nb_bits/reduce(lambda x, y: x*y, list(x_quantized.size()))

"""
def entropy_rate(x_quantized, phi, var):
    u = torch.arange(-0.5, 0.5+0.05, 0.05).cuda()   
    sum_log_gsm = torch.zeros(len(u)).cuda()
    for i in range(len(u)):
        x = x_quantized + u[i]
        gsm = compute_gsm(x, var, phi, 6)
        sum_log_gsm[i] = (-torch.log2(gsm)).sum()
    
    entropy = torch.trapz(sum_log_gsm, u)
    if entropy < 0:
        print("negative entropy")
    return entropy
"""

"""
def clip(x):
    x_n = (x - torch.min(x))/(torch.max(x) - torch.min(x))
    x_clipped = torch.round(255*x_n).float()
    return x_clipped
"""


class MyQuantization(torch.autograd.Function):
    """
    We can implement our own custom autograd Functions by subclassing
    torch.autograd.Function and implementing the forward and backward passes
    which operate on Tensors.
    """
    
    @staticmethod
    def forward(ctx, input):
        """
        In the forward pass we receive a Tensor containing the input and return
        a Tensor containing the output. ctx is a context object that can be used
        to stash information for backward computation. You can cache arbitrary
        objects for use in the backward pass using the ctx.save_for_backward method.
        """
        ctx.save_for_backward(input)
        return torch.round(input)
    
    @staticmethod
    def backward(ctx, grad_output):
        """
        In the backward pass we receive a Tensor containing the gradient of the loss
        with respect to the output, and we need to compute the gradient of the loss
        with respect to the input.
        """
        input, = ctx.saved_tensors
        return grad_output

        
        
class MyClipping(torch.autograd.Function):
  
    @staticmethod
    def forward(ctx, input):
        ctx.save_for_backward(input)
        return torch.round(input).clamp(min=0, max=255)
    
    @staticmethod
    def backward(ctx, grad_output):
        input = ctx.saved_tensors
        return grad_output

    
"""
class GaussianDistribution(torch.autograd.Function):
    @staticmethod
    def forward(ctx, input, var, phi, nScale, nChannel):
        batch_size = input.size(0)
        h = input.size(-1)
        w = input.size(-2)
        ctx.save_for_backward(input, var, phi)
        #print("input : ", input)
        coeff = torch.sqrt(1.0 / (2 * np.pi * var))
        #print("coeff : ", coeff)
        input_resized = input.repeat((nScale, 1, 1, 1, 1))
        #print("input : ", input_resized)
        exponent = (-0.5*(input_resized ** 2)/var.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w))
        #print("exponent : ", exponent)
        coeffs_resized = coeff.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
        #print("coeffs : ", coeffs_resized)
        gaussian = coeffs_resized * torch.exp(exponent)
        #print("gaussian : ", gaussian)
        phi_resized = phi.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
        phi_gaussian = phi_resized*gaussian
        sum_phi_gaussian = phi_gaussian.sum(dim=0)
        #print("sum over scales : ", sum_phi_gaussian)
        result = -torch.log2(sum_phi_gaussian).sum()

        return result

    @staticmethod
    def backward(ctx, grad_output):
        input, var, phi = ctx.saved_tensors
        batch_size = input.size(0)
        h = input.size(-1)
        w = input.size(-2)
        nChannel = var.size(1)
        nScale = var.size(0)
        
        
        var_resized = var.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
        phi_resized = phi.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
        input_resized = input.repeat((nScale, 1, 1, 1, 1))
        
        d_phi = -torch.log2(1.0/torch.sqrt(2.0*np.pi*var_resized)*(torch.exp(-0.5*input_resized**2/var_resized))).sum(dim = [3, 4])
        d_var = -torch.log2(phi_resized*(1.0/(np.sqrt(2.0*np.pi)*var_resized)*torch.exp(-0.5*input_resized**2/var_resized))*(1.0 + input_resized**2/var_resized)).sum(dim = [3, 4])
        d_xq = -torch.log2((phi_resized*(-input_resized/torch.sqrt(2.0*np.pi*var_resized**3))*torch.exp(-0.5*input_resized**2/var_resized)).sum(dim=[0]))
        print("d_xq : ", (phi_resized*(-input_resized/torch.sqrt(2.0*np.pi*var_resized**3))*torch.exp(-0.5*input_resized**2/var_resized)).sum(dim=[0]))
        
        return grad_output*d_phi, grad_output*d_var, grad_output*d_xq
"""
# Out:
# '\nclass GaussianDistribution(torch.autograd.Function):\n    @staticmethod\n    def forward(ctx, input, var, phi, nScale, nChannel):\n        batch_size = input.size(0)\n        h = input.size(-1)\n        w = input.size(-2)\n        ctx.save_for_backward(input, var, phi)\n        #print("input : ", input)\n        coeff = torch.sqrt(1.0 / (2 * np.pi * var))\n        #print("coeff : ", coeff)\n        input_resized = input.repeat((nScale, 1, 1, 1, 1))\n        #print("input : ", input_resized)\n        exponent = (-0.5*(input_resized ** 2)/var.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w))\n        #print("exponent : ", exponent)\n        coeffs_resized = coeff.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)\n        #print("coeffs : ", coeffs_resized)\n        gaussian = coeffs_resized * torch.exp(exponent)\n        #print("gaussian : ", gaussian)\n        phi_resized = phi.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)\n        phi_gaussian = phi_resized*gaussian\n        sum_phi_gaussian = phi_gaussian.sum(dim=0)\n        #print("sum over scales : ", sum_phi_gaussian)\n        result = -torch.log2(sum_phi_gaussian).sum()\n\n        return result\n\n    @staticmethod\n    def backward(ctx, grad_output):\n        input, var, phi = ctx.saved_tensors\n        batch_size = input.size(0)\n        h = input.size(-1)\n        w = input.size(-2)\n        nChannel = var.size(1)\n        nScale = var.size(0)\n        \n        \n        var_resized = var.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)\n        phi_resized = phi.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)\n        input_resized = input.repeat((nScale, 1, 1, 1, 1))\n        \n        d_phi = -torch.log2(1.0/torch.sqrt(2.0*np.pi*var_resized)*(torch.exp(-0.5*input_resized**2/var_resized))).sum(dim = [3, 4])\n        d_var = -torch.log2(phi_resized*(1.0/(np.sqrt(2.0*np.pi)*var_resized)*torch.exp(-0.5*input_resized**2/var_resized))*(1.0 + input_resized**2/var_resized)).sum(dim = [3, 4])\n        d_xq = -torch.log2((phi_resized*(-input_resized/torch.sqrt(2.0*np.pi*var_resized**3))*torch.exp(-0.5*input_resized**2/var_resized)).sum(dim=[0]))\n        print("d_xq : ", (phi_resized*(-input_resized/torch.sqrt(2.0*np.pi*var_resized**3))*torch.exp(-0.5*input_resized**2/var_resized)).sum(dim=[0]))\n        \n        return grad_output*d_phi, grad_output*d_var, grad_output*d_xq\n'

# %%
#Define the Convolutional Autoencoder with integrated classifer
    #taille de l'image d'entrée : 256*256
class LossyCompAutoencoder(nn.Module):
    def __init__(self):
        super(LossyCompAutoencoder, self).__init__()
       
        #Encoder
            # input block
        self.conv1 = nn.Conv2d(3, 64, 5, stride=2, padding=0)  
        self.conv2 = nn.Conv2d(64, 128, 5, stride=2, padding=0)
            # residual block 
        self.resConv = nn.Conv2d(128, 128, 3, stride=1, padding=1)
            # output block
        self.conv3 = nn.Conv2d(128, 96, 5, stride=2, padding=0)
        self.quantization = MyQuantization.apply
        #self.gaussian_distribution = GaussianDistribution.apply
        

       
        #Decoder
            # subpixel 1
        self.subpix1 = nn.Conv2d(96, 512, 3, stride=1, padding=1)
            # subpixel 2
        self.subpix2 = nn.Conv2d(128, 256, 3, stride=1, padding=1)
            # subpixel 3
        self.subpix3 = nn.Conv2d(256//4, 12, 3, stride=1, padding=1)
            #residual block
        self.deconv1 = nn.Conv2d(512//4, 128, 3, stride=1, padding=1)
        self.deconv2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.clip = MyClipping.apply
        
        #Bit-rate      
        self.var = nn.Parameter(torch.Tensor(6, 96))
        self.phi = nn.Parameter(torch.Tensor(6, 96))
        self.var.data.uniform_(0, 1)
        self.phi.data.uniform_(0, 1)
        
        """
        self.gsm_pi = torch.nn.Parameter(torch.randn(6, 96))
        self.gsm_sigma = torch.nn.Parameter(torch.randn(6, 96))
        """
    
    
    
    def forward(self, x, mask= 1, return_xq=False):
        #encoder
            # normalization
        x, radius, mean_channels = normalize_input(x)
            # mirror padding
        x = mirror_padding(x, 14)
        """
        with torch.no_grad():
            x_copy = x.cpu()
            show_image_batch(x_copy)
        """
            # input blocks
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x_c1 = x.clone()
            # residual block 1
        x = F.relu(self.resConv(x))
        x = self.resConv(x)
        x += x_c1
        x_c2 = x.clone()
            # residual block 2
        x = F.relu(self.resConv(x))
        x = self.resConv(x)
        x += x_c2
        x_c3 = x.clone()
            # residual block 3
        x = F.relu(self.resConv(x))
        x = self.resConv(x)
        x += x_c3
            # output block
        x = self.conv3(x)
            # quantization
        x = self.quantization(x)
            # add mask for incremental training
        x = x*mask
        x_quantized = x
        
        
        """
        w = x_quantized.size()[2]
        h = x_quantized.size()[3]
        gsm = 0.0
        for i in range(6)
            mi = torch.flatten(x_quantized),torch.diagonal(self.gsm_sigma[s, :].repeat(w*h, 1).squeeze(0))
            gsm += 
        """
        

        #decoder
            # subpixel 1
        x = self.subpix1(x)
        x = periodic_shuffling(x, 512//4)
        x_c4 = x.clone()
            # residual block 1
        x = F.relu(self.deconv1(x))
        x = self.deconv2(x)
        x += x_c4
        x_c5 = x.clone()
               # residual block 2
        x = F.relu(self.deconv2(x))
        x = self.deconv2(x)
        x += x_c5
        x_c6 = x.clone()
               # residual block 3
        x = F.relu(self.deconv2(x))
        x = self.deconv2(x)
        x += x_c6
                # subpixel 2
        x = self.subpix2(x)
        x = F.relu(periodic_shuffling(x, 256//4))
                # subpixel 3
        x = self.subpix3(x)
        x = periodic_shuffling(x, 12//4)
                # denormalization
        x = denormalize_output(x, radius, mean_channels)
                # clipping
        x = self.clip(x)

        
        if return_xq:
            return x, x_quantized
        else:
            return x

# %%
# instanciate the model
model = LossyCompAutoencoder()
print(model)
params = list(model.parameters())
print(len(params))
print(params)
# Out:
# LossyCompAutoencoder(
#   (conv1): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2))
#   (conv2): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2))
#   (resConv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(128, 96, kernel_size=(5, 5), stride=(2, 2))
#   (subpix1): Conv2d(96, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (subpix2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (subpix3): Conv2d(64, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# 20
# [Parameter containing:
# tensor([[0.974318, 0.517946, 0.874795, 0.822548, 0.313619, 0.442443, 0.384894,
#          0.321588, 0.299912, 0.576992, 0.093034, 0.508762, 0.212060, 0.041936,
#          0.915052, 0.617626, 0.946166, 0.345741, 0.780745, 0.087877, 0.647797,
#          0.367576, 0.592635, 0.203432, 0.337133, 0.402794, 0.888771, 0.098519,
#          0.575525, 0.868306, 0.951348, 0.795922, 0.694531, 0.994989, 0.316623,
#          0.231774, 0.879695, 0.799269, 0.532727, 0.386963, 0.831814, 0.466781,
#          0.762505, 0.563101, 0.559486, 0.953157, 0.357429, 0.630096, 0.887054,
#          0.924151, 0.787039, 0.171437, 0.218209, 0.313686, 0.077341, 0.757060,
#          0.922195, 0.620088, 0.418098, 0.830985, 0.236134, 0.104001, 0.152730,
#          0.932889, 0.467444, 0.131999, 0.520475, 0.067235, 0.276355, 0.485038,
#          0.142721, 0.884152, 0.244633, 0.416605, 0.261207, 0.155175, 0.403643,
#          0.412529, 0.588680, 0.188444, 0.101403, 0.598179, 0.626478, 0.493763,
#          0.746275, 0.870420, 0.056856, 0.054753, 0.693262, 0.745056, 0.709191,
#          0.964459, 0.302132, 0.891071, 0.475203, 0.541964],
#         [0.922383, 0.171166, 0.101628, 0.755236, 0.182174, 0.100042, 0.837609,
#          0.861256, 0.187409, 0.675602, 0.106009, 0.112084, 0.657917, 0.019060,
#          0.091861, 0.172849, 0.905241, 0.156218, 0.316677, 0.041237, 0.995902,
#          0.378957, 0.204477, 0.447657, 0.820234, 0.966547, 0.215032, 0.406937,
#          0.714435, 0.598340, 0.789577, 0.268190, 0.970776, 0.722708, 0.783093,
#          0.566053, 0.745671, 0.769232, 0.433684, 0.325956, 0.250812, 0.293259,
#          0.290598, 0.515125, 0.857489, 0.526953, 0.272862, 0.149218, 0.992492,
#          0.251405, 0.926449, 0.059380, 0.749721, 0.689855, 0.607070, 0.958625,
#          0.700392, 0.011255, 0.926317, 0.171854, 0.678829, 0.207455, 0.167644,
#          0.287258, 0.161339, 0.904995, 0.129766, 0.512075, 0.041371, 0.025778,
#          0.550224, 0.460843, 0.334178, 0.180335, 0.679050, 0.006963, 0.661636,
#          0.646090, 0.092683, 0.308765, 0.574997, 0.195937, 0.703890, 0.469293,
#          0.234441, 0.078922, 0.739407, 0.906118, 0.597489]],
#        requires_grad=True), Parameter containing:
# tensor([[[[-0.011230, -0.039126,  0.095870, -0.102651,  0.095220],
#           [-0.019749, -0.055687, -0.006948, -0.001702,  0.048674],
#           [-0.093558, -0.066325,  0.093580,  0.022123,  0.073970],
#           [-0.029124,  0.097347,  0.076699,  0.017885, -0.022973],
#           [-0.017564, -0.044299,  0.066265,  0.026103,  0.014850]],
#
#          [[ 0.061445, -0.098308,  0.089472, -0.030709, -0.056968],
#           [-0.019036, -0.058379,  0.060613,  0.079543,  0.110595],
#           [ 0.081451, -0.037528, -0.079207,  0.100087,  0.057984],
#           [-0.090668, -0.002811,  0.008104, -0.015605, -0.049777],
#           [-0.075449, -0.005556,  0.109811,  0.030746, -0.095358]],
#
#          [[-0.070512, -0.012518, -0.001999, -0.084856,  0.094693],
#           [ 0.029963,  0.006189, -0.023346,  0.036679,  0.090426],
#           [-0.024702,  0.077951,  0.019696,  0.056462, -0.083800],
#           [ 0.058568,  0.080576, -0.017014, -0.103250,  0.051631],
#           [ 0.061667,  0.004659,  0.088085,  0.055880, -0.008056]]],
#
#
#         [[[-0.020781,  0.081618,  0.042826,  0.053555, -0.035468],
#           [-0.087855,  0.051185, -0.006821,  0.063862, -0.003329],
#           [ 0.012498,  0.106117,  0.043071, -0.029469, -0.066932],
#           [-0.020492, -0.058113,  0.020764, -0.041025, -0.019583],
#           [-0.097424,  0.023446,  0.102949, -0.028433,  0.102485]],
#
#          [[-0.076453, -0.071461,  0.039059, -0.061383, -0.032125],
#           [ 0.056919,  0.018864, -0.038137, -0.073718, -0.091239],
#           [-0.037501,  0.059877,  0.091585, -0.019082,  0.003108],
#           [ 0.109308,  0.110793, -0.079022,  0.057826, -0.031281],
#           [-0.067331,  0.082071, -0.032712, -0.076588,  0.053423]],
#
#          [[-0.100645, -0.058282, -0.050643, -0.019920, -0.022905],
#           [ 0.003131,  0.098015,  0.027338, -0.095145,  0.100617],
#           [ 0.045004,  0.097666, -0.013391,  0.046621, -0.026511],
#           [-0.105081, -0.069695,  0.085916,  0.070851,  0.065383],
#           [ 0.005776, -0.108672,  0.110009,  0.089125, -0.036692]]],
#
#
#         [[[ 0.027405, -0.073098, -0.035739,  0.068265,  0.027035],
#           [-0.007742, -0.059769,  0.057426, -0.109849, -0.111530],
#           [-0.014228,  0.060968,  0.013814, -0.087226, -0.019430],
#           [ 0.071688, -0.028252, -0.069011, -0.079124, -0.034443],
#           [ 0.062318,  0.022453, -0.025991, -0.061912, -0.115296]],
#
#          [[ 0.066585,  0.077757, -0.005833, -0.021969, -0.112950],
#           [-0.078350,  0.113095, -0.014706, -0.021076,  0.088478],
#           [ 0.089612,  0.008961,  0.115252, -0.098718, -0.035398],
#           [-0.021935, -0.100154, -0.014016,  0.031142, -0.107142],
#           [-0.011574, -0.009245, -0.060368, -0.028514,  0.048136]],
#
#          [[-0.010863, -0.090868,  0.113008,  0.065658,  0.076106],
#           [ 0.103769, -0.065664,  0.090019, -0.075987, -0.059435],
#           [-0.026954,  0.075923, -0.015941,  0.040170,  0.080570],
#           [-0.109311,  0.003103, -0.097175, -0.049561,  0.022920],
#           [-0.036352, -0.044208, -0.054925,  0.093456,  0.079653]]],
#
#
#         ...,
#
#
#         [[[ 0.046071,  0.110213,  0.073777, -0.038139, -0.105029],
#           [-0.075339, -0.005970, -0.015176, -0.023639,  0.108144],
#           [-0.030931,  0.041414,  0.006452,  0.074232, -0.053127],
#           [ 0.003816, -0.084310, -0.086473,  0.037693, -0.072091],
#           [-0.061600,  0.088848,  0.110953,  0.003969,  0.045764]],
#
#          [[ 0.046018, -0.030048, -0.110791,  0.015987,  0.072693],
#           [ 0.007787, -0.107226,  0.048149,  0.014374, -0.036914],
#           [ 0.092834, -0.086219,  0.077120, -0.028253, -0.101864],
#           [ 0.100136, -0.034251, -0.061269, -0.041753, -0.072739],
#           [ 0.034767,  0.089336,  0.062313, -0.058965,  0.073300]],
#
#          [[-0.044976, -0.025770, -0.054553,  0.108240,  0.099274],
#           [ 0.013569,  0.098193,  0.092677, -0.036770,  0.085776],
#           [ 0.034487,  0.023930, -0.088632, -0.040771,  0.033192],
#           [-0.047072, -0.025815,  0.076690,  0.095300, -0.032769],
#           [-0.040898,  0.105861,  0.092512,  0.011671, -0.099681]]],
#
#
#         [[[ 0.018128,  0.107577, -0.100270,  0.043249,  0.040451],
#           [ 0.047144,  0.099182,  0.101031,  0.093729, -0.033460],
#           [ 0.065511, -0.064778, -0.024540, -0.070973, -0.077600],
#           [-0.032713,  0.040279,  0.063999, -0.082419, -0.074499],
#           [-0.043565, -0.009456,  0.063593,  0.100074, -0.049152]],
#
#          [[ 0.047767, -0.105655, -0.040990, -0.115164, -0.035133],
#           [ 0.086825,  0.029030, -0.086122,  0.071811,  0.030153],
#           [-0.045042, -0.025227,  0.099022, -0.071279, -0.064054],
#           [-0.076543,  0.006978, -0.014221,  0.070608,  0.005008],
#           [ 0.002170,  0.105737, -0.038214, -0.059637,  0.110888]],
#
#          [[ 0.010834,  0.016202, -0.054937,  0.086257,  0.013462],
#           [ 0.093509,  0.033983, -0.091722, -0.077719, -0.029941],
#           [ 0.102675,  0.115149, -0.046795, -0.089449,  0.061403],
#           [-0.093428,  0.069425, -0.037578,  0.039285,  0.075774],
#           [ 0.024042,  0.078452,  0.040888,  0.080462,  0.074054]]],
#
#
#         [[[-0.042817,  0.112612, -0.071197, -0.037408, -0.019488],
#           [ 0.073259,  0.110846,  0.074153, -0.012991, -0.100584],
#           [ 0.098124,  0.063252, -0.049078,  0.011266,  0.110144],
#           [ 0.100473,  0.034811,  0.108767, -0.099798,  0.054796],
#           [-0.055066,  0.104023,  0.106337, -0.045569,  0.092239]],
#
#          [[ 0.013445, -0.024151,  0.062589, -0.060599,  0.058931],
#           [-0.072851,  0.051199,  0.063551, -0.003503,  0.057652],
#           [-0.109477, -0.007504, -0.114374, -0.104945, -0.088062],
#           [ 0.025133,  0.100312, -0.038190,  0.003535, -0.079320],
#           [-0.026873,  0.069798, -0.114261, -0.030008, -0.092685]],
#          1.417696e-03, -1.902829e-02, -8.770596e-03, -1.259838e-02,
#          9.733984e-03,  1.031424e-02,  3.838077e-03,  2.305183e-02,
#          7.602213e-03,  1.795651e-02,  2.598476e-03,  1.066557e-02,
#         -1.241604e-03, -2.452741e-02, -1.076108e-02, -2.054721e-02,
#          7.015081e-03, -9.417474e-03,  1.173647e-02, -5.250182e-04,
#         -4.952587e-04,  1.914061e-02, -1.887365e-02, -1.799207e-02,
#          1.494903e-02,  2.113633e-02,  8.756870e-03,  8.528309e-03,
#         -1.311882e-02,  1.259480e-02, -2.200209e-02,  7.465230e-03,
#         -1.010560e-02, -8.181835e-03,  3.206298e-03,  2.172788e-02,
#          2.418358e-03, -2.016592e-02,  8.520929e-03,  8.981353e-03,
#         -1.112267e-03, -9.747664e-03,  1.207006e-02, -1.880620e-04,
#         -1.772214e-02, -9.728876e-03,  1.427293e-02, -5.251404e-03,
#          4.482508e-03,  1.004742e-02, -3.573503e-04, -1.420745e-02,
#          2.094945e-03, -5.735267e-03,  1.988528e-02,  1.738933e-02,
#         -1.975069e-02, -2.146236e-02, -1.694864e-02,  1.613537e-02,
#         -1.883985e-02, -1.226301e-02, -9.570029e-04, -3.597116e-03,
#          3.520027e-05, -1.611870e-02,  9.953389e-03, -3.993019e-03,
#          1.541028e-03, -4.325509e-04,  1.955140e-02, -6.458377e-03,
#         -2.375711e-02, -9.852600e-03, -8.653313e-03,  3.950331e-03],
#        requires_grad=True), Parameter containing:
# tensor([[[[-0.000145,  0.000344,  0.021776],
#           [ 0.020678,  0.008456,  0.002572],
#           [ 0.024896,  0.024565,  0.028135]],
#
#          [[ 0.010749, -0.020771,  0.013540],
#           [ 0.023703, -0.009992, -0.024286],
#           [ 0.005501, -0.028725,  0.016207]],
#
#          [[-0.015808,  0.007794, -0.007132],
#           [-0.014584,  0.020915,  0.004412],
#           [-0.018031,  0.013475, -0.012623]],
#
#          ...,
#
#          [[-0.021491,  0.001445,  0.008977],
#           [ 0.003296, -0.007614, -0.019245],
#           [ 0.025468,  0.018125, -0.018449]],
#
#          [[ 0.021929,  0.003367, -0.020433],
#           [-0.018095, -0.004846,  0.010300],
#           [-0.001511,  0.023087, -0.005599]],
#
#          [[ 0.006044, -0.016949,  0.008953],
#           [ 0.011554, -0.014306,  0.027331],
#           [-0.000297, -0.002322, -0.023803]]],
#
#
#         [[[-0.016485, -0.006502, -0.024010],
#           [-0.009966,  0.023031,  0.022039],
#           [ 0.016767,  0.021233, -0.025488]],
#
#          [[ 0.028577, -0.028581, -0.004538],
#           [-0.020847,  0.021963, -0.013522],
#           [ 0.003938,  0.005116, -0.008031]],
#
#          [[ 0.020951,  0.020070, -0.026622],
#           [ 0.008437,  0.028411,  0.009961],
#           [-0.017655, -0.009026,  0.006678]],
#
#          ...,
#
#          [[-0.007860,  0.003000, -0.009918],
#           [ 0.006771, -0.022545,  0.000457],
#           [ 0.004769, -0.011562,  0.002908]],
#
#          [[ 0.026659,  0.026626, -0.003982],
#           [ 0.025459,  0.001840,  0.016126],
#           [ 0.024216, -0.015625,  0.027941]],
#
#          [[-0.013872,  0.013526, -0.027070],
#           [ 0.020999, -0.001123,  0.020608],
#           [ 0.021846, -0.013675,  0.023033]]],
#
#
#         [[[ 0.010820, -0.006075, -0.008740],
#           [-0.028705,  0.009315, -0.018613],
#           [ 0.008287, -0.021724, -0.015439]],
#
#          [[-0.027305, -0.020538,  0.026587],
#           [-0.027026, -0.028303, -0.010264],
#           [ 0.024539, -0.008981, -0.027835]],
#
#          [[ 0.023551, -0.008453, -0.001189],
#           [-0.028458,  0.016412, -0.008774],
#           [-0.022590, -0.005865, -0.011088]],
#
#          ...,
#
#          [[ 0.028862,  0.005186, -0.016636],
#           [ 0.024496, -0.012421, -0.023676],
#           [ 0.021556, -0.024957, -0.003503]],
#
#          [[ 0.005343,  0.003428,  0.007188],
#           [ 0.027843, -0.014503, -0.013145],
#           [ 0.023714,  0.000938,  0.025086]],
#
#          [[ 0.009668,  0.020414,  0.022259],
#           [-0.008290, -0.021728,  0.028883],
#           [-0.021740,  0.006675, -0.003957]]],
#
#
#         ...,
#
#
#         [[[ 0.023447, -0.008538,  0.011560],
#           [ 0.010043, -0.017840,  0.004432],
#           [ 0.011299,  0.006398, -0.004785]],
#
#          [[-0.011526,  0.006985, -0.014862],
#           [ 0.015981, -0.008053,  0.027506],
#           [ 0.013419,  0.013484,  0.020953]],
#
#          [[ 0.022275,  0.011894, -0.013222],
#           [-0.006402, -0.018844, -0.014163],
#           [ 0.011121, -0.011743, -0.029265]],
#
#          ...,
#
#          [[-0.026498,  0.003864, -0.028825],
#           [ 0.018567,  0.004207,  0.006566],
#           [ 0.001929,  0.021561, -0.027135]],
#
#          [[-0.023325,  0.025771,  0.013462],
#           [ 0.027455, -0.028597, -0.023816],
#           [ 0.021899,  0.020762,  0.010913]],
#
#          [[ 0.029105,  0.028475,  0.003151],
#           [-0.027210, -0.021312, -0.023861],
#           [ 0.012080, -0.003497, -0.027941]]],
#
#
#         [[[-0.003174, -0.019120,  0.010053],
#           [ 0.010161,  0.003532,  0.015621],
#           [ 0.018894,  0.021685,  0.002266]],
#
#          [[ 0.018153,  0.021207,  0.022425],
#           [ 0.028459,  0.014362, -0.013933],
#           [ 0.020145,  0.005947, -0.004827]],
#
#          [[-0.004467, -0.013076, -0.028216],
#           [-0.020991,  0.017057,  0.016452],
#           [-0.000262,  0.005719, -0.014039]],
#
#          ...,
#
#          [[-0.002430,  0.004921,  0.015284],
#           [ 0.017717,  0.025003, -0.004441],
#           [-0.022509, -0.008933,  0.022754]],
#
#          [[-0.028908, -0.008979, -0.014452],
#           [-0.005541,  0.015687, -0.007888],
#           [-0.008633, -0.026635, -0.014028]],
#
#          [[ 0.012381, -0.012031, -0.005953],
#           [-0.007321,  0.024284,  0.019857],
#           [-0.025420,  0.024168, -0.026311]]],
#
#
#         [[[-0.025067, -0.016228,  0.024601],
#           [ 0.009203,  0.010971, -0.008827],
#           [ 0.010838, -0.011011, -0.004022]],
#
#          [[ 0.028593, -0.000991, -0.026971],
#          [[ 9.558383e-03,  3.887697e-02,  2.281471e-02],
#           [-1.708522e-02, -3.782450e-02,  3.274872e-02],
#           [-2.103313e-02, -1.502968e-02, -2.421461e-02]],
#
#          ...,
#
#          [[-7.307488e-03,  2.094747e-02, -1.288730e-02],
#           [ 1.370320e-02, -3.056647e-02,  3.380124e-03],
#           [ 1.449649e-02,  4.653543e-03,  1.213254e-02]],
#
#          [[ 1.417404e-02,  3.453286e-02, -2.041217e-03],
#           [-2.760473e-02,  1.675255e-02,  1.985794e-02],
#           [-1.447669e-02,  3.969542e-02, -1.488472e-02]],
#
#          [[ 1.080470e-02, -1.616319e-02,  3.211281e-02],
#           [ 2.468582e-03,  9.577483e-03,  1.464023e-02],
#           [ 1.695597e-02, -2.402015e-02,  1.155656e-03]]]], requires_grad=True), Parameter containing:
# tensor([ 0.023657,  0.035460,  0.017330, -0.005254, -0.008174, -0.014631,
#         -0.014686, -0.013660, -0.020814,  0.036391,  0.003615, -0.000661],
#        requires_grad=True), Parameter containing:
# tensor([[[[ 1.509138e-02,  1.116955e-02,  1.863594e-02],
#           [-1.066374e-02, -6.663203e-03,  5.493527e-03],
#           [ 1.257302e-02, -8.422282e-03, -1.197483e-03]],
#
#          [[ 1.665230e-02, -1.738549e-02,  2.926988e-02],
#           [ 2.199988e-02,  1.387848e-02,  2.250618e-02],
#           [-2.498107e-02,  1.490462e-02, -8.457640e-03]],
#
#          [[-2.021422e-02, -2.749316e-02,  1.997965e-02],
#           [-1.930655e-02,  2.408076e-02,  2.439406e-02],
#           [-2.613891e-02,  1.374906e-02,  7.964289e-03]],
#
#          ...,
#
#          [[ 1.423731e-03,  4.147278e-03, -1.242079e-03],
#           [ 1.698610e-02, -1.591881e-02,  1.388514e-02],
#           [-1.657002e-02,  2.349395e-02,  2.916576e-02]],
#
#          [[ 1.760046e-02,  2.461840e-02,  1.457661e-02],
#           [ 4.260061e-03, -5.052878e-03, -2.411561e-02],
#           [ 1.663349e-02,  2.787003e-02,  1.371235e-02]],
#
#          [[ 2.846292e-02,  3.579576e-04,  1.201697e-02],
#           [ 1.779838e-02,  1.238798e-02, -1.743045e-04],
#           [ 2.323277e-02,  1.781318e-02, -2.394278e-02]]],
#
#
#         [[[ 1.564934e-02, -1.571773e-03,  2.555790e-02],
#           [ 4.053509e-03,  5.056703e-03, -2.539198e-02],
#           [ 2.577822e-02, -1.089341e-02, -1.807883e-04]],
#
#          [[-1.409180e-02,  2.342955e-02,  1.726076e-02],
#           [-1.125668e-02,  2.210630e-02,  9.494198e-03],
#           [-1.507269e-03, -9.658130e-03,  1.209397e-02]],
#
#          [[ 1.302365e-02, -2.190526e-02, -2.360139e-02],
#           [ 1.711359e-02, -2.585803e-02, -2.820344e-02],
#           [ 3.467200e-03, -2.544027e-02,  4.220027e-04]],
#
#          ...,
#
#          [[-3.735870e-04,  2.010394e-02, -2.237906e-02],
#           [-1.087462e-02,  2.259404e-02,  1.096903e-02],
#           [-1.558914e-02,  2.079991e-02, -1.826651e-02]],
#
#          0.028802,  0.007611, -0.011380, -0.011555,  0.006524, -0.017528,
#         -0.014490, -0.015401,  0.021314,  0.011189,  0.019984, -0.014996,
#         -0.017088,  0.006567,  0.004478, -0.028825, -0.000207,  0.022175,
#         -0.024372,  0.001231,  0.002293, -0.026757,  0.007616, -0.007923,
#         -0.007348,  0.023156, -0.019898, -0.015094,  0.018746,  0.000323,
#          0.011908, -0.011286,  0.025618,  0.021627, -0.022787, -0.013696,
#         -0.019481,  0.002853, -0.008275,  0.004926,  0.020231,  0.018933,
#          0.021534,  0.009603,  0.024380, -0.024104, -0.026046,  0.028149,
#          0.009584, -0.028604, -0.008877, -0.000790,  0.007381,  0.026014,
#         -0.020909, -0.007822, -0.009706, -0.008512, -0.010647, -0.019087,
#          0.001007, -0.019518], requires_grad=True), Parameter containing:
# tensor([[[[-0.027115, -0.025067,  0.015712],
#           [ 0.026852,  0.004132,  0.005928],
#           [-0.016622,  0.019050,  0.023286]],
#
#          [[ 0.014453,  0.010980,  0.028557],
#           [-0.029011, -0.002920, -0.012316],
#           [-0.002555,  0.007981,  0.006002]],
#
#          [[-0.018036, -0.001544, -0.011405],
#           [-0.009290, -0.011310,  0.017425],
#           [-0.004340,  0.005175, -0.017333]],
#
#          ...,
#
#          [[-0.023910,  0.008291,  0.028212],
#           [-0.002780,  0.012889,  0.010876],
#           [-0.000760,  0.021141,  0.022443]],
#
#          [[-0.022563,  0.002095,  0.026022],
#           [ 0.007111, -0.016438,  0.025660],
#           [-0.010076, -0.013113, -0.015863]],
#
#          [[-0.025111, -0.022143,  0.017393],
#           [-0.019883, -0.010600, -0.025930],
#           [-0.002098, -0.011343,  0.024827]]],
#
#
#         [[[ 0.012381, -0.004344, -0.017105],
#           [ 0.016295,  0.025475,  0.018351],
#           [-0.025654,  0.001850,  0.013253]],
#
#          [[-0.019285, -0.018066, -0.018054],
#           [ 0.019930, -0.003541, -0.007248],
#           [-0.010945,  0.017577,  0.002691]],
#
#          [[-0.020244, -0.026786,  0.008913],
#           [ 0.013111,  0.006808,  0.007720],
#           [ 0.004689, -0.001560, -0.016710]],
#
#          ...,
#
#          [[ 0.010565,  0.006842,  0.028564],
#           [ 0.028515, -0.026032, -0.018436],
#           [ 0.019506,  0.001266,  0.012069]],
#
#          [[-0.026099, -0.015989,  0.010831],
#           [-0.017105, -0.022268, -0.001992],
#           [ 0.012024,  0.001100,  0.006307]],
#
#          [[-0.019284, -0.018295,  0.026330],
#           [-0.027762,  0.024015,  0.021538],
#           [-0.026085,  0.013818, -0.000961]]],
#
#
#         [[[-0.018123, -0.028225,  0.007101],
#           [-0.004366,  0.006775,  0.012585],
#           [ 0.025936,  0.004325, -0.022471]],
#
#          [[-0.008678, -0.027622, -0.008647],
#           [ 0.028383,  0.001510, -0.010801],
#           [ 0.006883, -0.018630,  0.009953]],
#
#          [[-0.025962,  0.022991, -0.011451],
#           [-0.024940, -0.017506,  0.001589],
#           [-0.013393, -0.011650, -0.010804]],
#
#          ...,
#
#          [[-0.001920,  0.014727,  0.004949],
#           [ 0.013468, -0.008721,  0.002825],
#           [ 0.025101,  0.017786,  0.026427]],
#
#          [[ 0.004641,  0.021901,  0.028632],
#           [ 0.023091, -0.008376,  0.013488],
#           [ 0.001480,  0.001190,  0.024622]],
#
#          [[-0.021832, -0.002241, -0.013425],
#           [-0.005874,  0.007062,  0.021484],
#           [ 0.017774, -0.013149,  0.003308]]],
#
#
#         ...,
#
#
#         [[[-0.006274,  0.015640, -0.010118],
#           [ 0.000265,  0.001123, -0.019684],
#           [-0.005430, -0.027758, -0.018407]],
#
#          [[ 0.013117,  0.010752,  0.002054],
#           [ 0.012669, -0.027579,  0.017133],
#           [ 0.019717, -0.015413, -0.021922]],
#
#          [[-0.018984, -0.014403, -0.010059],
#           [-0.009654,  0.013653, -0.004004],
#           [-0.006782, -0.023308,  0.003741]],
#
#          ...,
#
#          [[ 0.007525,  0.020925,  0.012374],
#           [ 0.006012, -0.022555, -0.007698],
#           [-0.006890,  0.008181, -0.002391]],
#
#          [[-0.001816,  0.012617, -0.021798],
#           [ 0.022940, -0.019963,  0.003323],
#           [-0.020844, -0.017108, -0.010133]],
#
#          [[-0.016463,  0.021629,  0.010616],
#           [-0.013057,  0.011614, -0.017432],
#           [-0.013952,  0.024921, -0.024688]]],
#
#
#         [[[ 0.027595, -0.028070,  0.009783],
#           [-0.028513,  0.008887, -0.019436],
#           [ 0.008643, -0.004036, -0.005041]],
#
#          [[-0.021022,  0.002356, -0.014364],
#           [ 0.024843,  0.014898, -0.016627],
#           [ 0.017890,  0.014429, -0.022147]],
#
#          [[ 0.008082, -0.018954,  0.012030],
#           [-0.015216,  0.023725, -0.021453],
#           [-0.026473,  0.006860, -0.022293]],
#
#          ...,
#
#          [[ 0.013067, -0.009922, -0.023071],
#           [ 0.020017,  0.011594,  0.023667],
#           [-0.022088,  0.004776,  0.022963]],
#
#          [[-0.008579, -0.002947,  0.022145],
#           [-0.018176, -0.028187,  0.015277],
#           [-0.016461, -0.013593,  0.000791]],
#
#          [[-0.024813, -0.004501, -0.022650],
#           [ 0.004979,  0.006243, -0.021389],
#           [-0.006248, -0.028466,  0.010168]]],
#
#
#         [[[ 0.016797, -0.015504,  0.004430],
#           [-0.009610, -0.007033,  0.016279],
#           [ 0.008704,  0.021546, -0.022140]],
#
#          [[-0.028025, -0.008979, -0.011559],
#           [ 0.016970, -0.027400,  0.004011],
#           [-0.008917, -0.016758,  0.020693]],
#
#          [[ 0.023086, -0.024218, -0.012085],
#           [-0.009022,  0.012843, -0.005382],
#           [ 0.027286, -0.028633,  0.017517]],
#
#          ...,
#
#          [[ 0.025406, -0.019454,  0.008883],
#           [ 0.002133, -0.026398,  0.024440],
#           [-0.027404,  0.003803, -0.006605]],
#
#          [[ 0.011562,  0.017592, -0.026535],
#           [-0.014373, -0.012973,  0.001796],
#           [ 0.025818, -0.021660, -0.008153]],
#
#          [[-0.012452, -0.009500,  0.002065],
#           [ 0.019019,  0.008642,  0.023133],
#           [ 0.028248, -0.029368,  0.010729]]]], requires_grad=True), Parameter containing:
# tensor([-0.008344,  0.021279, -0.003905,  0.006669, -0.002516, -0.017997,
#          0.013990,  0.025965, -0.027164, -0.010094, -0.014042, -0.008088,
#          0.010740,  0.021387, -0.017324,  0.028370,  0.028153,  0.029038,
#          0.005369,  0.012569,  0.004191, -0.025088, -0.017957,  0.020322,
#         -0.001884,  0.005846,  0.018247,  0.006859, -0.027381,  0.022921,
#         -0.009960,  0.019081, -0.026567, -0.014845, -0.019129, -0.013107,
#         -0.012403,  0.028107, -0.001501,  0.012730,  0.025061, -0.018704,
#         -0.008963,  0.012317, -0.006581,  0.007347, -0.022481, -0.009755,
#          0.020402, -0.023492,  0.025110, -0.007417,  0.015329, -0.026136,
#         -0.015405, -0.010620, -0.025226,  0.009029,  0.019726, -0.022689,
#          0.020610, -0.016248, -0.023559, -0.016861,  0.003738,  0.017195,
#          0.022891,  0.007205, -0.006742, -0.013971, -0.010555, -0.007494,
#         -0.022785, -0.015293, -0.027701,  0.010200, -0.006570,  0.005676,
#          0.010517, -0.007780, -0.025770,  0.019258,  0.025720, -0.010235,
#          0.010725,  0.006736,  0.023875,  0.000177, -0.000458, -0.022625,
#         -0.003148, -0.024575,  0.018426,  0.014864,  0.021283, -0.023676,
#         -0.010503, -0.019234, -0.011475, -0.016029, -0.004969,  0.008942,
#         -0.004172,  0.009591, -0.005333, -0.026292, -0.028524, -0.016750,
#          0.022933,  0.009620,  0.000434, -0.001935,  0.004179,  0.021170,
#          0.029381,  0.023542,  0.011378,  0.016261, -0.011672,  0.003935,
#          0.016051, -0.021221, -0.004818, -0.004101, -0.008347,  0.008707,
#          0.022519,  0.005545], requires_grad=True)]

# %%
def get_device():
    if torch.cuda.is_available():
        device = 'cuda:0'
    else:
        device = 'cpu'
    return device

device = get_device()
print(device)
# Out:
# cuda:0

# %%
# load incremental model
model_incremental = LossyCompAutoencoder()
model_incremental.load_state_dict(torch.load('./model_parameters/lossy_comp_params_with_rate_beta2_incremental_2.pth'))
model_incremental.eval()
model_incremental.to(device)

# transfert du model au gpu
model_incremental.to(device)

#define optimizer
optimizer = torch.optim.Adam(model_incremental.parameters(), lr=0.00001)

# define loss function
distortion = nn.MSELoss().cuda()
       

# general update of coefficients    
    #Epochs
n_epochs = 400
    # beta
beta = 2

    # Training the network
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
          
    #Training
    for i_batch, data in enumerate(dataloader):
        batch_images = data.to(device).float()
        [decoded_images, x_quantized] = model_incremental(batch_images, 1, True)
        optimizer.zero_grad()
        loss = beta * distortion(decoded_images, batch_images) + entropy_rate(x_quantized, model_incremental.phi, model_incremental.var)
        #print(loss)
            
        loss.backward()
        #print("conv1.weights grad: ", params[0].grad)
        #print(model.conv1.bias.grad)
        #print(model.conv1.weight.grad)
        optimizer.step()
        running_loss += loss.item()

    running_loss = running_loss/len(dataloader)
    print('running loss : {:.06f}'.format(running_loss), )
# Out:
# running loss : 44.923530
# running loss : 43.422592
# running loss : 42.746727
# running loss : 43.178691
# running loss : 43.178471
# running loss : 43.217670
# running loss : 42.766190
# running loss : 42.827812
# running loss : 43.265769
# running loss : 43.079006
# running loss : 43.148810
# running loss : 42.972984
# running loss : 42.695945
# running loss : 42.861766
# running loss : 42.832451
# running loss : 42.702663
# running loss : 42.645923
# running loss : 42.731988
# running loss : 42.829333
# running loss : 42.763890
# running loss : 42.861785
# running loss : 42.740514
# running loss : 42.990489
# running loss : 42.994992
# running loss : 43.038153
# running loss : 42.563785
# running loss : 42.935054
# running loss : 42.557880
# running loss : 42.854448
# running loss : 43.641883
# running loss : 42.778502
# running loss : 42.866602
# running loss : 42.902910
# running loss : 42.535625
# running loss : 42.315875
# running loss : 43.049296
# running loss : 43.260003
# running loss : 42.387189
# running loss : 42.784305
# running loss : 42.365922
# running loss : 42.511634
# running loss : 42.460831
# running loss : 42.492768
# running loss : 42.471322
# running loss : 42.943743
# running loss : 43.335035
# running loss : 42.713686
# running loss : 42.624963
# running loss : 42.161405
# running loss : 42.498004
# running loss : 42.319931
# running loss : 42.359559
# running loss : 42.374625
# running loss : 42.109003
# running loss : 42.179943
# running loss : 42.647691
# running loss : 42.302937
# running loss : 42.319128
# running loss : 42.262248
# running loss : 42.127206
# running loss : 42.653981
# running loss : 42.339595
# running loss : 42.542327
# running loss : 42.394363
# running loss : 42.253410
# running loss : 42.159700
# running loss : 42.223188
# running loss : 42.614771
# running loss : 42.583104
# running loss : 42.440596
# running loss : 42.414242
# running loss : 42.291857
# running loss : 42.278415
# running loss : 42.218198
# running loss : 42.553085
# running loss : 42.066193
# running loss : 42.264576
# running loss : 42.157740
# running loss : 42.160053
# running loss : 42.500378
# running loss : 42.576058
# running loss : 42.850151
# running loss : 42.535431
# running loss : 42.365121
# running loss : 42.059874
# running loss : 42.137930
# running loss : 41.704384
# running loss : 42.009096
# running loss : 42.114253
# running loss : 42.134407
# running loss : 42.017349
# running loss : 42.386073
# running loss : 41.845161
# running loss : 42.304321
# running loss : 41.855989
# running loss : 42.052804
# running loss : 42.226635
# running loss : 42.248075
# running loss : 42.124556
# running loss : 42.045099
# running loss : 42.086433
# running loss : 41.882611
# running loss : 41.624568
# running loss : 41.823497
# running loss : 42.146130
# running loss : 41.955842
# running loss : 42.150049
# running loss : 41.940780
# running loss : 41.904305
# running loss : 41.955680
# running loss : 41.866815
# running loss : 41.909500
# running loss : 41.736864
# running loss : 42.397150
# running loss : 41.807684
# running loss : 42.078180
# running loss : 41.823628
# running loss : 42.403819
# running loss : 42.298137
# running loss : 42.001175
# running loss : 41.961497
# running loss : 42.596310
# running loss : 42.372831
# running loss : 42.224506
# running loss : 41.622138
# running loss : 42.011167
# running loss : 41.916893
# running loss : 42.205901
# running loss : 41.807566
# running loss : 41.970901
# running loss : 41.654188
# running loss : 42.300280
# running loss : 41.759451
# running loss : 41.906544
# running loss : 41.737819
# running loss : 42.018984
# running loss : 42.044215
# running loss : 42.117140
# running loss : 41.892728
# running loss : 41.569490
# running loss : 41.689594
# running loss : 41.732475
# running loss : 42.037376
# running loss : 41.850109
# running loss : 42.288769
# running loss : 41.906202
# running loss : 41.367803
# running loss : 41.835298
# running loss : 41.637584
# running loss : 41.817786
# running loss : 41.661991
# running loss : 41.821755
# running loss : 41.547506
# running loss : 41.774717
# running loss : 41.807082
# running loss : 41.577825
# running loss : 41.507479
# running loss : 41.466095
# running loss : 41.791379
# running loss : 42.036470
# running loss : 41.758975
# running loss : 41.507225
# running loss : 41.871322
# running loss : 41.454668
# running loss : 41.656997
# running loss : 41.708262
# running loss : 41.817519
# running loss : 41.656917
# running loss : 41.603389
# running loss : 41.600409
# running loss : 41.688551
# running loss : 41.446240
# running loss : 41.396941
# running loss : 41.416018
# running loss : 41.793515
# running loss : 41.815457
# running loss : 41.893675
# running loss : 41.450977
# running loss : 41.227439
# running loss : 41.519179
# running loss : 41.607411
# running loss : 41.716486
# running loss : 41.232819
# running loss : 41.871367
# running loss : 41.456467
# running loss : 41.947609
# running loss : 41.668048
# running loss : 41.922854
# running loss : 41.473328
# running loss : 41.172597
# running loss : 41.741529
# running loss : 41.542988
# running loss : 41.281389
# running loss : 41.632765
# running loss : 41.454114
# running loss : 41.547477
# running loss : 41.652229
# running loss : 41.121975
# running loss : 41.619526
# running loss : 41.643709
# running loss : 41.570070
# running loss : 41.506962
# running loss : 41.278127
# running loss : 41.525280
# running loss : 41.167542
# running loss : 41.338245
# running loss : 41.030396
# running loss : 41.128537
# running loss : 40.996708
# running loss : 40.868746
# running loss : 41.392218
# running loss : 41.485216
# running loss : 41.254695
# running loss : 41.266690
# running loss : 40.951371
# running loss : 41.259905
# running loss : 41.034830
# running loss : 42.090954
# running loss : 41.326321
# running loss : 41.049956
# running loss : 41.319318
# running loss : 41.762899
# running loss : 41.436858
# running loss : 41.390870
# running loss : 41.316247
# running loss : 41.025010
# running loss : 41.118160
# running loss : 41.321979
# running loss : 41.171877
# running loss : 40.991369
# running loss : 41.317897
# running loss : 41.031378
# running loss : 41.227317
# running loss : 41.088493
# running loss : 41.060102
# running loss : 41.056391
# running loss : 41.117215
# running loss : 41.119861
# running loss : 41.238656
# running loss : 41.069055
# running loss : 41.191172
# running loss : 41.232970
# running loss : 41.101005
# running loss : 40.996147
# running loss : 41.335363
# running loss : 40.947520
# running loss : 41.273486
# running loss : 41.042204
# running loss : 40.913759
# running loss : 41.212111
# running loss : 41.320721
# running loss : 41.263608
# running loss : 40.945615
# running loss : 41.281483
# running loss : 41.110189
# running loss : 41.299095
# running loss : 41.146772
# running loss : 41.287276
# running loss : 41.183409
# running loss : 40.733906
# running loss : 40.965458
# running loss : 41.144368
# running loss : 41.221544
# running loss : 41.097657
# running loss : 40.882725
# running loss : 40.572456
# running loss : 41.471331
# running loss : 40.843707
# running loss : 41.040861
# running loss : 40.874936
# running loss : 41.305284
# running loss : 41.049167
# running loss : 40.616191
# running loss : 40.797179
# running loss : 40.696042
# running loss : 40.869761
# running loss : 41.055765
# running loss : 40.779230
# running loss : 41.313409
# running loss : 40.741772
# running loss : 41.246114
# running loss : 40.823011
# running loss : 41.275614
# running loss : 41.123846
# running loss : 40.810066
# running loss : 40.721724
# running loss : 40.703284
# running loss : 40.855388
# running loss : 40.539770
# running loss : 41.318316
# running loss : 40.831727
# running loss : 41.123685
# running loss : 40.887214
# running loss : 40.790885
# running loss : 40.621074
# running loss : 41.317755
# running loss : 40.983537
# running loss : 40.682260
# running loss : 40.624531
# running loss : 40.920307
# running loss : 41.120205
# running loss : 40.739484
# running loss : 40.630958
# running loss : 40.696628
# running loss : 40.707421
# running loss : 40.564199
# running loss : 40.776133
# running loss : 40.713116
# running loss : 40.420846
# running loss : 40.573526
# running loss : 40.771007
# running loss : 40.779507
# running loss : 40.627204
# running loss : 40.718256
# running loss : 40.847357
# running loss : 40.811629
# running loss : 40.470052
# running loss : 40.441044
# running loss : 40.905161
# running loss : 40.554113
# running loss : 40.475244
# running loss : 40.251629
# running loss : 40.854545
# running loss : 40.642477
# running loss : 40.444942
# running loss : 40.609610
# running loss : 40.698776
# running loss : 40.476899
# running loss : 40.439491
# running loss : 40.623884
# running loss : 40.595018
# running loss : 40.669544
# running loss : 40.574267
# running loss : 41.244713
# running loss : 40.084970
# running loss : 40.847029
# running loss : 40.543849
# running loss : 40.626065
# running loss : 40.911249
# running loss : 40.423082
# running loss : 40.306543
# running loss : 40.161401
# running loss : 40.338567
# running loss : 40.531435
# running loss : 40.050873
# running loss : 40.343762
# running loss : 41.390183
# running loss : 40.194072
# running loss : 40.755450
# running loss : 40.617160
# running loss : 40.430021
# running loss : 40.473687
# running loss : 40.603134
# running loss : 40.286817
# running loss : 40.487705
# running loss : 40.450451
# running loss : 40.563675
# running loss : 40.728410
# running loss : 40.623710
# running loss : 40.434028
# running loss : 40.554688
# running loss : 40.326010
# running loss : 40.222104
# running loss : 40.076177
# running loss : 40.170344
# running loss : 40.438091
# running loss : 40.417919
# running loss : 40.462432
# running loss : 40.102696
# running loss : 40.570839
# running loss : 40.233179
# running loss : 40.231006
# running loss : 40.698986
# running loss : 40.315425
# running loss : 40.532246
# running loss : 40.475672
# running loss : 40.382165
# running loss : 40.432858
# running loss : 40.523229
# running loss : 40.284332
# running loss : 40.224168
# running loss : 40.813915
# running loss : 40.157823
# running loss : 40.371618
# running loss : 40.660401
# running loss : 39.941136
# running loss : 40.074004
# running loss : 40.453655
# running loss : 40.216886
# running loss : 40.647225
# running loss : 40.330293
# running loss : 40.221175
# running loss : 40.459903
# running loss : 40.370718
# running loss : 40.030883
# running loss : 40.375860
# running loss : 39.841244
# running loss : 40.492327
# running loss : 40.102038
# running loss : 40.357261

# %%
# transfert du model au gpu
model.to(device)

#define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# define loss function
distortion = nn.MSELoss().cuda()
        
# incremental update of coefficients        

# define beta
beta = 0.10
# define threshold and loss_init
threshold = 0.95
loss_init = float("Inf")
nb_ones = 1
iteration = 0
mask=(compute_mask(1, (96, 16, 16)).unsqueeze(0)).cuda()
dim_latent = 16*16*96
output_flag = False

#Epochs
n_epochs = 6150


# Training the network
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
    
    """
    if epoch==100:
        # define a new learning rate and so a new optimizer
        optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
    """
        
    #Training
    for i_batch, data in enumerate(dataloader):
        batch_images = data.to(device).float()
        [decoded_images, x_quantized] = model(batch_images, mask, True)
        optimizer.zero_grad()
        loss_dist = distortion(decoded_images, batch_images)
        loss_bit = mean_bit_per_px(x_quantized, model.phi, model.var)
        #print(" loss distortion : ", loss_dist)
        #print("loss bit : ", loss_bit)
        loss = beta * loss_dist + loss_bit
        #print(loss)
        
        # check the value of the loss to see if another coefficient can be enabled
        if (loss.item() < loss_init*threshold or iteration > 5):
            if (nb_ones<dim_latent):
                nb_ones +=1
                loss_init = loss.item()
                iteration = 0
                mask = (compute_mask(nb_ones, tuple(x_quantized.size()[1:])).unsqueeze(0)).cuda()
            else:
                output_flag = True
                break
            
        loss.backward()
        #print("conv1.weights grad: ", params[0].grad)
        #print(model.conv1.bias.grad)
        #print(model.conv1.weight.grad)
        optimizer.step()
        running_loss += loss.item()
        iteration += 1

    if output_flag:
        break
    running_loss = running_loss/len(dataloader)
    print('running loss : {:.06f}'.format(running_loss), )
# Out:
# running loss : 372.205585
# running loss : 359.372388
# running loss : 334.788731
# running loss : 325.825894
# running loss : 315.114960
# running loss : 304.065219
# running loss : 295.658553
# running loss : 292.498881
# running loss : 286.837691
# running loss : 283.174444
# running loss : 278.368284
# running loss : 274.759016
# running loss : 269.422899
# running loss : 265.025387
# running loss : 258.820533
# running loss : 254.955923
# running loss : 253.190376
# running loss : 245.540859
# running loss : 242.330257
# running loss : 235.387582
# running loss : 231.870831
# running loss : 226.234155
# running loss : 221.412335
# running loss : 217.896230
# running loss : 212.383201
# running loss : 207.478181
# running loss : 202.734325
# running loss : 197.238168
# running loss : 193.072904
# running loss : 186.547903
# running loss : 181.209412
# running loss : 177.114478
# running loss : 171.197403
# running loss : 165.581685
# running loss : 162.310037
# running loss : 157.674718
# running loss : 154.390675
# running loss : 150.655775
# running loss : 146.872198
# running loss : 145.494732
# running loss : 143.120044
# running loss : 141.684558
# running loss : 139.786583
# running loss : 138.376223
# running loss : 137.188681
# running loss : 135.327412
# running loss : 133.900560
# running loss : 133.922155
# running loss : 131.793515
# running loss : 132.469426
# running loss : 131.151712
# running loss : 130.214122
# running loss : 129.850499
# running loss : 128.404971
# running loss : 128.997412
# running loss : 127.158644
# running loss : 127.395709
# running loss : 126.036255
# running loss : 124.172397
# running loss : 121.757916
# running loss : 121.176421
# running loss : 120.390660
# running loss : 119.427370
# running loss : 118.611875
# running loss : 118.958425
# running loss : 116.564157
# running loss : 116.135258
# running loss : 114.903285
# running loss : 114.178144
# running loss : 113.329229
# running loss : 112.497899
# running loss : 111.086713
# running loss : 110.237881
# running loss : 109.797268
# running loss : 109.398554
# running loss : 107.902211
# running loss : 106.950582
# running loss : 106.243044
# running loss : 105.029642
# running loss : 104.690534
# running loss : 102.956983
# running loss : 102.335711
# running loss : 101.171562
# running loss : 100.127976
# running loss : 99.660405
# running loss : 98.170889
# running loss : 96.922886
# running loss : 96.536592
# running loss : 95.605057
# running loss : 94.779239
# running loss : 93.851255
# running loss : 92.771638
# running loss : 92.048539
# running loss : 91.359101
# running loss : 90.952028
# running loss : 90.609793
# running loss : 89.264112
# running loss : 89.820567
# running loss : 89.267833
# running loss : 88.638947
# running loss : 88.028096
# running loss : 88.421383
# running loss : 87.609569
# running loss : 87.720282
# running loss : 86.979031
# running loss : 86.903557
# running loss : 86.657263
# running loss : 86.434625
# running loss : 86.199862
# running loss : 85.734471
# running loss : 85.835740
# running loss : 85.421239
# running loss : 85.450791
# running loss : 84.389202
# running loss : 84.327931
# running loss : 84.390836
# running loss : 83.811733
# running loss : 83.855783
# running loss : 83.510736
# running loss : 83.326901
# running loss : 83.253955
# running loss : 82.939570
# running loss : 82.662730
# running loss : 81.967564
# running loss : 81.646763
# running loss : 81.207904
# running loss : 81.235175
# running loss : 80.819216
# running loss : 80.622592
# running loss : 80.023190
# running loss : 80.081685
# running loss : 79.190850
# running loss : 79.437216
# running loss : 79.464308
# running loss : 78.620692
# running loss : 78.720370
# running loss : 78.097457
# running loss : 77.578414
# running loss : 77.733182
# running loss : 77.079548
# running loss : 76.280713
# running loss : 76.618958
# running loss : 76.220702
# running loss : 75.948428
# running loss : 76.130499
# running loss : 75.864280
# running loss : 75.766900
# running loss : 75.356820
# running loss : 74.975121
# running loss : 75.113718
# running loss : 74.817349
# running loss : 74.837862
# running loss : 74.552841
# running loss : 74.462165
# running loss : 74.338195
# running loss : 74.152781
# running loss : 73.983758
# running loss : 73.835420
# running loss : 73.403340
# running loss : 73.708833
# running loss : 73.098753
# running loss : 72.985710
# running loss : 72.704668
# running loss : 72.790952
# running loss : 72.693825
# running loss : 72.539045
# running loss : 72.239699
# running loss : 72.468044
# running loss : 71.576634
# running loss : 71.183416
# running loss : 71.492623
# running loss : 71.390845
# running loss : 70.804120
# running loss : 70.952473
# running loss : 70.954562
# running loss : 70.609870
# running loss : 70.204084
# running loss : 70.403028
# running loss : 70.225003
# running loss : 69.191689
# running loss : 69.218333
# running loss : 69.443509
# running loss : 69.289006
# running loss : 68.653663
# running loss : 68.616071
# running loss : 68.627216
# running loss : 68.052270
# running loss : 68.226690
# running loss : 67.917916
# running loss : 67.574195
# running loss : 67.352068
# running loss : 67.149223
# running loss : 67.027198
# running loss : 66.733139
# running loss : 66.943480
# running loss : 66.415186
# running loss : 66.542806
# running loss : 66.405943
# running loss : 66.140196
# running loss : 65.930512
# running loss : 66.230093
# running loss : 66.119444
# running loss : 65.229936
# running loss : 65.416420
# running loss : 65.376675
# running loss : 65.030602
# running loss : 64.502550
# running loss : 64.635207
# running loss : 64.241286
# running loss : 63.617497
# running loss : 63.647623
# running loss : 63.509374
# running loss : 63.250751
# running loss : 62.964346
# running loss : 62.798044
# running loss : 62.876697
# running loss : 62.546170
# running loss : 62.343739
# running loss : 62.382273
# running loss : 62.101205
# running loss : 61.556810
# running loss : 61.567535
# running loss : 61.466089
# running loss : 61.656597
# running loss : 60.966519
# running loss : 61.183327
# running loss : 60.538773
# running loss : 60.844715
# running loss : 60.773133
# running loss : 60.460751
# running loss : 60.462870
# running loss : 60.085318
# running loss : 60.165897
# running loss : 59.633252
# running loss : 59.932155
# running loss : 59.463807
# running loss : 59.146308
# running loss : 59.150161
# running loss : 59.432468
# running loss : 59.382841
# running loss : 58.740259
# running loss : 58.726815
# running loss : 58.536765
# running loss : 58.300292
# running loss : 58.230262
# running loss : 58.157460
# running loss : 57.604094
# running loss : 57.395812
# running loss : 57.557085
# running loss : 57.471709
# running loss : 57.183629
# running loss : 56.852050
# running loss : 57.489022
# running loss : 57.332825
# running loss : 57.104013
# running loss : 56.935299
# running loss : 57.009838
# running loss : 56.563147
# running loss : 56.593829
# running loss : 56.363718
# running loss : 56.381473
# running loss : 56.293341
# running loss : 56.509373
# running loss : 56.898832
# running loss : 55.970815
# running loss : 56.012577
# running loss : 55.972971
# running loss : 55.812824
# running loss : 55.435091
# running loss : 55.584338
# running loss : 55.549542
# running loss : 55.408596
# running loss : 55.309105
# running loss : 55.178113
# running loss : 54.703220
# running loss : 54.658176
# running loss : 54.897744
# running loss : 54.638713
# running loss : 54.291035
# running loss : 53.868457
# running loss : 53.696898
# running loss : 53.511603
# running loss : 53.387161
# running loss : 53.401424
# running loss : 53.793847
# running loss : 53.203204
# running loss : 53.271169
# running loss : 53.065885
# running loss : 53.071640
# running loss : 52.906802
# running loss : 52.493575
# running loss : 52.354071
# running loss : 52.239388
# running loss : 51.991223
# running loss : 51.912887
# running loss : 51.886254
# running loss : 51.739740
# running loss : 51.838955
# running loss : 51.037448
# running loss : 51.422322
# running loss : 51.381081
# running loss : 51.100479
# running loss : 51.576217
# running loss : 51.264900
# running loss : 50.900970
# running loss : 50.720608
# running loss : 51.053529
# running loss : 50.849009
# running loss : 50.401641
# running loss : 50.532240
# running loss : 50.409804
# running loss : 50.475279
# running loss : 50.372745
# running loss : 50.204986
# running loss : 50.084477
# running loss : 50.151814
# running loss : 49.811024
# running loss : 49.650126
# running loss : 49.439033
# running loss : 49.517446
# running loss : 49.792604
# running loss : 49.397411
# running loss : 49.236378
# running loss : 49.351499
# running loss : 49.002976
# running loss : 48.853631
# running loss : 48.917432
# running loss : 48.681510
# running loss : 48.636733
# running loss : 48.517869
# running loss : 48.254695
# running loss : 48.249825
# running loss : 48.258612
# running loss : 48.128626
# running loss : 47.780579
# running loss : 47.882384
# running loss : 47.859391
# running loss : 47.613675
# running loss : 47.439977
# running loss : 47.337895
# running loss : 47.591586
# running loss : 47.002056
# running loss : 46.869493
# running loss : 46.888115
# running loss : 47.035607
# running loss : 46.971596
# running loss : 46.643617
# running loss : 46.359414
# running loss : 46.387386
# running loss : 46.426638
# running loss : 46.151140
# running loss : 46.141243
# running loss : 45.946510
# running loss : 46.134060
# running loss : 45.840311
# running loss : 46.097734
# running loss : 45.712201
# running loss : 45.670355
# running loss : 45.774177
# running loss : 45.902608
# running loss : 45.636942
# running loss : 45.352897
# running loss : 45.626225
# running loss : 45.901805
# running loss : 45.418458
# running loss : 45.381871
# running loss : 45.477491
# running loss : 45.334408
# running loss : 45.386642
# running loss : 44.832477
# running loss : 44.995156
# running loss : 44.711426
# running loss : 44.751199
# running loss : 44.756095
# running loss : 44.445187
# running loss : 44.920089
# running loss : 44.437029
# running loss : 44.517546
# running loss : 44.394488
# running loss : 43.931878
# running loss : 43.755518
# running loss : 44.042652
# running loss : 43.763317
# running loss : 44.187782
# running loss : 43.696348
# running loss : 43.666137
# running loss : 43.309142
# running loss : 43.744372
# running loss : 43.414551
# running loss : 43.380848
# running loss : 43.196796
# running loss : 43.125820
# running loss : 43.076149
# running loss : 42.505061
# running loss : 42.836422
# running loss : 42.771375
# running loss : 42.876182
# running loss : 42.402497
# running loss : 42.153205
# running loss : 42.509579
# running loss : 42.466657
# running loss : 42.524687
# running loss : 42.095951
# running loss : 42.363647
# running loss : 42.335262
# running loss : 42.292061
# running loss : 41.996178
# running loss : 41.997660
# running loss : 41.985016
# running loss : 42.039548
# running loss : 42.199046
# running loss : 41.787609
# running loss : 42.039896
# running loss : 41.719253
# running loss : 41.903100
# running loss : 41.699843
# running loss : 41.774319
# running loss : 41.387936
# running loss : 41.587090
# running loss : 41.469121
# running loss : 41.427819
# running loss : 41.246108
# running loss : 41.449999
# running loss : 41.141565
# running loss : 41.036232
# running loss : 41.219351
# running loss : 41.030657
# running loss : 40.996516
# running loss : 40.612440
# running loss : 40.865535
# running loss : 40.824099
# running loss : 40.846842
# running loss : 40.495740
# running loss : 40.527748
# running loss : 40.445820
# running loss : 40.745079
# running loss : 40.310310
# running loss : 40.182884
# running loss : 40.141207
# running loss : 40.038430
# running loss : 40.150410
# running loss : 39.926407
# running loss : 39.897175
# running loss : 39.883502
# running loss : 39.570824
# running loss : 39.453685
# running loss : 39.299101
# running loss : 39.483179
# running loss : 39.329072
# running loss : 39.484882
# running loss : 39.509461
# running loss : 39.635656
# running loss : 39.567134
# running loss : 39.306738
# running loss : 39.222596
# running loss : 39.126738
# running loss : 38.959306
# running loss : 39.080873
# running loss : 38.779649
# running loss : 38.657890
# running loss : 38.849682
# running loss : 38.956258
# running loss : 38.861489
# running loss : 38.832011
# running loss : 39.225904
# running loss : 38.965480
# running loss : 38.625509
# running loss : 38.468286
# running loss : 38.737402
# running loss : 38.526064
# running loss : 38.432773
# running loss : 38.620316
# running loss : 38.691863
# running loss : 38.342909
# running loss : 38.733043
# running loss : 38.499545
# running loss : 38.455902
# running loss : 38.471263
# running loss : 39.537513
# running loss : 46.861522
# running loss : 40.137570
# running loss : 38.932948
# running loss : 38.588857
# running loss : 38.380526
# running loss : 38.090865
# running loss : 38.199954
# running loss : 37.900712
# running loss : 37.795963
# running loss : 37.905989
# running loss : 37.589577
# running loss : 37.891514
# running loss : 37.554344
# running loss : 37.589771
# running loss : 37.567961
# running loss : 37.487612
# running loss : 37.369912
# running loss : 37.424914
# running loss : 37.573954
# running loss : 37.258008
# running loss : 37.339491
# running loss : 37.155522
# running loss : 37.164166
# running loss : 36.842037
# running loss : 37.046116
# running loss : 37.208162
# running loss : 37.061333
# running loss : 37.023832
# running loss : 36.891819
# running loss : 36.898672
# running loss : 36.914647
# running loss : 36.691586
# running loss : 36.536106
# running loss : 36.802712
# running loss : 36.416475
# running loss : 36.375576
# running loss : 36.281647
# running loss : 36.413241
# running loss : 36.533987
# running loss : 36.144123
# running loss : 36.296385
# running loss : 36.222762
# running loss : 35.950545
# running loss : 36.067194
# running loss : 36.079012
# running loss : 36.213429
# running loss : 35.916706
# running loss : 35.952640
# running loss : 35.948180
# running loss : 35.945121
# running loss : 35.620972
# running loss : 35.755832
# running loss : 35.691138
# running loss : 35.649604
# running loss : 35.549278
# running loss : 35.462584
# running loss : 35.554728
# running loss : 35.225659
# running loss : 35.420717
# running loss : 35.491539
# running loss : 35.180619
# running loss : 35.332403
# running loss : 35.294201
# running loss : 35.027967
# running loss : 35.033442
# running loss : 34.965205
# running loss : 34.749418
# running loss : 34.922173
# running loss : 34.852426
# running loss : 34.661178
# running loss : 34.582387
# running loss : 34.471694
# running loss : 34.795228
# running loss : 34.532275
# running loss : 34.332156
# running loss : 34.598028
# running loss : 34.446686
# running loss : 34.312609
# running loss : 34.498670
# running loss : 34.397217
# running loss : 34.417936
# running loss : 34.193280
# running loss : 34.405833
# running loss : 34.543284
# running loss : 34.162865
# running loss : 34.177541
# running loss : 34.084872
# running loss : 34.105951
# running loss : 34.171985
# running loss : 34.077813
# running loss : 33.753386
# running loss : 33.830759
# running loss : 33.911301
# running loss : 33.617675
# running loss : 33.531039
# running loss : 33.639515
# running loss : 33.402917
# running loss : 33.551204
# running loss : 33.603167
# running loss : 33.377606
# running loss : 33.357011
# running loss : 33.432972
# running loss : 33.155043
# running loss : 33.205082
# running loss : 33.218118
# running loss : 33.380082
# running loss : 33.048511
# running loss : 32.744972
# running loss : 32.895761
# running loss : 32.743682
# running loss : 32.694037
# running loss : 33.029815
# running loss : 32.748392
# running loss : 32.843315
# running loss : 32.545462
# running loss : 32.583489
# running loss : 32.290169
# running loss : 32.420669
# running loss : 32.570340
# running loss : 32.354817
# running loss : 32.214216
# running loss : 32.256795
# running loss : 32.250236
# running loss : 32.173708
# running loss : 32.261758
# running loss : 32.229100
# running loss : 32.175899
# running loss : 32.285524
# running loss : 32.389860
# running loss : 32.166243
# running loss : 32.083677
# running loss : 32.347514
# running loss : 31.939007
# running loss : 32.151459
# running loss : 32.089912
# running loss : 31.823515
# running loss : 32.144815
# running loss : 31.885848
# running loss : 32.199972
# running loss : 31.650217
# running loss : 31.624122
# running loss : 31.847272
# running loss : 31.930180
# running loss : 31.642979
# running loss : 31.603717
# running loss : 31.626818
# running loss : 31.699279
# running loss : 31.513442
# running loss : 31.242974
# running loss : 31.401541
# running loss : 31.613429
# running loss : 31.626031
# running loss : 31.430882
# running loss : 31.306517
# running loss : 31.279008
# running loss : 31.141858
# running loss : 31.162971
# running loss : 30.997286
# running loss : 30.954869
# running loss : 30.697917
# running loss : 30.923768
# running loss : 30.901645
# running loss : 30.853846
# running loss : 30.633959
# running loss : 30.655281
# running loss : 30.703077
# running loss : 30.473792
# running loss : 30.578856
# running loss : 30.615368
# running loss : 30.851767
# running loss : 30.584076
# running loss : 30.486356
# running loss : 30.475696
# running loss : 30.476761
# running loss : 30.367534
# running loss : 30.339043
# running loss : 30.148935
# running loss : 30.370609
# running loss : 30.460649
# running loss : 30.392978
# running loss : 30.176837
# running loss : 30.345933
# running loss : 30.414758
# running loss : 30.202333
# running loss : 30.231761
# running loss : 30.306386
# running loss : 30.180506
# running loss : 30.143678
# running loss : 29.969756
# running loss : 30.202102
# running loss : 30.289136
# running loss : 29.980442
# running loss : 29.798060
# running loss : 29.778703
# running loss : 29.995658
# running loss : 29.620659
# running loss : 29.811133
# running loss : 29.682057
# running loss : 29.813139
# running loss : 29.633829
# running loss : 29.575030
# running loss : 29.535408
# running loss : 29.466001
# running loss : 29.426331
# running loss : 29.286091
# running loss : 29.513084
# running loss : 29.463093
# running loss : 29.482171
# running loss : 29.138780
# running loss : 29.214388
# running loss : 29.103028
# running loss : 29.106188
# running loss : 29.086785
# running loss : 29.083191
# running loss : 28.984189
# running loss : 29.006227
# running loss : 29.071015
# running loss : 29.123341
# running loss : 28.861499
# running loss : 29.076533
# running loss : 28.711132
# running loss : 28.766003
# running loss : 28.875801
# running loss : 28.999974
# running loss : 28.584505
# running loss : 28.891721
# running loss : 28.896343
# running loss : 28.693466
# running loss : 28.858355
# running loss : 28.704306
# running loss : 28.730880
# running loss : 28.601089
# running loss : 28.470161
# running loss : 28.535090
# running loss : 28.638988
# running loss : 28.508477
# running loss : 28.508653
# running loss : 28.410828
# running loss : 28.580419
# running loss : 28.400643
# running loss : 28.433862
# running loss : 28.288617
# running loss : 28.267227
# running loss : 28.460858
# running loss : 28.601423
# running loss : 28.310811
# running loss : 28.276841
# running loss : 28.236187
# running loss : 28.110353
# running loss : 28.225964
# running loss : 28.057164
# running loss : 28.157484
# running loss : 28.301664
# running loss : 28.139196
# running loss : 28.026674
# running loss : 28.091733
# running loss : 27.953739
# running loss : 27.923330
# running loss : 27.847024
# running loss : 27.887834
# running loss : 27.896297
# running loss : 27.921720
# running loss : 27.833205
# running loss : 27.798399
# running loss : 27.606773
# running loss : 27.698110
# running loss : 27.453071
# running loss : 27.528492
# running loss : 27.507954
# running loss : 27.601955
# running loss : 27.644910
# running loss : 27.448782
# running loss : 27.456526
# running loss : 27.443842
# running loss : 27.665513
# running loss : 27.377277
# running loss : 27.255585
# running loss : 27.365880
# running loss : 27.231662
# running loss : 27.223400
# running loss : 27.353355
# running loss : 27.380001
# running loss : 27.598754
# running loss : 27.195582
# running loss : 27.203130
# running loss : 27.069155
# running loss : 27.083554
# running loss : 27.072700
# running loss : 27.033467
# running loss : 27.064633
# running loss : 26.975612
# running loss : 27.076599
# running loss : 26.990271
# running loss : 26.990922
# running loss : 26.908582
# running loss : 26.868134
# running loss : 27.060566
# running loss : 26.834326
# running loss : 26.956344
# running loss : 26.704733
# running loss : 26.910296
# running loss : 26.808274
# running loss : 26.805725
# running loss : 26.732136
# running loss : 26.546324
# running loss : 26.725644
# running loss : 26.509892
# running loss : 26.809316
# running loss : 26.912966
# running loss : 26.678222
# running loss : 26.527592
# running loss : 26.323305
# running loss : 26.241793
# running loss : 26.403688
# running loss : 26.335219
# running loss : 26.159548
# running loss : 26.162711
# running loss : 26.169813
# running loss : 26.210293
# running loss : 26.307503
# running loss : 26.405783
# running loss : 26.088062
# running loss : 26.077835
# running loss : 26.096329
# running loss : 25.963556
# running loss : 25.974272
# running loss : 25.890981
# running loss : 26.251021
# running loss : 25.919679
# running loss : 25.899821
# running loss : 25.975531
# running loss : 26.060885
# running loss : 26.023093
# running loss : 25.878148
# running loss : 26.025169
# running loss : 25.908096
# running loss : 25.865522
# running loss : 25.813762
# running loss : 25.843709
# running loss : 25.925007
# running loss : 25.812014
# running loss : 25.649767
# running loss : 25.769660
# running loss : 25.695519
# running loss : 25.789961
# running loss : 25.679091
# running loss : 25.577273
# running loss : 25.594327
# running loss : 25.632415
# running loss : 25.543751
# running loss : 25.521504
# running loss : 25.580754
# running loss : 25.571206
# running loss : 25.565585
# running loss : 25.451839
# running loss : 25.430044
# running loss : 25.450121
# running loss : 25.343397
# running loss : 25.339808
# running loss : 25.228161
# running loss : 25.056137
# running loss : 25.126060
# running loss : 25.216439
# running loss : 25.168414
# running loss : 25.202994
# running loss : 25.264084
# running loss : 25.100301
# running loss : 24.989319
# running loss : 25.192748
# running loss : 24.806390
# running loss : 25.024376
# running loss : 24.972591
# running loss : 24.882621
# running loss : 24.937899
# running loss : 24.938996
# running loss : 24.874884
# running loss : 24.748957
# running loss : 24.817834
# running loss : 24.757808
# running loss : 24.826215
# running loss : 24.781973
# running loss : 24.759797
# running loss : 25.016992
# running loss : 24.701425
# running loss : 24.760175
# running loss : 24.859598
# running loss : 24.689071
# running loss : 24.574704
# running loss : 24.624803
# running loss : 24.578994
# running loss : 24.621157
# running loss : 24.629856
# running loss : 24.647485
# running loss : 24.423591
# running loss : 24.589163
# running loss : 24.433640
# running loss : 24.447690
# running loss : 24.382792
# running loss : 24.526577
# running loss : 24.359010
# running loss : 24.540421
# running loss : 24.186892
# running loss : 24.277668
# running loss : 24.132254
# running loss : 24.246443
# running loss : 24.043057
# running loss : 24.110654
# running loss : 24.125124
# running loss : 24.075601
# running loss : 24.105037
# running loss : 23.985282
# running loss : 23.922225
# running loss : 23.947387
# running loss : 23.855999
# running loss : 23.910465
# running loss : 23.879932
# running loss : 24.004430
# running loss : 23.893299
# running loss : 23.707164
# running loss : 23.651246
# running loss : 23.700550
# running loss : 23.716348
# running loss : 23.593729
# running loss : 23.466541
# running loss : 23.780420
# running loss : 23.542442
# running loss : 23.771188
# running loss : 23.659101
# running loss : 23.584194
# running loss : 23.454218
# running loss : 23.412002
# running loss : 23.497731
# running loss : 23.613256
# running loss : 23.630883
# running loss : 23.607884
# running loss : 23.323174
# running loss : 23.478646
# running loss : 23.277810
# running loss : 23.498779
# running loss : 23.327275
# running loss : 23.352522
# running loss : 23.334276
# running loss : 23.102925
# running loss : 23.238336
# running loss : 23.471144
# running loss : 23.184843
# running loss : 23.047880
# running loss : 23.049277
# running loss : 23.088802
# running loss : 22.977998
# running loss : 22.873369
# running loss : 23.005198
# running loss : 22.861885
# running loss : 22.793003
# running loss : 22.965009
# running loss : 22.883265
# running loss : 22.802960
# running loss : 22.872125
# running loss : 22.823120
# running loss : 23.015338
# running loss : 22.686996
# running loss : 22.549036
# running loss : 22.776509
# running loss : 22.549908
# running loss : 22.482762
# running loss : 22.559445
# running loss : 22.547776
# running loss : 22.566400
# running loss : 22.587146
# running loss : 22.507638
# running loss : 22.459365
# running loss : 22.506588
# running loss : 22.479761
# running loss : 22.523049
# running loss : 22.556690
# running loss : 22.399902
# running loss : 22.661103
# running loss : 22.384162
# running loss : 22.255403
# running loss : 22.316840
# running loss : 22.341123
# running loss : 22.360727
# running loss : 22.418242
# running loss : 22.494935
# running loss : 22.317433
# running loss : 22.210625
# running loss : 22.212812
# running loss : 22.189203
# running loss : 22.175191
# running loss : 22.056816
# running loss : 22.155065
# running loss : 21.918443
# running loss : 22.106547
# running loss : 22.128486
# running loss : 21.918602
# running loss : 22.075022
# running loss : 22.028265
# running loss : 21.959557
# running loss : 21.958193
# running loss : 21.999424
# running loss : 22.086338
# running loss : 21.992185
# running loss : 21.866253
# running loss : 21.683495
# running loss : 21.869756
# running loss : 21.791341
# running loss : 21.783459
# running loss : 21.662022
# running loss : 21.718304
# running loss : 21.732225
# running loss : 21.654993
# running loss : 21.704809
# running loss : 21.770820
# running loss : 21.732747
# running loss : 21.621520
# running loss : 21.569589
# running loss : 21.554491
# running loss : 21.404058
# running loss : 21.518849
# running loss : 21.518168
# running loss : 21.386341
# running loss : 21.365301
# running loss : 21.309323
# running loss : 21.467385
# running loss : 21.441322
# running loss : 21.484326
# running loss : 21.554762
# running loss : 21.394458
# running loss : 21.424843
# running loss : 21.426579
# running loss : 21.300792
# running loss : 21.296264
# running loss : 21.312311
# running loss : 21.195081
# running loss : 21.363481
# running loss : 21.345148
# running loss : 21.208177
# running loss : 21.279117
# running loss : 21.286907
# running loss : 21.217037
# running loss : 21.394860
# running loss : 21.219374
# running loss : 21.146841
# running loss : 21.170989
# running loss : 21.050189
# running loss : 21.241672
# running loss : 21.157327
# running loss : 21.075272
# running loss : 21.015526
# running loss : 20.987213
# running loss : 21.031225
# running loss : 20.913767
# running loss : 21.041225
# running loss : 21.049498
# running loss : 21.028113
# running loss : 21.018488
# running loss : 20.863063
# running loss : 20.847273
# running loss : 20.889680
# running loss : 20.832733
# running loss : 20.738472
# running loss : 20.907417
# running loss : 20.694501
# running loss : 20.720588
# running loss : 20.772842
# running loss : 20.830797
# running loss : 20.732763
# running loss : 20.891416
# running loss : 20.743653
# running loss : 20.627347
# running loss : 20.640172
# running loss : 20.929578
# running loss : 20.462202
# running loss : 20.585727
# running loss : 20.487037
# running loss : 20.663039
# running loss : 20.517771
# running loss : 20.558682
# running loss : 20.630945
# running loss : 20.542146
# running loss : 20.506405
# running loss : 20.499333
# running loss : 20.416307
# running loss : 20.313188
# running loss : 20.366484
# running loss : 20.219528
# running loss : 20.351117
# running loss : 20.476820
# running loss : 20.392618
# running loss : 20.338933
# running loss : 20.293357
# running loss : 20.300234
# running loss : 20.359318
# running loss : 20.158081
# running loss : 20.199972
# running loss : 20.072629
# running loss : 20.166392
# running loss : 20.197008
# running loss : 20.113673
# running loss : 20.145494
# running loss : 20.130826
# running loss : 19.982582
# running loss : 19.974940
# running loss : 20.039205
# running loss : 20.042828
# running loss : 20.048075
# running loss : 19.964974
# running loss : 19.893138
# running loss : 20.042123
# running loss : 19.915111
# running loss : 19.918799
# running loss : 19.914089
# running loss : 20.000083
# running loss : 19.760430
# running loss : 19.891891
# running loss : 19.803788
# running loss : 19.908735
# running loss : 19.836913
# running loss : 19.731786
# running loss : 19.733491
# running loss : 19.673865
# running loss : 19.713104
# running loss : 19.626247
# running loss : 19.761920
# running loss : 19.814728
# running loss : 19.662734
# running loss : 19.689134
# running loss : 19.667226
# running loss : 19.624586
# running loss : 19.696024
# running loss : 19.484812
# running loss : 19.604584
# running loss : 19.507103
# running loss : 19.575666
# running loss : 19.518715
# running loss : 19.679947
# running loss : 19.668246
# running loss : 19.451414
# running loss : 19.535168
# running loss : 19.448653
# running loss : 19.576179
# running loss : 19.581868
# running loss : 19.447663
# running loss : 19.386791
# running loss : 19.389763
# running loss : 19.470964
# running loss : 19.294203
# running loss : 19.371332
# running loss : 19.348217
# running loss : 19.232051
# running loss : 19.247253
# running loss : 19.252692
# running loss : 19.261763
# running loss : 19.272333
# running loss : 19.262755
# running loss : 19.234608
# running loss : 19.117451
# running loss : 19.162905
# running loss : 19.116511
# running loss : 19.106463
# running loss : 19.015474
# running loss : 19.088083
# running loss : 18.957495
# running loss : 18.867837
# running loss : 18.854991
# running loss : 19.073046
# running loss : 18.858407
# running loss : 18.840631
# running loss : 18.946656
# running loss : 18.986237
# running loss : 18.854501
# running loss : 18.888599
# running loss : 18.865275
# running loss : 18.835969
# running loss : 19.011657
# running loss : 19.140213
# running loss : 18.911072
# running loss : 18.998453
# running loss : 18.920707
# running loss : 18.847402
# running loss : 18.847407
# running loss : 18.858757
# running loss : 18.704478
# running loss : 18.824167
# running loss : 18.782628
# running loss : 18.876251
# running loss : 18.772566
# running loss : 18.689009
# running loss : 18.687121
# running loss : 18.760404
# running loss : 19.000535
# running loss : 18.804041
# running loss : 18.709829
# running loss : 18.596086
# running loss : 18.624966
# running loss : 18.554126
# running loss : 18.554000
# running loss : 18.578948
# running loss : 18.708156
# running loss : 18.561440
# running loss : 18.439454
# running loss : 18.519585
# running loss : 18.345524
# running loss : 18.440047
# running loss : 18.533522
# running loss : 18.532277
# running loss : 18.436950
# running loss : 18.395707
# running loss : 18.437267
# running loss : 18.441789
# running loss : 18.497783
# running loss : 18.254618
# running loss : 18.343069
# running loss : 18.405943
# running loss : 18.304816
# running loss : 18.212885
# running loss : 18.298975
# running loss : 18.207953
# running loss : 18.229157
# running loss : 18.301825
# running loss : 18.218864
# running loss : 18.333928
# running loss : 18.207184
# running loss : 18.259436
# running loss : 18.360542
# running loss : 18.210856
# running loss : 18.126947
# running loss : 18.146684
# running loss : 18.180698
# running loss : 18.103121
# running loss : 18.164084
# running loss : 18.186539
# running loss : 18.377456
# running loss : 18.107435
# running loss : 18.078467
# running loss : 18.092847
# running loss : 18.041206
# running loss : 17.942211
# running loss : 18.018290
# running loss : 17.974770
# running loss : 17.914690
# running loss : 18.071100
# running loss : 17.987236
# running loss : 17.978131
# running loss : 17.895266
# running loss : 17.933380
# running loss : 17.854367
# running loss : 17.812008
# running loss : 17.871262
# running loss : 17.692973
# running loss : 17.826491
# running loss : 17.817895
# running loss : 17.780366
# running loss : 17.918200
# running loss : 17.729296
# running loss : 17.687211
# running loss : 17.705602
# running loss : 17.675425
# running loss : 17.609907
# running loss : 17.725788
# running loss : 17.748938
# running loss : 17.754430
# running loss : 17.638223
# running loss : 17.629380
# running loss : 17.628390
# running loss : 17.586231
# running loss : 17.656780
# running loss : 17.689261
# running loss : 17.642105
# running loss : 17.469102
# running loss : 17.534146
# running loss : 17.674697
# running loss : 17.502403
# running loss : 17.505647
# running loss : 17.645993
# running loss : 17.523668
# running loss : 17.494384
# running loss : 17.450467
# running loss : 17.535820
# running loss : 17.552191
# running loss : 17.410092
# running loss : 17.472200
# running loss : 17.465765
# running loss : 17.235416
# running loss : 17.234304
# running loss : 17.392760
# running loss : 17.354505
# running loss : 17.508373
# running loss : 17.355219
# running loss : 17.384136
# running loss : 17.165671
# running loss : 17.276756
# running loss : 17.225845
# running loss : 17.140257
# running loss : 17.146580
# running loss : 17.180139
# running loss : 17.240789
# running loss : 17.270156
# running loss : 17.145031
# running loss : 17.150254
# running loss : 17.119646
# running loss : 17.210218
# running loss : 17.285996
# running loss : 17.095482
# running loss : 16.963586
# running loss : 17.007726
# running loss : 17.024615
# running loss : 17.073422
# running loss : 16.872616
# running loss : 16.837298
# running loss : 16.833333
# running loss : 17.028046
# running loss : 16.827249
# running loss : 16.958154
# running loss : 16.912632
# running loss : 16.895440
# running loss : 16.932890
# running loss : 16.871352
# running loss : 16.874891
# running loss : 16.989657
# running loss : 16.905394
# running loss : 16.960161
# running loss : 16.804253
# running loss : 16.814708
# running loss : 16.814710
# running loss : 16.828973
# running loss : 16.895672
# running loss : 16.820905
# running loss : 16.774041
# running loss : 16.900464
# running loss : 16.851163
# running loss : 16.746624
# running loss : 16.806982
# running loss : 16.756103
# running loss : 16.731215
# running loss : 16.861963
# running loss : 16.878074
# running loss : 16.880382
# running loss : 16.775134
# running loss : 16.677456
# running loss : 16.634263
# running loss : 16.616592
# running loss : 16.646622
# running loss : 16.618057
# running loss : 16.565145
# running loss : 16.586118
# running loss : 16.547494
# running loss : 16.574384
# running loss : 16.612042
# running loss : 16.559904
# running loss : 16.670056
# running loss : 16.630602
# running loss : 16.430337
# running loss : 16.467009
# running loss : 16.423631
# running loss : 16.428021
# running loss : 16.416072
# running loss : 16.430048
# running loss : 16.342268
# running loss : 16.487398
# running loss : 16.359010
# running loss : 16.333756
# running loss : 16.298015
# running loss : 16.291941
# running loss : 16.275274
# running loss : 16.446896
# running loss : 16.248646
# running loss : 16.324672
# running loss : 16.259098
# running loss : 16.235103
# running loss : 16.265734
# running loss : 16.416802
# running loss : 16.186104
# running loss : 16.271686
# running loss : 16.191735
# running loss : 16.212493
# running loss : 16.238174
# running loss : 16.175246
# running loss : 16.177787
# running loss : 16.238474
# running loss : 16.171436
# running loss : 16.248777
# running loss : 16.247490
# running loss : 16.261404
# running loss : 16.125238
# running loss : 16.115693
# running loss : 16.043912
# running loss : 16.142570
# running loss : 16.227891
# running loss : 16.122692
# running loss : 16.097239
# running loss : 15.998677
# running loss : 16.094107
# running loss : 16.119306
# running loss : 16.100388
# running loss : 16.036890
# running loss : 16.032961
# running loss : 16.097698
# running loss : 16.019369
# running loss : 15.889577
# running loss : 15.951029
# running loss : 16.047289
# running loss : 15.793087
# running loss : 15.830720
# running loss : 15.984076
# running loss : 15.991384
# running loss : 16.069087
# running loss : 15.888967
# running loss : 15.932442
# running loss : 15.983487
# running loss : 15.835637
# running loss : 15.801029
# running loss : 15.732467
# running loss : 15.766810
# running loss : 15.691709
# running loss : 15.810699
# running loss : 15.782680
# running loss : 15.757798
# running loss : 15.840851
# running loss : 15.764005
# running loss : 15.646415
# running loss : 15.931514
# running loss : 15.605703
# running loss : 15.714569
# running loss : 15.647716
# running loss : 15.688061
# running loss : 15.740264
# running loss : 15.728785
# running loss : 15.632970
# running loss : 15.749761
# running loss : 15.621063
# running loss : 15.688094
# running loss : 15.582661
# running loss : 15.657131
# running loss : 15.575194
# running loss : 15.654286
# running loss : 15.534491
# running loss : 15.559389
# running loss : 15.527652
# running loss : 15.575155
# running loss : 15.475462
# running loss : 15.584268
# running loss : 15.628851
# running loss : 15.706544
# running loss : 15.561214
# running loss : 15.440864
# running loss : 15.491640
# running loss : 15.520844
# running loss : 15.395759
# running loss : 15.352440
# running loss : 15.374755
# running loss : 15.417190
# running loss : 15.360009
# running loss : 15.456267
# running loss : 15.440933
# running loss : 15.297073
# running loss : 15.324966
# running loss : 15.300228
# running loss : 15.227955
# running loss : 15.413339
# running loss : 15.225460
# running loss : 15.326251
# running loss : 15.254108
# running loss : 15.294832
# running loss : 15.172238
# running loss : 15.184780
# running loss : 15.220046
# running loss : 15.242970
# running loss : 15.298554
# running loss : 15.201120
# running loss : 15.270480
# running loss : 15.204223
# running loss : 15.145120
# running loss : 15.227293
# running loss : 15.209964
# running loss : 15.131986
# running loss : 15.164937
# running loss : 15.086086
# running loss : 15.187703
# running loss : 15.134585
# running loss : 15.134699
# running loss : 15.088344
# running loss : 15.115172
# running loss : 15.106609
# running loss : 15.194544
# running loss : 15.011464
# running loss : 15.046603
# running loss : 15.047681
# running loss : 14.939871
# running loss : 14.929452
# running loss : 15.076953
# running loss : 15.024983
# running loss : 14.936023
# running loss : 14.841490
# running loss : 14.902694
# running loss : 15.088813
# running loss : 15.081702
# running loss : 14.930295
# running loss : 14.908157
# running loss : 14.940023
# running loss : 14.830608
# running loss : 14.872870
# running loss : 14.833381
# running loss : 14.812495
# running loss : 14.839723
# running loss : 14.749964
# running loss : 14.730080
# running loss : 14.741178
# running loss : 14.746412
# running loss : 14.709714
# running loss : 14.837469
# running loss : 14.802126
# running loss : 14.659619
# running loss : 14.708540
# running loss : 14.711427
# running loss : 14.781331
# running loss : 14.679626
# running loss : 14.646092
# running loss : 14.665083
# running loss : 14.559965
# running loss : 14.693211
# running loss : 14.729438
# running loss : 14.661769
# running loss : 14.771578
# running loss : 14.521290
# running loss : 14.724398
# running loss : 14.627155
# running loss : 14.582067
# running loss : 14.601820
# running loss : 14.573593
# running loss : 14.502511
# running loss : 14.562557
# running loss : 14.546271
# running loss : 14.587209
# running loss : 14.466137
# running loss : 14.568234
# running loss : 14.495769
# running loss : 14.573018
# running loss : 14.682465
# running loss : 14.561589
# running loss : 14.539015
# running loss : 14.499882
# running loss : 14.444471
# running loss : 14.504158
# running loss : 14.577749
# running loss : 14.408032
# running loss : 14.428874
# running loss : 14.423207
# running loss : 14.378534
# running loss : 14.425202
# running loss : 14.306607
# running loss : 14.455693
# running loss : 14.401189
# running loss : 14.478899
# running loss : 14.432436
# running loss : 14.436242
# running loss : 14.226914
# running loss : 14.400387
# running loss : 14.289128
# running loss : 14.235358
# running loss : 14.305247
# running loss : 14.203593
# running loss : 14.316132
# running loss : 14.221313
# running loss : 14.281647
# running loss : 14.285780
# running loss : 14.206174
# running loss : 14.241560
# running loss : 14.150481
# running loss : 14.195067
# running loss : 14.231641
# running loss : 14.220491
# running loss : 14.207963
# running loss : 14.120623
# running loss : 14.155794
# running loss : 14.039239
# running loss : 14.012619
# running loss : 14.072581
# running loss : 14.058762
# running loss : 14.056334
# running loss : 14.005580
# running loss : 14.129434
# running loss : 14.130036
# running loss : 14.180920
# running loss : 14.138263
# running loss : 14.077562
# running loss : 14.127136
# running loss : 14.065768
# running loss : 14.027285
# running loss : 14.067306
# running loss : 13.943207
# running loss : 14.025634
# running loss : 14.055573
# running loss : 13.975979
# running loss : 14.043501
# running loss : 14.001596
# running loss : 14.031305
# running loss : 13.943261
# running loss : 13.979182
# running loss : 14.014338
# running loss : 13.928363
# running loss : 13.897991
# running loss : 13.859362
# running loss : 13.944821
# running loss : 13.922775
# running loss : 13.822818
# running loss : 14.001652
# running loss : 13.922970
# running loss : 13.780280
# running loss : 13.815779
# running loss : 13.790935
# running loss : 13.775260
# running loss : 13.821152
# running loss : 13.722564
# running loss : 13.648738
# running loss : 13.789932
# running loss : 13.768165
# running loss : 13.725153
# running loss : 13.829129
# running loss : 13.746776
# running loss : 13.680340
# running loss : 13.788029
# running loss : 13.763858
# running loss : 13.701667
# running loss : 13.653585
# running loss : 13.674239
# running loss : 13.654496
# running loss : 13.665368
# running loss : 13.613042
# running loss : 13.673801
# running loss : 13.725839
# running loss : 13.648542
# running loss : 13.693358
# running loss : 13.802316
# running loss : 13.777368
# running loss : 13.701241
# running loss : 13.547588
# running loss : 13.672789
# running loss : 13.600890
# running loss : 13.642157
# running loss : 13.525429
# running loss : 13.582739
# running loss : 13.455612
# running loss : 13.564050
# running loss : 13.558673
# running loss : 13.527821
# running loss : 13.555658
# running loss : 13.562625
# running loss : 13.520881
# running loss : 13.552354
# running loss : 13.411335
# running loss : 13.413793
# running loss : 13.417871
# running loss : 13.489926
# running loss : 13.516429
# running loss : 13.434743
# running loss : 13.435544
# running loss : 13.407749
# running loss : 13.317851
# running loss : 13.317589
# running loss : 13.394872
# running loss : 13.480879
# running loss : 13.412921
# running loss : 13.469276
# running loss : 13.376238
# running loss : 13.253544
# running loss : 13.287036
# running loss : 13.304591
# running loss : 13.234347
# running loss : 13.251539
# running loss : 13.209412
# running loss : 13.234113
# running loss : 13.215656
# running loss : 13.258262
# running loss : 13.272750
# running loss : 13.200421
# running loss : 13.163514
# running loss : 13.321822
# running loss : 13.339384
# running loss : 13.246353
# running loss : 13.129528
# running loss : 13.234130
# running loss : 13.249416
# running loss : 13.144196
# running loss : 13.292755
# running loss : 13.203940
# running loss : 13.129746
# running loss : 13.179255
# running loss : 13.144566
# running loss : 13.104362
# running loss : 13.082541
# running loss : 13.024972
# running loss : 13.066373
# running loss : 13.033634
# running loss : 13.033470
# running loss : 13.102671
# running loss : 12.959844
# running loss : 13.041441
# running loss : 13.102824
# running loss : 13.017584
# running loss : 13.136466
# running loss : 13.056961
# running loss : 13.111532
# running loss : 13.022362
# running loss : 12.975826
# running loss : 12.993497
# running loss : 12.918414
# running loss : 12.857503
# running loss : 12.872191
# running loss : 12.881189
# running loss : 12.911607
# running loss : 12.871985
# running loss : 12.862750
# running loss : 12.866624
# running loss : 12.855333
# running loss : 12.786963
# running loss : 12.947297
# running loss : 12.899146
# running loss : 12.838678
# running loss : 12.951015
# running loss : 12.809728
# running loss : 12.735172
# running loss : 12.843064
# running loss : 12.773866
# running loss : 12.764045
# running loss : 12.864987
# running loss : 12.820436
# running loss : 12.839869
# running loss : 12.772665
# running loss : 12.770136
# running loss : 12.756513
# running loss : 12.732888
# running loss : 12.786817
# running loss : 12.744321
# running loss : 12.818558
# running loss : 12.818160
# running loss : 12.781171
# running loss : 12.666469
# running loss : 12.764527
# running loss : 12.776802
# running loss : 12.820694
# running loss : 12.633675
# running loss : 12.659784
# running loss : 12.618545
# running loss : 12.655834
# running loss : 12.634290
# running loss : 12.575435
# running loss : 12.590630
# running loss : 12.605142
# running loss : 12.636318
# running loss : 12.610629
# running loss : 12.623952
# running loss : 12.581677
# running loss : 12.564756
# running loss : 12.544172
# running loss : 12.571534
# running loss : 12.487542
# running loss : 12.461975
# running loss : 12.490254
# running loss : 12.553710
# running loss : 12.499369
# running loss : 12.491940
# running loss : 12.437985
# running loss : 12.470967
# running loss : 12.485253
# running loss : 12.437006
# running loss : 12.481684
# running loss : 12.483324
# running loss : 12.441011
# running loss : 12.402914
# running loss : 12.443073
# running loss : 12.406533
# running loss : 12.511353
# running loss : 12.418826
# running loss : 12.410747
# running loss : 12.464901
# running loss : 12.413708
# running loss : 12.321311
# running loss : 12.385566
# running loss : 12.356772
# running loss : 12.355534
# running loss : 12.385813
# running loss : 12.383318
# running loss : 12.448296
# running loss : 12.364188
# running loss : 12.435555
# running loss : 12.298779
# running loss : 12.305594
# running loss : 12.330383
# running loss : 12.349492
# running loss : 12.309087
# running loss : 12.435199
# running loss : 12.278616
# running loss : 12.237631
# running loss : 12.341893
# running loss : 12.429918
# running loss : 12.308986
# running loss : 12.235612
# running loss : 12.240595
# running loss : 12.214866
# running loss : 12.193111
# running loss : 12.162065
# running loss : 12.141780
# running loss : 12.271315
# running loss : 12.160042
# running loss : 12.263232
# running loss : 12.271984
# running loss : 12.203042
# running loss : 12.184750
# running loss : 12.094167
# running loss : 12.035880
# running loss : 12.118570
# running loss : 12.127700
# running loss : 12.087809
# running loss : 12.158526
# running loss : 12.122711
# running loss : 12.011842
# running loss : 12.050504
# running loss : 12.072284
# running loss : 12.012391
# running loss : 12.099096
# running loss : 11.993446
# running loss : 11.970013
# running loss : 12.067079
# running loss : 12.049941
# running loss : 11.961940
# running loss : 11.990770
# running loss : 11.984673
# running loss : 11.986029
# running loss : 12.039777
# running loss : 12.091071
# running loss : 12.009024
# running loss : 11.938032
# running loss : 12.040488
# running loss : 12.079858
# running loss : 12.023468
# running loss : 12.042532
# running loss : 12.002001
# running loss : 11.999985
# running loss : 12.138184
# running loss : 12.062653
# running loss : 12.023052
# running loss : 11.956776
# running loss : 12.038030
# running loss : 11.997981
# running loss : 11.960747
# running loss : 11.872513
# running loss : 11.970199
# running loss : 11.906580
# running loss : 11.921491
# running loss : 12.038803
# running loss : 11.938084
# running loss : 11.873166
# running loss : 11.935540
# running loss : 11.883658
# running loss : 11.827663
# running loss : 11.863164
# running loss : 11.940370
# running loss : 11.864920
# running loss : 11.917147
# running loss : 11.810067
# running loss : 11.776792
# running loss : 11.851916
# running loss : 11.864684
# running loss : 11.843580
# running loss : 11.778297
# running loss : 11.794397
# running loss : 11.769404
# running loss : 11.829731
# running loss : 13.503414
# running loss : 30.698190
# running loss : 16.815714
# running loss : 14.370366
# running loss : 13.482320
# running loss : 13.021021
# running loss : 12.872548
# running loss : 12.639758
# running loss : 12.548047
# running loss : 12.434420
# running loss : 12.318442
# running loss : 12.199697
# running loss : 12.126725
# running loss : 12.119236
# running loss : 12.059807
# running loss : 12.058167
# running loss : 11.983663
# running loss : 12.037616
# running loss : 12.018967
# running loss : 11.935610
# running loss : 11.906962
# running loss : 11.823874
# running loss : 11.804163
# running loss : 11.849326
# running loss : 11.875946
# running loss : 11.846465
# running loss : 11.775793
# running loss : 11.756288
# running loss : 11.806653
# running loss : 11.755202
# running loss : 11.764454
# running loss : 11.805947
# running loss : 11.745988
# running loss : 11.772055
# running loss : 11.701855
# running loss : 11.701529
# running loss : 11.714770
# running loss : 11.682140
# running loss : 11.780645
# running loss : 11.730811
# running loss : 11.655572
# running loss : 11.728101
# running loss : 11.694462
# running loss : 11.708043
# running loss : 11.684786
# running loss : 11.649063
# running loss : 11.670302
# running loss : 11.656271
# running loss : 11.673393
# running loss : 11.717966
# running loss : 11.647306
# running loss : 11.661029
# running loss : 11.631475
# running loss : 11.661360
# running loss : 11.598952
# running loss : 11.728464
# running loss : 11.690376
# running loss : 11.610852
# running loss : 11.587631
# running loss : 11.698608
# running loss : 11.704031
# running loss : 11.631045
# running loss : 11.553114
# running loss : 11.633433
# running loss : 11.677388
# running loss : 11.610288
# running loss : 11.629537
# running loss : 11.669165
# ...
# running loss : 5.427497
# running loss : 5.411063
# running loss : 5.459054
# running loss : 5.433950
# running loss : 5.424242
# running loss : 5.409686
# running loss : 5.421577
# running loss : 5.433759
# running loss : 5.414460
# running loss : 5.456600
# running loss : 5.443442
# running loss : 5.436958
# running loss : 5.423955
# running loss : 5.487646
# running loss : 5.481715
# running loss : 5.480077
# running loss : 5.442957
# running loss : 5.405048
# running loss : 5.422090
# running loss : 5.464820
# running loss : 5.415202
# running loss : 5.436975
# running loss : 5.446964
# running loss : 5.466633
# running loss : 5.468991
# running loss : 5.404860
# running loss : 5.377388
# running loss : 5.411260
# running loss : 5.401489
# running loss : 5.387577
# running loss : 5.376673
# running loss : 5.426227
# running loss : 5.356164
# running loss : 5.386138
# running loss : 5.403760
# running loss : 5.424180
# running loss : 5.370523
# running loss : 5.415367
# running loss : 5.383440
# running loss : 5.374113
# running loss : 5.433587
# running loss : 5.404083
# running loss : 5.403363
# running loss : 5.363357
# running loss : 5.418064
# running loss : 5.397363
# running loss : 5.412748
# running loss : 5.434639
# running loss : 5.425665
# running loss : 5.412195
# running loss : 5.428623
# running loss : 5.416817
# running loss : 5.390007
# running loss : 5.359011
# running loss : 5.366867
# running loss : 5.385841
# running loss : 5.362267
# running loss : 5.375114
# running loss : 5.356240
# running loss : 5.386206
# running loss : 5.348407
# running loss : 5.409553
# running loss : 5.373686
# running loss : 5.442165
# running loss : 5.373781
# running loss : 5.350006
# running loss : 5.360820
# running loss : 5.368178
# running loss : 5.349503
# running loss : 5.387812
# running loss : 5.447565
# running loss : 5.367471
# running loss : 5.357792
# running loss : 5.333951
# running loss : 5.350093
# running loss : 5.323155
# running loss : 5.319343
# running loss : 5.323443
# running loss : 5.359479
# running loss : 5.362839
# running loss : 5.334350
# running loss : 5.336825
# running loss : 5.355327
# running loss : 5.354261
# running loss : 5.377793
# running loss : 5.416482
# running loss : 5.371614
# running loss : 5.360301
# running loss : 5.354121
# running loss : 5.309466
# running loss : 5.338929
# running loss : 5.334578
# running loss : 5.347648
# running loss : 5.325330
# running loss : 5.315777
# running loss : 5.329748
# running loss : 5.340629
# running loss : 5.327742
# running loss : 5.333268
# running loss : 5.331405
# running loss : 5.306829
# running loss : 5.284240
# running loss : 5.315764
# running loss : 5.382468
# running loss : 5.444591
# running loss : 5.396701
# running loss : 5.342714
# running loss : 5.309541
# running loss : 5.334280
# running loss : 5.377562
# running loss : 5.398395
# running loss : 5.350692
# running loss : 5.339949
# running loss : 5.324073
# running loss : 5.271782
# running loss : 5.333650
# running loss : 5.333766
# running loss : 5.347074
# running loss : 5.336159
# running loss : 5.306817
# running loss : 5.294636
# running loss : 5.331419
# running loss : 5.272901
# running loss : 5.334382
# running loss : 5.264319
# running loss : 5.296981
# running loss : 5.270611
# running loss : 5.273741
# running loss : 5.345996
# running loss : 5.329032
# running loss : 5.287406
# running loss : 5.265846
# running loss : 5.264498
# running loss : 5.265676
# running loss : 5.273711
# running loss : 5.243622
# running loss : 5.282854
# running loss : 5.262169
# running loss : 5.264071
# running loss : 5.319442
# running loss : 5.309190
# running loss : 5.281112
# running loss : 5.262550
# running loss : 5.256227
# running loss : 5.265691
# running loss : 5.283416
# running loss : 5.244199
# running loss : 5.265647
# running loss : 5.320804
# running loss : 5.292270
# running loss : 5.353170
# running loss : 5.253208
# running loss : 5.291597
# running loss : 5.304895
# running loss : 5.312948
# running loss : 5.240364
# running loss : 5.246931
# running loss : 5.266504
# running loss : 5.233531
# running loss : 5.250002
# running loss : 5.235696
# running loss : 5.257589
# running loss : 5.244234
# running loss : 5.261612
# running loss : 5.266313
# running loss : 5.260119
# running loss : 5.260910
# running loss : 5.256144
# running loss : 5.286486
# running loss : 5.277307
# running loss : 5.276240
# running loss : 5.265760
# running loss : 5.277976
# running loss : 5.254497
# running loss : 5.254305
# running loss : 5.237738
# running loss : 5.238522
# running loss : 5.267129
# running loss : 9.663978
# running loss : 10.805665
# running loss : 6.874380
# running loss : 6.040024
# running loss : 5.768105
# running loss : 5.663554
# running loss : 5.603643
# running loss : 5.542971
# running loss : 5.482696
# running loss : 5.421369
# running loss : 5.410366
# running loss : 5.415824
# running loss : 5.364275
# running loss : 5.335859
# running loss : 5.362518
# running loss : 5.345926
# running loss : 5.328079
# running loss : 5.351087
# running loss : 5.348398
# running loss : 5.327576
# running loss : 5.307396
# running loss : 5.299296
# running loss : 5.283098
# running loss : 5.268640
# running loss : 5.271739
# running loss : 5.271271
# running loss : 5.245439
# running loss : 5.273594
# running loss : 5.264133
# running loss : 5.244206
# running loss : 5.256521
# running loss : 5.274750
# running loss : 5.256047
# running loss : 5.254027
# running loss : 5.256596
# running loss : 5.274636
# running loss : 5.264444
# running loss : 5.237563
# running loss : 5.244299
# running loss : 5.223850
# running loss : 5.241082
# running loss : 5.222957
# running loss : 5.261871
# running loss : 5.215630
# running loss : 5.216880
# running loss : 5.231321
# running loss : 5.205962
# running loss : 5.236456
# running loss : 5.225548
# running loss : 5.226420
# running loss : 5.206136
# running loss : 5.223997
# running loss : 5.237466
# running loss : 5.230483
# running loss : 5.223621
# running loss : 5.215819
# running loss : 5.240807
# running loss : 5.220412
# running loss : 5.215125
# running loss : 5.224768
# running loss : 5.224004
# running loss : 5.199979
# running loss : 5.207985
# running loss : 5.224323
# running loss : 5.259604
# running loss : 5.247851
# running loss : 5.245441
# running loss : 5.227004
# running loss : 5.239192
# running loss : 5.187877
# running loss : 5.227364
# running loss : 5.222454
# running loss : 5.245688
# running loss : 5.219095
# running loss : 5.191490
# running loss : 5.249736
# running loss : 5.205045
# running loss : 5.197188
# running loss : 5.198856
# running loss : 5.202127
# running loss : 5.228442
# running loss : 5.210941
# running loss : 5.275284
# running loss : 5.232158
# running loss : 5.222111
# running loss : 5.206115
# running loss : 5.185510
# running loss : 5.191715
# running loss : 5.199016
# running loss : 5.210486
# running loss : 5.199419
# running loss : 5.164453
# running loss : 5.193787
# running loss : 5.221804
# running loss : 5.201163
# running loss : 5.215954
# running loss : 5.171289
# running loss : 5.184566
# running loss : 5.228948
# running loss : 5.224145
# running loss : 5.195859
# running loss : 5.207135
# running loss : 5.206853
# running loss : 5.223086
# running loss : 5.225071
# running loss : 5.206697
# running loss : 5.221563
# running loss : 5.194340
# running loss : 5.186508
# running loss : 5.162005
# running loss : 5.186001
# running loss : 5.184527
# running loss : 5.185606
# running loss : 5.214489
# running loss : 5.228674
# running loss : 5.189839
# running loss : 5.204535
# running loss : 5.178648
# running loss : 5.211454
# running loss : 5.196767
# running loss : 5.166268
# running loss : 5.172326
# running loss : 5.182912
# running loss : 5.197302
# running loss : 5.203906
# running loss : 5.185354
# running loss : 5.170841
# running loss : 5.206814
# running loss : 5.211181
# running loss : 5.170340
# running loss : 5.188826
# running loss : 5.173997
# running loss : 5.215630
# running loss : 5.191896
# running loss : 5.203823
# running loss : 5.198365
# running loss : 5.178617
# running loss : 5.175686
# running loss : 5.172721
# running loss : 5.145390
# running loss : 5.144730
# running loss : 5.204609
# running loss : 5.186697
# running loss : 5.203530
# running loss : 5.162290
# running loss : 5.170933
# running loss : 5.151480
# running loss : 5.166758
# running loss : 5.218796
# running loss : 5.308982
# running loss : 5.223172
# running loss : 5.209206
# running loss : 5.224453
# running loss : 5.183301
# running loss : 5.173245
# running loss : 5.161164
# running loss : 5.140173
# running loss : 5.157499
# running loss : 5.170969
# running loss : 5.203712
# running loss : 5.156584
# running loss : 5.163491
# running loss : 5.169846
# running loss : 5.121105
# running loss : 5.157367
# running loss : 5.132322
# running loss : 5.144718
# running loss : 5.141962
# running loss : 5.148350
# running loss : 5.147233
# running loss : 5.156611
# running loss : 5.216454
# running loss : 5.155630
# running loss : 5.139795
# running loss : 5.145619
# running loss : 5.215021
# running loss : 5.241939
# running loss : 5.178581
# running loss : 5.147499
# running loss : 5.140472
# running loss : 5.156233
# running loss : 5.216829
# running loss : 5.225939
# running loss : 5.179209
# running loss : 5.163388
# running loss : 5.127958
# running loss : 5.110916
# running loss : 5.218545
# running loss : 5.188317
# running loss : 5.167303
# running loss : 5.130807
# running loss : 5.146847
# running loss : 5.155727
# running loss : 5.126216
# running loss : 5.146279
# running loss : 5.109572
# running loss : 5.157887
# running loss : 5.150844
# running loss : 5.127973
# running loss : 5.134012
# running loss : 5.143635
# running loss : 5.126012
# running loss : 5.144150
# running loss : 5.140644
# running loss : 5.139260
# running loss : 5.183474
# running loss : 5.154106
# running loss : 5.129683
# running loss : 5.112443
# running loss : 5.180097
# running loss : 5.172344
# running loss : 5.127583
# running loss : 5.125332
# running loss : 5.133718
# running loss : 5.143137
# running loss : 5.084488
# running loss : 5.092268
# running loss : 5.102384
# running loss : 5.110799
# running loss : 5.115924
# running loss : 5.135137
# running loss : 5.129239
# running loss : 5.109035
# running loss : 5.136796
# running loss : 5.126027
# running loss : 5.115073
# running loss : 5.096401
# running loss : 5.096086
# running loss : 5.077908
# running loss : 5.093401
# running loss : 5.124392
# running loss : 5.071949
# running loss : 5.116935
# running loss : 5.097157
# running loss : 5.096590
# running loss : 5.084566
# running loss : 5.111170
# running loss : 5.105801
# running loss : 5.091526
# running loss : 5.086776
# running loss : 5.100041
# running loss : 5.052103
# running loss : 5.112156
# running loss : 5.085009
# running loss : 5.101944
# running loss : 5.090347
# running loss : 5.110452
# running loss : 5.366234
# running loss : 5.200693
# running loss : 5.108163
# running loss : 5.088122
# running loss : 5.103443
# running loss : 5.108208
# running loss : 5.114319
# running loss : 5.096211
# running loss : 5.080226
# running loss : 5.094646
# running loss : 5.082574
# running loss : 5.068665
# running loss : 5.074689
# running loss : 5.071859
# running loss : 5.074527
# running loss : 5.081584
# running loss : 5.102369
# running loss : 5.070325
# running loss : 5.076219
# running loss : 5.102573
# running loss : 5.069024
# running loss : 5.083781
# running loss : 5.060956
# running loss : 5.063673
# running loss : 5.105855
# running loss : 5.078484
# running loss : 5.073340
# running loss : 5.061121
# running loss : 5.059535
# running loss : 5.066343
# running loss : 5.067757
# running loss : 5.048947
# running loss : 5.043000
# running loss : 5.060103
# running loss : 5.043119
# running loss : 5.086378
# running loss : 5.075317
# running loss : 5.047248
# running loss : 5.050675
# running loss : 5.072107
# running loss : 5.054084
# running loss : 5.103760
# running loss : 5.075175
# running loss : 5.057457
# running loss : 5.074662
# running loss : 5.057624
# running loss : 5.061891
# running loss : 5.089377
# running loss : 5.055343
# running loss : 5.056545
# running loss : 5.089908
# running loss : 5.044090
# running loss : 5.003544
# running loss : 5.062587
# running loss : 5.049423
# running loss : 5.018762
# running loss : 5.026092
# running loss : 5.015039
# running loss : 5.024656
# running loss : 5.015787
# running loss : 5.023278
# running loss : 5.030725
# running loss : 5.073892
# running loss : 5.058978
# running loss : 5.458254
# running loss : 5.201210
# running loss : 5.086315
# running loss : 5.052933
# running loss : 5.042770
# running loss : 5.010881
# running loss : 5.014750
# running loss : 4.992999
# running loss : 5.042280
# running loss : 5.035976
# running loss : 5.010280
# running loss : 5.007648
# running loss : 5.011523
# running loss : 4.996565
# running loss : 5.018859
# running loss : 5.017732
# running loss : 5.020946
# running loss : 5.032265
# running loss : 5.015803
# running loss : 5.037849
# running loss : 4.999506
# running loss : 5.012924
# running loss : 5.026690
# running loss : 5.002260
# running loss : 5.026030
# running loss : 5.009357
# running loss : 5.010852
# running loss : 5.004343
# running loss : 4.997797
# running loss : 5.012246
# running loss : 5.014169
# running loss : 5.031860
# running loss : 5.059131
# running loss : 5.033042
# running loss : 5.071550
# running loss : 5.020227
# running loss : 5.020525
# running loss : 5.003608
# running loss : 5.045702
# running loss : 5.030232
# running loss : 5.002446
# running loss : 5.034531
# running loss : 5.008673
# running loss : 4.997295
# running loss : 5.019320
# running loss : 5.010810
# running loss : 4.992091
# running loss : 5.030977
# running loss : 5.105605
# running loss : 5.047355
# running loss : 5.001720
# running loss : 5.006496
# running loss : 4.994189
# running loss : 4.995852
# running loss : 5.000080
# running loss : 4.966914
# running loss : 4.979042
# running loss : 5.006172
# running loss : 4.989705
# running loss : 4.957097
# running loss : 4.968260
# running loss : 4.966415
# running loss : 5.016908
# running loss : 5.016461
# running loss : 4.990985
# running loss : 5.088551
# running loss : 5.052554
# running loss : 4.991149
# running loss : 4.938311
# running loss : 4.978999
# running loss : 4.961376
# running loss : 4.994702
# running loss : 4.985926
# running loss : 5.006453
# running loss : 4.987161
# running loss : 4.978015
# running loss : 5.030627
# running loss : 5.004504
# running loss : 4.987577
# running loss : 4.965315
# running loss : 4.948328
# running loss : 4.990996
# running loss : 5.019857
# running loss : 4.998227
# running loss : 5.017184
# running loss : 4.995095
# running loss : 4.978794
# running loss : 4.972224
# running loss : 4.950102
# running loss : 4.957143
# running loss : 4.947934
# running loss : 4.943686
# running loss : 4.965447
# running loss : 4.968078
# running loss : 4.935648
# running loss : 4.987308
# running loss : 4.963714
# running loss : 5.074531
# running loss : 4.998753
# running loss : 4.951953
# running loss : 4.973372
# running loss : 4.975645
# running loss : 5.003257
# running loss : 4.980279
# running loss : 5.005201
# running loss : 4.992523
# running loss : 4.951909
# running loss : 4.953756
# running loss : 4.959982
# running loss : 4.944219
# running loss : 4.976591
# running loss : 5.013694
# running loss : 4.963918
# running loss : 4.928940
# running loss : 4.955881
# running loss : 4.988876
# running loss : 4.949667
# running loss : 5.003318
# running loss : 4.979382
# running loss : 4.949640
# running loss : 4.935441
# running loss : 4.925590
# running loss : 4.932205
# running loss : 4.927427
# running loss : 4.923905
# running loss : 4.938759
# running loss : 4.957927
# running loss : 4.955086
# running loss : 4.929166
# running loss : 4.928696
# running loss : 4.932541
# running loss : 4.933171
# running loss : 4.970680
# running loss : 14.350937
# running loss : 18.923295
# running loss : 9.202816
# running loss : 7.086665
# running loss : 6.368355
# running loss : 6.024366
# running loss : 5.863812
# running loss : 5.685408
# running loss : 5.615607
# running loss : 5.558140
# running loss : 5.487729
# running loss : 5.477631
# running loss : 5.460902
# running loss : 5.352131
# running loss : 5.320736
# running loss : 5.302616
# running loss : 5.275428
# running loss : 5.259619
# running loss : 5.224458
# running loss : 5.225148
# running loss : 5.216823
# running loss : 5.186094
# running loss : 5.186111
# running loss : 5.214086
# running loss : 5.168967
# running loss : 5.127483
# running loss : 5.159858
# running loss : 5.156936
# running loss : 5.138620
# running loss : 5.125373
# running loss : 5.108466
# running loss : 5.095903
# running loss : 5.108440
# running loss : 5.140157
# running loss : 5.099578
# running loss : 5.087403
# running loss : 5.101167
# running loss : 5.107706
# running loss : 5.061659
# running loss : 5.069372
# running loss : 5.043243
# running loss : 5.078125
# running loss : 5.062963
# running loss : 5.066297

# %%
# save model parameters
torch.save(model.state_dict(), './model_parameters/mean_bit_ppx/lossy_comp_params_with_rate_beta01_incremental.pth')

# %%
model = LossyCompAutoencoder()
model.load_state_dict(torch.load('./model_parameters/mean_bit_ppx/lossy_comp_params_with_rate_beta005_incremental.pth'))
model.eval()
model.to(device)

# transfert du model au gpu
model.to(device)

# general update of coefficients    
    #define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
    # define loss function
distortion = nn.MSELoss().cuda()
    #Epochs
n_epochs = 600
beta = 0.05

    # Training the network
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
          
    #Training
    for i_batch, data in enumerate(dataloader):
        batch_images = data.to(device).float()
        [decoded_images, x_quantized] = model(batch_images, 1, True)
        optimizer.zero_grad()
        loss_dist = distortion(decoded_images, batch_images)
        loss_bit = mean_bit_per_px(x_quantized, model.phi, model.var)
        loss = beta * loss_dist + loss_bit
        #print(loss)
            
        loss.backward()
        #print("conv1.weights grad: ", params[0].grad)
        #print(model.conv1.bias.grad)
        #print(model.conv1.weight.grad)
        optimizer.step()
        running_loss += loss.item()

    running_loss = running_loss/len(dataloader)
    print('running loss : {:.06f}'.format(running_loss), )
# Out:
# running loss : 3.608064
# running loss : 3.595169
# running loss : 3.577811
# running loss : 3.565715
# running loss : 3.556746
# running loss : 3.551123
# running loss : 3.508999
# running loss : 3.493525
# running loss : 3.477084
# running loss : 3.480756
# running loss : 3.484556
# running loss : 3.470062
# running loss : 3.494472
# running loss : 3.480626
# running loss : 3.473711
# running loss : 3.469631
# running loss : 3.474533
# running loss : 3.457910
# running loss : 3.457608
# running loss : 3.463701
# running loss : 3.462066
# running loss : 3.455566
# running loss : 3.454701
# running loss : 3.452302
# running loss : 3.461875
# running loss : 3.440914
# running loss : 3.449169
# running loss : 3.461837
# running loss : 3.453840
# running loss : 3.431719
# running loss : 3.450540
# running loss : 3.444341
# running loss : 3.436081
# running loss : 3.438335
# running loss : 3.434041
# running loss : 3.437564
# running loss : 3.452365
# running loss : 3.440963
# running loss : 3.444202
# running loss : 3.428230
# running loss : 3.436434
# running loss : 3.443303
# running loss : 3.439506
# running loss : 3.427543
# running loss : 3.431219
# running loss : 3.448644
# running loss : 3.422745
# running loss : 3.433221
# running loss : 3.450936
# running loss : 3.433569
# running loss : 3.442692
# running loss : 3.429689
# running loss : 3.430512
# running loss : 3.426101
# running loss : 3.430047
# running loss : 3.432502
# running loss : 3.439135
# running loss : 3.429702
# running loss : 3.420823
# running loss : 3.431744
# running loss : 3.428611
# running loss : 3.433411
# running loss : 3.418620
# running loss : 3.420307
# running loss : 3.428004
# running loss : 3.420471
# running loss : 3.434505
# running loss : 3.439297
# running loss : 3.418552
# running loss : 3.423885
# running loss : 3.438213
# running loss : 3.421547
# running loss : 3.447951
# running loss : 3.426076
# running loss : 3.431946
# running loss : 3.421086
# running loss : 3.422254
# running loss : 3.434877
# running loss : 3.446865
# running loss : 3.416438
# running loss : 3.411806
# running loss : 3.418630
# running loss : 3.406292
# running loss : 3.428759
# running loss : 3.416834
# running loss : 3.421250
# running loss : 3.428968
# running loss : 3.419444
# running loss : 3.411746
# running loss : 3.431971
# running loss : 3.417159
# running loss : 3.417692
# running loss : 3.423909
# running loss : 3.426233
# running loss : 3.416708
# running loss : 3.409153
# running loss : 3.410394
# running loss : 3.412747
# running loss : 3.416086
# running loss : 3.417805
# running loss : 3.416933
# running loss : 3.418952
# running loss : 3.411268
# running loss : 3.418695
# running loss : 3.415554
# running loss : 3.407512
# running loss : 3.418305
# running loss : 3.417855
# running loss : 3.415935
# running loss : 3.404594
# running loss : 3.407119
# running loss : 3.408349
# running loss : 3.416635
# running loss : 3.411231
# running loss : 3.417814
# running loss : 3.407900
# running loss : 3.417695
# running loss : 3.410966
# running loss : 3.411711
# running loss : 3.405085
# running loss : 3.405621
# running loss : 3.403342
# running loss : 3.418212
# running loss : 3.418930
# running loss : 3.400970
# running loss : 3.425234
# running loss : 3.405430
# running loss : 3.414903
# running loss : 3.397287
# running loss : 3.409523
# running loss : 3.405635
# running loss : 3.404655
# running loss : 3.423258
# running loss : 3.418636
# running loss : 3.403312
# running loss : 3.402433
# running loss : 3.408503
# running loss : 3.411906
# running loss : 3.396481
# running loss : 3.413033
# running loss : 3.401829
# running loss : 3.399232
# running loss : 3.408765
# running loss : 3.413618
# running loss : 3.401739
# running loss : 3.393259
# running loss : 3.409699
# running loss : 3.405459
# running loss : 3.402204
# running loss : 3.401693
# running loss : 3.415576
# running loss : 3.393906
# running loss : 3.410737
# running loss : 3.409878
# running loss : 3.406994
# running loss : 3.402496
# running loss : 3.398531
# running loss : 3.406441
# running loss : 3.405680
# running loss : 3.404914
# running loss : 3.403816
# running loss : 3.415388
# running loss : 3.404948
# running loss : 3.404524
# running loss : 3.408215
# running loss : 3.397031
# running loss : 3.391528
# running loss : 3.394352
# running loss : 3.388567
# running loss : 3.402069
# running loss : 3.407573
# running loss : 3.401749
# running loss : 3.397013
# running loss : 3.380713
# running loss : 3.416723
# running loss : 3.395859
# running loss : 3.401124
# running loss : 3.395975
# running loss : 3.401524
# running loss : 3.397739
# running loss : 3.398284
# running loss : 3.397540
# running loss : 3.390580
# running loss : 3.395998
# running loss : 3.406830
# running loss : 3.400811
# running loss : 3.399028
# running loss : 3.391226
# running loss : 3.391155
# running loss : 3.403034
# running loss : 3.386472
# running loss : 3.391889
# running loss : 3.410040
# running loss : 3.396352
# running loss : 3.393411
# running loss : 3.392596
# running loss : 3.398096
# running loss : 3.419137
# running loss : 3.386801
# running loss : 3.393241
# running loss : 3.405118
# running loss : 3.401632
# running loss : 3.391891
# running loss : 3.387445
# running loss : 3.391386
# running loss : 3.387829
# running loss : 3.392365
# running loss : 3.400446
# running loss : 3.372927
# running loss : 3.404625
# running loss : 3.388007
# running loss : 3.395960
# running loss : 3.412260
# running loss : 3.404648
# running loss : 3.398713
# running loss : 3.397545
# running loss : 3.384526
# running loss : 3.385824
# running loss : 3.383352
# running loss : 3.393349
# running loss : 3.387968
# running loss : 3.382640
# running loss : 3.380239
# running loss : 3.384858
# running loss : 3.374717
# running loss : 3.409348
# running loss : 3.401197
# running loss : 3.389739
# running loss : 3.388080
# running loss : 3.392952
# running loss : 3.398019
# running loss : 3.404827
# running loss : 3.382396
# running loss : 3.380256
# running loss : 3.378441
# running loss : 3.373515
# running loss : 3.379723
# running loss : 3.386646
# running loss : 3.381797
# running loss : 3.386999
# running loss : 3.384829
# running loss : 3.369290
# running loss : 3.385859
# running loss : 3.388848
# running loss : 3.379311
# running loss : 3.373440
# running loss : 3.392347
# running loss : 3.382227
# running loss : 3.367000
# running loss : 3.378753
# running loss : 3.377418
# running loss : 3.396743
# running loss : 3.378321
# running loss : 3.384744
# running loss : 3.383695
# running loss : 3.388330
# running loss : 3.387338
# running loss : 3.391584
# running loss : 3.387342
# running loss : 3.375059
# running loss : 3.383311
# running loss : 3.387176
# running loss : 3.387320
# running loss : 3.379785
# running loss : 3.388733
# running loss : 3.375195
# running loss : 3.377278
# running loss : 3.381037
# running loss : 3.378940
# running loss : 3.377081
# running loss : 3.379055
# running loss : 3.384051
# running loss : 3.372547
# running loss : 3.359944
# running loss : 3.389396
# running loss : 3.377261
# running loss : 3.375371
# running loss : 3.374853
# running loss : 3.375038
# running loss : 3.371395
# running loss : 3.380230
# running loss : 3.374034
# running loss : 3.381019
# running loss : 3.379792
# running loss : 3.379630
# running loss : 3.375633
# running loss : 3.380527
# running loss : 3.374819
# running loss : 3.374065
# running loss : 3.376456
# running loss : 3.372698
# running loss : 3.376132
# running loss : 3.382859
# running loss : 3.361300
# running loss : 3.369921
# running loss : 3.382626
# running loss : 3.365912
# running loss : 3.374336
# running loss : 3.370419
# running loss : 3.375273
# running loss : 3.381060
# running loss : 3.368045
# running loss : 3.384040
# running loss : 3.379451
# running loss : 3.377281
# running loss : 3.376848
# running loss : 3.379195
# running loss : 3.377004
# running loss : 3.366520
# running loss : 3.369531
# running loss : 3.359590
# running loss : 3.379268
# running loss : 3.370147
# running loss : 3.380034
# running loss : 3.371945
# running loss : 3.378165
# running loss : 3.371639
# running loss : 3.365722
# running loss : 3.378202
# running loss : 3.383245
# running loss : 3.372720
# running loss : 3.357288
# running loss : 3.363374
# running loss : 3.380017
# running loss : 3.369098
# running loss : 3.370510
# running loss : 3.373468
# running loss : 3.365971
# running loss : 3.371524
# running loss : 3.371745
# running loss : 3.368102
# running loss : 3.368026
# running loss : 3.382858
# running loss : 3.381158
# running loss : 3.372145
# running loss : 3.366211
# running loss : 3.379800
# running loss : 3.365970
# running loss : 3.388563
# running loss : 3.364501
# running loss : 3.361850
# running loss : 3.367398
# running loss : 3.370314
# running loss : 3.377068
# running loss : 3.380413
# running loss : 3.369731
# running loss : 3.372108
# running loss : 3.373563
# running loss : 3.365202
# running loss : 3.375456
# running loss : 3.366879
# running loss : 3.364543
# running loss : 3.367663
# running loss : 3.371529
# running loss : 3.359032
# running loss : 3.364099
# running loss : 3.354579
# running loss : 3.367204
# running loss : 3.370713
# running loss : 3.366639
# running loss : 3.360884
# running loss : 3.353266
# running loss : 3.368702
# running loss : 3.359209
# running loss : 3.361315
# running loss : 3.372081
# running loss : 3.363859
# running loss : 3.356524
# running loss : 3.360332
# running loss : 3.353770
# running loss : 3.355852
# running loss : 3.365560
# running loss : 3.375980
# running loss : 3.351310
# running loss : 3.372552
# running loss : 3.356415
# running loss : 3.355415
# running loss : 3.359442
# running loss : 3.354993
# running loss : 3.353920
# running loss : 3.357007
# running loss : 3.347224
# running loss : 3.360047
# running loss : 3.356805
# running loss : 3.377442
# running loss : 3.360175
# running loss : 3.349696
# running loss : 3.370999
# running loss : 3.359068
# running loss : 3.362040
# running loss : 3.358622
# running loss : 3.352350
# running loss : 3.358476
# running loss : 3.346589
# running loss : 3.363932
# running loss : 3.356358
# running loss : 3.360231
# running loss : 3.361587
# running loss : 3.361075
# running loss : 3.363794
# running loss : 3.346298
# running loss : 3.363001
# running loss : 3.358429
# running loss : 3.357310
# running loss : 3.356154
# running loss : 3.360374
# running loss : 3.370111
# running loss : 3.365619
# running loss : 3.345095
# running loss : 3.357239
# running loss : 3.355625
# running loss : 3.357598
# running loss : 3.357125
# running loss : 3.355613
# running loss : 3.355986
# running loss : 3.368297
# running loss : 3.357122
# running loss : 3.355062
# running loss : 3.353528
# running loss : 3.369331
# running loss : 3.354843
# running loss : 3.371120
# running loss : 3.358374
# running loss : 3.369029
# running loss : 3.351763
# running loss : 3.356055
# running loss : 3.356574
# running loss : 3.353526
# running loss : 3.346547
# running loss : 3.355653
# running loss : 3.344817
# running loss : 3.366189
# running loss : 3.357121
# running loss : 3.355565
# running loss : 3.360159
# running loss : 3.346670
# running loss : 3.349266
# running loss : 3.361551
# running loss : 3.345708
# running loss : 3.346406
# running loss : 3.364660
# running loss : 3.348421
# running loss : 3.366565
# running loss : 3.357172
# running loss : 3.360273
# running loss : 3.361555
# running loss : 3.360843
# running loss : 3.364662
# running loss : 3.356550
# running loss : 3.346063
# running loss : 3.359142
# running loss : 3.352849
# running loss : 3.369623
# running loss : 3.360721
# running loss : 3.351882
# running loss : 3.359600
# running loss : 3.355730
# running loss : 3.353931
# running loss : 3.343998
# running loss : 3.359867
# running loss : 3.354931
# running loss : 3.346388
# running loss : 3.347316
# running loss : 3.372011
# running loss : 3.353952
# running loss : 3.336895
# running loss : 3.341002
# running loss : 3.344184
# running loss : 3.348712
# running loss : 3.357724
# running loss : 3.342228
# running loss : 3.339523
# running loss : 3.336710
# running loss : 3.359275
# running loss : 3.352273
# running loss : 3.355335
# running loss : 3.346686
# running loss : 3.351825
# running loss : 3.343329
# running loss : 3.353132
# running loss : 3.348568
# running loss : 3.349761
# running loss : 3.346203
# running loss : 3.345687
# running loss : 3.346822
# running loss : 3.359846
# running loss : 3.344461
# running loss : 3.347605
# running loss : 3.360306
# running loss : 3.349484
# running loss : 3.361984
# running loss : 3.345488
# running loss : 3.352357
# running loss : 3.350787
# running loss : 3.363186
# running loss : 3.358625
# running loss : 3.349598
# running loss : 3.350769
# running loss : 3.356160
# running loss : 3.355965
# running loss : 3.347878
# running loss : 3.362272
# running loss : 3.334891
# running loss : 3.350863
# running loss : 3.352918
# running loss : 3.351285
# running loss : 3.340953
# running loss : 3.351766
# running loss : 3.346930
# running loss : 3.345097
# running loss : 3.359069
# running loss : 3.344168
# running loss : 3.351817
# running loss : 3.335797
# running loss : 3.336338
# running loss : 3.369614
# running loss : 3.348467
# running loss : 3.338204
# running loss : 3.348724
# running loss : 3.343201
# running loss : 3.337590
# running loss : 3.345075
# running loss : 3.343137
# running loss : 3.342944
# running loss : 3.333315
# running loss : 3.359916
# running loss : 3.343439
# running loss : 3.348096
# running loss : 3.348777
# running loss : 3.342959
# running loss : 3.355742
# running loss : 3.344180
# running loss : 3.339853
# running loss : 3.346722
# running loss : 3.344836
# running loss : 3.338519
# running loss : 3.354768
# running loss : 3.354207
# running loss : 3.354161
# running loss : 3.350398
# running loss : 3.335574
# running loss : 3.339052
# running loss : 3.325654
# running loss : 3.346711
# running loss : 3.345718
# running loss : 3.342996
# running loss : 3.345942
# running loss : 3.340115
# running loss : 3.351426
# running loss : 3.335214
# running loss : 3.348179
# running loss : 3.339886
# running loss : 3.341955
# running loss : 3.343468
# running loss : 3.342511
# running loss : 3.339258
# running loss : 3.352079
# running loss : 3.351474
# running loss : 3.349672
# running loss : 3.326735
# running loss : 3.331779
# running loss : 3.332662
# running loss : 3.344620
# running loss : 3.342527
# running loss : 3.338769
# running loss : 3.329740
# running loss : 3.334696
# running loss : 3.349396
# running loss : 3.331655
# running loss : 3.343893
# running loss : 3.334330
# running loss : 3.341412
# running loss : 3.341261
# running loss : 3.342445
# running loss : 3.355054
# running loss : 3.342108
# running loss : 3.342142
# running loss : 3.333979
# running loss : 3.329740
# running loss : 3.330187
# running loss : 3.320707
# running loss : 3.337103
# running loss : 3.341556
# running loss : 3.334582
# running loss : 3.343184
# running loss : 3.342706
# running loss : 3.340070
# running loss : 3.344993
# running loss : 3.349691
# running loss : 3.340178
# running loss : 3.336386
# running loss : 3.342811
# running loss : 3.344449
# running loss : 3.357886
# running loss : 3.348683
# running loss : 3.346992
# running loss : 3.331960
# running loss : 3.348751
# running loss : 3.343655
# running loss : 3.350069

# %%
# save model parameters
torch.save(model.state_dict(), './model_parameters/lossy_comp_params_with_rate_beta2_incremental_2.pth')

# %%
# test set 

model = LossyCompAutoencoder()
model.load_state_dict(torch.load('./model_parameters/mean_bit_ppx/lossy_comp_params_with_rate_beta00005_incremental.pth'))
model.eval()
model.to(device)



#test_dataset = ImageDataset(root_dir='./data/kodac/', transform=transforms.Compose([RandomCrop(128), ToTensor()]))
test_dataset = ImageDataset(root_dir='./data/kodac/', transform=ToTensor())
#fig, axes = plt.subplots(nrows=4, ncols=6, sharex=True, sharey=True, figsize=(8,8))
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        if test_image.size(2)<test_image.size(3):
            test_image = test_image.permute(0, 1, 3, 2)
        
        [reconstructed_image, vec_latent ]= model(test_image, 1, True)
        print("min vec latent : ", torch.min(vec_latent))
        print("max vec latent : ", torch.max(vec_latent)) 
        """
        ax = fig.add_subplot(4, 6, i+1, xticks=[], yticks=[])
        plt.imshow(np.squeeze(reconstructed_image.int().cpu()).permute(1, 2, 0))
        """

        # We can set the number of bins with the `bins` kwarg
        bins_list = [-6.5, -5.5, -4.5, -3.5, -2.5, -1.5, -0.5, 0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5]
        for k in range(96):
            # plot histograms
            fig, ax = plt.subplots(1, 1, sharey=True, tight_layout=True)
            ax.hist((vec_latent[:, k, :, :]).view(-1).cpu(), bins=bins_list)
            plt.savefig("D:\\autoencoder_data\\histograms\\rgb\\" + "img" + str(i)+ "hist" + str(k) + ".png")
# Out:
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(7., device='cuda:0')
# <ipython-input-17-2faacbdd681e>:32: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(1, 1, sharey=True, tight_layout=True)
# min vec latent :  tensor(-4., device='cuda:0')
# max vec latent :  tensor(7., device='cuda:0')
# min vec latent :  tensor(-4., device='cuda:0')
# max vec latent :  tensor(6., device='cuda:0')
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(7., device='cuda:0')
# min vec latent :  tensor(-6., device='cuda:0')
# max vec latent :  tensor(9., device='cuda:0')
# min vec latent :  tensor(-6., device='cuda:0')
# max vec latent :  tensor(6., device='cuda:0')
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(7., device='cuda:0')
# min vec latent :  tensor(-6., device='cuda:0')
# max vec latent :  tensor(9., device='cuda:0')
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(7., device='cuda:0')
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(8., device='cuda:0')
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(7., device='cuda:0')
# min vec latent :  tensor(-6., device='cuda:0')
# max vec latent :  tensor(5., device='cuda:0')
# min vec latent :  tensor(-6., device='cuda:0')
# max vec latent :  tensor(7., device='cuda:0')
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(8., device='cuda:0')
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(8., device='cuda:0')
# min vec latent :  tensor(-4., device='cuda:0')
# max vec latent :  tensor(6., device='cuda:0')
# min vec latent :  tensor(-4., device='cuda:0')
# max vec latent :  tensor(7., device='cuda:0')
# min vec latent :  tensor(-4., device='cuda:0')
# max vec latent :  tensor(9., device='cuda:0')
# min vec latent :  tensor(-6., device='cuda:0')
# max vec latent :  tensor(6., device='cuda:0')
# min vec latent :  tensor(-8., device='cuda:0')
# max vec latent :  tensor(5., device='cuda:0')
# min vec latent :  tensor(-6., device='cuda:0')
# max vec latent :  tensor(7., device='cuda:0')
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(7., device='cuda:0')
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(7., device='cuda:0')
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(7., device='cuda:0')
# Error in callback <function flush_figures at 0x0000029EAD960670> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2117
#    2118             try:
# -> 2119                 result = print_method(
#    2120                     filename,
#    2121                     dpi=dpi,
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     512         }
#     513
# --> 514         FigureCanvasAgg.draw(self)
#     515         if pil_kwargs is not None:
#     516             from PIL import Image
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     391              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     392               else nullcontext()):
# --> 393             self.figure.draw(self.renderer)
#     394             # A GUI class may be need to update a window using this draw, so
#     395             # don't forget to call the superclass.
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1733
#    1734             self.patch.draw(renderer)
# -> 1735             mimage._draw_list_compositing_images(
#    1736                 renderer, self, artists, self.suppressComposite)
#    1737
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1226
#    1227         ticks_to_draw = self._update_ticks()
# -> 1228         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1229                                                                 renderer)
#    1230
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1171     def _get_tick_bboxes(self, ticks, renderer):
#    1172         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1173         return ([tick.label1.get_window_extent(renderer)
#    1174                  for tick in ticks if tick.label1.get_visible()],
#    1175                 [tick.label2.get_window_extent(renderer)
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#    1171     def _get_tick_bboxes(self, ticks, renderer):
#    1172         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1173         return ([tick.label1.get_window_extent(renderer)
#    1174                  for tick in ticks if tick.label1.get_visible()],
#    1175                 [tick.label2.get_window_extent(renderer)
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     903             raise RuntimeError('Cannot get window extent w/o renderer')
#     904
# --> 905         bbox, info, descent = self._get_layout(self._renderer)
#     906         x, y = self.get_unitless_position()
#     907         x, y = self.get_transform().transform((x, y))
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     338
#     339         # get the rotation matrix
# --> 340         M = Affine2D().rotate_deg(self.get_rotation())
#     341
#     342         # now offset the individual text lines within the box
#
# ~\anaconda3\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1842         if matrix is None:
#    1843             # A bit faster than np.identity(3).
# -> 1844             matrix = IdentityTransform._mtx.copy()
#    1845         self._mtx = matrix
#    1846         self._invalid = 0
#
# KeyboardInterrupt:

# %%
# save results
from torchvision.utils import save_image

with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        reconstructed_image = np.squeeze(model(test_image).cpu())
        print(reconstructed_image.type())
        save_image(reconstructed_image, ".\\reconstructed_data\\kodac\\loss_distortion_and_mean_bit_ppx\\beta_01_incremental\\" + "img" + str(i)+".png", normalize=True)
# Out:
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor

# %%
# compute PSNR for each image of the test set and its reconstruction
# and write the latent vector in a file

def write_data(filepath , tensor_data):
    batch, channel, h, w = tensor_data.size()
    matrix = tensor_data.cpu().numpy()
    file = open(filepath, "w")
    for image in range(batch):
        np.savetxt(file, matrix[image, :, :, :].reshape(channel*h, w), fmt ='%.0f')

    file.close()
    
def compute_entropy(tensor_data):
    min_val = tensor_data.min()
    max_val = tensor_data.max()
    nb_bins = max_val - min_val + 1
    hist = torch.histc(tensor_data, bins=nb_bins.int(), min=min_val, max=max_val)
    hist_prob = hist/hist.sum()
    hist_prob[hist_prob == 0] = 1
    entropy = -(hist_prob*torch.log2(hist_prob)).sum()
    return entropy
    
        
    
    
def psnr(original, compressed, max_pixel): 
    mse = torch.mean((original - compressed) ** 2) 
    if(mse == 0):  # MSE is zero means no noise is present in the signal . 
                  # Therefore PSNR have no importance. 
        return 100
    psnr = 20 * np.log10(max_pixel / np.sqrt(mse)) 
    return psnr 


test_dataset = ImageDataset(root_dir='./data/kodac/', transform=ToTensor())
psnr_sum = 0.0
bit_rate_sum = 0.0
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        [reconstructed_image, im_quantized] = model(test_image, 1, True)
        #write_data('.\\reconstructed_data\\kodac\\loss_distortion_and_bitrate\\beta_2\\latent_vect\\' + 'vec' + str(i) +'.txt', im_quantized)
        nb_symbols = im_quantized.size(0)*im_quantized.size(1)*im_quantized.size(2)*im_quantized.size(3)
        entropy = compute_entropy(im_quantized)
        nbpp = nb_symbols*entropy/float(test_image.size(0)*test_image.size(2)*test_image.size(3))
        psnr_sum+= psnr(test_image.cpu(), reconstructed_image.cpu(), 255.0)
        bit_rate_sum += nbpp
        print("entropy : ", entropy)
        print( "nb bits per pixel : ", nbpp)
        print("psnr : " , psnr(test_image.cpu(), reconstructed_image.cpu(), 255.0))
print( "mean nb bits per pixel : ", bit_rate_sum/len(test_dataset))
print("psnr mean : ", psnr_sum/len(test_dataset) )
# entropy :  tensor(0.276063, device='cuda:0')
# nb bits per pixel :  tensor(0.414094, device='cuda:0')
# psnr :  tensor(27.933672)
# entropy :  tensor(0.311144, device='cuda:0')
# nb bits per pixel :  tensor(0.466717, device='cuda:0')
# psnr :  tensor(25.808447)
# mean nb bits per pixel :  tensor(0.497200, device='cuda:0')
# psnr mean :  tensor(27.350943)

# %%
def compute_entropy(tensor_data):
    min_val = tensor_data.min()
    max_val = tensor_data.max()
    nb_bins = max_val - min_val + 1
    hist = torch.histc(tensor_data, bins=nb_bins.int(), min=min_val, max=max_val)
    hist_prob = hist/hist.sum()
    hist_prob[hist_prob == 0] = 1
    entropy = -(hist_prob*torch.log2(hist_prob)).sum()
    return entropy
    
        
    
    
def psnr(original, compressed, max_pixel): 
    mse = torch.mean((original - compressed) ** 2) 
    if(mse == 0):  # MSE is zero means no noise is present in the signal . 
                  # Therefore PSNR have no importance. 
        return 100
    psnr = 20 * np.log10(max_pixel / np.sqrt(mse)) 
    return psnr 


# Load previous model
model_prev = LossyCompAutoencoder()
#model_prev.load_state_dict(torch.load('./model_parameters/lossy_comp_params_with_rate_beta2_incremental_2.pth'))
model_prev.load_state_dict(torch.load('./model_parameters/mean_bit_ppx/lossy_comp_params_with_rate_beta0000001_incremental.pth'))
model_prev.eval()
model_prev.to(device)


# And run test 
#test_dataset = ImageDataset(root_dir='./data/kodac/', transform=ToTensor())
test_dataset = ImageDataset(root_dir='F:/full_depthmaps_rgb/', transform=ToTensor())
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        [reconstructed_image, im_quantized] = model_prev(test_image,1, True)
        nb_symbols = im_quantized.size(0)*im_quantized.size(1)*im_quantized.size(2)*im_quantized.size(3)
        entropy = compute_entropy(im_quantized)
        nbpp = nb_symbols*entropy/float(test_image.size(0)*test_image.size(1)*test_image.size(2)*test_image.size(3))
        print("nb_symbols : ", nb_symbols)
        print("entropy : ", entropy)
        print( "nb bits per pixel : ", nbpp)
        print("psnr : " , psnr(test_image.cpu(), reconstructed_image.cpu(), 255.0))
    
# And print figures
fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=True, figsize=(8,8))
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        if test_image.size(2)<test_image.size(3):
            test_image = test_image.permute(0, 1, 3, 2)
        
        reconstructed_image = model_prev(test_image, 1,  False)
        ax = fig.add_subplot(2, 1, i+1, xticks=[], yticks=[])
        plt.imshow(np.squeeze(reconstructed_image.int().cpu()).permute(1, 2, 0))
        
# And save figures
from torchvision.utils import save_image

with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        reconstructed_image = np.squeeze(model_prev(test_image).cpu())
        print(reconstructed_image.type())
        #save_image(reconstructed_image, ".\\reconstructed_data\\kodac\\loss_distortion_and_bitrate\\beta_2_incremental_bis\\" + "img" + str(i)+".png", normalize=True)
        save_image(reconstructed_image, "F:\\full_depthmaps_rgb\\reconstructed\\" + "img" + str(i)+".png", normalize=True)
# Out:
# nb_symbols :  460800
# entropy :  tensor(0.083253, device='cuda:0')
# nb bits per pixel :  tensor(0.041627, device='cuda:0')
# psnr :  tensor(19.131523)
# nb_symbols :  460800
# entropy :  tensor(0.129859, device='cuda:0')
# nb bits per pixel :  tensor(0.064929, device='cuda:0')
# psnr :  tensor(19.730471)
# torch.FloatTensor
# torch.FloatTensor

# %%
def entropy_rate(x_quantized, phi, var):
    u = torch.arange(-0.5, 0.5+0.01, 0.01).cuda()        
    gsm_sum = torch.zeros(len(u)).cuda()
    for i in range(len(u)):
        x = x_quantized + u[i]
        gsm_sum_i = sum_gsm(x, var, phi, 6)
        gsm_sum[i] = gsm_sum_i

    entropy = torch.trapz(gsm_sum, u)
    
    return entropy


# Load incremental model
incremental_model = LossyCompAutoencoder()
incremental_model.load_state_dict(torch.load('./model_parameters/lossy_comp_params_with_rate_beta2_incremental.pth'))
incremental_model.eval()
incremental_model.to(device)

# train again the model starting form incremental-learned weights
    #define optimizer
optimizer = torch.optim.Adam(incremental_model.parameters(), lr=0.0001)

# define loss function
distortion = nn.MSELoss().cuda()


# define beta
beta = 2.0

#Epochs
n_epochs = 600


# Training the network
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
           
    #Training
    for i_batch, data in enumerate(dataloader):
        batch_images = data.to(device).float()
        [decoded_images, x_quantized] = incremental_model(batch_images, False, True)
        optimizer.zero_grad()
        entropy = entropy_rate(x_quantized, incremental_model.phi, incremental_model.var)
        print("entropy : ", entropy)
        dist = distortion(decoded_images, batch_images)
        print("distortion : ", dist)
        loss = beta * dist + entropy
        loss.backward()
        #print("conv1.weights grad: ", params[0].grad)
        #print(model.conv1.bias.grad)
        #print(model.conv1.weight.grad)
        optimizer.step()
        running_loss += loss.item()

    running_loss = running_loss/len(dataloader)
    print('running loss : {:.06f}'.format(running_loss), )
# Out:
# entropy :  tensor(4.992423, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3783.756348, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(35.316048, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3331.412354, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(33.194473, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3280.784668, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(16.982132, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3833.349854, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(6.236253, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(2998.021240, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(13.942085, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4020.668213, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(11.401224, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4049.084229, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.091653, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3914.844238, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(7.532864, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3699.531006, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(11.252965, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3502.669678, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(10.172251, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3233.638916, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(7.888332, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3444.639160, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.890505, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3758.968750, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(6.177967, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4241.679688, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(9.358366, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3220.504639, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(9.724493, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4545.562988, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(9.402671, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4369.997559, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(6.538430, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3352.075195, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.289365, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3834.843750, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(8.297033, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4144.026855, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(9.374476, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3154.157715, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(8.841386, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4223.809570, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(7.746368, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3535.041992, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(7.335207, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3648.764893, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.753038, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3968.517578, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.264740, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3936.420410, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(6.236658, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3609.426758, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(6.787442, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3621.904053, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.986058, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3584.592773, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.134099, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3085.294434, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.148417, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3078.743896, device='cuda:0', grad_fn=<MseLossBackward>)
# running loss : 7364.701818
# entropy :  tensor(4.213949, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3561.325195, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.420860, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4118.843750, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.712553, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3637.174072, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.181670, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3776.993408, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.715181, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3658.700684, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.026452, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3791.611328, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.472366, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4050.481445, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.867154, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3336.663330, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.950971, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3322.977051, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.643092, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4383.884766, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.033780, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3470.098389, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.374466, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3601.259033, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.418680, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3595.695068, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.429362, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3701.815430, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.102546, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3141.937500, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.463200, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3970.664551, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.480068, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3244.265625, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.471892, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(2789.662354, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.854553, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3421.625000, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.668358, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3847.244141, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.893020, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3640.884033, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.753895, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3621.660889, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.477390, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3783.617676, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.891545, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3746.264893, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.493074, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3678.192139, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.630400, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3549.524658, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.559849, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4365.400879, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.162018, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3316.888916, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.600066, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(
device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3802.956543, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.281355, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3690.774658, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.307217, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3914.927246, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.948053, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3237.705078, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(2.646946, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3699.364990, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.319393, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3790.334229, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.034118, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4250.434082, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.208065, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3926.363525, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.747485, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3669.388184, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.253601, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3282.483643, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.040407, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(2838.232910, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.175869, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3185.782471, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.151800, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4109.848145, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.158847, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3655.943604, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.653343, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3582.857666, device='cuda:0', grad_fn=<MseLossBackward>)
# running loss : 7388.880544
# entropy :  tensor(4.078692, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4331.937500, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.303016, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3650.385498, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.910847, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3701.556152, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.063138, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3586.044678, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.186852, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3436.955322, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.935975, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3857.169678, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.243153, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4031.090088, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.233263, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3312.595947, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.272809, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3685.513916, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.544210, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3571.533936, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.963799, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3686.460693, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.587257, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3620.589844, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.902643, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3835.430908, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.706846, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3853.415283, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.016892, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3530.089355, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.708622, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3393.946533, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.012492, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3616.270264, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.857601, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3201.696533, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.309969, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3394.364746, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.094294, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4268.666504, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.429111, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3004.241211, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.262102, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3367.807373, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.463998, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3204.622803, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.628301, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3945.990479, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.638970, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4537.041016, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.390480, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4347.650391, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.352649, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4050.649658, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.300420, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3470.998291, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.867441, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3542.787354, device='cuda:0', grad_fn=<MseLossBackward>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-17527ea6f60d> in <module>
#      47         print("distortion : ", dist)
#      48         loss = beta * dist + entropy
# ---> 49         loss.backward()
#      50         #print("conv1.weights grad: ", params[0].grad)
#      51         #print(model.conv1.bias.grad)
#
# ~\anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# ~\anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     123         retain_graph = create_graph
#     124
# --> 125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
#     127         allow_unreachable=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
from range_coder import RangeEncoder, RangeDecoder, prob_to_cum_freq
import os

# Load previous model
model = LossyCompAutoencoder()
model.load_state_dict(torch.load('./model_parameters/mean_bit_ppx/lossy_comp_params_with_rate_beta0005_incremental.pth'))
model.eval()
model.to(device)

nb_bits = 0.0
test_dataset = ImageDataset(root_dir='./data/kodac/', transform=ToTensor())
with torch.no_grad():  
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        [reconstructed_image, data_comp] = model(test_image, 1, True)
            # compute symbol probabilities
        min_val = data_comp.min()
        if min_val <0:
            data_comp -= min_val
            min_val = 0
        max_val = data_comp.max()
        nb_bins = max_val - min_val + 1
        hist = torch.histc(data_comp, bins=nb_bins.int(), min=min_val, max=max_val)
        prob = hist/hist.sum()
        #print("data comp : ", data_comp)
        #print(prob)
        
        """
        if len(torch.nonzero(prob)) != len(prob):
            zero_indices = ((prob == 0).nonzero())
            for j in reversed(range(0, len(zero_indices), 1)):
                data_comp[data_comp > int(zero_indices[j])+min_val] -=1
            min_val = data_comp.min()
            max_val = data_comp.max()
            nb_bins = max_val - min_val + 1
            hist = torch.histc(data_comp, bins=nb_bins.int(), min=min_val, max=max_val)
            prob = hist/hist.sum()
            print(min_val)
            print(max_val)
            print("data comp : ", data_comp)
            print(prob)
         """ 
            
            # convert probabilities to cumulative integer frequency table
        #cumFreq = prob_to_cum_freq(torch.clamp(prob, min=np.finfo(np.float32).eps).cpu(), resolution=128)
        cumFreq = prob_to_cum_freq(prob.cpu(), resolution=128)
        #print(cumFreq)
        
        # encode data
        filepath_to_write = "D:\\lossy_autoencoder\\latent_vect_encoded\\" + "img" + str(i) + ".bin"
        encoder = RangeEncoder(filepath_to_write)
        #print(torch.flatten(data_comp).cpu().tolist())
        encoder.encode(torch.flatten(data_comp.int()).cpu().tolist(), cumFreq)
        encoder.close()
        
        
        file_size = os.path.getsize(filepath_to_write)*8 #number of bits in the file
        print(file_size)
        nb_bits += file_size
        
    nb_bits_per_image = nb_bits/len(test_dataset)
    print(nb_bits_per_image)
    nb_bits_per_pixel = nb_bits_per_image/(512*768)
    print(nb_bits_per_pixel)
    
    
"""
    test_image = test_dataset[1].unsqueeze(0).to(device).float()
    [reconstructed_image, data_comp] = model(test_image, 1, True)
        # compute symbol probabilities
    min_val = data_comp.min()
    print(min_val)
    print(data_comp.max())
    if min_val <0:
        data_comp -= min_val
        min_val = 0
    max_val = data_comp.max()
    
    print(max_val)
    nb_bins = max_val - min_val + 1
    print(nb_bins)
    hist = torch.histc(data_comp, bins=nb_bins.int(), min=min_val, max=max_val)
    prob = hist/hist.sum()
    print(prob)
         # convert probabilities to cumulative integer frequency table
    cumFreq = prob_to_cum_freq(prob.cpu(), resolution=128)
    #print(cumFreq)

    print(torch.flatten(data_comp).cpu().tolist())
    
    
        # encode data
    filepath_to_write = "D:\\lossy_autoencoder\\latent_vect_encoded\\" + "img" + str(1) + ".bin"
    encoder = RangeEncoder(filepath_to_write)
    print(torch.flatten(data_comp).cpu().tolist())
    encoder.encode(torch.flatten(data_comp.int()).cpu().tolist(), cumFreq)
    encoder.close()   
"""
# Out:
# 619240
# 417832
# 381184
# 485040
# 681856
# 566208
# 438336
# 716840
# 393552
# 406752
# 519136
# 394736
# 786376
# 594720
# 470824
# 428256
# 399592
# 613760
# 510416
# 464416
# 540400
# 507440
# 400992
# 585792
# 513487.3333333333
# 1.3058658175998263
# '\n    test_image = test_dataset[1].unsqueeze(0).to(device).float()\n    [reconstructed_image, data_comp] = model(test_image, 1, True)\n        # compute symbol probabilities\n    min_val = data_comp.min()\n    print(min_val)\n    print(data_comp.max())\n    if min_val <0:\n        data_comp -= min_val\n        min_val = 0\n    max_val = data_comp.max()\n    \n    print(max_val)\n    nb_bins = max_val - min_val + 1\n    print(nb_bins)\n    hist = torch.histc(data_comp, bins=nb_bins.int(), min=min_val, max=max_val)\n    prob = hist/hist.sum()\n    print(prob)\n         # convert probabilities to cumulative integer frequency table\n    cumFreq = prob_to_cum_freq(prob.cpu(), resolution=128)\n    #print(cumFreq)\n\n    print(torch.flatten(data_comp).cpu().tolist())\n    \n    \n        # encode data\n    filepath_to_write = "D:\\lossy_autoencoder\\latent_vect_encoded\\" + "img" + str(1) + ".bin"\n    encoder = RangeEncoder(filepath_to_write)\n    print(torch.flatten(data_comp).cpu().tolist())\n    encoder.encode(torch.flatten(data_comp.int()).cpu().tolist(), cumFreq)\n    encoder.close()   \n'
