# %%
import numpy as np
import torch
import torch.nn as nn
import pandas as pd
from skimage import io, transform
import torch.autograd as ag
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from PIL import Image
import os
from scipy import signal
from sklearn.metrics import mean_squared_error
from torch.autograd import Variable
import time
from functools import reduce

torch.set_printoptions(precision=6)

# %%
class ImageDataset(Dataset):

    def __init__(self, root_dir, transform=None):
        """
        Args:
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        path, dirs, files = next(os.walk(self.root_dir))
        file_count = len(files)
        return file_count

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        path, dirs, files = next(os.walk(self.root_dir))
        img_name = os.path.join(self.root_dir, files[idx])
        image = io.imread(img_name)

        if self.transform:
            image = self.transform(image)

        return image


class RandomCrop(object):
    """Crop randomly the image

    Args:
        output_size (tuple or int): Desired output size. If int, square crop
            is made.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            assert len(output_size) == 2
            self.output_size = output_size

    def __call__(self, image):
        
        h, w = image.shape[:2]
        new_h, new_w = self.output_size
        
        if h!= new_h:
            top = np.random.randint(0, h - new_h)
        else:
            top = 0
        if w!= new_w:
            left = np.random.randint(0, w - new_w)
        else:
            left = 0
     
        image = image[top: top + new_h,
                      left: left + new_w]
        
        image = np.expand_dims(image, axis=2)

        return image
    
    
class Downsample(object):
    """Downsample the image

    Args:
        downsampling_factor (int or tuple): Desired downsampling factor for rows and columns.
        If the downsampling factor is an int, then both rows and columns are sampled by the same factor
    """

    def __init__(self, downsampling_factor):
        assert isinstance(downsampling_factor, (int, tuple))
        if isinstance(downsampling_factor, int):
            self.downsampling_factor = (downsampling_factor, downsampling_factor)
        else:
            assert len(downsampling_factor) == 2
            self.downsampling_factor = downsampling_factor

    def __call__(self, image):
        
        down_fact_h, down_fact_w = self.downsampling_factor
        image = image[::down_fact_h,
                      ::down_fact_w]

        return image
    
    
    
class ToTensor(object):
    """Convert ndarrays in images to Tensors."""

    def __call__(self, images):

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        images = images.transpose((2, 0, 1))
        images = images.astype(float)
        return torch.from_numpy(images)
    

    
def show_image_batch(images_batch):
    """Show image for a batch of samples."""
    if images_batch.size(1) == 1:
        images_batch_normed = images_batch/torch.max(images_batch)
        grid = utils.make_grid(images_batch_normed)
        plt.imshow(grid.numpy().transpose((1, 2, 0)))

        plt.title('Batch from dataloader')
    else:
        print(images_batch.size())
        images_b_batch = torch.zeros(images_batch.size(0), 1, images_batch.size(2) , images_batch.size(3))
        images_color_batch = torch.cat((images_batch, images_b_batch), 1) 
        print(images_color_batch.size())
        grid = utils.make_grid(images_color_batch)
        plt.imshow(grid.numpy().transpose((1, 2, 0)))

        plt.title('Batch from dataloader')
    
    
    
    
# Load training dataset

#mirror_padding_transform = transforms.Compose([transforms.ToPILImage(), transforms.Pad(padding=12, padding_mode='reflect'), transforms.ToTensor()])
transformed_dataset = ImageDataset(root_dir='D:/autoencoder_data/depthmaps/training', 
                                           transform=transforms.Compose([
                                            RandomCrop((384, 640)), Downsample(( 3, 5)), ToTensor()])
                                  )
dataloader = DataLoader(transformed_dataset, batch_size=18, shuffle=True, num_workers=0)

for i_batch, batch_images in enumerate(dataloader):
    print(i_batch, batch_images.size())

    # observe 4th batch and stop.
    if i_batch == 2:
        plt.figure()
        show_image_batch(batch_images)
        plt.axis('off')
        plt.ioff()
        plt.show()
        break
# Out:
# 0 torch.Size([18, 1, 128, 128])
# 1 torch.Size([18, 1, 128, 128])
# 2 torch.Size([18, 1, 128, 128])

# %%
#Define additionnnal functions
def periodic_shuffling(T, C):
    T_copy = T.clone()
    batch_size = T.size()[0]
    H = T.size()[2]
    W = T.size()[3]
    T = T.view(batch_size, C, H*2, W*2)
                
    T[:, :, ::2, ::2] = T_copy[:, 0:C, :, :]
    T[:, :, 1::2, ::2] = T_copy[:, C:2*C, :, :]
    T[:, :, ::2, 1::2] = T_copy[:, 2*C:3*C, :, :]
    T[:, :, 1::2, 1::2] = T_copy[:, 3*C:4*C, :, :]

    return T
    
    
def mirror_padding(x, padding_size):
    up_line = x[:, :, 0:padding_size, :].flip(2)
    left_col = x[:, :, :, 0:padding_size].flip(3)
    right_col = x[:, :, :, -padding_size:].flip(3)
    bottom_line = x[:, :, -padding_size:, :].flip(2)
    left_up_corner = left_col[:, :, 0:padding_size, :].flip(2)
    right_up_corner = right_col[:, :, 0:padding_size, :].flip(2)
    left_bottom_corner = left_col[:, :, -padding_size:, :].flip(2)
    right_bottom_corner = right_col[:, :, -padding_size:, :].flip(2)

    x_mirror_pad = torch.cat((torch.cat((left_up_corner, up_line, right_up_corner), 3), torch.cat((left_col, x, right_col), 3), torch.cat((left_bottom_corner, bottom_line, right_bottom_corner), 3)), 2)
    return x_mirror_pad
    

def normalize_input(x):
    mean_channels = torch.mean(1.0*x, [2,3])
    mean_channels_images = (mean_channels.repeat_interleave(x.size()[2]*x.size()[3])).view(x.size()[0], x.size()[1], x.size()[2], x.size()[3])
    x_centered = x - mean_channels_images
    max_value = torch.max(x)
    min_value = torch.min(x)
    radius = max(max_value, abs(min_value))
    x_centered_normalized = x_centered/radius
    return x_centered_normalized, radius, mean_channels

def standardize_input(x):
    mean_channels = torch.mean(1.0*x, [2,3])
    mean_channels_images = (mean_channels.repeat_interleave(x.size()[2]*x.size()[3])).view(x.size()[0], x.size()[1], x.size()[2], x.size()[3])
    x_centered = x - mean_channels_images
    var = torch.sum(x_centered**2, (2, 3))/(x.size()[2]*x.size()[3])
    x_standardized = x_centered / torch.sqrt(var.view(x_centered.size()[0], x_centered.size()[1], 1, 1))
    return x_standardized, mean_channels, var
    
def denormalize_output(x, radius, mean_channels):
    x_denormalized = x*radius
    mean_channels_images = (mean_channels.repeat_interleave(x.size()[2]*x.size()[3])).view(x.size()[0], x.size()[1], x.size()[2], x.size()[3])
    x_denormalized_centered = x_denormalized + mean_channels_images
    return x_denormalized_centered

def destandardize_output(x, mean_channels, var):
    x_rescaled = x*torch.sqrt(var.view(x.size()[0], x.size()[1], 1, 1))
    mean_channels_images = (mean_channels.repeat_interleave(x.size()[2]*x.size()[3])).view(x.size()[0], x.size()[1], x.size()[2], x.size()[3])
    x_destandardized = x_rescaled + mean_channels_images
    return x_destandardized



def compute_gsm(x, var, phi, nScale):
    gsm = 0.0
    
    phi = torch.abs(phi)
    var = torch.abs(var)
    phi_s_sum = torch.sum(phi, 0).unsqueeze(0)
    phi_norm = phi/phi_s_sum
    
    for s in range(nScale):
        var_s = var[s, :].view(1, -1, 1, 1)
        phi_s = phi_norm[s, :].view(1, -1, 1, 1)
        gaussian = phi_s*(1.0/(torch.sqrt(2*np.pi*var_s)))*torch.exp(-0.5*(x**2/var_s))
        gsm += gaussian
    return gsm


def sum_gsm(x, var, phi, nScale):
    gsm = 0.0
    
    phi = torch.abs(phi)
    var = torch.abs(var)
    phi_s_sum = torch.sum(phi, 0).unsqueeze(0)
    phi_norm = phi/phi_s_sum
    
    for s in range(nScale):
        var_s = var[s, :].view(1, -1, 1, 1)
        phi_s = phi_norm[s, :].view(1, -1, 1, 1)
        gaussian = phi_s*(1.0/(torch.sqrt(2*np.pi*var_s)))*torch.exp(-0.5*(x**2/var_s))
        gsm += gaussian
    #gsm_sum = (torch.log2(gsm)).sum()
    gsm_sum = gsm.sum()
    return gsm_sum

   
    
def compute_mask(nb_ones, dims):
    mask = torch.zeros(dims)
    indices = np.arange(nb_ones)
    mask_flatten = mask.view(-1, 1, 1, 1)
    mask_flatten[indices] = 1
    mask_reshaped = mask_flatten.view(dims)
    return mask_reshaped


def entropy_rate(x_quantized, phi, var):
    u = torch.arange(-0.5, 0.5+0.1, 0.1).cuda()        
    gsm_sum = torch.zeros(len(u)).cuda()
    for i in range(len(u)):
        x = x_quantized + u[i]
        gsm_sum_i = sum_gsm(x, var, phi, 6)
        gsm_sum[i] = gsm_sum_i

    integral_u = torch.trapz(gsm_sum, u)
    #print("gsm sum : ", gsm_sum)
    #print("integral over u : ", integral_u)
    entropy = -torch.log2(integral_u)
    
    return entropy



def mean_bit_per_px(x_quantized, phi, var):
    u = torch.arange(-0.5, 0.5+0.1, 0.1).cuda()   
    gsm_stacked = []
    #u_stacked = []
    for i in range(len(u)):
        x = x_quantized + u[i]
        gsm = compute_gsm(x, var, phi, 6)
        gsm_stacked.append(gsm)
        #u_stacked.append(torch.ones(gsm.size()).cuda()*u[i])
    
    gsms = torch.stack(gsm_stacked, dim=0)
    #us = torch.stack(u_stacked, dim=0)
    integral_u = torch.trapz(gsms, dx=0.1, dim=0)
    if torch.any(integral_u.isnan()):
        print("integral u is nan", integral_u)
        integral_u[integral_u.isnan()] = 1
    nb_bits = (-torch.log2(torch.clamp(integral_u, min=np.exp(-10**2), max=1))).sum()
    if nb_bits < 0:
        #print("integral u : ", integral_u)
        print("nb_bits negative : ", nb_bits)
    return nb_bits/reduce(lambda x, y: x*y, list(x_quantized.size()))


def distortion_pc(x, x_reconstructed, focal_length, skew, scaling_factor, image_size, principal_point):
    # compute intrinsic matrix and its inverse
    K = torch.tensor([[focal_length, skew, principal_point[0]], [ 0.0, focal_length, principal_point[1]], [0.0, 0.0, 1.0]])
    K_ext = torch.eye(4)
    K_ext[0:3:1, 0:3:1] = K
    K_ext_inv = torch.inverse(K_ext).cuda()
    
    size_batch = x.size()[0]
    total_mse = 0.0
    for example in range(size_batch):
        # compute x,y,z coords from u,v coords and gray-level value
        z_reconstructed = x_reconstructed[example, :, :, :].view(image_size[0]*image_size[1])/scaling_factor
        z = x[example, :, :, :].view(image_size[0]*image_size[1])/scaling_factor
        bool_matrix = torch.logical_and(z_reconstructed != 0 , z != 0)
            # for reconstructed depthmap
        v_reconstructed = (torch.arange(1, image_size[0]+1)).repeat_interleave(image_size[1])
        v_reconstructed = v_reconstructed[bool_matrix].view(1, -1).cuda()
        u_reconstructed = (torch.arange(1, image_size[1]+1)).repeat(image_size[0])
        u_reconstructed = u_reconstructed[bool_matrix].view(1, -1).cuda()
        z_reconstructed = z_reconstructed[bool_matrix].view(1, -1)
        homogeneous_reconstructed_camera_points = torch.cat((u_reconstructed, v_reconstructed, torch.ones(1, u_reconstructed.size()[1]).cuda(), 1.0/z_reconstructed), 0)
        homogeneous_reconstructed_coords = z_reconstructed*(torch.mm(K_ext_inv,homogeneous_reconstructed_camera_points))
        coords_reconstructed = homogeneous_reconstructed_coords[0:3:1, :]
            # for original depthmap
        v = (torch.arange(1, image_size[0]+1)).repeat_interleave(image_size[1])
        v = v[bool_matrix].view(1, -1).cuda()
        u =  (torch.arange(1, image_size[1]+1)).repeat(image_size[0])
        u = u[bool_matrix].view(1, -1).cuda()    
        z = z[bool_matrix].view(1, -1)
        homogeneous_camera_points = torch.cat((u, v, torch.ones(1, u.size()[1]).cuda(), 1.0/z))
        homogeneous_coords = z*(torch.mm(K_ext_inv,homogeneous_camera_points))
        coords = homogeneous_coords[0:3:1, :]
        
        print(" x original : ", torch.squeeze(z)[10]*scaling_factor)
        print(" original coords : ", coords[:, 10])
        
        # compute MSE on points
        total_mse += torch.sum(torch.sqrt(torch.sum((coords_reconstructed - coords)**2, 0)))
    return total_mse
        


class MyQuantization(torch.autograd.Function):
    """
    We can implement our own custom autograd Functions by subclassing
    torch.autograd.Function and implementing the forward and backward passes
    which operate on Tensors.
    """
    
    @staticmethod
    def forward(ctx, input):
        """
        In the forward pass we receive a Tensor containing the input and return
        a Tensor containing the output. ctx is a context object that can be used
        to stash information for backward computation. You can cache arbitrary
        objects for use in the backward pass using the ctx.save_for_backward method.
        """
        ctx.save_for_backward(input)
        return torch.round(input)
    
    @staticmethod
    def backward(ctx, grad_output):
        """
        In the backward pass we receive a Tensor containing the gradient of the loss
        with respect to the output, and we need to compute the gradient of the loss
        with respect to the input.
        """
        input, = ctx.saved_tensors
        return grad_output

        
        
class MyClipping(torch.autograd.Function):
  
    @staticmethod
    def forward(ctx, input):
        ctx.save_for_backward(input)
        return torch.round(input).clamp(min=0, max=255)
    
    @staticmethod
    def backward(ctx, grad_output):
        input = ctx.saved_tensors
        return grad_output

# %%
#Define the Convolutional Autoencoder with integrated classifer
    #taille de l'image d'entrée : 128*128
class LossyCompAutoencoder(nn.Module):
    def __init__(self):
        super(LossyCompAutoencoder, self).__init__()
       
        #Encoder
            # input block
        self.conv1 = nn.Conv2d(1, 64, 5, stride=2, padding=0)  
        self.conv2 = nn.Conv2d(64, 128, 5, stride=2, padding=0)
            # residual block 1
        self.resConv1_1 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.resConv1_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
            # residual block 2
        self.resConv2_1 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.resConv2_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
            # residual block 3
        self.resConv3_1 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.resConv3_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
            # output block
        self.conv3 = nn.Conv2d(128, 96, 5, stride=2, padding=0)
        self.quantization = MyQuantization.apply
        
       
        #Decoder
            # subpixel 1
        self.subpix1 = nn.Conv2d(96, 512, 3, stride=1, padding=1)
            #residual block 1
        self.deconv1_1 = nn.Conv2d(512//4, 128, 3, stride=1, padding=1)
        self.deconv1_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)    
            #residual block 2
        self.deconv2_1 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.deconv2_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
            #residual block 3
        self.deconv3_1 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.deconv3_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1) 
            # subpixel 2
        self.subpix2 = nn.Conv2d(128, 256, 3, stride=1, padding=1)
            # subpixel 3
        self.subpix3 = nn.Conv2d(256//4, 4, 3, stride=1, padding=1)
            # clipping
        self.clip = MyClipping.apply
        
        #Bit-rate      
        self.var = nn.Parameter(torch.Tensor(6, 96))
        self.phi = nn.Parameter(torch.Tensor(6, 96))
        self.var.data.uniform_(0, 1)
        self.phi.data.uniform_(0, 1)
    
    
    
    def forward(self, x, mask= 1, return_xq=False):
        
        #encoder
            # normalization
        x, mean_channels, var = standardize_input(x)
        if torch.any(x.isnan()):
            print("x after normalization is nan", x)
            # mirror padding
        x = mirror_padding(x, 14)
        if torch.any(x.isnan()):
            print("x after mirror padding is nan", x)
            # input blocks
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x_c1 = x.clone()
        if torch.any(x.isnan()):
            print("x after input block is nan", x)
            # residual block 1
        x = F.relu(self.resConv1_1(x))
        x = self.resConv1_2(x)
        x += x_c1
        x_c2 = x.clone()
        if torch.any(x.isnan()):
            print("x after residual block 1 is nan", x)
            # residual block 2
        x = F.relu(self.resConv2_1(x))
        x = self.resConv2_2(x)
        x += x_c2
        x_c3 = x.clone()
        if torch.any(x.isnan()):
            print("x after residual block 2 is nan", x)
            # residual block 3
        x = F.relu(self.resConv3_1(x))
        x = self.resConv3_2(x)
        x += x_c3
        if torch.any(x.isnan()):
            print("x after residual block 3 is nan", x)
            # output block
        x = self.conv3(x)
        if torch.any(x.isnan()):
            print("x after output block is nan", x)
            # quantization
        x = self.quantization(x)
        if torch.any(x.isnan()):
            print("x after quantization block is nan", x)
            # add mask for incremental training
        x = x*mask
        x_quantized = x
        if torch.any(x.isnan()):
            print("x after mask is nan", x)

        #decoder
            # subpixel 1
        x = self.subpix1(x)
        x = periodic_shuffling(x, 512//4)
        x_c4 = x.clone()
        if torch.any(x.isnan()):
            print("x after subpix 1 is nan", x)
            # residual block 1
        x = F.relu(self.deconv1_1(x))
        x = self.deconv1_2(x)
        x += x_c4
        x_c5 = x.clone()
        if torch.any(x.isnan()):
            print("x after residual block 1 is nan", x)
               # residual block 2
        x = F.relu(self.deconv2_1(x))
        x = self.deconv2_2(x)
        x += x_c5
        x_c6 = x.clone()
        if torch.any(x.isnan()):
            print("x after residual block 2 is nan", x)
               # residual block 3
        x = F.relu(self.deconv3_1(x))
        x = self.deconv3_2(x)
        x += x_c6
        if torch.any(x.isnan()):
            print("x after residual block 3 is nan", x)
                # subpixel 2
        x = self.subpix2(x)
        x = F.relu(periodic_shuffling(x, 256//4))
        if torch.any(x.isnan()):
            print("x after subpix 2 is nan", x)
                # subpixel 3
        x = self.subpix3(x)
        x = periodic_shuffling(x, 4//4)
        if torch.any(x.isnan()):
            print("x after subpix 3 is nan", x)
                # denormalization
        x = destandardize_output(x, mean_channels, var)
        if torch.any(x.isnan()):
            print("x after denormalization is nan", x)
                # clipping
        x = self.clip(x)
        if torch.any(x.isnan()):
            print("x after clipping is nan", x)


        if return_xq:
            return x, x_quantized
        else:
            return x

# %%
# instanciate the model
model = LossyCompAutoencoder()
print(model)
params = list(model.parameters())
print(len(params))
print(params)
# Out:
# LossyCompAutoencoder(
#   (conv1): Conv2d(1, 64, kernel_size=(5, 5), stride=(2, 2))
#   (conv2): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2))
#   (resConv1_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (resConv1_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (resConv2_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (resConv2_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (resConv3_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (resConv3_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(128, 96, kernel_size=(5, 5), stride=(2, 2))
#   (subpix1): Conv2d(96, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv1_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv1_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv2_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv2_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv3_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv3_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (subpix2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (subpix3): Conv2d(64, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# 38
# [Parameter containing:
# tensor([[4.975154e-01, 5.221394e-01, 1.651735e-01, 4.970171e-01, 9.666851e-01,
#          2.082514e-01, 7.255042e-02, 2.630866e-02, 4.010222e-01, 2.452152e-01,
#          6.576536e-01, 3.224504e-01, 5.770676e-01, 2.273231e-01, 7.886407e-01,
#          9.093116e-01, 4.968554e-01, 5.807549e-01, 8.221058e-01, 5.962055e-01,
#          4.486119e-01, 8.932357e-01, 7.236803e-01, 4.703785e-01, 9.181143e-01,
#          1.490295e-01, 6.435181e-01, 3.064873e-01, 1.615955e-01, 9.938414e-01,
#          4.186311e-01, 8.563285e-01, 1.001579e-01, 8.272917e-01, 8.339598e-01,
#          9.367658e-01, 6.218486e-01, 4.542857e-02, 5.531871e-01, 1.409525e-01,
#          9.590885e-01, 4.086348e-01, 8.757713e-01, 1.671683e-01, 8.618937e-01,
#           [ 0.009131,  0.022719, -0.018066],
#           [-0.010538, -0.002958, -0.015539]],
#
#          [[ 0.013823,  0.026154,  0.028733],
#           [ 0.011544,  0.016463,  0.015769],
#           [ 0.005737,  0.019715,  0.019503]],
#
#          [[-0.023815,  0.024557,  0.018353],
#           [-0.022860,  0.017599,  0.003918],
#           [-0.011246,  0.002283,  0.000273]],
#
#          ...,
#
#          [[-0.015664,  0.020144,  0.016727],
#           [ 0.029413,  0.008928, -0.021716],
#           [-0.017372,  0.002972,  0.027536]],
#
#          [[-0.027803, -0.024246,  0.011216],
#           [-0.023103, -0.026840,  0.002263],
#           [-0.015029, -0.000923,  0.006273]],
#
#          [[ 0.006822, -0.005118, -0.029090],
#           [ 0.003112, -0.010975, -0.028624],
#           [ 0.022832, -0.005526, -0.027511]]],
#
#
#         [[[-0.012494,  0.020544, -0.029117],
#           [-0.025631, -0.020926, -0.010381],
#           [ 0.013531,  0.023298,  0.025880]],
#
#          [[-0.007225,  0.006426,  0.017610],
#           [-0.026987,  0.018466,  0.001695],
#           [-0.027452,  0.017582, -0.017774]],
#
#          [[ 0.000530,  0.003289,  0.021877],
#           [-0.023357,  0.028675,  0.024294],
#           [-0.026458, -0.029182,  0.004444]],
#
#          ...,
#
#          [[-0.000485, -0.022383, -0.025578],
#           [ 0.027676,  0.019456,  0.017838],
#           [ 0.004599, -0.016115,  0.019844]],
#
#          [[ 0.005597, -0.016784,  0.020607],
#           [ 0.024965,  0.009594,  0.022692],
#           [-0.010748,  0.029381,  0.028727]],
#
#          [[-0.004386, -0.012196,  0.007734],
#           [ 0.028236,  0.006707,  0.002291],
#           [ 0.004765,  0.019597, -0.029424]]],
#
#
#         [[[ 0.021732,  0.003582, -0.025137],
#           [-0.010642, -0.025828,  0.021460],
#           [ 0.006185,  0.017176,  0.010728]],
#
#          [[-0.004549,  0.021397, -0.029459],
#           [-0.001472, -0.005291, -0.010813],
#           [ 0.025214, -0.001276, -0.027242]],
#
#          [[ 0.006225,  0.004279,  0.017470],
#           [-0.007581,  0.023447,  0.013121],
#           [-0.012584, -0.011089,  0.008774]],
#
#          ...,
#
#          [[ 0.009565, -0.007983, -0.021588],
#           [ 0.013874,  0.017304, -0.016982],
#           [ 0.027404, -0.005475, -0.015402]],
#
#          [[-0.017647,  0.018776, -0.016835],
#           [-0.003673,  0.025907, -0.001002],
#           [ 0.020172,  0.025263,  0.027500]],
#
#          [[-0.010865, -0.025615, -0.016048],
#           [ 0.018097,  0.027423, -0.007917],
#           [ 0.022719, -0.025591, -0.022257]]],
#
#
#         ...,
#
#
#         [[[ 0.019895,  0.027064,  0.022583],
#           [ 0.014056, -0.021288, -0.012110],
#           [-0.000297, -0.015462, -0.000903]],
#
#          [[-0.010267, -0.024097, -0.001905],
#           [-0.008074,  0.012293, -0.020496],
#           [ 0.008346,  0.024406, -0.012317]],
#
#          [[ 0.017906,  0.028237, -0.017074],
#           [ 0.005795, -0.005989,  0.008330],
#           [-0.023135, -0.025670,  0.004779]],
#
#          ...,
#
#          [[-0.010654,  0.020571,  0.012223],
#           [ 0.008245, -0.012954, -0.006196],
#           [-0.015867, -0.013314, -0.017250]],
#
#          [[ 0.000309, -0.010737, -0.022275],
#           [-0.001612, -0.016733, -0.004608],
#           [-0.028796, -0.009606,  0.024003]],
#
#          [[-0.010342,  0.009026, -0.006930],
#           [-0.010636,  0.000301,  0.012388],
#           [ 0.014232,  0.022862, -0.011308]]],
#
#
#         [[[ 0.026936, -0.000647, -0.017378],
#           [ 0.019161,  0.025115,  0.021192],
#           [ 0.003812,  0.019692,  0.023861]],
#
#          [[ 0.026858, -0.001010,  0.006309],
#           [ 0.007772,  0.003394, -0.002761],
#           [ 0.017522,  0.013729,  0.005587]],
#
#          [[ 0.012572, -0.029427,  0.002642],
#           [-0.008502,  0.005824,  0.008240],
#           [ 0.029310,  0.009100, -0.011498]],
#
#          ...,
#
#          [[-0.006141, -0.005385,  0.021526],
#           [ 0.002722, -0.025530, -0.002066],
#           [ 0.028605, -0.019389,  0.027166]],
#
#          [[ 0.002652, -0.007749, -0.017715],
#           [-0.024135, -0.000637,  0.011910],
#           [ 0.001149,  0.006825,  0.009855]],
#
#          [[ 0.013084,  0.000444, -0.025116],
#           [-0.019588,  0.028700,  0.008902],
#           [-0.010813,  0.015072,  0.025073]]],
#
#
#         [[[-0.003080, -0.017314,  0.025280],
#           [-0.014744,  0.012134, -0.004323],
#           [-0.019914, -0.004334,  0.022319]],
#
#          [[ 0.021115, -0.025285, -0.009849],
#           [ 0.016356, -0.001254,  0.014809],
#           [-0.026854, -0.005321,  0.006688]],
#
#          [[-0.023524,  0.025066, -0.022695],
#           [-0.024953,  0.012946, -0.025286],
#           [-0.009435, -0.001101,  0.026943]],
#
#          ...,
#
#          [[ 0.029350, -0.004493, -0.025875],
#           [ 0.002792, -0.011457,  0.022189],
#           [-0.002025, -0.022171, -0.019981]],
#
#          [[ 0.024030,  0.024074, -0.003876],
#           [ 0.000739, -0.008977,  0.004890],
#           [-0.010893, -0.000827,  0.012558]],
#
#          [[-0.028050,  0.001472,  0.006369],
#           [-0.024302, -0.015665,  0.014010],
#           [-0.019174,  0.024901,  0.006670]]]], requires_grad=True), Parameter containing:
# tensor([-5.305655e-03, -1.726281e-02, -1.779304e-02, -1.356419e-03,
#          9.969952e-03, -1.960623e-02, -2.009477e-02, -2.446410e-02,
#          7.529905e-03,  2.316668e-02,  1.898455e-02,  1.091314e-03,
#         -2.288476e-02,  1.685291e-02,  3.204631e-03, -2.945071e-03,
#         -2.255504e-02, -2.750780e-02, -2.590187e-02, -7.243909e-03,
#         -2.011195e-03, -7.280208e-03,  2.829392e-02, -1.632387e-03,
#         -2.732076e-02, -6.135205e-03, -6.394815e-03, -1.407462e-02,
#          8.877216e-03,  4.467143e-03, -1.351459e-02,  2.134845e-02,
#          6.056091e-03, -1.330066e-02, -1.452845e-02, -1.549824e-02,
#         -2.727904e-02, -1.537248e-02, -8.229166e-05,  6.253222e-03,
#         -1.637480e-02, -9.845251e-03,  2.915566e-02, -2.942515e-02,
#          2.665668e-02, -7.192029e-03, -5.803196e-03, -2.499797e-02,
#          [[ 3.525189e-02, -4.760921e-03,  1.129793e-02],
#           [ 9.508055e-03, -1.139772e-02,  2.785836e-02],
#           [-7.384162e-03, -7.511403e-03, -7.525265e-03]],
#
#          [[ 2.014643e-02, -4.057241e-02,  3.034267e-02],
#           [ 3.858593e-02, -1.155124e-02,  3.800377e-02],
#           [ 1.506023e-02,  1.378114e-02,  2.805020e-02]]]], requires_grad=True), Parameter containing:
# tensor([ 0.035005,  0.033462, -0.021327,  0.010812], requires_grad=True)]

# %%
def get_device():
    if torch.cuda.is_available():
        device = 'cuda:0'
    else:
        device = 'cpu'
    return device

device = get_device()
print(device)
# Out:
# cuda:0

# %%
# transfert du model au gpu
model.to(device)

#define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# define loss function
distortion = nn.MSELoss().cuda()
        
# incremental update of coefficients        

# define beta
beta = 10.0
# define threshold and loss_init
threshold = 0.95
loss_init = float("Inf")
nb_ones = 1
iteration = 0
mask=(compute_mask(1, (96, 16, 16)).unsqueeze(0)).cuda()
dim_latent = 16*16*96
output_flag = False

#Epochs
n_epochs = 6150


# Training the network
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
        
    #Training
    for i_batch, data in enumerate(dataloader):
        batch_images = data.to(device).float()
        batch_images = torch.round(batch_images*(255/(2**16-1)))
        [decoded_images, x_quantized] = model(batch_images, mask, True)
        optimizer.zero_grad()
        loss_dist = distortion(decoded_images, batch_images)
        loss_bit = mean_bit_per_px(x_quantized, model.phi, model.var)
        #print(" loss distortion : ", loss_dist)
        #print("loss bit : ", loss_bit)
        loss = beta * loss_dist + loss_bit
        #print(loss)
        
        # check the value of the loss to see if another coefficient can be enabled
        if (loss.item() < loss_init*threshold or iteration > 5):
            if (nb_ones<dim_latent):
                nb_ones +=1
                loss_init = loss.item()
                iteration = 0
                mask = (compute_mask(nb_ones, tuple(x_quantized.size()[1:])).unsqueeze(0)).cuda()
            else:
                output_flag = True
                break
            
        loss.backward()
        #print("conv1.weights grad: ", params[0].grad)
        #print(model.conv1.bias.grad)
        #print(model.conv1.weight.grad)
        optimizer.step()
        running_loss += loss.item()
        iteration += 1

    if output_flag:
        break
    running_loss = running_loss/len(dataloader)
    print('running loss : {:.06f}'.format(running_loss), )
# Out:
# running loss : 2.632389
# running loss : 2.366267
# running loss : 2.107673
# running loss : 2.012685
# running loss : 1.912321
# running loss : 1.822550
# running loss : 1.736556
# running loss : 1.740569
# running loss : 1.655671
# running loss : 1.590971
# running loss : 1.558519
# running loss : 1.516154
# running loss : 1.500604
# running loss : 1.456193
# running loss : 1.422841
# running loss : 1.411579
# running loss : 1.350852
# running loss : 1.346690
# running loss : 1.313963
# running loss : 1.300346
# running loss : 1.268507
# running loss : 1.245135
# running loss : 1.226426
# running loss : 1.217876
# running loss : 1.205105
# running loss : 1.173048
# running loss : 1.156275
# running loss : 1.146322
# running loss : 1.155015
# running loss : 1.140505
# running loss : 1.104178
# running loss : 1.088845
# running loss : 1.075015
# running loss : 1.057921
# running loss : 1.052261
# running loss : 1.049979
# running loss : 1.042298
# running loss : 1.018749
# running loss : 1.024177
# running loss : 1.004219
# running loss : 0.998510
# running loss : 0.992437
# running loss : 0.989484
# running loss : 0.983702
# running loss : 0.972123
# running loss : 0.950818
# running loss : 0.945026
# running loss : 0.954239
# running loss : 0.953368
# running loss : 0.933105
# running loss : 0.916956
# running loss : 0.894285
# running loss : 0.903323
# running loss : 0.896746
# running loss : 0.872175
# running loss : 0.866289
# running loss : 0.867218
# running loss : 0.852159
# running loss : 0.849579
# running loss : 0.833737
# running loss : 0.821111
# running loss : 0.823946
# running loss : 0.810154
# running loss : 0.816457
# running loss : 0.791990
# running loss : 0.793665
# running loss : 0.787866
# running loss : 0.771626
# running loss : 0.767945
# running loss : 0.800004
# running loss : 0.782228
# running loss : 0.751513
# running loss : 0.740438
# running loss : 0.731392
# running loss : 0.726891
# running loss : 0.719213
# running loss : 0.718800
# running loss : 0.714190
# running loss : 0.709506
# running loss : 0.698616
# running loss : 0.685016
# running loss : 0.700641
# running loss : 0.696979
# running loss : 0.684291
# running loss : 0.678413
# running loss : 0.668872
# running loss : 0.689558
# running loss : 0.680770
# running loss : 0.673311
# running loss : 0.644461
# running loss : 0.646371
# running loss : 0.649749
# running loss : 0.648228
# running loss : 0.635184
# running loss : 0.639478
# running loss : 0.630855
# running loss : 0.621700
# running loss : 0.627154
# running loss : 0.615332
# running loss : 0.602966
# running loss : 0.594768
# running loss : 0.595563
# running loss : 0.589099
# running loss : 0.576549
# running loss : 0.572340
# running loss : 0.574348
# running loss : 0.575364
# running loss : 0.557242
# running loss : 0.553913
# running loss : 0.541292
# running loss : 0.545739
# running loss : 0.544435
# running loss : 0.543322
# running loss : 0.527966
# running loss : 0.526550
# running loss : 0.534829
# running loss : 0.526546
# running loss : 0.511528
# running loss : 0.511717
# running loss : 0.509880
# running loss : 0.497035
# running loss : 0.496947
# running loss : 0.506898
# running loss : 0.495532
# running loss : 0.498221
# running loss : 0.491796
# running loss : 0.483361
# running loss : 0.474492
# running loss : 0.483418
# running loss : 0.484970
# running loss : 0.471545
# running loss : 0.478480
# running loss : 0.454932
# running loss : 0.455250
# running loss : 0.448766
# running loss : 0.451357
# running loss : 0.457394
# running loss : 0.446899
# running loss : 0.449063
# running loss : 0.435368
# running loss : 0.441561
# running loss : 0.435901
# running loss : 0.427419
# running loss : 0.433659
# running loss : 0.422626
# running loss : 0.419414
# running loss : 0.426515
# running loss : 0.418162
# running loss : 0.414996
# running loss : 0.414252
# running loss : 0.410265
# running loss : 0.399168
# running loss : 0.394541
# running loss : 0.412495
# running loss : 0.395548
# running loss : 0.395761
# running loss : 0.394980
# running loss : 0.403317
# running loss : 0.393588
# running loss : 0.395427
# running loss : 0.382824
# running loss : 0.382694
# running loss : 0.375086
# running loss : 0.371678
# running loss : 0.382806
# running loss : 0.373204
# running loss : 0.381639
# running loss : 0.365621
# running loss : 0.363798
# running loss : 0.366704
# running loss : 0.363882
# running loss : 0.359526
# running loss : 0.360064
# running loss : 0.361050
# running loss : 0.353378
# running loss : 0.352948
# running loss : 0.352336
# running loss : 0.361924
# running loss : 0.357072
# running loss : 0.345565
# running loss : 0.355033
# running loss : 0.348148
# running loss : 0.342491
# running loss : 0.347281
# running loss : 0.346399
# running loss : 0.339770
# running loss : 0.342159
# running loss : 0.341177
# running loss : 0.343809
# running loss : 0.329471
# running loss : 0.335304
# running loss : 0.334024
# running loss : 0.329113
# running loss : 0.323966
# running loss : 0.324663
# running loss : 0.319021
# running loss : 0.319886
# running loss : 0.328131
# running loss : 0.316763
# running loss : 0.329093
# running loss : 0.327498
# running loss : 0.316752
# running loss : 0.322268
# running loss : 0.316964
# running loss : 0.310016
# running loss : 0.311292
# running loss : 0.322504
# running loss : 0.311525
# running loss : 0.312271
# running loss : 0.311677
# running loss : 0.299753
# running loss : 0.304634
# running loss : 0.308366
# running loss : 0.322530
# running loss : 0.301787
# running loss : 0.296788
# running loss : 0.309886
# running loss : 0.294745
# running loss : 0.297025
# running loss : 0.289559
# running loss : 0.294477
# running loss : 0.293954
# running loss : 0.296694
# running loss : 0.302735
# running loss : 0.299013
# running loss : 0.296980
# running loss : 0.297114
# running loss : 0.312476
# running loss : 0.299749
# running loss : 0.290325
# running loss : 0.298061
# running loss : 0.289372
# running loss : 0.283675
# running loss : 0.281950
# running loss : 0.277554
# running loss : 0.279898
# running loss : 0.282129
# running loss : 0.277945
# running loss : 0.282515
# running loss : 0.283883
# running loss : 0.272545
# running loss : 0.279624
# running loss : 0.280436
# running loss : 0.274328
# running loss : 0.273993
# running loss : 0.274330
# running loss : 0.278753
# running loss : 0.274255
# running loss : 0.275219
# running loss : 0.276972
# running loss : 0.271629
# running loss : 0.276676
# running loss : 0.269839
# running loss : 0.269513
# running loss : 0.269515
# running loss : 0.269104
# running loss : 0.264777
# running loss : 0.265792
# running loss : 0.261696
# running loss : 0.268261
# running loss : 0.272645
# running loss : 0.260584
# running loss : 0.264513
# running loss : 0.267430
# running loss : 0.265000
# running loss : 0.260364
# running loss : 0.263267
# running loss : 0.265551
# running loss : 0.261418
# running loss : 0.263715
# running loss : 0.265395
# running loss : 0.255710
# running loss : 0.256328
# running loss : 0.261997
# running loss : 0.267733
# running loss : 0.262031
# running loss : 0.266227
# running loss : 0.265838
# running loss : 0.262044
# running loss : 0.265465
# running loss : 0.256013
# running loss : 0.255726
# running loss : 0.261038
# running loss : 0.254535
# running loss : 0.253849
# running loss : 0.251117
# running loss : 0.256185
# running loss : 0.255799
# running loss : 0.253613
# running loss : 0.260010
# running loss : 0.255103
# running loss : 0.257769
# running loss : 0.257612
# running loss : 0.248124
# running loss : 0.253814
# running loss : 0.257437
# running loss : 0.255403
# running loss : 0.257685
# running loss : 0.251495
# running loss : 0.251619
# running loss : 0.256600
# running loss : 0.252604
# running loss : 0.248335
# running loss : 0.246749
# running loss : 0.249163
# running loss : 0.254536
# running loss : 0.246389
# running loss : 0.247952
# running loss : 0.245066
# running loss : 0.246479
# running loss : 0.250136
# running loss : 0.251909
# running loss : 0.249027
# running loss : 0.248448
# running loss : 0.241920
# running loss : 0.258498
# running loss : 0.253707
# running loss : 0.249118
# running loss : 0.251518
# running loss : 0.243606
# running loss : 0.247596
# running loss : 0.249806
# running loss : 0.252729
# running loss : 0.245813
# running loss : 0.241591
# running loss : 0.245547
# running loss : 0.244571
# running loss : 0.253560
# running loss : 0.243185
# running loss : 0.244267
# running loss : 0.246174
# running loss : 0.244803
# running loss : 0.245042
# running loss : 0.244642
# running loss : 0.244741
# running loss : 0.241774
# running loss : 0.244923
# running loss : 0.242942
# running loss : 0.243384
# running loss : 0.238486
# running loss : 0.241897
# running loss : 0.246014
# running loss : 0.234201
# running loss : 0.238357
# running loss : 0.244449
# running loss : 0.243728
# running loss : 0.241499
# running loss : 0.238608
# running loss : 0.234314
# running loss : 0.243838
# running loss : 0.243241
# running loss : 0.237575
# running loss : 0.237093
# running loss : 0.238533
# running loss : 0.240998
# running loss : 0.245642
# running loss : 0.244357
# running loss : 0.233592
# running loss : 0.232968
# running loss : 0.238864
# running loss : 0.242439
# running loss : 0.246208
# running loss : 0.233763
# running loss : 0.236761
# running loss : 0.231858
# running loss : 0.237277
# running loss : 0.239529
# running loss : 0.233003
# running loss : 0.232128
# running loss : 0.233254
# running loss : 0.232328
# running loss : 0.235657
# running loss : 0.233513
# running loss : 0.229427
# running loss : 0.232876
# running loss : 0.233391
# running loss : 0.230959
# running loss : 0.238375
# running loss : 0.245792
# running loss : 0.236427
# running loss : 0.228087
# running loss : 0.239676
# running loss : 0.238708
# running loss : 0.243850
# running loss : 0.244872
# running loss : 0.237860
# running loss : 0.239088
# running loss : 0.231482
# running loss : 0.229133
# running loss : 0.235439
# running loss : 0.230134
# running loss : 0.228920
# running loss : 0.233688
# running loss : 0.234684
# running loss : 0.231048
# running loss : 0.230208
# running loss : 0.234590
# running loss : 0.233059
# running loss : 0.232200
# running loss : 0.236429
# running loss : 0.230958
# running loss : 0.231117
# running loss : 0.230968
# running loss : 0.235963
# running loss : 0.228876
# running loss : 0.235014
# running loss : 0.229342
# running loss : 0.237138
# running loss : 0.231708
# running loss : 0.230242
# running loss : 0.230530
# running loss : 0.228214
# running loss : 0.230018
# running loss : 0.233292
# running loss : 0.236093
# running loss : 0.221819
# running loss : 0.230108
# running loss : 0.223080
# running loss : 0.227948
# running loss : 0.229028
# running loss : 0.230982
# running loss : 0.233431
# running loss : 0.228965
# running loss : 0.231037
# running loss : 0.229162
# running loss : 0.231977
# running loss : 0.223880
# running loss : 0.221830
# running loss : 0.225280
# running loss : 0.225599
# running loss : 0.225742
# running loss : 0.224069
# running loss : 0.224512
# running loss : 0.224499
# running loss : 0.225264
# running loss : 0.224102
# running loss : 0.231715
# running loss : 0.221901
# running loss : 0.227244
# running loss : 0.218032
# running loss : 0.228194
# running loss : 0.224068
# running loss : 0.225461
# running loss : 0.228215
# running loss : 0.221237
# running loss : 0.228058
# running loss : 0.226349
# running loss : 0.227538
# running loss : 0.226027
# running loss : 0.223937
# running loss : 0.228721
# running loss : 0.228117
# running loss : 0.225027
# running loss : 0.225998
# running loss : 0.219231
# running loss : 0.222430
# running loss : 0.225151
# running loss : 0.226558
# running loss : 0.224257
# running loss : 0.222744
# running loss : 0.220457
# running loss : 0.225088
# running loss : 0.224263
# running loss : 0.225846
# running loss : 0.221077
# running loss : 0.218706
# running loss : 0.220214
# running loss : 0.217313
# running loss : 0.217308
# running loss : 0.220382
# running loss : 0.224261
# running loss : 0.223678
# running loss : 0.224605
# running loss : 0.230708
# running loss : 0.227772
# running loss : 0.225844
# running loss : 0.233180
# running loss : 0.225729
# running loss : 0.226339
# running loss : 0.230473
# running loss : 0.231769
# running loss : 0.226045
# running loss : 0.226361
# running loss : 0.228310
# running loss : 0.226269
# running loss : 0.221714
# running loss : 0.225493
# running loss : 0.225865
# running loss : 0.231508
# running loss : 0.223804
# running loss : 0.225927
# running loss : 0.221961
# running loss : 0.226234
# running loss : 0.224905
# running loss : 0.227486
# running loss : 0.223946
# running loss : 0.220327
# running loss : 0.220073
# running loss : 0.226629
# running loss : 0.220995
# running loss : 0.216934
# running loss : 0.220915
# running loss : 0.218546
# running loss : 0.221643
# running loss : 0.221405
# running loss : 0.216346
# running loss : 0.211106
# running loss : 0.216469
# running loss : 0.219936
# running loss : 0.218492
# running loss : 0.214378
# running loss : 0.216236
# running loss : 0.215917
# running loss : 0.213594
# running loss : 0.212134
# running loss : 0.214114
# running loss : 0.222236
# running loss : 0.218465
# running loss : 0.216859
# running loss : 0.209891
# running loss : 0.207983
# running loss : 0.212800
# running loss : 0.212506
# running loss : 0.208673
# running loss : 0.210209
# running loss : 0.215849
# running loss : 0.215473
# running loss : 0.211636
# running loss : 0.216544
# running loss : 0.210550
# running loss : 0.210431
# running loss : 0.212198
# running loss : 0.210984
# running loss : 0.213170
# running loss : 0.206177
# running loss : 0.206141
# running loss : 0.214606
# running loss : 0.211065
# running loss : 0.217269
# running loss : 0.213299
# running loss : 0.206520
# running loss : 0.211225
# running loss : 0.211338
# running loss : 0.212807
# running loss : 0.213170
# running loss : 0.215426
# running loss : 0.210043
# running loss : 0.212471
# running loss : 0.210620
# running loss : 0.207955
# running loss : 0.221421
# running loss : 0.211305
# running loss : 0.213754
# running loss : 0.207245
# running loss : 0.207092
# running loss : 0.214315
# running loss : 0.213181
# running loss : 0.215855
# running loss : 0.211749
# running loss : 0.210875
# running loss : 0.212963
# running loss : 0.219293
# running loss : 0.208981
# running loss : 0.208275
# running loss : 0.214047
# running loss : 0.209030
# running loss : 0.212888
# running loss : 0.214165
# running loss : 0.209351
# running loss : 0.205881
# running loss : 0.213892
# running loss : 0.207516
# running loss : 0.214071
# running loss : 0.211876
# running loss : 0.215932
# running loss : 0.211439
# running loss : 0.211895
# running loss : 0.206430
# running loss : 0.206627
# running loss : 0.213175
# running loss : 0.212012
# running loss : 0.211802
# running loss : 0.205386
# running loss : 0.212729
# running loss : 0.210513
# running loss : 0.209842
# running loss : 0.210377
# running loss : 0.210700
# running loss : 0.215777
# running loss : 0.216467
# running loss : 0.217149
# running loss : 0.206288
# running loss : 0.215820
# running loss : 0.207006
# running loss : 0.211118
# running loss : 0.210491
# running loss : 0.211868
# running loss : 0.208366
# running loss : 0.209270
# running loss : 0.202914
# running loss : 0.201609
# running loss : 0.204628
# running loss : 0.208143
# running loss : 0.207717
# running loss : 0.207412
# running loss : 0.209468
# running loss : 0.213307
# running loss : 0.207205
# running loss : 0.203502
# running loss : 0.209475
# running loss : 0.208387
# running loss : 0.203780
# running loss : 0.206695
# running loss : 0.205488
# running loss : 0.204356
# running loss : 0.206239
# running loss : 0.203797
# running loss : 0.206271
# running loss : 0.203064
# running loss : 0.201544
# running loss : 0.202390
# running loss : 0.204053
# running loss : 0.204443
# running loss : 0.208282
# running loss : 0.209356
# running loss : 0.203413
# running loss : 0.203921
# running loss : 0.209583
# running loss : 0.215665
# running loss : 0.209995
# running loss : 0.201767
# running loss : 0.205652
# running loss : 0.203980
# running loss : 0.201503
# running loss : 0.202937
# running loss : 0.205043
# running loss : 0.204682
# running loss : 0.205334
# running loss : 0.208686
# running loss : 0.199403
# running loss : 0.204781
# running loss : 0.201702
# running loss : 0.202199
# running loss : 0.197615
# running loss : 0.201072
# running loss : 0.201546
# running loss : 0.202967
# running loss : 0.204858
# running loss : 0.200226
# running loss : 0.208684
# running loss : 0.199898
# running loss : 0.204153
# running loss : 0.203030
# running loss : 0.206731
# running loss : 0.207833
# running loss : 0.204077
# running loss : 0.205908
# running loss : 0.202064
# running loss : 0.206561
# running loss : 0.201078
# running loss : 0.200100
# running loss : 0.197134
# running loss : 0.199571
# running loss : 0.202367
# running loss : 0.197623
# running loss : 0.201808
# running loss : 0.202429
# running loss : 0.201806
# running loss : 0.198302
# running loss : 0.199058
# running loss : 0.195493
# running loss : 0.199685
# running loss : 0.197460
# running loss : 0.204601
# running loss : 0.203414
# running loss : 0.197225
# running loss : 0.200289
# running loss : 0.202185
# running loss : 0.203004
# running loss : 0.200377
# running loss : 0.199308
# running loss : 0.198738
# running loss : 0.198941
# running loss : 0.195645
# running loss : 0.197550
# running loss : 0.192821
# running loss : 0.199581
# running loss : 0.197782
# running loss : 0.197190
# running loss : 0.198757
# running loss : 0.198994
# running loss : 0.206447
# running loss : 0.202432
# running loss : 0.204373
# running loss : 0.202956
# running loss : 0.203251
# running loss : 0.203201
# running loss : 0.205902
# running loss : 0.200617
# running loss : 0.201356
# running loss : 0.199787
# running loss : 0.200774
# running loss : 0.198637
# running loss : 0.198947
# running loss : 0.201103
# running loss : 0.202281
# running loss : 0.198066
# running loss : 0.196555
# running loss : 0.195651
# running loss : 0.196616
# running loss : 0.197648
# running loss : 0.196402
# running loss : 0.200056
# running loss : 0.198154
# running loss : 0.192644
# running loss : 0.191710
# running loss : 0.198684
# running loss : 0.196346
# running loss : 0.193913
# running loss : 0.193820
# running loss : 0.195600
# running loss : 0.199865
# running loss : 0.194889
# running loss : 0.197247
# running loss : 0.190819
# running loss : 0.193585
# running loss : 0.187458
# running loss : 0.186775
# running loss : 0.184585
# running loss : 0.188038
# running loss : 0.185307
# running loss : 0.184988
# running loss : 0.185789
# running loss : 0.183978
# running loss : 0.188477
# running loss : 0.189053
# running loss : 0.190191
# running loss : 0.190858
# running loss : 0.185329
# running loss : 0.185485
# running loss : 0.189026
# running loss : 0.184713
# running loss : 0.185418
# running loss : 0.186146
# running loss : 0.187619
# running loss : 0.185437
# running loss : 0.184187
# running loss : 0.188259
# running loss : 0.185102
# running loss : 0.190173
# running loss : 0.186421
# running loss : 0.187366
# running loss : 0.185355
# running loss : 0.186483
# running loss : 0.188327
# running loss : 0.183101
# running loss : 0.178928
# running loss : 0.180447
# running loss : 0.179912
# running loss : 0.181546
# running loss : 0.182476
# running loss : 0.183530
# running loss : 0.180739
# running loss : 0.182512
# running loss : 0.181208
# running loss : 0.179657
# running loss : 0.191108
# running loss : 0.190670
# running loss : 0.189563
# running loss : 0.195188
# running loss : 0.188765
# running loss : 0.191534
# running loss : 0.188873
# running loss : 0.187866
# running loss : 0.186088
# running loss : 0.187752
# running loss : 0.183072
# running loss : 0.187294
# running loss : 0.189715
# running loss : 0.186852
# running loss : 0.183845
# running loss : 0.180674
# running loss : 0.181450
# running loss : 0.191398
# running loss : 0.188012
# running loss : 0.193121
# running loss : 0.191112
# running loss : 0.203194
# running loss : 0.192704
# running loss : 0.192506
# running loss : 0.197197
# running loss : 0.197996
# running loss : 0.200284
# running loss : 0.201378
# running loss : 0.199980
# running loss : 0.199633
# running loss : 0.199275
# running loss : 0.200296
# running loss : 0.197414
# running loss : 0.200130
# running loss : 0.197681
# running loss : 0.200977
# running loss : 0.199585
# running loss : 0.198078
# running loss : 0.195638
# running loss : 0.190641
# running loss : 0.190198
# running loss : 0.193689
# running loss : 0.193823
# running loss : 0.193564
# running loss : 0.194992
# running loss : 0.193434
# running loss : 0.194170
# running loss : 0.196347
# running loss : 0.195728
# running loss : 0.191460
# running loss : 0.191661
# running loss : 0.198784
# running loss : 0.204456
# running loss : 0.206852
# running loss : 0.209737
# running loss : 0.209691
# running loss : 0.201286
# running loss : 0.205434
# running loss : 0.200860
# running loss : 0.203057
# running loss : 0.197123
# running loss : 0.195982
# running loss : 0.199483
# running loss : 0.203925
# running loss : 0.203987
# running loss : 0.201662
# running loss : 0.199029
# running loss : 0.197795
# running loss : 0.193906
# running loss : 0.192732
# running loss : 0.195738
# running loss : 0.193981
# running loss : 0.194771
# running loss : 0.195205
# running loss : 0.199046
# running loss : 0.203029
# running loss : 0.201393
# running loss : 0.199155
# running loss : 0.198952
# running loss : 0.197890
# running loss : 0.195930
# running loss : 0.196537
# running loss : 0.193466
# running loss : 0.191944
# running loss : 0.193472
# running loss : 0.197618
# running loss : 0.193852
# running loss : 0.192546
# running loss : 0.191927
# running loss : 0.194085
# running loss : 0.193428
# running loss : 0.191449
# running loss : 0.209110
# running loss : 0.208358
# running loss : 0.213544
# running loss : 0.210590
# running loss : 0.206312
# running loss : 0.207395
# running loss : 0.206430
# running loss : 0.209446
# running loss : 0.201585
# running loss : 0.203701
# running loss : 0.202167
# running loss : 0.200279
# running loss : 0.199259
# running loss : 0.196605
# running loss : 0.195874
# running loss : 0.195745
# running loss : 0.193298
# running loss : 0.195889
# running loss : 0.195063
# running loss : 0.190113
# running loss : 0.196236
# running loss : 0.198438
# running loss : 0.199439
# running loss : 0.201691
# running loss : 0.205521
# running loss : 0.202393
# running loss : 0.201303
# running loss : 0.197986
# running loss : 0.194420
# running loss : 0.197082
# running loss : 0.195281
# running loss : 0.192947
# running loss : 0.189125
# running loss : 0.188132
# running loss : 0.191255
# running loss : 0.191012
# running loss : 0.192971
# running loss : 0.192007
# running loss : 0.185226
# running loss : 0.189121
# running loss : 0.183085
# running loss : 0.191028
# running loss : 0.189283
# running loss : 0.176145
# running loss : 0.176368
# running loss : 0.184156
# running loss : 0.175911
# running loss : 0.175481
# running loss : 0.177662
# running loss : 0.177444
# running loss : 0.176062
# running loss : 0.172938
# running loss : 0.176247
# running loss : 0.178652
# running loss : 0.177241
# running loss : 0.175599
# running loss : 0.174333
# running loss : 0.176178
# running loss : 0.175983
# running loss : 0.175746
# running loss : 0.175653
# running loss : 0.178656
# running loss : 0.175392
# running loss : 0.172928
# running loss : 0.173060
# running loss : 0.173297
# running loss : 0.174092
# running loss : 0.171371
# running loss : 0.176373
# running loss : 0.181838
# running loss : 0.180586
# running loss : 0.190748
# running loss : 0.188299
# running loss : 0.191625
# running loss : 0.190296
# running loss : 0.187995
# running loss : 0.188443
# running loss : 0.183370
# running loss : 0.185048
# running loss : 0.187305
# running loss : 0.182087
# running loss : 0.179146
# running loss : 0.175477
# running loss : 0.183294
# running loss : 0.185109
# running loss : 0.186638
# running loss : 0.185406
# running loss : 0.184456
# running loss : 0.187736
# running loss : 0.182283
# running loss : 0.182385
# running loss : 0.182474
# running loss : 0.183773
# running loss : 0.190231
# running loss : 0.182994
# running loss : 0.182110
# running loss : 0.189526
# running loss : 0.188096
# running loss : 0.190235
# running loss : 0.186152
# running loss : 0.185531
# running loss : 0.186722
# running loss : 0.188736
# running loss : 0.184335
# running loss : 0.190603
# running loss : 0.183906
# running loss : 0.186571
# running loss : 0.189856
# running loss : 0.186430
# running loss : 0.182968
# running loss : 0.185548
# running loss : 0.192447
# running loss : 0.199261
# running loss : 0.203823
# running loss : 0.197162
# running loss : 0.200021
# running loss : 0.195729
# running loss : 0.203256
# running loss : 0.198416
# running loss : 0.196124
# running loss : 0.202410
# running loss : 0.202928
# running loss : 0.205353
# running loss : 0.201333
# running loss : 0.204198
# running loss : 0.197433
# running loss : 0.194331
# running loss : 0.195362
# running loss : 0.195156
# running loss : 0.195262
# running loss : 0.191803
# running loss : 0.192310
# running loss : 0.189628
# running loss : 0.191625
# running loss : 0.192025
# running loss : 0.189619
# running loss : 0.186041
# running loss : 0.183743
# running loss : 0.182838
# running loss : 0.179467
# running loss : 0.180015
# running loss : 0.180812
# running loss : 0.175688
# running loss : 0.176605
# running loss : 0.178042
# running loss : 0.175686
# running loss : 0.178550
# running loss : 0.176913
# running loss : 0.175615
# running loss : 0.168126
# running loss : 0.170783
# running loss : 0.163298
# running loss : 0.167980
# running loss : 0.176793
# running loss : 0.172604
# running loss : 0.173311
# running loss : 0.171265
# running loss : 0.172848
# running loss : 0.174576
# running loss : 0.172037
# running loss : 0.168614
# running loss : 0.171762
# running loss : 0.169346
# running loss : 0.168490
# running loss : 0.169160
# running loss : 0.169458
# running loss : 0.170564
# running loss : 0.171052
# running loss : 0.167842
# running loss : 0.173613
# running loss : 0.178026
# running loss : 0.186775
# running loss : 0.188457
# running loss : 0.193938
# running loss : 0.187209
# running loss : 0.187653
# running loss : 0.188105
# running loss : 0.184984
# running loss : 0.193067
# running loss : 0.192729
# running loss : 0.192842
# running loss : 0.193496
# running loss : 0.194837
# running loss : 0.191274
# running loss : 0.185201
# running loss : 0.185848
# running loss : 0.186928
# running loss : 0.185664
# running loss : 0.184025
# running loss : 0.182469
# running loss : 0.180503
# running loss : 0.190684
# running loss : 0.191346
# running loss : 0.193650
# running loss : 0.190537
# running loss : 0.191677
# running loss : 0.180394
# running loss : 0.184064
# running loss : 0.179769
# running loss : 0.178105
# running loss : 0.186357
# running loss : 0.188031
# running loss : 0.186959
# running loss : 0.184872
# running loss : 0.184267
# running loss : 0.181725
# running loss : 0.180738
# running loss : 0.182957
# running loss : 0.191068
# running loss : 0.192969
# running loss : 0.194774
# running loss : 0.194637
# running loss : 0.193269
# running loss : 0.196442
# running loss : 0.191923
# running loss : 0.187322
# running loss : 0.189867
# running loss : 0.192223
# running loss : 0.188768
# running loss : 0.187472
# running loss : 0.188758
# running loss : 0.190453
# running loss : 0.192629
# running loss : 0.190340
# running loss : 0.185180
# running loss : 0.184420
# running loss : 0.186773
# running loss : 0.185096
# running loss : 0.180964
# running loss : 0.183280
# running loss : 0.182492
# running loss : 0.180669
# running loss : 0.178283
# running loss : 0.185703
# running loss : 0.190716
# running loss : 0.191867
# running loss : 0.191761
# running loss : 0.189509
# running loss : 0.188585
# running loss : 0.188922
# running loss : 0.190640
# running loss : 0.187049
# running loss : 0.182544
# running loss : 0.181850
# running loss : 0.178503
# running loss : 0.180832
# running loss : 0.179972
# running loss : 0.184928
# running loss : 0.179884
# running loss : 0.179758
# running loss : 0.186175
# running loss : 0.190538
# running loss : 0.186663
# running loss : 0.185383
# running loss : 0.184794
# running loss : 0.189815
# running loss : 0.187386
# running loss : 0.191975
# running loss : 0.189985
# running loss : 0.189772
# running loss : 0.189364
# running loss : 0.187489
# running loss : 0.188833
# running loss : 0.188089
# running loss : 0.181897
# running loss : 0.178524
# running loss : 0.177847
# running loss : 0.180337
# running loss : 0.175385
# running loss : 0.169547
# running loss : 0.170835
# running loss : 0.170842
# running loss : 0.166571
# running loss : 0.168141
# running loss : 0.168056
# running loss : 0.165753
# running loss : 0.170262
# running loss : 0.175034
# running loss : 0.175292
# running loss : 0.172495
# running loss : 0.174657
# running loss : 0.177558
# running loss : 0.169342
# running loss : 0.160947
# running loss : 0.165129
# running loss : 0.162853
# running loss : 0.165326
# running loss : 0.165597
# running loss : 0.168717
# running loss : 0.164350
# running loss : 0.161562
# running loss : 0.162092
# running loss : 0.158215
# running loss : 0.164050
# running loss : 0.164531
# running loss : 0.163693
# running loss : 0.169414
# running loss : 0.162022
# running loss : 0.164767
# running loss : 0.163341
# running loss : 0.168335
# running loss : 0.167648
# running loss : 0.162424
# running loss : 0.165396
# running loss : 0.169182
# running loss : 0.175535
# running loss : 0.172174
# running loss : 0.172433
# running loss : 0.183192
# running loss : 0.180175
# running loss : 0.188319
# running loss : 0.190376
# running loss : 0.186431
# running loss : 0.189055
# running loss : 0.189098
# running loss : 0.184547
# running loss : 0.187022
# running loss : 0.188204
# running loss : 0.180981
# running loss : 0.176155
# running loss : 0.176105
# running loss : 0.192584
# running loss : 0.190421
# running loss : 0.192804
# running loss : 0.186216
# running loss : 0.189978
# running loss : 0.187052
# running loss : 0.186224
# running loss : 0.187794
# running loss : 0.189060
# running loss : 0.188485
# running loss : 0.187660
# running loss : 0.187364
# running loss : 0.185264
# running loss : 0.181738
# running loss : 0.177799
# running loss : 0.186330
# running loss : 0.187529
# running loss : 0.182313
# running loss : 0.181328
# running loss : 0.181417
# running loss : 0.181845
# running loss : 0.187738
# running loss : 0.182545
# running loss : 0.181683
# running loss : 0.173972
# running loss : 0.173807
# running loss : 0.176823
# running loss : 0.176610
# running loss : 0.176813
# running loss : 0.180420
# running loss : 0.177268
# running loss : 0.176193
# running loss : 0.181281
# running loss : 0.174677
# running loss : 0.173612
# running loss : 0.176425
# running loss : 0.177650
# running loss : 0.189316
# running loss : 0.190739
# running loss : 0.191947
# running loss : 0.192757
# running loss : 0.189154
# running loss : 0.187410
# running loss : 0.188425
# running loss : 0.185466
# running loss : 0.187942
# running loss : 0.189545
# running loss : 0.187231
# running loss : 0.183986
# running loss : 0.185250
# running loss : 0.185411
# running loss : 0.182780
# running loss : 0.185377
# running loss : 0.199391
# running loss : 0.203950
# running loss : 0.211479
# running loss : 0.210745
# running loss : 0.208034
# running loss : 0.208121
# running loss : 0.215018
# running loss : 0.219865
# running loss : 0.224223
# running loss : 0.222854
# running loss : 0.226787
# running loss : 0.221116
# running loss : 0.219131
# running loss : 0.220466
# running loss : 0.225325
# running loss : 0.226714
# running loss : 0.235679
# running loss : 0.236677
# running loss : 0.233558
# running loss : 0.222107
# running loss : 0.220480
# running loss : 0.219044
# running loss : 0.220937
# running loss : 0.216252
# running loss : 0.215001
# running loss : 0.217355
# running loss : 0.212250
# running loss : 0.211809
# running loss : 0.210239
# running loss : 0.205395
# running loss : 0.207066
# running loss : 0.204791
# running loss : 0.200792
# running loss : 0.202908
# running loss : 0.202152
# running loss : 0.202183
# running loss : 0.199316
# running loss : 0.194610
# running loss : 0.195290
# running loss : 0.191104
# running loss : 0.189521
# running loss : 0.189048
# running loss : 0.189037
# running loss : 0.186757
# running loss : 0.193079
# running loss : 0.190270
# running loss : 0.190062
# running loss : 0.183115
# running loss : 0.181012
# running loss : 0.184429
# running loss : 0.178591
# running loss : 0.175099
# running loss : 0.174581
# running loss : 0.172226
# running loss : 0.175256
# running loss : 0.174602
# running loss : 0.170540
# running loss : 0.172132
# running loss : 0.176028
# running loss : 0.182873
# running loss : 0.179325
# running loss : 0.175601
# running loss : 0.173082
# running loss : 0.173749
# running loss : 0.185342
# running loss : 0.192599
# running loss : 0.191295
# running loss : 0.190231
# running loss : 0.191784
# running loss : 0.189963
# running loss : 0.189159
# running loss : 0.186116
# running loss : 0.188154
# running loss : 0.191662
# running loss : 0.195884
# running loss : 0.195467
# running loss : 0.193560
# running loss : 0.194630
# running loss : 0.194324
# running loss : 0.195219
# running loss : 0.187859
# running loss : 0.186023
# running loss : 0.190219
# running loss : 0.186738
# running loss : 0.178706
# running loss : 0.184569
# running loss : 0.176804
# running loss : 0.184259
# running loss : 0.181689
# running loss : 0.183965
# running loss : 0.183241
# running loss : 0.182762
# running loss : 0.185175
# running loss : 0.182377
# running loss : 0.187256
# running loss : 0.176820
# running loss : 0.178323
# running loss : 0.176638
# running loss : 0.177314
# running loss : 0.175928
# running loss : 0.178413
# running loss : 0.194312
# running loss : 0.195689
# running loss : 0.193892
# running loss : 0.191566
# running loss : 0.188982
# running loss : 0.187826
# running loss : 0.188432
# running loss : 0.183753
# running loss : 0.177232
# running loss : 0.180663
# running loss : 0.186522
# running loss : 0.179469
# running loss : 0.175419
# running loss : 0.176770
# running loss : 0.166625
# running loss : 0.166071
# running loss : 0.170123
# running loss : 0.173118
# running loss : 0.171053
# running loss : 0.163228
# running loss : 0.161383
# running loss : 0.161995
# running loss : 0.171777
# running loss : 0.166968
# running loss : 0.162110
# running loss : 0.164474
# running loss : 0.164471
# running loss : 0.163060
# running loss : 0.157917
# running loss : 0.161574
# running loss : 0.166888
# running loss : 0.171386
# running loss : 0.169283
# running loss : 0.166429
# running loss : 0.163167
# running loss : 0.166876
# running loss : 0.179039
# running loss : 0.177634
# running loss : 0.181533
# running loss : 0.178236
# running loss : 0.174826
# running loss : 0.176623
# running loss : 0.177514
# running loss : 0.176896
# running loss : 0.176195
# running loss : 0.178415
# running loss : 0.180072
# running loss : 0.176078
# running loss : 0.169530
# running loss : 0.167420
# running loss : 0.168464
# running loss : 0.167584
# running loss : 0.175350
# running loss : 0.170672
# running loss : 0.174175
# running loss : 0.174297
# running loss : 0.171413
# running loss : 0.173329
# running loss : 0.164421
# running loss : 0.164088
# running loss : 0.165710
# running loss : 0.171553
# running loss : 0.172591
# running loss : 0.166742
# running loss : 0.166048
# running loss : 0.166284
# running loss : 0.166926
# running loss : 0.163562
# running loss : 0.163474
# running loss : 0.163907
# running loss : 0.165534
# running loss : 0.163663
# running loss : 0.163593
# running loss : 0.164737
# running loss : 0.163061
# running loss : 0.161481
# running loss : 0.162244
# running loss : 0.163704
# running loss : 0.166202
# running loss : 0.163317
# running loss : 0.165008
# running loss : 0.162905
# running loss : 0.162612
# running loss : 0.162540
# running loss : 0.163158
# running loss : 0.173144
# running loss : 0.176161
# running loss : 0.171248
# running loss : 0.164940
# running loss : 0.171827
# running loss : 0.172503
# running loss : 0.169336
# running loss : 0.171086
# running loss : 0.180228
# running loss : 0.171325
# running loss : 0.176925
# running loss : 0.176478
# running loss : 0.183526
# running loss : 0.195148
# running loss : 0.188347
# running loss : 0.180679
# running loss : 0.182122
# running loss : 0.180454
# running loss : 0.183196
# running loss : 0.183357
# running loss : 0.187014
# running loss : 0.189936
# running loss : 0.187273
# running loss : 0.190167
# running loss : 0.185837
# running loss : 0.185958
# running loss : 0.187052
# running loss : 0.187746
# running loss : 0.186914
# running loss : 0.190158
# running loss : 0.189030
# running loss : 0.187469
# running loss : 0.187659
# running loss : 0.187607
# running loss : 0.198175
# running loss : 0.200450
# running loss : 0.196654
# running loss : 0.196415
# running loss : 0.198027
# running loss : 0.194878
# running loss : 0.195846
# running loss : 0.197153
# running loss : 0.195742
# running loss : 0.197499
# running loss : 0.196195
# running loss : 0.196559
# running loss : 0.193456
# running loss : 0.193983
# running loss : 0.194963
# running loss : 0.193762
# running loss : 0.193769
# running loss : 0.196232
# running loss : 0.199968
# running loss : 0.193499
# running loss : 0.194858
# running loss : 0.195486
# running loss : 0.201540
# running loss : 0.199651
# running loss : 0.199317
# running loss : 0.204590
# running loss : 0.207685
# running loss : 0.204726
# running loss : 0.205243
# running loss : 0.201762
# running loss : 0.201110
# running loss : 0.200254
# running loss : 0.204884
# running loss : 0.202024
# running loss : 0.195874
# running loss : 0.192386
# running loss : 0.188931
# running loss : 0.184518
# running loss : 0.183589
# running loss : 0.193060
# running loss : 0.200486
# running loss : 0.197403
# running loss : 0.203628
# running loss : 0.202726
# running loss : 0.206604
# running loss : 0.209426
# running loss : 0.203005
# running loss : 0.199528
# running loss : 0.198458
# running loss : 0.197009
# running loss : 0.198936
# running loss : 0.201757
# running loss : 0.198787
# running loss : 0.214253
# running loss : 0.213766
# running loss : 0.212878
# running loss : 0.210340
# running loss : 0.209833
# running loss : 0.209559
# running loss : 0.207261
# running loss : 0.204507
# running loss : 0.211017
# running loss : 0.220099
# running loss : 0.222673
# running loss : 0.235307
# running loss : 0.220416
# running loss : 0.215092
# running loss : 0.216489
# running loss : 0.212479
# running loss : 0.204713
# running loss : 0.201537
# running loss : 0.202293
# running loss : 0.204806
# running loss : 0.202726
# running loss : 0.201211
# running loss : 0.200050
# running loss : 0.202407
# running loss : 0.208257
# running loss : 0.199906
# running loss : 0.197029
# running loss : 0.197448
# running loss : 0.200470
# running loss : 0.202317
# running loss : 0.201035
# running loss : 0.209226
# running loss : 0.205701
# running loss : 0.199689
# running loss : 0.196505
# running loss : 0.198087
# running loss : 0.200476
# running loss : 0.195107
# running loss : 0.195653
# running loss : 0.197226
# running loss : 0.193341
# running loss : 0.189659
# running loss : 0.192241
# running loss : 0.189704
# running loss : 0.192234
# running loss : 0.191563
# running loss : 0.190470
# running loss : 0.187431
# running loss : 0.199110
# running loss : 0.205897
# running loss : 0.192268
# running loss : 0.200517
# running loss : 0.200856
# running loss : 0.209294
# running loss : 0.210281
# running loss : 0.205786
# running loss : 0.207870
# running loss : 0.208278
# running loss : 0.208520
# running loss : 0.213548
# running loss : 0.215471
# running loss : 0.210834
# running loss : 0.219903
# running loss : 0.217021
# running loss : 0.207877
# running loss : 0.207579
# running loss : 0.214404
# running loss : 0.229781
# running loss : 0.211583
# running loss : 0.204565
# running loss : 0.199083
# running loss : 0.197951
# running loss : 0.210620
# running loss : 0.208250
# running loss : 0.206738
# running loss : 0.205645
# running loss : 0.203020
# running loss : 0.203129
# running loss : 0.202942
# running loss : 0.198531
# running loss : 0.200788
# running loss : 0.199153
# running loss : 0.200932
# running loss : 0.199932
# running loss : 0.209779
# running loss : 0.206936
# running loss : 0.204749
# running loss : 0.202602
# running loss : 0.200448
# running loss : 0.206960
# running loss : 0.201644
# running loss : 0.200338
# running loss : 0.201091
# running loss : 0.201859
# running loss : 0.202353
# running loss : 0.196911
# running loss : 0.196747
# running loss : 0.200313
# running loss : 0.209103
# running loss : 0.207632
# running loss : 0.208592
# running loss : 0.202214
# running loss : 0.204221
# running loss : 0.204884
# running loss : 0.198676
# running loss : 0.195131
# running loss : 0.195735
# running loss : 0.197651
# running loss : 0.196588
# running loss : 0.195950
# running loss : 0.203291
# running loss : 0.196593
# running loss : 0.195204
# running loss : 0.200812
# running loss : 0.197340
# running loss : 0.195230
# running loss : 0.196700
# running loss : 0.195230
# running loss : 0.195941
# running loss : 0.196451
# running loss : 0.194008
# running loss : 0.192433
# running loss : 0.191439
# running loss : 0.189596
# running loss : 0.187866
# running loss : 0.185000
# running loss : 0.188883
# running loss : 0.184423
# running loss : 0.180553
# running loss : 0.176739
# running loss : 0.185139
# running loss : 0.188759
# running loss : 0.189550
# running loss : 0.192433
# running loss : 0.194995
# running loss : 0.199907
# running loss : 0.198475
# running loss : 0.194430
# running loss : 0.188303
# running loss : 0.189207
# running loss : 0.185924
# running loss : 0.193736
# running loss : 0.188307
# running loss : 0.190151
# running loss : 0.204774
# running loss : 0.189638
# running loss : 0.186911
# running loss : 0.192498
# running loss : 0.207062
# running loss : 0.200728
# running loss : 0.200437
# running loss : 0.195828
# running loss : 0.195056
# running loss : 0.192171
# running loss : 0.191340
# running loss : 0.186946
# running loss : 0.194654
# running loss : 0.198242
# running loss : 0.201890
# running loss : 0.208713
# running loss : 0.210113
# running loss : 0.208828
# running loss : 0.206907
# running loss : 0.213939
# running loss : 0.212332
# running loss : 0.214365
# running loss : 0.215273
# running loss : 0.211430
# running loss : 0.213390
# running loss : 0.210441
# running loss : 0.208725
# running loss : 0.212384
# running loss : 0.209965
# running loss : 0.208224
# running loss : 0.203697
# running loss : 0.207876
# running loss : 0.207984
# running loss : 0.208834
# running loss : 0.203558
# running loss : 0.203064
# running loss : 0.206421
# running loss : 0.213371
# running loss : 0.206930
# running loss : 0.202652
# running loss : 0.200148
# running loss : 0.201946
# running loss : 0.199318
# running loss : 0.212274
# running loss : 0.206267
# running loss : 0.207492
# running loss : 0.211719
# running loss : 0.213273
# running loss : 0.208126
# running loss : 0.206622
# running loss : 0.204497
# running loss : 0.195656
# running loss : 0.189682
# running loss : 0.187589
# running loss : 0.193221
# running loss : 0.200064
# running loss : 0.191803
# running loss : 0.188364
# running loss : 0.187280
# running loss : 0.185615
# running loss : 0.188536
# running loss : 0.189895
# running loss : 0.189514
# running loss : 0.187784
# running loss : 0.179565
# running loss : 0.177895
# running loss : 0.175995
# running loss : 0.174426
# running loss : 0.181917
# running loss : 0.190405
# running loss : 0.191395
# running loss : 0.194629
# running loss : 0.194230
# running loss : 0.192194
# running loss : 0.187610
# running loss : 0.182141
# running loss : 0.184359
# running loss : 0.175296
# running loss : 0.176960
# running loss : 0.173474
# running loss : 0.173305
# running loss : 0.172272
# running loss : 0.171405
# running loss : 0.172498
# running loss : 0.170838
# running loss : 0.169374
# running loss : 0.169095
# running loss : 0.170536
# running loss : 0.174876
# running loss : 0.168251
# running loss : 0.172349
# running loss : 0.169290
# running loss : 0.165897
# running loss : 0.165445
# running loss : 0.171346
# running loss : 0.179019
# running loss : 0.192730
# running loss : 0.191321
# running loss : 0.192744
# running loss : 0.189935
# running loss : 0.191594
# running loss : 0.186269
# running loss : 0.183886
# running loss : 0.190519
# running loss : 0.197965
# running loss : 0.197421
# running loss : 0.194276
# running loss : 0.194129
# running loss : 0.204158
# running loss : 0.194756
# running loss : 0.208311
# running loss : 0.200691
# running loss : 0.194469
# running loss : 0.199544
# running loss : 0.193199
# running loss : 0.189980
# running loss : 0.190840
# running loss : 0.177429
# running loss : 0.179315
# running loss : 0.179534
# running loss : 0.178780
# running loss : 0.176471
# running loss : 0.183944
# running loss : 0.187722
# running loss : 0.185658
# running loss : 0.182080
# running loss : 0.184411
# running loss : 0.203001
# running loss : 0.193910
# running loss : 0.197962
# running loss : 0.194487
# running loss : 0.188062
# running loss : 0.189760
# running loss : 0.189545
# running loss : 0.189504
# running loss : 0.191959
# running loss : 0.195895
# running loss : 0.193026
# running loss : 0.189784
# running loss : 0.200052
# running loss : 0.198233
# running loss : 0.211848
# running loss : 0.214809
# running loss : 0.213687
# running loss : 0.203649
# running loss : 0.201107
# running loss : 0.200458
# running loss : 0.202931
# running loss : 0.202631
# running loss : 0.200461
# running loss : 0.198838
# running loss : 0.202564
# running loss : 0.212056
# running loss : 0.219523
# running loss : 0.224476
# running loss : 0.213599
# running loss : 0.214417
# running loss : 0.209766
# running loss : 0.205323
# running loss : 0.200902
# running loss : 0.211188
# running loss : 0.216242
# running loss : 0.218087
# running loss : 0.211454
# running loss : 0.211375
# running loss : 0.217477
# running loss : 0.212176
# running loss : 0.216954
# running loss : 0.223100
# running loss : 0.216939
# running loss : 0.208182
# running loss : 0.207982
# running loss : 0.202678
# running loss : 0.198638
# running loss : 0.197603
# running loss : 0.196215
# running loss : 0.200613
# running loss : 0.201635
# running loss : 0.199604
# running loss : 0.211008
# running loss : 0.215439
# running loss : 0.220317
# running loss : 0.207775
# running loss : 0.208177
# running loss : 0.207772
# running loss : 0.211940
# running loss : 0.207307
# running loss : 0.211263
# running loss : 0.202486
# running loss : 0.209923
# running loss : 0.213003
# running loss : 0.212421
# running loss : 0.228759
# running loss : 0.228741
# running loss : 0.228060
# running loss : 0.229501
# running loss : 0.231378
# running loss : 0.229790
# running loss : 0.237671
# running loss : 0.230400
# running loss : 0.225078
# running loss : 0.225546
# running loss : 0.215293
# running loss : 0.212937
# running loss : 0.217052
# running loss : 0.213366
# running loss : 0.208807
# running loss : 0.208014
# running loss : 0.209995
# running loss : 0.209540
# running loss : 0.201948
# running loss : 0.199170
# running loss : 0.196816
# running loss : 0.203604
# running loss : 0.202283
# running loss : 0.201642
# running loss : 0.205846
# running loss : 0.201415
# running loss : 0.202758
# running loss : 0.208093
# running loss : 0.214905
# running loss : 0.209578
# running loss : 0.206971
# running loss : 0.202476
# running loss : 0.203897
# running loss : 0.199434
# running loss : 0.204360
# running loss : 0.208543
# running loss : 0.208109
# running loss : 0.203524
# running loss : 0.203568
# running loss : 0.198947
# running loss : 0.208112
# running loss : 0.216938
# running loss : 0.222503
# running loss : 0.221129
# running loss : 0.228273
# running loss : 0.227074
# running loss : 0.210845
# running loss : 0.207079
# running loss : 0.201299
# running loss : 0.195864
# running loss : 0.199131
# running loss : 0.186804
# running loss : 0.206719
# running loss : 0.212541
# running loss : 0.201159
# running loss : 0.198959
# running loss : 0.197018
# running loss : 0.186277
# running loss : 0.184771
# running loss : 0.189764
# running loss : 0.192386
# running loss : 0.188852
# running loss : 0.188389
# running loss : 0.189525
# running loss : 0.184418
# running loss : 0.187794
# running loss : 0.183636
# running loss : 0.181767
# running loss : 0.194465
# running loss : 0.190024
# running loss : 0.194501
# running loss : 0.183831
# running loss : 0.187170
# running loss : 0.186429
# running loss : 0.183855
# running loss : 0.180694
# running loss : 0.190787
# running loss : 0.188534
# running loss : 0.200907
# running loss : 0.190404
# running loss : 0.182798
# running loss : 0.185325
# running loss : 0.192003
# running loss : 0.188346
# running loss : 0.196447
# running loss : 0.194696
# running loss : 0.195527
# running loss : 0.199360
# running loss : 0.191423
# running loss : 0.191614
# running loss : 0.195431
# running loss : 0.205595
# running loss : 0.211988
# running loss : 0.207201
# running loss : 0.201221
# running loss : 0.203338
# running loss : 0.200128
# running loss : 0.208400
# running loss : 0.193141
# running loss : 0.189975
# running loss : 0.186109
# running loss : 0.189797
# running loss : 0.183336
# running loss : 0.184816
# running loss : 0.191979
# running loss : 0.195301
# running loss : 0.203752
# running loss : 0.198225
# running loss : 0.191993
# running loss : 0.192041
# running loss : 0.189465
# running loss : 0.189107
# running loss : 0.192853
# running loss : 0.192476
# running loss : 0.185969
# running loss : 0.181209
# running loss : 0.185025
# running loss : 0.194146
# running loss : 0.185192
# running loss : 0.179692
# running loss : 0.175672
# running loss : 0.190642
# running loss : 0.200591
# running loss : 0.197864
# running loss : 0.186004
# running loss : 0.176279
# running loss : 0.191498
# running loss : 0.180212
# running loss : 0.187552
# running loss : 0.192773
# running loss : 0.196419
# running loss : 0.195077
# running loss : 0.190865
# running loss : 0.182893
# running loss : 0.181868
# running loss : 0.181934
# running loss : 0.177434
# running loss : 0.175277
# running loss : 0.176367
# running loss : 0.175602
# running loss : 0.206280
# running loss : 0.193886
# running loss : 0.186944
# running loss : 0.184559
# running loss : 0.181431
# running loss : 0.175787
# running loss : 0.181034
# running loss : 0.182282
# running loss : 0.188018
# running loss : 0.184292
# running loss : 0.179606
# running loss : 0.176010
# running loss : 0.173155
# running loss : 0.173980
# running loss : 0.180580
# running loss : 0.180150
# running loss : 0.175123
# running loss : 0.179227
# running loss : 0.190855
# ...
# running loss : 0.231225
# running loss : 0.237177
# running loss : 0.236127
# running loss : 0.259314
# running loss : 0.267608
# running loss : 0.267843
# running loss : 0.263669
# running loss : 0.268234
# running loss : 0.256402
# running loss : 0.258777
# running loss : 0.261836
# running loss : 0.263662
# running loss : 0.261110
# running loss : 0.257562
# running loss : 0.254413
# running loss : 0.251322
# running loss : 0.268186
# running loss : 0.262029
# running loss : 0.254104
# running loss : 0.258272
# running loss : 0.253408
# running loss : 0.252346
# running loss : 0.246956
# running loss : 0.230853
# running loss : 0.236622
# running loss : 0.237550
# running loss : 0.235714
# running loss : 0.244945
# running loss : 0.236315
# running loss : 0.237036
# running loss : 0.238116
# running loss : 0.241210
# running loss : 0.248767
# running loss : 0.245867
# running loss : 0.247886
# running loss : 0.242175
# running loss : 0.262686
# running loss : 0.284682
# running loss : 0.283335
# running loss : 0.291794
# running loss : 0.282180
# running loss : 0.288858
# running loss : 0.287390
# running loss : 0.271726
# running loss : 0.270218
# running loss : 0.267977
# running loss : 0.265495
# running loss : 0.258159
# running loss : 0.265440
# running loss : 0.277158
# running loss : 0.272402
# running loss : 0.274295
# running loss : 0.275786
# running loss : 0.278189
# running loss : 0.287999
# running loss : 0.293436
# running loss : 0.335016
# running loss : 0.331725
# running loss : 0.315143
# running loss : 0.295868
# running loss : 0.295239
# running loss : 0.297738
# running loss : 0.302925
# running loss : 0.284043
# running loss : 0.279787
# running loss : 0.268501
# running loss : 0.266505
# running loss : 0.266907
# running loss : 0.280361
# running loss : 0.283423
# running loss : 0.269237
# running loss : 0.269565
# running loss : 0.294312
# running loss : 0.282312
# running loss : 0.277620
# running loss : 0.295047
# running loss : 0.279163
# running loss : 0.271715
# running loss : 0.276165
# running loss : 0.289795
# running loss : 0.287124
# running loss : 0.289124
# running loss : 0.286649
# running loss : 0.281885
# running loss : 0.315479
# running loss : 0.297430
# running loss : 0.288905
# running loss : 0.264649
# running loss : 0.257777
# running loss : 0.253728
# running loss : 0.260241
# running loss : 0.259916
# running loss : 0.255757
# running loss : 0.272394
# running loss : 0.286957
# running loss : 0.275927
# running loss : 0.270800
# running loss : 0.274921
# running loss : 0.277644
# running loss : 0.270594
# running loss : 0.268641
# running loss : 0.258988
# running loss : 0.259649
# running loss : 0.254523
# running loss : 0.254869
# running loss : 0.250518
# running loss : 0.259345
# running loss : 0.249232
# running loss : 0.249872
# running loss : 0.248064
# running loss : 0.247408
# running loss : 0.247784
# running loss : 0.249432
# running loss : 0.261397
# running loss : 0.256516
# running loss : 0.245485
# running loss : 0.234290
# running loss : 0.244064
# running loss : 0.242834
# running loss : 0.246709
# running loss : 0.245090
# running loss : 0.245944
# running loss : 0.256695
# running loss : 0.253671
# running loss : 0.255460
# running loss : 0.240857
# running loss : 0.234340
# running loss : 0.236342
# running loss : 0.229517
# running loss : 0.260262
# running loss : 0.239815
# running loss : 0.234641
# running loss : 0.237672
# running loss : 0.231675
# running loss : 0.226326
# running loss : 0.226692
# running loss : 0.226471
# running loss : 0.234331
# running loss : 0.237345
# running loss : 0.225850
# running loss : 0.232024
# running loss : 0.221413
# running loss : 0.227675
# running loss : 0.221198
# running loss : 0.231457
# running loss : 0.237537
# running loss : 0.232622
# running loss : 0.225923
# running loss : 0.245076
# running loss : 0.254200
# running loss : 0.240081
# running loss : 0.229341
# running loss : 0.214741
# running loss : 0.211698
# running loss : 0.214951
# running loss : 0.222621
# running loss : 0.225092
# running loss : 0.228330
# running loss : 0.225565
# running loss : 0.226863
# running loss : 0.229342
# running loss : 0.229073
# running loss : 0.232945
# running loss : 0.223834
# running loss : 0.222316
# running loss : 0.239974
# running loss : 0.248854
# running loss : 0.256567
# running loss : 0.235784
# running loss : 0.232090
# running loss : 0.238294
# running loss : 0.236336
# running loss : 0.238533
# running loss : 0.240532
# running loss : 0.231157
# running loss : 0.231489
# running loss : 0.235799
# running loss : 0.238365
# running loss : 0.241154
# running loss : 0.239467
# running loss : 0.241003
# running loss : 0.238967
# running loss : 0.240814
# running loss : 0.241401
# running loss : 0.234269
# running loss : 0.236512
# running loss : 0.291632
# running loss : 0.328487
# running loss : 0.281511
# running loss : 0.242994
# running loss : 0.256664
# running loss : 0.244300
# running loss : 0.236771
# running loss : 0.236610
# running loss : 0.241932
# running loss : 0.250132
# running loss : 0.246561
# running loss : 0.240848
# running loss : 0.242976
# running loss : 0.233063
# running loss : 0.238414
# running loss : 0.241953
# running loss : 0.238634
# running loss : 0.219019
# running loss : 0.225326
# running loss : 0.225400
# running loss : 0.224012
# running loss : 0.221253
# running loss : 0.211829
# running loss : 0.201929
# running loss : 0.203919
# running loss : 0.212290
# running loss : 0.215554
# running loss : 0.219724
# running loss : 0.231115
# running loss : 0.207955
# running loss : 0.202827
# running loss : 0.194495
# running loss : 0.189884
# running loss : 0.198404
# running loss : 0.197431
# running loss : 0.203289
# running loss : 0.216193
# running loss : 0.220867
# running loss : 0.220534
# running loss : 0.228560
# running loss : 0.235039
# running loss : 0.227814
# running loss : 0.213374
# running loss : 0.203795
# running loss : 0.216473
# running loss : 0.216904
# running loss : 0.204336
# running loss : 0.203112
# running loss : 0.215504
# running loss : 0.210480
# running loss : 0.221139
# running loss : 0.222781
# running loss : 0.232998
# running loss : 0.229212
# running loss : 0.222988
# running loss : 0.231848
# running loss : 0.232238
# running loss : 0.249097
# running loss : 0.251002
# running loss : 0.235913
# running loss : 0.238654
# running loss : 0.228894
# running loss : 0.229150
# running loss : 0.234705
# running loss : 0.224717
# running loss : 0.225273
# running loss : 0.229928
# running loss : 0.222505
# running loss : 0.222150
# running loss : 0.229569
# running loss : 0.235222
# running loss : 0.238669
# running loss : 0.291728
# running loss : 0.274379
# running loss : 0.264817
# running loss : 0.284684
# running loss : 0.272209
# running loss : 0.272242
# running loss : 0.272024
# running loss : 0.272635
# running loss : 0.267414
# running loss : 0.264404
# running loss : 0.261744
# running loss : 0.271683
# running loss : 0.261311
# running loss : 0.271916
# running loss : 0.279185
# running loss : 0.276401
# running loss : 0.278002
# running loss : 0.278894
# running loss : 0.284768
# running loss : 0.281316
# running loss : 0.278332
# running loss : 0.272362
# running loss : 0.288451
# running loss : 0.287490
# running loss : 0.308373
# running loss : 0.288042
# running loss : 0.293468
# running loss : 0.311786
# running loss : 0.285445
# running loss : 0.284868
# running loss : 0.276960
# running loss : 0.281285
# running loss : 0.261222
# running loss : 0.258397
# running loss : 0.274006
# running loss : 0.262091
# running loss : 0.256685
# running loss : 0.253433
# running loss : 0.254873
# running loss : 0.251819
# running loss : 0.245293
# running loss : 0.242722
# running loss : 0.236621
# running loss : 0.230839
# running loss : 0.223206
# running loss : 0.230453
# running loss : 0.223471
# running loss : 0.225063
# running loss : 0.224131
# running loss : 0.224302
# running loss : 0.237981
# running loss : 0.236782
# running loss : 0.230478
# running loss : 0.228728
# running loss : 0.239294
# running loss : 0.237773
# running loss : 0.235894
# running loss : 0.236914
# running loss : 0.236666
# running loss : 0.231722
# running loss : 0.228587
# running loss : 0.219540
# running loss : 0.209928
# running loss : 0.209893
# running loss : 0.221243
# running loss : 0.210727
# running loss : 0.205779
# running loss : 0.203809
# running loss : 0.193751
# running loss : 0.193492
# running loss : 0.199778
# running loss : 0.200333
# running loss : 0.231345
# running loss : 0.220215
# running loss : 0.219178
# running loss : 0.226091
# running loss : 0.227716
# running loss : 0.216868
# running loss : 0.217110
# running loss : 0.206517
# running loss : 0.203755
# running loss : 0.211080
# running loss : 0.212877
# running loss : 0.207577
# running loss : 0.208786
# running loss : 0.260083
# running loss : 0.247087
# running loss : 0.247492
# running loss : 0.232669
# running loss : 0.227399
# running loss : 0.223242
# running loss : 0.229254
# running loss : 0.227177
# running loss : 0.221241
# running loss : 0.236262
# running loss : 0.228604
# running loss : 0.225491
# running loss : 0.228874
# running loss : 0.225995
# running loss : 0.225118
# running loss : 0.223209
# running loss : 0.210129
# running loss : 0.213351
# running loss : 0.222215
# running loss : 0.229637
# running loss : 0.233096
# running loss : 0.232917
# running loss : 0.229287
# running loss : 0.242359
# running loss : 0.226994
# running loss : 0.225107
# running loss : 0.230848
# running loss : 0.238022
# running loss : 0.221078
# running loss : 0.224359
# running loss : 0.225709
# running loss : 0.222859
# running loss : 0.223088
# running loss : 0.226283
# running loss : 0.213663
# running loss : 0.207400
# running loss : 0.222528
# running loss : 0.215225
# running loss : 0.211079
# running loss : 0.219643
# running loss : 0.223546
# running loss : 0.214526
# running loss : 0.213055
# running loss : 0.208600
# running loss : 0.204718
# running loss : 0.209548
# running loss : 0.205717
# running loss : 0.202032
# running loss : 0.211403
# running loss : 0.203378
# running loss : 0.205651
# running loss : 0.204299
# running loss : 0.200737
# running loss : 0.210177
# running loss : 0.215772
# running loss : 0.212985
# running loss : 0.222288
# running loss : 0.204661
# running loss : 0.201728
# running loss : 0.199127
# running loss : 0.200695
# running loss : 0.216844
# running loss : 0.204333
# running loss : 0.210496
# running loss : 0.204416
# running loss : 0.216914
# running loss : 0.216610
# running loss : 0.221642
# running loss : 0.224704
# running loss : 0.223096
# running loss : 0.218937
# running loss : 0.231241
# running loss : 0.224912
# running loss : 0.231882
# running loss : 0.239095
# running loss : 0.260558
# running loss : 0.264388
# running loss : 0.253763
# running loss : 0.251295
# running loss : 0.274631
# running loss : 0.269790
# running loss : 0.252084
# running loss : 0.259743
# running loss : 0.260525
# running loss : 0.249526
# running loss : 0.263881
# running loss : 0.255627
# running loss : 0.257860
# running loss : 0.280705
# running loss : 0.280218
# running loss : 0.269068
# running loss : 0.261649
# running loss : 0.257454
# running loss : 0.271810
# running loss : 0.266645
# running loss : 0.272321
# running loss : 0.265356
# running loss : 0.320457
# running loss : 0.296420
# running loss : 0.273971
# running loss : 0.266154
# running loss : 0.283420
# running loss : 0.253256
# running loss : 0.241221
# running loss : 0.234074
# running loss : 0.234222
# running loss : 0.229644
# running loss : 0.227571
# running loss : 0.221727
# running loss : 0.218328
# running loss : 0.229130
# running loss : 0.222549
# running loss : 0.219941
# running loss : 0.215319
# running loss : 0.207354
# running loss : 0.217971
# running loss : 0.225244
# running loss : 0.227483
# running loss : 0.222117
# running loss : 0.220488
# running loss : 0.225924
# running loss : 0.213683
# running loss : 0.221908
# running loss : 0.231501
# running loss : 0.222623
# running loss : 0.219236
# running loss : 0.222882
# running loss : 0.233098
# running loss : 0.242808
# running loss : 0.239180
# running loss : 0.239616
# running loss : 0.248240
# running loss : 0.247509
# running loss : 0.259171
# running loss : 0.268963
# running loss : 0.266933
# running loss : 0.293293
# running loss : 0.281969
# running loss : 0.263973
# running loss : 0.274070
# running loss : 0.273738
# running loss : 0.262446
# running loss : 0.259025
# running loss : 0.249369
# running loss : 0.238340
# running loss : 0.240874
# running loss : 0.235326
# running loss : 0.234016
# running loss : 0.235696
# running loss : 0.229405
# running loss : 0.221504
# running loss : 0.235106
# running loss : 0.226991
# running loss : 0.235003
# running loss : 0.238200
# running loss : 0.231461
# running loss : 0.223974
# running loss : 0.218491
# running loss : 0.226648
# running loss : 0.229830
# running loss : 0.230997
# running loss : 0.217281
# running loss : 0.215973
# running loss : 0.226907
# running loss : 0.215577
# running loss : 0.223844
# running loss : 0.214008
# running loss : 0.252002
# running loss : 0.287263
# running loss : 0.239687
# running loss : 0.237628
# running loss : 0.234351
# running loss : 0.223026
# running loss : 0.221253
# running loss : 0.219431
# running loss : 0.219506
# running loss : 0.214214
# running loss : 0.215390
# running loss : 0.209066
# running loss : 0.204659
# running loss : 0.199592
# running loss : 0.197645
# running loss : 0.193036
# running loss : 0.200107
# running loss : 0.194970
# running loss : 0.198828
# running loss : 0.197877
# running loss : 0.201152
# running loss : 0.208352
# running loss : 0.207237
# running loss : 0.203068
# running loss : 0.200295
# running loss : 0.215363
# running loss : 0.228562
# running loss : 0.213096
# running loss : 0.211055
# running loss : 0.195198
# running loss : 0.209473
# running loss : 0.213787
# running loss : 0.208544
# running loss : 0.204442
# running loss : 0.203332
# running loss : 0.208111
# running loss : 0.201716
# running loss : 0.212264
# running loss : 0.212000
# running loss : 0.212995
# running loss : 0.231517
# running loss : 0.230918
# running loss : 0.225717
# running loss : 0.239230
# running loss : 0.234504
# running loss : 0.235501
# running loss : 0.221351
# running loss : 0.224597
# running loss : 0.241845
# running loss : 0.234190
# running loss : 0.231952
# running loss : 0.233180
# running loss : 0.240356
# running loss : 0.252069
# running loss : 0.259529
# running loss : 0.245875
# running loss : 0.253705
# running loss : 0.260678
# running loss : 0.255185
# running loss : 0.239980
# running loss : 0.226444
# running loss : 0.215721
# running loss : 0.214271
# running loss : 0.214421
# running loss : 0.219709
# running loss : 0.246006
# running loss : 0.240151
# running loss : 0.229471
# running loss : 0.236715
# running loss : 0.227900
# running loss : 0.240130
# running loss : 0.235009
# running loss : 0.243455
# running loss : 0.238356
# running loss : 0.232909
# running loss : 0.233012
# running loss : 0.260165
# running loss : 0.254128
# running loss : 0.243968
# running loss : 0.250017
# running loss : 0.249274
# running loss : 0.245506
# running loss : 0.241621
# running loss : 0.247704
# running loss : 0.262184
# running loss : 0.261575
# running loss : 0.255054
# running loss : 0.256035
# running loss : 0.246493
# running loss : 0.235989
# running loss : 0.246229
# running loss : 0.249484
# running loss : 0.258061
# running loss : 0.256978
# running loss : 0.259163
# running loss : 0.258883
# running loss : 0.257041
# running loss : 0.253538
# running loss : 0.272753
# running loss : 0.264137
# running loss : 0.262378
# running loss : 0.275528
# running loss : 0.264848
# running loss : 0.259713
# running loss : 0.248257
# running loss : 0.242578
# running loss : 0.250623
# running loss : 0.267537
# running loss : 0.256232
# running loss : 0.255209
# running loss : 0.255030
# running loss : 0.249850
# running loss : 0.270440
# running loss : 0.260157
# running loss : 0.250479
# running loss : 0.246311
# running loss : 0.249784
# running loss : 0.272736
# running loss : 0.268276
# running loss : 0.256213
# running loss : 0.260469
# running loss : 0.257992
# running loss : 0.250050
# running loss : 0.265263
# running loss : 0.247537
# running loss : 0.247886
# running loss : 0.236180
# running loss : 0.237645
# running loss : 0.233317
# running loss : 0.235064
# running loss : 0.234238
# running loss : 0.232004
# running loss : 0.249866
# running loss : 0.235688
# running loss : 0.240951
# running loss : 0.242584
# running loss : 0.241240
# running loss : 0.238905
# running loss : 0.250272
# running loss : 0.238129
# running loss : 0.247930
# running loss : 0.237457
# running loss : 0.234204
# running loss : 0.244727
# running loss : 0.259968
# running loss : 0.251191
# running loss : 0.255141
# running loss : 0.253773
# running loss : 0.259517
# running loss : 0.253984
# running loss : 0.245898
# running loss : 0.273757
# running loss : 0.253655
# running loss : 0.249711
# running loss : 0.254947
# running loss : 0.267811

# %%
# save model parameters
torch.save(model.state_dict(), './model_parameters/mean_bit_ppx/lossy_comp_test_depthmap_beta01.pth')

# %%
model = LossyCompAutoencoder()
model.load_state_dict(torch.load('./model_parameters/mean_bit_ppx/lossy_comp_params_with_rate_beta005_incremental.pth'))
model.eval()
model.to(device)

# transfert du model au gpu
model.to(device)

# general update of coefficients    
    #define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
    # define loss function
distortion = nn.MSELoss().cuda()
    #Epochs
n_epochs = 600
beta = 0.05

    # Training the network
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
          
    #Training
    for i_batch, data in enumerate(dataloader):
        batch_images = data.to(device).float()
        [decoded_images, x_quantized] = model(batch_images, 1, True)
        optimizer.zero_grad()
        loss_dist = distortion(decoded_images, batch_images)
        loss_bit = mean_bit_per_px(x_quantized, model.phi, model.var)
        loss = beta * loss_dist + loss_bit
        #print(loss)
            
        loss.backward()
        #print("conv1.weights grad: ", params[0].grad)
        #print(model.conv1.bias.grad)
        #print(model.conv1.weight.grad)
        optimizer.step()
        running_loss += loss.item()

    running_loss = running_loss/len(dataloader)
    print('running loss : {:.06f}'.format(running_loss), )
# Out:
# running loss : 3.608064
# running loss : 3.595169
# running loss : 3.577811
# running loss : 3.565715
# running loss : 3.556746
# running loss : 3.551123
# running loss : 3.508999
# running loss : 3.493525
# running loss : 3.477084
# running loss : 3.480756
# running loss : 3.484556
# running loss : 3.470062
# running loss : 3.494472
# running loss : 3.480626
# running loss : 3.473711
# running loss : 3.469631
# running loss : 3.474533
# running loss : 3.457910
# running loss : 3.457608
# running loss : 3.463701
# running loss : 3.462066
# running loss : 3.455566
# running loss : 3.454701
# running loss : 3.452302
# running loss : 3.461875
# running loss : 3.440914
# running loss : 3.449169
# running loss : 3.461837
# running loss : 3.453840
# running loss : 3.431719
# running loss : 3.450540
# running loss : 3.444341
# running loss : 3.436081
# running loss : 3.438335
# running loss : 3.434041
# running loss : 3.437564
# running loss : 3.452365
# running loss : 3.440963
# running loss : 3.444202
# running loss : 3.428230
# running loss : 3.436434
# running loss : 3.443303
# running loss : 3.439506
# running loss : 3.427543
# running loss : 3.431219
# running loss : 3.448644
# running loss : 3.422745
# running loss : 3.433221
# running loss : 3.450936
# running loss : 3.433569
# running loss : 3.442692
# running loss : 3.429689
# running loss : 3.430512
# running loss : 3.426101
# running loss : 3.430047
# running loss : 3.432502
# running loss : 3.439135
# running loss : 3.429702
# running loss : 3.420823
# running loss : 3.431744
# running loss : 3.428611
# running loss : 3.433411
# running loss : 3.418620
# running loss : 3.420307
# running loss : 3.428004
# running loss : 3.420471
# running loss : 3.434505
# running loss : 3.439297
# running loss : 3.418552
# running loss : 3.423885
# running loss : 3.438213
# running loss : 3.421547
# running loss : 3.447951
# running loss : 3.426076
# running loss : 3.431946
# running loss : 3.421086
# running loss : 3.422254
# running loss : 3.434877
# running loss : 3.446865
# running loss : 3.416438
# running loss : 3.411806
# running loss : 3.418630
# running loss : 3.406292
# running loss : 3.428759
# running loss : 3.416834
# running loss : 3.421250
# running loss : 3.428968
# running loss : 3.419444
# running loss : 3.411746
# running loss : 3.431971
# running loss : 3.417159
# running loss : 3.417692
# running loss : 3.423909
# running loss : 3.426233
# running loss : 3.416708
# running loss : 3.409153
# running loss : 3.410394
# running loss : 3.412747
# running loss : 3.416086
# running loss : 3.417805
# running loss : 3.416933
# running loss : 3.418952
# running loss : 3.411268
# running loss : 3.418695
# running loss : 3.415554
# running loss : 3.407512
# running loss : 3.418305
# running loss : 3.417855
# running loss : 3.415935
# running loss : 3.404594
# running loss : 3.407119
# running loss : 3.408349
# running loss : 3.416635
# running loss : 3.411231
# running loss : 3.417814
# running loss : 3.407900
# running loss : 3.417695
# running loss : 3.410966
# running loss : 3.411711
# running loss : 3.405085
# running loss : 3.405621
# running loss : 3.403342
# running loss : 3.418212
# running loss : 3.418930
# running loss : 3.400970
# running loss : 3.425234
# running loss : 3.405430
# running loss : 3.414903
# running loss : 3.397287
# running loss : 3.409523
# running loss : 3.405635
# running loss : 3.404655
# running loss : 3.423258
# running loss : 3.418636
# running loss : 3.403312
# running loss : 3.402433
# running loss : 3.408503
# running loss : 3.411906
# running loss : 3.396481
# running loss : 3.413033
# running loss : 3.401829
# running loss : 3.399232
# running loss : 3.408765
# running loss : 3.413618
# running loss : 3.401739
# running loss : 3.393259
# running loss : 3.409699
# running loss : 3.405459
# running loss : 3.402204
# running loss : 3.401693
# running loss : 3.415576
# running loss : 3.393906
# running loss : 3.410737
# running loss : 3.409878
# running loss : 3.406994
# running loss : 3.402496
# running loss : 3.398531
# running loss : 3.406441
# running loss : 3.405680
# running loss : 3.404914
# running loss : 3.403816
# running loss : 3.415388
# running loss : 3.404948
# running loss : 3.404524
# running loss : 3.408215
# running loss : 3.397031
# running loss : 3.391528
# running loss : 3.394352
# running loss : 3.388567
# running loss : 3.402069
# running loss : 3.407573
# running loss : 3.401749
# running loss : 3.397013
# running loss : 3.380713
# running loss : 3.416723
# running loss : 3.395859
# running loss : 3.401124
# running loss : 3.395975
# running loss : 3.401524
# running loss : 3.397739
# running loss : 3.398284
# running loss : 3.397540
# running loss : 3.390580
# running loss : 3.395998
# running loss : 3.406830
# running loss : 3.400811
# running loss : 3.399028
# running loss : 3.391226
# running loss : 3.391155
# running loss : 3.403034
# running loss : 3.386472
# running loss : 3.391889
# running loss : 3.410040
# running loss : 3.396352
# running loss : 3.393411
# running loss : 3.392596
# running loss : 3.398096
# running loss : 3.419137
# running loss : 3.386801
# running loss : 3.393241
# running loss : 3.405118
# running loss : 3.401632
# running loss : 3.391891
# running loss : 3.387445
# running loss : 3.391386
# running loss : 3.387829
# running loss : 3.392365
# running loss : 3.400446
# running loss : 3.372927
# running loss : 3.404625
# running loss : 3.388007
# running loss : 3.395960
# running loss : 3.412260
# running loss : 3.404648
# running loss : 3.398713
# running loss : 3.397545
# running loss : 3.384526
# running loss : 3.385824
# running loss : 3.383352
# running loss : 3.393349
# running loss : 3.387968
# running loss : 3.382640
# running loss : 3.380239
# running loss : 3.384858
# running loss : 3.374717
# running loss : 3.409348
# running loss : 3.401197
# running loss : 3.389739
# running loss : 3.388080
# running loss : 3.392952
# running loss : 3.398019
# running loss : 3.404827
# running loss : 3.382396
# running loss : 3.380256
# running loss : 3.378441
# running loss : 3.373515
# running loss : 3.379723
# running loss : 3.386646
# running loss : 3.381797
# running loss : 3.386999
# running loss : 3.384829
# running loss : 3.369290
# running loss : 3.385859
# running loss : 3.388848
# running loss : 3.379311
# running loss : 3.373440
# running loss : 3.392347
# running loss : 3.382227
# running loss : 3.367000
# running loss : 3.378753
# running loss : 3.377418
# running loss : 3.396743
# running loss : 3.378321
# running loss : 3.384744
# running loss : 3.383695
# running loss : 3.388330
# running loss : 3.387338
# running loss : 3.391584
# running loss : 3.387342
# running loss : 3.375059
# running loss : 3.383311
# running loss : 3.387176
# running loss : 3.387320
# running loss : 3.379785
# running loss : 3.388733
# running loss : 3.375195
# running loss : 3.377278
# running loss : 3.381037
# running loss : 3.378940
# running loss : 3.377081
# running loss : 3.379055
# running loss : 3.384051
# running loss : 3.372547
# running loss : 3.359944
# running loss : 3.389396
# running loss : 3.377261
# running loss : 3.375371
# running loss : 3.374853
# running loss : 3.375038
# running loss : 3.371395
# running loss : 3.380230
# running loss : 3.374034
# running loss : 3.381019
# running loss : 3.379792
# running loss : 3.379630
# running loss : 3.375633
# running loss : 3.380527
# running loss : 3.374819
# running loss : 3.374065
# running loss : 3.376456
# running loss : 3.372698
# running loss : 3.376132
# running loss : 3.382859
# running loss : 3.361300
# running loss : 3.369921
# running loss : 3.382626
# running loss : 3.365912
# running loss : 3.374336
# running loss : 3.370419
# running loss : 3.375273
# running loss : 3.381060
# running loss : 3.368045
# running loss : 3.384040
# running loss : 3.379451
# running loss : 3.377281
# running loss : 3.376848
# running loss : 3.379195
# running loss : 3.377004
# running loss : 3.366520
# running loss : 3.369531
# running loss : 3.359590
# running loss : 3.379268
# running loss : 3.370147
# running loss : 3.380034
# running loss : 3.371945
# running loss : 3.378165
# running loss : 3.371639
# running loss : 3.365722
# running loss : 3.378202
# running loss : 3.383245
# running loss : 3.372720
# running loss : 3.357288
# running loss : 3.363374
# running loss : 3.380017
# running loss : 3.369098
# running loss : 3.370510
# running loss : 3.373468
# running loss : 3.365971
# running loss : 3.371524
# running loss : 3.371745
# running loss : 3.368102
# running loss : 3.368026
# running loss : 3.382858
# running loss : 3.381158
# running loss : 3.372145
# running loss : 3.366211
# running loss : 3.379800
# running loss : 3.365970
# running loss : 3.388563
# running loss : 3.364501
# running loss : 3.361850
# running loss : 3.367398
# running loss : 3.370314
# running loss : 3.377068
# running loss : 3.380413
# running loss : 3.369731
# running loss : 3.372108
# running loss : 3.373563
# running loss : 3.365202
# running loss : 3.375456
# running loss : 3.366879
# running loss : 3.364543
# running loss : 3.367663
# running loss : 3.371529
# running loss : 3.359032
# running loss : 3.364099
# running loss : 3.354579
# running loss : 3.367204
# running loss : 3.370713
# running loss : 3.366639
# running loss : 3.360884
# running loss : 3.353266
# running loss : 3.368702
# running loss : 3.359209
# running loss : 3.361315
# running loss : 3.372081
# running loss : 3.363859
# running loss : 3.356524
# running loss : 3.360332
# running loss : 3.353770
# running loss : 3.355852
# running loss : 3.365560
# running loss : 3.375980
# running loss : 3.351310
# running loss : 3.372552
# running loss : 3.356415
# running loss : 3.355415
# running loss : 3.359442
# running loss : 3.354993
# running loss : 3.353920
# running loss : 3.357007
# running loss : 3.347224
# running loss : 3.360047
# running loss : 3.356805
# running loss : 3.377442
# running loss : 3.360175
# running loss : 3.349696
# running loss : 3.370999
# running loss : 3.359068
# running loss : 3.362040
# running loss : 3.358622
# running loss : 3.352350
# running loss : 3.358476
# running loss : 3.346589
# running loss : 3.363932
# running loss : 3.356358
# running loss : 3.360231
# running loss : 3.361587
# running loss : 3.361075
# running loss : 3.363794
# running loss : 3.346298
# running loss : 3.363001
# running loss : 3.358429
# running loss : 3.357310
# running loss : 3.356154
# running loss : 3.360374
# running loss : 3.370111
# running loss : 3.365619
# running loss : 3.345095
# running loss : 3.357239
# running loss : 3.355625
# running loss : 3.357598
# running loss : 3.357125
# running loss : 3.355613
# running loss : 3.355986
# running loss : 3.368297
# running loss : 3.357122
# running loss : 3.355062
# running loss : 3.353528
# running loss : 3.369331
# running loss : 3.354843
# running loss : 3.371120
# running loss : 3.358374
# running loss : 3.369029
# running loss : 3.351763
# running loss : 3.356055
# running loss : 3.356574
# running loss : 3.353526
# running loss : 3.346547
# running loss : 3.355653
# running loss : 3.344817
# running loss : 3.366189
# running loss : 3.357121
# running loss : 3.355565
# running loss : 3.360159
# running loss : 3.346670
# running loss : 3.349266
# running loss : 3.361551
# running loss : 3.345708
# running loss : 3.346406
# running loss : 3.364660
# running loss : 3.348421
# running loss : 3.366565
# running loss : 3.357172
# running loss : 3.360273
# running loss : 3.361555
# running loss : 3.360843
# running loss : 3.364662
# running loss : 3.356550
# running loss : 3.346063
# running loss : 3.359142
# running loss : 3.352849
# running loss : 3.369623
# running loss : 3.360721
# running loss : 3.351882
# running loss : 3.359600
# running loss : 3.355730
# running loss : 3.353931
# running loss : 3.343998
# running loss : 3.359867
# running loss : 3.354931
# running loss : 3.346388
# running loss : 3.347316
# running loss : 3.372011
# running loss : 3.353952
# running loss : 3.336895
# running loss : 3.341002
# running loss : 3.344184
# running loss : 3.348712
# running loss : 3.357724
# running loss : 3.342228
# running loss : 3.339523
# running loss : 3.336710
# running loss : 3.359275
# running loss : 3.352273
# running loss : 3.355335
# running loss : 3.346686
# running loss : 3.351825
# running loss : 3.343329
# running loss : 3.353132
# running loss : 3.348568
# running loss : 3.349761
# running loss : 3.346203
# running loss : 3.345687
# running loss : 3.346822
# running loss : 3.359846
# running loss : 3.344461
# running loss : 3.347605
# running loss : 3.360306
# running loss : 3.349484
# running loss : 3.361984
# running loss : 3.345488
# running loss : 3.352357
# running loss : 3.350787
# running loss : 3.363186
# running loss : 3.358625
# running loss : 3.349598
# running loss : 3.350769
# running loss : 3.356160
# running loss : 3.355965
# running loss : 3.347878
# running loss : 3.362272
# running loss : 3.334891
# running loss : 3.350863
# running loss : 3.352918
# running loss : 3.351285
# running loss : 3.340953
# running loss : 3.351766
# running loss : 3.346930
# running loss : 3.345097
# running loss : 3.359069
# running loss : 3.344168
# running loss : 3.351817
# running loss : 3.335797
# running loss : 3.336338
# running loss : 3.369614
# running loss : 3.348467
# running loss : 3.338204
# running loss : 3.348724
# running loss : 3.343201
# running loss : 3.337590
# running loss : 3.345075
# running loss : 3.343137
# running loss : 3.342944
# running loss : 3.333315
# running loss : 3.359916
# running loss : 3.343439
# running loss : 3.348096
# running loss : 3.348777
# running loss : 3.342959
# running loss : 3.355742
# running loss : 3.344180
# running loss : 3.339853
# running loss : 3.346722
# running loss : 3.344836
# running loss : 3.338519
# running loss : 3.354768
# running loss : 3.354207
# running loss : 3.354161
# running loss : 3.350398
# running loss : 3.335574
# running loss : 3.339052
# running loss : 3.325654
# running loss : 3.346711
# running loss : 3.345718
# running loss : 3.342996
# running loss : 3.345942
# running loss : 3.340115
# running loss : 3.351426
# running loss : 3.335214
# running loss : 3.348179
# running loss : 3.339886
# running loss : 3.341955
# running loss : 3.343468
# running loss : 3.342511
# running loss : 3.339258
# running loss : 3.352079
# running loss : 3.351474
# running loss : 3.349672
# running loss : 3.326735
# running loss : 3.331779
# running loss : 3.332662
# running loss : 3.344620
# running loss : 3.342527
# running loss : 3.338769
# running loss : 3.329740
# running loss : 3.334696
# running loss : 3.349396
# running loss : 3.331655
# running loss : 3.343893
# running loss : 3.334330
# running loss : 3.341412
# running loss : 3.341261
# running loss : 3.342445
# running loss : 3.355054
# running loss : 3.342108
# running loss : 3.342142
# running loss : 3.333979
# running loss : 3.329740
# running loss : 3.330187
# running loss : 3.320707
# running loss : 3.337103
# running loss : 3.341556
# running loss : 3.334582
# running loss : 3.343184
# running loss : 3.342706
# running loss : 3.340070
# running loss : 3.344993
# running loss : 3.349691
# running loss : 3.340178
# running loss : 3.336386
# running loss : 3.342811
# running loss : 3.344449
# running loss : 3.357886
# running loss : 3.348683
# running loss : 3.346992
# running loss : 3.331960
# running loss : 3.348751
# running loss : 3.343655
# running loss : 3.350069

# %%
# save model parameters
torch.save(model.state_dict(), './model_parameters/lossy_comp_params_with_rate_beta2_incremental_2.pth')

# %%
# test set 

"""
model = LossyCompAutoencoder()
model.load_state_dict(torch.load('./model_parameters/mean_bit_ppx/lossy_comp_params_with_rate_beta00005_incremental.pth'))
model.eval()
model.to(device)
"""


test_dataset = ImageDataset(root_dir='D:/autoencoder_data/depthmaps/test', transform=transforms.Compose([RandomCrop((480, 640)), ToTensor()]))
fig, axes = plt.subplots(nrows=4, ncols=6, sharex=True, sharey=True, figsize=(8,8))
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        test_image = test_image*(255.0/(2**16-1))
        
        if test_image.size(2)<test_image.size(3):
            test_image = test_image.permute(0, 1, 3, 2)
        
        [reconstructed_image, vec_latent ]= model(test_image, 1, True)
        print("min vec latent : ", torch.min(vec_latent))
        print("max vec latent : ", torch.max(vec_latent)) 
        
        print(reconstructed_image.size())
        
        ax = fig.add_subplot(4, 6, i+1, xticks=[], yticks=[])
        plt.imshow(np.squeeze(reconstructed_image.int().cpu()))
        
        """
        # We can set the number of bins with the `bins` kwarg
        bins_list = [-6.5, -5.5, -4.5, -3.5, -2.5, -1.5, -0.5, 0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5]
        for k in range(96):
            # plot histograms
            fig, ax = plt.subplots(1, 1, sharey=True, tight_layout=True)
            ax.hist((vec_latent[:, k, :, :]).view(-1).cpu(), bins=bins_list)
            plt.savefig("D:\\autoencoder_data\\histograms\\rgb\\" + "img" + str(i)+ "hist" + str(k) + ".png")
        """
# Out:
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])
# min vec latent :  tensor(-1., device='cuda:0')
# max vec latent :  tensor(1., device='cuda:0')
# torch.Size([1, 1, 640, 480])

# %%
# save results
from torchvision.utils import save_image

with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        reconstructed_image = np.squeeze(model(test_image).cpu())
        print(reconstructed_image.type())
        save_image(reconstructed_image, ".\\reconstructed_data\\kodac\\loss_distortion_and_mean_bit_ppx\\beta_01_incremental\\" + "img" + str(i)+".png", normalize=True)
# Out:
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor

# %%
# compute PSNR for each image of the test set and its reconstruction
# and write the latent vector in a file

def write_data(filepath , tensor_data):
    batch, channel, h, w = tensor_data.size()
    matrix = tensor_data.cpu().numpy()
    file = open(filepath, "w")
    for image in range(batch):
        np.savetxt(file, matrix[image, :, :, :].reshape(channel*h, w), fmt ='%.0f')

    file.close()
    
def compute_entropy(tensor_data):
    min_val = tensor_data.min()
    max_val = tensor_data.max()
    nb_bins = max_val - min_val + 1
    hist = torch.histc(tensor_data, bins=nb_bins.int(), min=min_val, max=max_val)
    hist_prob = hist/hist.sum()
    hist_prob[hist_prob == 0] = 1
    entropy = -(hist_prob*torch.log2(hist_prob)).sum()
    return entropy
    
        
    
    
def psnr(original, compressed, max_pixel): 
    mse = torch.mean((original - compressed) ** 2) 
    if(mse == 0):  # MSE is zero means no noise is present in the signal . 
                  # Therefore PSNR have no importance. 
        return 100
    psnr = 20 * np.log10(max_pixel / np.sqrt(mse)) 
    return psnr 


test_dataset = ImageDataset(root_dir='D:/autoencoder_data/depthmaps/test', transform=transforms.Compose([RandomCrop((480, 640)), ToTensor()]))
psnr_sum = 0.0
bit_rate_sum = 0.0
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        test_image = test_image*(255.0/(2**16-1))
        [reconstructed_image, im_quantized] = model(test_image, 1, True)
        #write_data('.\\reconstructed_data\\kodac\\loss_distortion_and_bitrate\\beta_2\\latent_vect\\' + 'vec' + str(i) +'.txt', im_quantized)
        nb_symbols = im_quantized.size(0)*im_quantized.size(1)*im_quantized.size(2)*im_quantized.size(3)
        entropy = compute_entropy(im_quantized)
        nbpp = nb_symbols*entropy/float(test_image.size(0)*test_image.size(2)*test_image.size(3))
        psnr_sum+= psnr(test_image.cpu(), reconstructed_image.cpu(), 255.0)
        bit_rate_sum += nbpp
        print("entropy : ", entropy)
        print( "nb bits per pixel : ", nbpp)
        print("psnr : " , psnr(test_image.cpu(), reconstructed_image.cpu(), 255.0))
print( "mean nb bits per pixel : ", bit_rate_sum/len(test_dataset))
print("psnr mean : ", psnr_sum/len(test_dataset) )
# Out:
# entropy :  tensor(0.251756, device='cuda:0')
# nb bits per pixel :  tensor(0.377634, device='cuda:0')
# psnr :  tensor(49.390800)
# entropy :  tensor(0.208490, device='cuda:0')
# nb bits per pixel :  tensor(0.312734, device='cuda:0')
# psnr :  tensor(46.653938)
# entropy :  tensor(0.247474, device='cuda:0')
# nb bits per pixel :  tensor(0.371211, device='cuda:0')
# psnr :  tensor(47.044262)
# entropy :  tensor(0.229768, device='cuda:0')
# nb bits per pixel :  tensor(0.344652, device='cuda:0')
# psnr :  tensor(45.899693)
# entropy :  tensor(0.213871, device='cuda:0')
# nb bits per pixel :  tensor(0.320807, device='cuda:0')
# psnr :  tensor(45.983612)
# entropy :  tensor(0.258366, device='cuda:0')
# nb bits per pixel :  tensor(0.387549, device='cuda:0')
# psnr :  tensor(49.158703)
# entropy :  tensor(0.216262, device='cuda:0')
# nb bits per pixel :  tensor(0.324393, device='cuda:0')
# psnr :  tensor(45.756760)
# entropy :  tensor(0.212753, device='cuda:0')
# nb bits per pixel :  tensor(0.319130, device='cuda:0')
# psnr :  tensor(45.067963)
# entropy :  tensor(0.246936, device='cuda:0')
# nb bits per pixel :  tensor(0.370405, device='cuda:0')
# psnr :  tensor(48.053974)
# entropy :  tensor(0.234991, device='cuda:0')
# nb bits per pixel :  tensor(0.352487, device='cuda:0')
# psnr :  tensor(50.203098)
# entropy :  tensor(0.218476, device='cuda:0')
# nb bits per pixel :  tensor(0.327713, device='cuda:0')
# psnr :  tensor(48.399273)
# entropy :  tensor(0.225754, device='cuda:0')
# nb bits per pixel :  tensor(0.338631, device='cuda:0')
# psnr :  tensor(47.193336)
# entropy :  tensor(0.269348, device='cuda:0')
# nb bits per pixel :  tensor(0.404023, device='cuda:0')
# psnr :  tensor(48.362156)
# entropy :  tensor(0.269125, device='cuda:0')
# nb bits per pixel :  tensor(0.403687, device='cuda:0')
# psnr :  tensor(50.666245)
# entropy :  tensor(0.268124, device='cuda:0')
# nb bits per pixel :  tensor(0.402186, device='cuda:0')
# psnr :  tensor(48.946960)
# entropy :  tensor(0.252792, device='cuda:0')
# nb bits per pixel :  tensor(0.379187, device='cuda:0')
# psnr :  tensor(49.709908)
# entropy :  tensor(0.220386, device='cuda:0')
# nb bits per pixel :  tensor(0.330580, device='cuda:0')
# psnr :  tensor(47.213573)
# entropy :  tensor(0.183918, device='cuda:0')
# nb bits per pixel :  tensor(0.275877, device='cuda:0')
# psnr :  tensor(42.617874)
# entropy :  tensor(0.179430, device='cuda:0')
# nb bits per pixel :  tensor(0.269145, device='cuda:0')
# psnr :  tensor(40.790745)
# entropy :  tensor(0.183447, device='cuda:0')
# nb bits per pixel :  tensor(0.275171, device='cuda:0')
# psnr :  tensor(38.898499)
# entropy :  tensor(0.175898, device='cuda:0')
# nb bits per pixel :  tensor(0.263847, device='cuda:0')
# psnr :  tensor(41.714218)
# entropy :  tensor(0.245709, device='cuda:0')
# nb bits per pixel :  tensor(0.368563, device='cuda:0')
# psnr :  tensor(44.729729)
# entropy :  tensor(0.199706, device='cuda:0')
# nb bits per pixel :  tensor(0.299559, device='cuda:0')
# psnr :  tensor(48.522369)
# entropy :  tensor(0.187617, device='cuda:0')
# nb bits per pixel :  tensor(0.281426, device='cuda:0')
# psnr :  tensor(39.230694)
# mean nb bits per pixel :  tensor(0.337525, device='cuda:0')
# psnr mean :  tensor(46.258686)

# %%
def compute_entropy(tensor_data):
    min_val = tensor_data.min()
    max_val = tensor_data.max()
    nb_bins = max_val - min_val + 1
    hist = torch.histc(tensor_data, bins=nb_bins.int(), min=min_val, max=max_val)
    hist_prob = hist/hist.sum()
    hist_prob[hist_prob == 0] = 1
    entropy = -(hist_prob*torch.log2(hist_prob)).sum()
    return entropy
    
        
    
    
def psnr(original, compressed, max_pixel): 
    mse = torch.mean((original - compressed) ** 2) 
    if(mse == 0):  # MSE is zero means no noise is present in the signal . 
                  # Therefore PSNR have no importance. 
        return 100
    psnr = 20 * np.log10(max_pixel / np.sqrt(mse)) 
    return psnr 


# Load previous model
model_prev = LossyCompAutoencoder()
model_prev.load_state_dict(torch.load('./model_parameters/lossy_comp_params_with_rate_beta2_incremental_2.pth'))
model_prev.eval()
model_prev.to(device)


# And run test 
test_dataset = ImageDataset(root_dir='./data/kodac/', transform=ToTensor())
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        [reconstructed_image, im_quantized] = model_prev(test_image,1, True)
        nb_symbols = im_quantized.size(0)*im_quantized.size(1)*im_quantized.size(2)*im_quantized.size(3)
        entropy = compute_entropy(im_quantized)
        nbpp = nb_symbols*entropy/float(test_image.size(0)*test_image.size(1)*test_image.size(2)*test_image.size(3))
        print("nb_symbols : ", nb_symbols)
        print("entropy : ", entropy)
        print( "nb bits per pixel : ", nbpp)
        print("psnr : " , psnr(test_image.cpu(), reconstructed_image.cpu(), 255.0))
    
# And print figures
fig, axes = plt.subplots(nrows=4, ncols=6, sharex=True, sharey=True, figsize=(8,8))
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        if test_image.size(2)<test_image.size(3):
            test_image = test_image.permute(0, 1, 3, 2)
        
        reconstructed_image = model_prev(test_image, 1,  False)
        ax = fig.add_subplot(4, 6, i+1, xticks=[], yticks=[])
        plt.imshow(np.squeeze(reconstructed_image.int().cpu()).permute(1, 2, 0))
        
# And save figures
from torchvision.utils import save_image

with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        reconstructed_image = np.squeeze(model_prev(test_image).cpu())
        print(reconstructed_image.type())
        save_image(reconstructed_image, ".\\reconstructed_data\\kodac\\loss_distortion_and_bitrate\\beta_2_incremental_bis\\" + "img" + str(i)+".png", normalize=True)
# Out:
# nb_symbols :  589824
# entropy :  tensor(5.433585, device='cuda:0')
# nb bits per pixel :  tensor(2.716793, device='cuda:0')
# psnr :  tensor(42.711697)
# nb_symbols :  589824
# entropy :  tensor(4.738198, device='cuda:0')
# nb bits per pixel :  tensor(2.369099, device='cuda:0')
# psnr :  tensor(44.366920)
# nb_symbols :  589824
# entropy :  tensor(5.278986, device='cuda:0')
# nb bits per pixel :  tensor(2.639493, device='cuda:0')
# psnr :  tensor(43.741898)
# nb_symbols :  589824
# entropy :  tensor(5.257313, device='cuda:0')
# nb bits per pixel :  tensor(2.628657, device='cuda:0')
# psnr :  tensor(44.050468)
# nb_symbols :  589824
# entropy :  tensor(5.570083, device='cuda:0')
# nb bits per pixel :  tensor(2.785042, device='cuda:0')
# psnr :  tensor(41.256756)
# nb_symbols :  589824
# entropy :  tensor(5.662136, device='cuda:0')
# nb bits per pixel :  tensor(2.831068, device='cuda:0')
# psnr :  tensor(43.080311)
# nb_symbols :  589824
# entropy :  tensor(5.116849, device='cuda:0')
# nb bits per pixel :  tensor(2.558424, device='cuda:0')
# psnr :  tensor(44.563042)
# nb_symbols :  589824
# entropy :  tensor(5.881482, device='cuda:0')
# nb bits per pixel :  tensor(2.940741, device='cuda:0')
# psnr :  tensor(40.955025)
# nb_symbols :  589824
# entropy :  tensor(5.085561, device='cuda:0')
# nb bits per pixel :  tensor(2.542780, device='cuda:0')
# psnr :  tensor(44.030388)
# nb_symbols :  589824
# entropy :  tensor(5.034587, device='cuda:0')
# nb bits per pixel :  tensor(2.517294, device='cuda:0')
# psnr :  tensor(44.090431)
# nb_symbols :  589824
# entropy :  tensor(5.315285, device='cuda:0')
# nb bits per pixel :  tensor(2.657643, device='cuda:0')
# psnr :  tensor(43.732460)
# nb_symbols :  589824
# entropy :  tensor(5.278862, device='cuda:0')
# nb bits per pixel :  tensor(2.639431, device='cuda:0')
# psnr :  tensor(44.424889)
# nb_symbols :  589824
# entropy :  tensor(5.721937, device='cuda:0')
# nb bits per pixel :  tensor(2.860968, device='cuda:0')
# psnr :  tensor(39.624790)
# nb_symbols :  589824
# entropy :  tensor(5.549026, device='cuda:0')
# nb bits per pixel :  tensor(2.774513, device='cuda:0')
# psnr :  tensor(41.797176)
# nb_symbols :  589824
# entropy :  tensor(5.991822, device='cuda:0')
# nb bits per pixel :  tensor(2.995911, device='cuda:0')
# psnr :  tensor(42.317528)
# nb_symbols :  589824
# entropy :  tensor(5.187307, device='cuda:0')
# nb bits per pixel :  tensor(2.593653, device='cuda:0')
# psnr :  tensor(45.182747)
# nb_symbols :  589824
# entropy :  tensor(5.300200, device='cuda:0')
# nb bits per pixel :  tensor(2.650100, device='cuda:0')
# psnr :  tensor(43.788574)
# nb_symbols :  589824
# entropy :  tensor(5.268565, device='cuda:0')
# nb bits per pixel :  tensor(2.634283, device='cuda:0')
# psnr :  tensor(41.059765)
# nb_symbols :  589824
# entropy :  tensor(5.418479, device='cuda:0')
# nb bits per pixel :  tensor(2.709240, device='cuda:0')
# psnr :  tensor(43.560848)
# nb_symbols :  589824
# entropy :  tensor(6.062364, device='cuda:0')
# nb bits per pixel :  tensor(3.031182, device='cuda:0')
# psnr :  tensor(42.766666)
# nb_symbols :  589824
# entropy :  tensor(5.341250, device='cuda:0')
# nb bits per pixel :  tensor(2.670625, device='cuda:0')
# psnr :  tensor(42.850250)
# nb_symbols :  589824
# entropy :  tensor(5.328340, device='cuda:0')
# nb bits per pixel :  tensor(2.664170, device='cuda:0')
# psnr :  tensor(42.178059)
# nb_symbols :  589824
# entropy :  tensor(5.568606, device='cuda:0')
# nb bits per pixel :  tensor(2.784303, device='cuda:0')
# psnr :  tensor(43.223347)
# nb_symbols :  589824
# entropy :  tensor(5.464958, device='cuda:0')
# nb bits per pixel :  tensor(2.732479, device='cuda:0')
# psnr :  tensor(39.438251)
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor

# %%
def entropy_rate(x_quantized, phi, var):
    u = torch.arange(-0.5, 0.5+0.01, 0.01).cuda()        
    gsm_sum = torch.zeros(len(u)).cuda()
    for i in range(len(u)):
        x = x_quantized + u[i]
        gsm_sum_i = sum_gsm(x, var, phi, 6)
        gsm_sum[i] = gsm_sum_i

    entropy = torch.trapz(gsm_sum, u)
    
    return entropy


# Load incremental model
incremental_model = LossyCompAutoencoder()
incremental_model.load_state_dict(torch.load('./model_parameters/lossy_comp_params_with_rate_beta2_incremental.pth'))
incremental_model.eval()
incremental_model.to(device)

# train again the model starting form incremental-learned weights
    #define optimizer
optimizer = torch.optim.Adam(incremental_model.parameters(), lr=0.0001)

# define loss function
distortion = nn.MSELoss().cuda()


# define beta
beta = 2.0

#Epochs
n_epochs = 600


# Training the network
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
           
    #Training
    for i_batch, data in enumerate(dataloader):
        batch_images = data.to(device).float()
        [decoded_images, x_quantized] = incremental_model(batch_images, False, True)
        optimizer.zero_grad()
        entropy = entropy_rate(x_quantized, incremental_model.phi, incremental_model.var)
        print("entropy : ", entropy)
        dist = distortion(decoded_images, batch_images)
        print("distortion : ", dist)
        loss = beta * dist + entropy
        loss.backward()
        #print("conv1.weights grad: ", params[0].grad)
        #print(model.conv1.bias.grad)
        #print(model.conv1.weight.grad)
        optimizer.step()
        running_loss += loss.item()

    running_loss = running_loss/len(dataloader)
    print('running loss : {:.06f}'.format(running_loss), )
# Out:
# entropy :  tensor(4.992423, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3783.756348, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(35.316048, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3331.412354, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(33.194473, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3280.784668, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(16.982132, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3833.349854, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(6.236253, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(2998.021240, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(13.942085, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4020.668213, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(11.401224, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4049.084229, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.091653, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3914.844238, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(7.532864, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3699.531006, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(11.252965, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3502.669678, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(10.172251, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3233.638916, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(7.888332, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3444.639160, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.890505, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3758.968750, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(6.177967, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4241.679688, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(9.358366, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3220.504639, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(9.724493, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4545.562988, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(9.402671, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4369.997559, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(6.538430, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3352.075195, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.289365, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3834.843750, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(8.297033, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4144.026855, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(9.374476, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3154.157715, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(8.841386, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4223.809570, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(7.746368, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3535.041992, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(7.335207, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3648.764893, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.753038, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3968.517578, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.264740, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3936.420410, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(6.236658, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3609.426758, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(6.787442, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3621.904053, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.986058, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3584.592773, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.134099, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3085.294434, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.148417, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3078.743896, device='cuda:0', grad_fn=<MseLossBackward>)
# running loss : 7364.701818
# entropy :  tensor(4.213949, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3561.325195, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.420860, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4118.843750, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.712553, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3637.174072, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.181670, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3776.993408, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.715181, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3658.700684, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.026452, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3791.611328, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.472366, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4050.481445, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.867154, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3336.663330, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.950971, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3322.977051, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.643092, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4383.884766, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.033780, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3470.098389, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.374466, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3601.259033, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.418680, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3595.695068, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.429362, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3701.815430, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.102546, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3141.937500, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.463200, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3970.664551, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.480068, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3244.265625, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.471892, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(2789.662354, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.854553, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3421.625000, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.668358, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3847.244141, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.893020, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3640.884033, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.753895, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3621.660889, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.477390, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3783.617676, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.891545, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3746.264893, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.493074, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3678.192139, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.630400, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3549.524658, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.559849, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4365.400879, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.162018, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3316.888916, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.600066, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4416.073242, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.738790, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3471.339355, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.830067, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3463.139160, device='cuda:0', grad_fn=<MseLossBackward>)
# running loss : 7325.527312
# entropy :  tensor(4.101906, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3192.148926, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.396014, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3742.691406, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.590349, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3849.504639, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.895749, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3491.651123, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.641007, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4195.920410, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.343550, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3944.066650, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.613401, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4216.042480, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.502293, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(
device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3582.857666, device='cuda:0', grad_fn=<MseLossBackward>)
# running loss : 7388.880544
# entropy :  tensor(4.078692, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4331.937500, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.303016, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3650.385498, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.910847, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3701.556152, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.063138, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3586.044678, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.186852, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3436.955322, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.935975, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3857.169678, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.243153, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4031.090088, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.233263, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3312.595947, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.272809, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3685.513916, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.544210, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3571.533936, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.963799, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3686.460693, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.587257, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3620.589844, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.902643, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3835.430908, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.706846, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3853.415283, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.016892, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3530.089355, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.708622, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3393.946533, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.012492, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3616.270264, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.857601, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3201.696533, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.309969, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3394.364746, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.094294, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4268.666504, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.429111, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3004.241211, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.262102, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3367.807373, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.463998, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3204.622803, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.628301, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3945.990479, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.638970, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4537.041016, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.390480, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4347.650391, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.352649, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4050.649658, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.300420, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3470.998291, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.867441, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3542.787354, device='cuda:0', grad_fn=<MseLossBackward>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-17527ea6f60d> in <module>
#      47         print("distortion : ", dist)
#      48         loss = beta * dist + entropy
# ---> 49         loss.backward()
#      50         #print("conv1.weights grad: ", params[0].grad)
#      51         #print(model.conv1.bias.grad)
#
# ~\anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# ~\anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     123         retain_graph = create_graph
#     124
# --> 125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
#     127         allow_unreachable=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
from range_coder import RangeEncoder, RangeDecoder, prob_to_cum_freq
import os

# Load previous model
model = LossyCompAutoencoder()
model.load_state_dict(torch.load('./model_parameters/mean_bit_ppx/lossy_comp_params_with_rate_beta0005_incremental.pth'))
model.eval()
model.to(device)

nb_bits = 0.0
test_dataset = ImageDataset(root_dir='./data/kodac/', transform=ToTensor())
with torch.no_grad():  
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        [reconstructed_image, data_comp] = model(test_image, 1, True)
            # compute symbol probabilities
        min_val = data_comp.min()
        if min_val <0:
            data_comp -= min_val
            min_val = 0
        max_val = data_comp.max()
        nb_bins = max_val - min_val + 1
        hist = torch.histc(data_comp, bins=nb_bins.int(), min=min_val, max=max_val)
        prob = hist/hist.sum()
        #print("data comp : ", data_comp)
        #print(prob)
        
        """
        if len(torch.nonzero(prob)) != len(prob):
            zero_indices = ((prob == 0).nonzero())
            for j in reversed(range(0, len(zero_indices), 1)):
                data_comp[data_comp > int(zero_indices[j])+min_val] -=1
            min_val = data_comp.min()
            max_val = data_comp.max()
            nb_bins = max_val - min_val + 1
            hist = torch.histc(data_comp, bins=nb_bins.int(), min=min_val, max=max_val)
            prob = hist/hist.sum()
            print(min_val)
            print(max_val)
            print("data comp : ", data_comp)
            print(prob)
         """ 
            
            # convert probabilities to cumulative integer frequency table
        #cumFreq = prob_to_cum_freq(torch.clamp(prob, min=np.finfo(np.float32).eps).cpu(), resolution=128)
        cumFreq = prob_to_cum_freq(prob.cpu(), resolution=128)
        #print(cumFreq)
        
        # encode data
        filepath_to_write = "D:\\lossy_autoencoder\\latent_vect_encoded\\" + "img" + str(i) + ".bin"
        encoder = RangeEncoder(filepath_to_write)
        #print(torch.flatten(data_comp).cpu().tolist())
        encoder.encode(torch.flatten(data_comp.int()).cpu().tolist(), cumFreq)
        encoder.close()
        
        
        file_size = os.path.getsize(filepath_to_write)*8 #number of bits in the file
        print(file_size)
        nb_bits += file_size
        
    nb_bits_per_image = nb_bits/len(test_dataset)
    print(nb_bits_per_image)
    nb_bits_per_pixel = nb_bits_per_image/(512*768)
    print(nb_bits_per_pixel)
    
    
"""
    test_image = test_dataset[1].unsqueeze(0).to(device).float()
    [reconstructed_image, data_comp] = model(test_image, 1, True)
        # compute symbol probabilities
    min_val = data_comp.min()
    print(min_val)
    print(data_comp.max())
    if min_val <0:
        data_comp -= min_val
        min_val = 0
    max_val = data_comp.max()
    
    print(max_val)
    nb_bins = max_val - min_val + 1
    print(nb_bins)
    hist = torch.histc(data_comp, bins=nb_bins.int(), min=min_val, max=max_val)
    prob = hist/hist.sum()
    print(prob)
         # convert probabilities to cumulative integer frequency table
    cumFreq = prob_to_cum_freq(prob.cpu(), resolution=128)
    #print(cumFreq)

    print(torch.flatten(data_comp).cpu().tolist())
    
    
        # encode data
    filepath_to_write = "D:\\lossy_autoencoder\\latent_vect_encoded\\" + "img" + str(1) + ".bin"
    encoder = RangeEncoder(filepath_to_write)
    print(torch.flatten(data_comp).cpu().tolist())
    encoder.encode(torch.flatten(data_comp.int()).cpu().tolist(), cumFreq)
    encoder.close()   
"""
# Out:
# 619240
# 417832
# 381184
# 485040
# 681856
# 566208
# 438336
# 716840
# 393552
# 406752
# 519136
# 394736
# 786376
# 594720
# 470824
# 428256
# 399592
# 613760
# 510416
# 464416
# 540400
# 507440
# 400992
# 585792
# 513487.3333333333
# 1.3058658175998263
# '\n    test_image = test_dataset[1].unsqueeze(0).to(device).float()\n    [reconstructed_image, data_comp] = model(test_image, 1, True)\n        # compute symbol probabilities\n    min_val = data_comp.min()\n    print(min_val)\n    print(data_comp.max())\n    if min_val <0:\n        data_comp -= min_val\n        min_val = 0\n    max_val = data_comp.max()\n    \n    print(max_val)\n    nb_bins = max_val - min_val + 1\n    print(nb_bins)\n    hist = torch.histc(data_comp, bins=nb_bins.int(), min=min_val, max=max_val)\n    prob = hist/hist.sum()\n    print(prob)\n         # convert probabilities to cumulative integer frequency table\n    cumFreq = prob_to_cum_freq(prob.cpu(), resolution=128)\n    #print(cumFreq)\n\n    print(torch.flatten(data_comp).cpu().tolist())\n    \n    \n        # encode data\n    filepath_to_write = "D:\\lossy_autoencoder\\latent_vect_encoded\\" + "img" + str(1) + ".bin"\n    encoder = RangeEncoder(filepath_to_write)\n    print(torch.flatten(data_comp).cpu().tolist())\n    encoder.encode(torch.flatten(data_comp.int()).cpu().tolist(), cumFreq)\n    encoder.close()   \n'
