# %%
import numpy as np
import torch
import torch.nn as nn
import pandas as pd
from skimage import io, transform
import torch.autograd as ag
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import os
from scipy import signal
from sklearn.metrics import mean_squared_error
from torch.autograd import Variable
import time
from functools import reduce

torch.set_printoptions(precision=6)

# %%
class ImageDataset(Dataset):

    def __init__(self, root_dir, transform=None):
        """
        Args:
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        path, dirs, files = next(os.walk(self.root_dir))
        file_count = len(files)
        return file_count

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        path, dirs, files = next(os.walk(self.root_dir))
        img_name = os.path.join(self.root_dir, files[idx])
        image = io.imread(img_name)

        if self.transform:
            image = self.transform(image)

        return image


class RandomCrop(object):
    """Crop randomly the image

    Args:
        output_size (tuple or int): Desired output size. If int, square crop
            is made.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            assert len(output_size) == 2
            self.output_size = output_size

    def __call__(self, image):
        
        h, w = image.shape[:2]
        new_h, new_w = self.output_size
        
        if h!= new_h:
            top = np.random.randint(0, h - new_h)
        else:
            top = 0
        if w!= new_w:
            left = np.random.randint(0, w - new_w)
        else:
            left = 0
     
        image = image[top: top + new_h,
                      left: left + new_w]
        
        image = np.expand_dims(image, axis=2)

        return image
    
    
class Downsample(object):
    """Downsample the image

    Args:
        downsampling_factor (int or tuple): Desired downsampling factor for rows and columns.
        If the downsampling factor is an int, then both rows and columns are sampled by the same factor
    """

    def __init__(self, downsampling_factor):
        assert isinstance(downsampling_factor, (int, tuple))
        if isinstance(downsampling_factor, int):
            self.downsampling_factor = (downsampling_factor, downsampling_factor)
        else:
            assert len(downsampling_factor) == 2
            self.downsampling_factor = downsampling_factor

    def __call__(self, image):
        
        down_fact_h, down_fact_w = self.downsampling_factor
        image = image[::down_fact_h,
                      ::down_fact_w]

        return image
    
    
class ConvertDepthToColor(object):
    """ convert a 1xmxn 16-bits depthmap to a 2xmxn 8-bits colormap

    """

    def __call__(self, image):
        if len(image.shape[:]) <3:
            image = np.expand_dims(image, axis=2)
            
        h, w = image.shape[:2]
        image_r_color= np.zeros((h,w,1), dtype=int)
        image_g_color= np.zeros((h,w,1), dtype=int)
        image_g_color[(image > 2**8 - 1)] = image[(image > 2**8 - 1)] >> 8
        image_r_color = image - (image_g_color <<8)

        return np.concatenate((image_r_color, image_g_color), axis=2)
    

class ToTensor(object):
    """Convert ndarrays in images to Tensors."""

    def __call__(self, images):

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        images = images.transpose((2, 0, 1))
        images = images.astype(float)
        return torch.from_numpy(images)
    

    
class ConvertColorToDepth(object):
    """ convert a 2xmxn 8-bits colormap to a 1xmxn 16-bits depthmap

    """

    def __call__(self, color_image):
            
        depth_image = color_image[:, 0, :, :]
        depth_image += color_image[:, 1, :, :] << 8

        return depth_image

    
def show_image_batch(images_batch):
    """Show image for a batch of samples."""
    if images_batch.size(1) == 1:
        images_batch_normed = images_batch/torch.max(images_batch)
        grid = utils.make_grid(images_batch_normed)
        plt.imshow(grid.numpy().transpose((1, 2, 0)))

        plt.title('Batch from dataloader')
    else:
        print(images_batch.size())
        images_b_batch = torch.zeros(images_batch.size(0), 1, images_batch.size(2) , images_batch.size(3))
        images_color_batch = torch.cat((images_batch, images_b_batch), 1) 
        print(images_color_batch.size())
        grid = utils.make_grid(images_color_batch)
        plt.imshow(grid.numpy().transpose((1, 2, 0)))

        plt.title('Batch from dataloader')
    
    
    
    
# Load training dataset

#mirror_padding_transform = transforms.Compose([transforms.ToPILImage(), transforms.Pad(padding=12, padding_mode='reflect'), transforms.ToTensor()])
transformed_dataset = ImageDataset(root_dir='D:/autoencoder_data/depthmaps/training', 
                                           transform=transforms.Compose([
                                            RandomCrop((384, 640)), Downsample(( 3, 5)), ConvertDepthToColor(), ToTensor()])
                                  )
dataloader = DataLoader(transformed_dataset, batch_size=25, shuffle=True, num_workers=0)

for i_batch, batch_images in enumerate(dataloader):
    print(i_batch, batch_images.size())

    # observe 4th batch and stop.
    if i_batch == 2:
        plt.figure()
        show_image_batch(batch_images)
        plt.axis('off')
        plt.ioff()
        plt.show()
        break

"""
transform = transforms.Compose([
    transforms.Pad(12, padding_mode='reflect'),
    transforms.ToTensor()])

trainset = torchvision.datasets.Flickr8k(root='./data/flickr', ann_file = './data/flickr/file.csv', transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=2)
"""
# Out:
# 0 torch.Size([25, 2, 128, 128])
# 1 torch.Size([25, 2, 128, 128])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 2 torch.Size([25, 2, 128, 128])
# torch.Size([25, 2, 128, 128])
# torch.Size([25, 3, 128, 128])
# "\ntransform = transforms.Compose([\n    transforms.Pad(12, padding_mode='reflect'),\n    transforms.ToTensor()])\n\ntrainset = torchvision.datasets.Flickr8k(root='./data/flickr', ann_file = './data/flickr/file.csv', transform=transform)\ntrainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=2)\n"

# %%
#Define additionnnal functions
def periodic_shuffling(T, C):
    T_copy = T.clone()
    batch_size = T.size()[0]
    H = T.size()[2]
    W = T.size()[3]
    T = T.view(batch_size, C, H*2, W*2)
    """
    for k in range(C):
        for i in range(2*H):
            for j in range(2*W):
                T[:, k, i, j] = T_copy[:, C*((j&1)<<1)+C*(i&1)+k, i>>1, j>>1]
    """
                
    T[:, :, ::2, ::2] = T_copy[:, 0:C, :, :]
    T[:, :, 1::2, ::2] = T_copy[:, C:2*C, :, :]
    T[:, :, ::2, 1::2] = T_copy[:, 2*C:3*C, :, :]
    T[:, :, 1::2, 1::2] = T_copy[:, 3*C:4*C, :, :]

    return T
    
    
def mirror_padding(x, padding_size):
    up_line = x[:, :, 0:padding_size, :].flip(2)
    left_col = x[:, :, :, 0:padding_size].flip(3)
    right_col = x[:, :, :, -padding_size:].flip(3)
    bottom_line = x[:, :, -padding_size:, :].flip(2)
    left_up_corner = left_col[:, :, 0:padding_size, :].flip(2)
    right_up_corner = right_col[:, :, 0:padding_size, :].flip(2)
    left_bottom_corner = left_col[:, :, -padding_size:, :].flip(2)
    right_bottom_corner = right_col[:, :, -padding_size:, :].flip(2)

    x_mirror_pad = torch.cat((torch.cat((left_up_corner, up_line, right_up_corner), 3), torch.cat((left_col, x, right_col), 3), torch.cat((left_bottom_corner, bottom_line, right_bottom_corner), 3)), 2)
    return x_mirror_pad
    

def normalize_input(x):
    mean_channels = torch.mean(1.0*x, [2,3])
    mean_channels_images = (mean_channels.repeat_interleave(x.size()[2]*x.size()[3])).view(x.size()[0], x.size()[1], x.size()[2], x.size()[3])
    x_centered = x - mean_channels_images
    max_value = torch.max(x)
    min_value = torch.min(x)
    radius = max(max_value, abs(min_value))
    x_centered_normalized = x_centered/radius
    return x_centered_normalized, radius, mean_channels

def standardize_input(x):
    mean_channels = torch.mean(1.0*x, [2,3])
    mean_channels_images = (mean_channels.repeat_interleave(x.size()[2]*x.size()[3])).view(x.size()[0], x.size()[1], x.size()[2], x.size()[3])
    x_centered = x - mean_channels_images
    var = torch.sum(x_centered**2, (0, 1))/(x.size()[0]*x.size()[1])
    return x_centered/torch.sqrt(var)
    
def denormalize_output(x, radius, mean_channels):
    x_denormalized = x*radius
    mean_channels_images = (mean_channels.repeat_interleave(x.size()[2]*x.size()[3])).view(x.size()[0], x.size()[1], x.size()[2], x.size()[3])
    x_denormalized_centered = x_denormalized + mean_channels_images
    return x_denormalized_centered

def destandardize_output(x, mean_channels, var):
    x_rescaled = x*torch.sqrt(var)
    mean_channels_images = (mean_channels.repeat_interleave(x.size()[2]*x.size()[3])).view(x.size()[0], x.size()[1], x.size()[2], x.size()[3])
    x_destandardized = x_rescaled + mean_channels_images
    return x_destandardized



def compute_gsm(x, var, phi, nScale):
    gsm = 0.0
    
    phi = torch.abs(phi)
    var = torch.abs(var)
    phi_s_sum = torch.sum(phi, 0).unsqueeze(0)
    phi_norm = phi/phi_s_sum
    
    for s in range(nScale):
        var_s = var[s, :].view(1, -1, 1, 1)
        phi_s = phi_norm[s, :].view(1, -1, 1, 1)
        gaussian = phi_s*(1.0/(torch.sqrt(2*np.pi*var_s)))*torch.exp(-0.5*(x**2/var_s))
        gsm += gaussian
    return gsm


def sum_gsm(x, var, phi, nScale):
    gsm = 0.0
    
    phi = torch.abs(phi)
    var = torch.abs(var)
    phi_s_sum = torch.sum(phi, 0).unsqueeze(0)
    phi_norm = phi/phi_s_sum
    
    for s in range(nScale):
        var_s = var[s, :].view(1, -1, 1, 1)
        phi_s = phi_norm[s, :].view(1, -1, 1, 1)
        gaussian = phi_s*(1.0/(torch.sqrt(2*np.pi*var_s)))*torch.exp(-0.5*(x**2/var_s))
        gsm += gaussian
    #gsm_sum = (torch.log2(gsm)).sum()
    gsm_sum = gsm.sum()
    return gsm_sum
    
    
    """
    batch_size = x.size(0)
    h = x.size(-1)
    w = x.size(-2)
    #print("input : ", input)
    coeff = torch.sqrt(1.0 / (2 * np.pi * var))
    #print("coeff : ", coeff)
    x_resized = x.repeat((nScale, 1, 1, 1, 1))
    #print("input : ", input_resized)
    exponent = (-0.5*(x_resized ** 2)/var.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w))
    #print("exponent : ", exponent)
    coeffs_resized = coeff.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
    #print("coeffs : ", coeffs_resized)
    gaussian = coeffs_resized * torch.exp(exponent)
    #print("gaussian : ", gaussian)
    phi_resized = phi.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
    phi_gaussian = phi_resized*gaussian
    sum_phi_gaussian = phi_gaussian.sum(dim=0)
    #print("sum over scales : ", sum_phi_gaussian)
    result = -torch.log2(sum_phi_gaussian).sum()

    return result
    """
    
def compute_mask(nb_ones, dims):
    mask = torch.zeros(dims)
    indices = np.arange(nb_ones)
    mask_flatten = mask.view(-1, 1, 1, 1)
    mask_flatten[indices] = 1
    mask_reshaped = mask_flatten.view(dims)
    return mask_reshaped


def entropy_rate(x_quantized, phi, var):
    u = torch.arange(-0.5, 0.5+0.1, 0.1).cuda()        
    gsm_sum = torch.zeros(len(u)).cuda()
    for i in range(len(u)):
        x = x_quantized + u[i]
        gsm_sum_i = sum_gsm(x, var, phi, 6)
        gsm_sum[i] = gsm_sum_i

    integral_u = torch.trapz(gsm_sum, u)
    #print("gsm sum : ", gsm_sum)
    #print("integral over u : ", integral_u)
    entropy = -torch.log2(integral_u)
    
    return entropy



def mean_bit_per_px(x_quantized, phi, var):
    u = torch.arange(-0.5, 0.5+0.1, 0.1).cuda()   
    gsm_stacked = []
    #u_stacked = []
    for i in range(len(u)):
        x = x_quantized + u[i]
        gsm = compute_gsm(x, var, phi, 6)
        gsm_stacked.append(gsm)
        #u_stacked.append(torch.ones(gsm.size()).cuda()*u[i])
    
    gsms = torch.stack(gsm_stacked, dim=0)
    #us = torch.stack(u_stacked, dim=0)
    integral_u = torch.trapz(gsms, dx=0.1, dim=0)
    if torch.any(integral_u.isnan()):
        print("integral u is nan", integral_u)
        integral_u[integral_u.isnan()] = 1
    nb_bits = (-torch.log2(torch.clamp(integral_u, min=np.exp(-10**2), max=1))).sum()
    if nb_bits < 0:
        #print("integral u : ", integral_u)
        print("nb_bits negative : ", nb_bits)
    return nb_bits/reduce(lambda x, y: x*y, list(x_quantized.size()))

"""
def entropy_rate(x_quantized, phi, var):
    u = torch.arange(-0.5, 0.5+0.05, 0.05).cuda()   
    sum_log_gsm = torch.zeros(len(u)).cuda()
    for i in range(len(u)):
        x = x_quantized + u[i]
        gsm = compute_gsm(x, var, phi, 6)
        sum_log_gsm[i] = (-torch.log2(gsm)).sum()
    
    entropy = torch.trapz(sum_log_gsm, u)
    if entropy < 0:
        print("negative entropy")
    return entropy
"""

"""
def clip(x):
    x_n = (x - torch.min(x))/(torch.max(x) - torch.min(x))
    x_clipped = torch.round(255*x_n).float()
    return x_clipped
"""


class MyQuantization(torch.autograd.Function):
    """
    We can implement our own custom autograd Functions by subclassing
    torch.autograd.Function and implementing the forward and backward passes
    which operate on Tensors.
    """
    
    @staticmethod
    def forward(ctx, input):
        """
        In the forward pass we receive a Tensor containing the input and return
        a Tensor containing the output. ctx is a context object that can be used
        to stash information for backward computation. You can cache arbitrary
        objects for use in the backward pass using the ctx.save_for_backward method.
        """
        ctx.save_for_backward(input)
        return torch.round(input)
    
    @staticmethod
    def backward(ctx, grad_output):
        """
        In the backward pass we receive a Tensor containing the gradient of the loss
        with respect to the output, and we need to compute the gradient of the loss
        with respect to the input.
        """
        input, = ctx.saved_tensors
        return grad_output

        
        
class MyClipping(torch.autograd.Function):
  
    @staticmethod
    def forward(ctx, input):
        ctx.save_for_backward(input)
        return torch.round(input).clamp(min=0, max=255.0)
    
    @staticmethod
    def backward(ctx, grad_output):
        input = ctx.saved_tensors
        return grad_output

    
"""
class GaussianDistribution(torch.autograd.Function):
    @staticmethod
    def forward(ctx, input, var, phi, nScale, nChannel):
        batch_size = input.size(0)
        h = input.size(-1)
        w = input.size(-2)
        ctx.save_for_backward(input, var, phi)
        #print("input : ", input)
        coeff = torch.sqrt(1.0 / (2 * np.pi * var))
        #print("coeff : ", coeff)
        input_resized = input.repeat((nScale, 1, 1, 1, 1))
        #print("input : ", input_resized)
        exponent = (-0.5*(input_resized ** 2)/var.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w))
        #print("exponent : ", exponent)
        coeffs_resized = coeff.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
        #print("coeffs : ", coeffs_resized)
        gaussian = coeffs_resized * torch.exp(exponent)
        #print("gaussian : ", gaussian)
        phi_resized = phi.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
        phi_gaussian = phi_resized*gaussian
        sum_phi_gaussian = phi_gaussian.sum(dim=0)
        #print("sum over scales : ", sum_phi_gaussian)
        result = -torch.log2(sum_phi_gaussian).sum()

        return result

    @staticmethod
    def backward(ctx, grad_output):
        input, var, phi = ctx.saved_tensors
        batch_size = input.size(0)
        h = input.size(-1)
        w = input.size(-2)
        nChannel = var.size(1)
        nScale = var.size(0)
        
        
        var_resized = var.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
        phi_resized = phi.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
        input_resized = input.repeat((nScale, 1, 1, 1, 1))
        
        d_phi = -torch.log2(1.0/torch.sqrt(2.0*np.pi*var_resized)*(torch.exp(-0.5*input_resized**2/var_resized))).sum(dim = [3, 4])
        d_var = -torch.log2(phi_resized*(1.0/(np.sqrt(2.0*np.pi)*var_resized)*torch.exp(-0.5*input_resized**2/var_resized))*(1.0 + input_resized**2/var_resized)).sum(dim = [3, 4])
        d_xq = -torch.log2((phi_resized*(-input_resized/torch.sqrt(2.0*np.pi*var_resized**3))*torch.exp(-0.5*input_resized**2/var_resized)).sum(dim=[0]))
        print("d_xq : ", (phi_resized*(-input_resized/torch.sqrt(2.0*np.pi*var_resized**3))*torch.exp(-0.5*input_resized**2/var_resized)).sum(dim=[0]))
        
        return grad_output*d_phi, grad_output*d_var, grad_output*d_xq
"""
# Out:
# '\nclass GaussianDistribution(torch.autograd.Function):\n    @staticmethod\n    def forward(ctx, input, var, phi, nScale, nChannel):\n        batch_size = input.size(0)\n        h = input.size(-1)\n        w = input.size(-2)\n        ctx.save_for_backward(input, var, phi)\n        #print("input : ", input)\n        coeff = torch.sqrt(1.0 / (2 * np.pi * var))\n        #print("coeff : ", coeff)\n        input_resized = input.repeat((nScale, 1, 1, 1, 1))\n        #print("input : ", input_resized)\n        exponent = (-0.5*(input_resized ** 2)/var.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w))\n        #print("exponent : ", exponent)\n        coeffs_resized = coeff.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)\n        #print("coeffs : ", coeffs_resized)\n        gaussian = coeffs_resized * torch.exp(exponent)\n        #print("gaussian : ", gaussian)\n        phi_resized = phi.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)\n        phi_gaussian = phi_resized*gaussian\n        sum_phi_gaussian = phi_gaussian.sum(dim=0)\n        #print("sum over scales : ", sum_phi_gaussian)\n        result = -torch.log2(sum_phi_gaussian).sum()\n\n        return result\n\n    @staticmethod\n    def backward(ctx, grad_output):\n        input, var, phi = ctx.saved_tensors\n        batch_size = input.size(0)\n        h = input.size(-1)\n        w = input.size(-2)\n        nChannel = var.size(1)\n        nScale = var.size(0)\n        \n        \n        var_resized = var.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)\n        phi_resized = phi.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)\n        input_resized = input.repeat((nScale, 1, 1, 1, 1))\n        \n        d_phi = -torch.log2(1.0/torch.sqrt(2.0*np.pi*var_resized)*(torch.exp(-0.5*input_resized**2/var_resized))).sum(dim = [3, 4])\n        d_var = -torch.log2(phi_resized*(1.0/(np.sqrt(2.0*np.pi)*var_resized)*torch.exp(-0.5*input_resized**2/var_resized))*(1.0 + input_resized**2/var_resized)).sum(dim = [3, 4])\n        d_xq = -torch.log2((phi_resized*(-input_resized/torch.sqrt(2.0*np.pi*var_resized**3))*torch.exp(-0.5*input_resized**2/var_resized)).sum(dim=[0]))\n        print("d_xq : ", (phi_resized*(-input_resized/torch.sqrt(2.0*np.pi*var_resized**3))*torch.exp(-0.5*input_resized**2/var_resized)).sum(dim=[0]))\n        \n        return grad_output*d_phi, grad_output*d_var, grad_output*d_xq\n'

# %%
#Define the Convolutional Autoencoder with integrated classifer
    #taille de l'image d'entrée : 128*128
class LossyCompAutoencoder(nn.Module):
    def __init__(self):
        super(LossyCompAutoencoder, self).__init__()
       
        #Encoder
            # input block
        self.conv1 = nn.Conv2d(2, 64, 5, stride=2, padding=0)  
        self.conv2 = nn.Conv2d(64, 128, 5, stride=2, padding=0)
            # residual block 
        self.resConv = nn.Conv2d(128, 128, 3, stride=1, padding=1)
            # output block
        self.conv3 = nn.Conv2d(128, 96, 5, stride=2, padding=0)
        self.quantization = MyQuantization.apply
        #self.gaussian_distribution = GaussianDistribution.apply
        

       
        #Decoder
            # subpixel 1
        self.subpix1 = nn.Conv2d(96, 512, 3, stride=1, padding=1)
            # subpixel 2
        self.subpix2 = nn.Conv2d(128, 256, 3, stride=1, padding=1)
            # subpixel 3
        self.subpix3 = nn.Conv2d(256//4, 8, 3, stride=1, padding=1)
            #residual block
        self.deconv1 = nn.Conv2d(512//4, 128, 3, stride=1, padding=1)
        self.deconv2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.clip = MyClipping.apply
        
        #Bit-rate      
        self.var = nn.Parameter(torch.Tensor(6, 96))
        self.phi = nn.Parameter(torch.Tensor(6, 96))
        self.var.data.uniform_(0, 1)
        self.phi.data.uniform_(0, 1)
        
        """
        self.gsm_pi = torch.nn.Parameter(torch.randn(6, 96))
        self.gsm_sigma = torch.nn.Parameter(torch.randn(6, 96))
        """
    
    
    
    def forward(self, x, mask= 1, return_xq=False):
        #encoder
            # normalization
        x, var, mean_channels = standardize_input(x)
        if torch.any(x.isnan()):
            print("x after normalization is nan", x)
            # mirror padding
        x = mirror_padding(x, 14)
        if torch.any(x.isnan()):
            print("x after mirror padding is nan", x)
        """
        with torch.no_grad():
            x_copy = x.cpu()
            show_image_batch(x_copy)
        """
            # input blocks
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x_c1 = x.clone()
        if torch.any(x.isnan()):
            print("x after input block is nan", x)
            # residual block 1
        x = F.relu(self.resConv(x))
        x = self.resConv(x)
        x += x_c1
        x_c2 = x.clone()
        if torch.any(x.isnan()):
            print("x after residual block 1 is nan", x)
            # residual block 2
        x = F.relu(self.resConv(x))
        x = self.resConv(x)
        x += x_c2
        x_c3 = x.clone()
        if torch.any(x.isnan()):
            print("x after residual block 2 is nan", x)
            # residual block 3
        x = F.relu(self.resConv(x))
        x = self.resConv(x)
        x += x_c3
        if torch.any(x.isnan()):
            print("x after residual block 3 is nan", x)
            # output block
        x = self.conv3(x)
        if torch.any(x.isnan()):
            print("x after output block is nan", x)
            # quantization
        x = self.quantization(x)
        if torch.any(x.isnan()):
            print("x after quantization block is nan", x)
            # add mask for incremental training
        x = x*mask
        x_quantized = x
        if torch.any(x.isnan()):
            print("x after mask is nan", x)
        
        
        """
        w = x_quantized.size()[2]
        h = x_quantized.size()[3]
        gsm = 0.0
        for i in range(6)
            mi = torch.flatten(x_quantized),torch.diagonal(self.gsm_sigma[s, :].repeat(w*h, 1).squeeze(0))
            gsm += 
        """
        

        #decoder
            # subpixel 1
        x = self.subpix1(x)
        x = periodic_shuffling(x, 512//4)
        x_c4 = x.clone()
        if torch.any(x.isnan()):
            print("x after subpix 1 is nan", x)
            # residual block 1
        x = F.relu(self.deconv1(x))
        x = self.deconv2(x)
        x += x_c4
        x_c5 = x.clone()
        if torch.any(x.isnan()):
            print("x after residual block 1 is nan", x)
               # residual block 2
        x = F.relu(self.deconv2(x))
        x = self.deconv2(x)
        x += x_c5
        x_c6 = x.clone()
        if torch.any(x.isnan()):
            print("x after residual block 2 is nan", x)
               # residual block 3
        x = F.relu(self.deconv2(x))
        x = self.deconv2(x)
        x += x_c6
        if torch.any(x.isnan()):
            print("x after residual block 3 is nan", x)
                # subpixel 2
        x = self.subpix2(x)
        x = F.relu(periodic_shuffling(x, 256//4))
        if torch.any(x.isnan()):
            print("x after subpix 2 is nan", x)
                # subpixel 3
        x = self.subpix3(x)
        x = periodic_shuffling(x, 8//4)
        if torch.any(x.isnan()):
            print("x after subpix 3 is nan", x)
                # denormalization
        x = destandardize_output(x, mean_channels, var)
        if torch.any(x.isnan()):
            print("x after denormalization is nan", x)
                # clipping
        x = self.clip(x)
        if torch.any(x.isnan()):
            print("x after clipping is nan", x)

        
        if return_xq:
            return x, x_quantized
        else:
            return x

# %%
# instanciate the model
model = LossyCompAutoencoder()
print(model)
params = list(model.parameters())
print(len(params))
print(params)
# Out:
# LossyCompAutoencoder(
#   (conv1): Conv2d(2, 64, kernel_size=(5, 5), stride=(2, 2))
#   (conv2): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2))
#   (resConv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(128, 96, kernel_size=(5, 5), stride=(2, 2))
#   (subpix1): Conv2d(96, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (subpix2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (subpix3): Conv2d(64, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# 20
# [Parameter containing:
# tensor([[2.125180e-02, 3.341254e-01, 3.041879e-01, 3.453088e-01, 8.558905e-01,
#          7.573051e-01, 7.953330e-01, 6.164231e-01, 6.891525e-01, 8.971518e-01,
#          8.160567e-02, 8.191848e-02, 6.860585e-01, 6.820121e-01, 9.818667e-02,
#          8.232255e-01, 1.761252e-01, 9.803039e-01, 3.951728e-02, 1.814902e-02,
#          5.833333e-01, 7.739850e-01, 5.916018e-01, 9.004091e-01, 1.906074e-01,
#          3.917396e-03, 8.252084e-01, 3.967597e-01, 1.421070e-01, 5.752760e-01,
#          7.699557e-01, 3.652782e-01, 6.278874e-01, 9.676250e-01, 6.140190e-02,
#          8.471043e-01, 6.022130e-01, 5.196434e-01, 2.339131e-01, 9.768965e-01,
#          5.352714e-01, 8.271176e-01, 6.122137e-01, 5.798649e-01, 7.223948e-01,
#          8.174818e-01, 5.383551e-01, 7.534290e-01, 4.952608e-01, 1.288953e-01,
#          6.529421e-02, 2.861612e-01, 7.389871e-01, 1.760848e-01, 2.329226e-01,
#          4.840717e-01, 6.579720e-01, 1.336581e-01, 4.934381e-01, 3.149905e-01,
#          1.763629e-01, 7.041054e-01, 2.435387e-01, 1.919433e-01, 5.295237e-01,
#          3.836991e-01, 4.388665e-01, 1.703340e-01, 4.329178e-01, 4.802717e-01,
#          4.195904e-01, 7.587224e-02, 3.987551e-02, 2.800687e-01, 5.318645e-01,
#          1.346049e-01, 6.229287e-01, 4.138526e-01, 7.109351e-01, 1.419917e-01,
#          9.229454e-01, 7.196200e-01, 2.264184e-01, 4.832801e-01, 3.398533e-01,
#          6.444308e-01, 4.037388e-01, 8.114307e-01, 8.175757e-01, 7.133727e-01,
#          2.865971e-01, 5.656570e-01, 6.639794e-01, 2.292591e-01, 5.689812e-02,
#          6.439587e-01],
#
#          [[-0.019659, -0.026521, -0.002670],
#           [ 0.000984, -0.018013,  0.021572],
#           [-0.022083, -0.013100, -0.024934]],
#
#          [[ 0.013000,  0.008409, -0.010703],
#           [-0.020278, -0.024646, -0.013296],
#           [ 0.009670,  0.007989, -0.014159]]],
#
#
#         [[[ 0.001603,  0.014166, -0.012335],
#           [ 0.025091,  0.002739, -0.015450],
#           [ 0.025680, -0.017771,  0.011526]],
#
#          [[-0.025335,  0.020353, -0.001701],
#           [ 0.007939,  0.022983,  0.009054],
#           [-0.016988,  0.014709, -0.010359]],
#
#          [[ 0.021046,  0.007327,  0.014053],
#           [ 0.017593,  0.024674,  0.008959],
#           [ 0.027073,  0.023963,  0.005883]],
#
#          ...,
#
#          [[-0.017463,  0.013773,  0.006049],
#           [-0.005207,  0.025288, -0.023309],
#           [-0.009854, -0.017300, -0.023249]],
#
#          [[ 0.025391,  0.017288,  0.002798],
#           [ 0.006981,  0.027225, -0.012531],
#           [-0.018193, -0.014025,  0.011368]],
#
#          [[ 0.012715, -0.015193,  0.017477],
#           [-0.013334,  0.015052, -0.002341],
#           [ 0.027656,  0.000886,  0.005785]]],
#
#
#         [[[-0.011081,  0.009258, -0.026792],
#           [-0.011093, -0.020889, -0.016335],
#           [ 0.005880,  0.001190, -0.015096]],
#
#          [[-0.004186, -0.021080,  0.013576],
#           [-0.007154, -0.009676,  0.028625],
#           [ 0.012668,  0.011083, -0.007995]],
#
# ...
#           [-3.269285e-03, -1.886836e-02, -1.592990e-02],
#           [ 1.204957e-02,  9.315474e-03,  1.064597e-02]],
#
#          [[-2.297021e-02,  4.957492e-03, -2.143741e-02],
#           [ 2.065713e-03, -2.846291e-02,  1.744866e-02],
#           [ 1.196193e-02,  2.288025e-02, -4.392542e-03]],
#
#          [[-1.077670e-02,  1.836798e-02,  1.654777e-02],
#           [ 5.978290e-04, -2.060652e-02,  1.119119e-02],
#           [ 2.193080e-02,  2.636139e-02, -1.631346e-02]],
#
#          ...,
#
#          [[-9.440782e-03,  4.953971e-03,  2.201989e-02],
#           [-8.397724e-03, -1.746130e-02,  1.844689e-02],
#           [-2.830555e-02,  1.203512e-02, -9.391926e-03]],
#
#          [[ 2.650267e-02, -8.889958e-04,  1.908487e-02],
#           [ 2.235760e-02,  1.113923e-02, -2.023007e-02],
#           [ 7.655812e-03, -4.387291e-03,  1.397948e-02]],
#
#          [[ 8.754103e-03, -5.925091e-03,  1.822032e-02],
#           [-2.697248e-03, -1.836661e-02, -5.836779e-03],
#           [-1.917721e-02,  2.895740e-02,  2.745576e-02]]],
#
#
#         [[[-2.091910e-02,  1.911107e-02,  1.208792e-02],
#           [ 2.636458e-02, -2.703574e-02, -4.750304e-03],
#           [-3.601557e-03, -2.351331e-02,  7.880570e-03]],
#
#          [[-8.857977e-04,  2.909453e-02, -2.445972e-02],
#           [-2.967343e-03, -2.072979e-02,  9.214418e-03],
#           [-1.857347e-02, -1.579399e-02,  2.725737e-02]],
#
#          [[ 2.612468e-02,  2.765304e-02,  1.911550e-02],
#
#          [[-2.519892e-02,  1.049502e-02, -3.865318e-03],
#           [-2.487501e-02, -1.041017e-02,  4.808480e-03],
#           [-2.513606e-03,  2.093855e-02, -1.555166e-02]],
#
#          [[ 2.923942e-02, -1.636978e-02,  3.516661e-03],
#           [-2.330037e-02, -2.460498e-02, -1.363147e-02],
#           [ 4.119949e-03,  1.618118e-02,  1.618679e-02]]],
#
#
#         [[[-9.873420e-03,  7.493617e-03,  5.040927e-03],
#           [ 2.789404e-02,  1.108344e-02,  9.875009e-03],
#           [-1.479020e-02,  9.499395e-03, -5.670022e-03]],
#
#          [[-1.075548e-02, -3.842644e-03,  1.210422e-02],
#           [-3.814613e-03, -1.502289e-02, -8.474924e-04],
#           [-2.058143e-02,  9.379162e-03,  9.235715e-03]],
#
#          [[ 1.981818e-02, -5.694306e-03,  3.693154e-03],
#           [-6.655268e-03,  1.701875e-02, -9.638546e-03],
#           [ 2.840996e-02, -9.899206e-03,  1.223250e-02]],
#
#          ...,
#
#          [[ 2.120312e-02,  2.181903e-02, -8.028314e-03],
#           [ 1.003324e-02, -1.702139e-02, -1.799999e-02],
#           [ 9.781616e-03, -1.370136e-02, -1.541084e-02]],
#
#          [[ 1.041107e-02, -1.071577e-02, -5.836830e-03],
#           [ 1.333505e-03,  3.903942e-03,  1.023219e-02],
#           [-1.770496e-02, -4.474055e-04,  8.324472e-03]],
#
#          [[-1.080811e-02, -8.689908e-03,  2.549203e-02],
#           [ 7.530527e-03,  1.218601e-02, -5.357005e-03],
#           [-1.272704e-02, -2.484544e-02,  9.284914e-05]]],
#
#
#         ...,
#
#
#         [[[ 2.453733e-02,  1.466064e-02, -1.243932e-03],
#           [-3.801815e-03,  1.154646e-02,  2.370781e-02],
#           [ 2.292205e-02,  2.322068e-02,  2.867744e-02]],
#
#          [[-4.972678e-03, -2.348624e-02,  1.218516e-02],
#           [ 5.147124e-03,  2.060973e-02,  9.283887e-03],
#           [-2.895834e-02, -1.753684e-02,  1.853999e-02]],
#
#          [[-1.488387e-02, -2.287684e-02,  1.695711e-02],
#           [ 1.722491e-02,  2.866885e-02, -1.608620e-02],
#           [-1.623992e-02,  1.734410e-02,  9.153882e-03]],
#
#          ...,
#
#          [[ 1.974350e-02,  2.654810e-02, -2.729617e-02],
#           [-1.538361e-02, -1.141616e-02,  5.697878e-03],
#           [ 3.632603e-03, -5.942730e-03, -2.108065e-02]],
#
#          [[-1.995800e-02, -2.180900e-02,  3.034065e-03],
#           [-2.708521e-02,  2.122885e-03,  5.307468e-03],
#           [ 6.389486e-03,  6.929319e-04, -1.613378e-02]],
#
#          [[ 2.106674e-02, -6.042602e-03, -1.229250e-02],
#           [-1.175015e-02,  8.670101e-03,  1.921917e-02],
#           [ 6.954258e-03,  2.686847e-02, -1.273405e-02]]],
#
#
#         [[[ 2.181549e-02,  9.874111e-03, -2.422171e-02],
#           [-1.028838e-02,  1.270162e-02, -1.724335e-02],
#           [-1.406839e-02,  1.897744e-02,  1.096061e-02]],
#
#          [[ 2.874515e-02,  1.539116e-02, -2.873430e-02],
#          0.028539,  0.017444,  0.016520, -0.001779,  0.016078, -0.002970,
#         -0.024353, -0.026273, -0.004059,  0.013703,  0.019405, -0.023792,
#          0.021120, -0.014900, -0.005257,  0.016375, -0.003480,  0.023699,
#          0.025470,  0.006602, -0.010157, -0.025396,  0.027029, -0.025556,
#         -0.000783,  0.010805, -0.018251,  0.026494,  0.023506,  0.014790,
#         -0.012590, -0.025743,  0.000863,  0.013866,  0.006167,  0.027606,
#          0.003958, -0.016001,  0.013743, -0.004418, -0.015547,  0.019460,
#         -0.026242, -0.010543,  0.015224,  0.012070,  0.020977, -0.001523,
#         -0.018915,  0.020536, -0.014308,  0.002760,  0.008145,  0.021557,
#          0.021445, -0.000524], requires_grad=True)]

# %%
def get_device():
    if torch.cuda.is_available():
        device = 'cuda:0'
    else:
        device = 'cpu'
    return device

device = get_device()
print(device)
# Out:
# cuda:0

# %%
# transfert du model au gpu
model.to(device)

#define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# define loss function
distortion = nn.MSELoss().cuda()
        
# incremental update of coefficients        

# define beta
beta = 1
# define threshold and loss_init
threshold = 0.95
loss_init = float("Inf")
nb_ones = 1
iteration = 0
mask=(compute_mask(1, (96, 16, 16)).unsqueeze(0)).cuda()
dim_latent = 16*16*96
output_flag = False

#Epochs
n_epochs = 6150


# Training the network
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
    
    """
    if epoch==100:
        # define a new learning rate and so a new optimizer
        optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
    """
        
    #Training
    for i_batch, data in enumerate(dataloader):
        batch_images = data.to(device).float()
        [decoded_images, x_quantized] = model(batch_images, mask, True)
        optimizer.zero_grad()
        loss_dist = distortion(decoded_images, batch_images)
        loss_bit = mean_bit_per_px(x_quantized, model.phi, model.var)
        #print(" loss distortion : ", loss_dist)
        #print("loss bit : ", loss_bit)
        loss = beta * loss_dist + loss_bit
        #print(loss)
        
        # check the value of the loss to see if another coefficient can be enabled
        if (loss.item() < loss_init*threshold or iteration > 5):
            if (nb_ones<dim_latent):
                nb_ones +=1
                loss_init = loss.item()
                iteration = 0
                mask = (compute_mask(nb_ones, tuple(x_quantized.size()[1:])).unsqueeze(0)).cuda()
            else:
                output_flag = True
                break
            
        loss.backward()
        #print("conv1.weights grad: ", params[0].grad)
        #print(model.conv1.bias.grad)
        #print(model.conv1.weight.grad)
        optimizer.step()
        running_loss += loss.item()
        iteration += 1

    if output_flag:
        break
    running_loss = running_loss/len(dataloader)
    print('running loss : {:.06f}'.format(running_loss), )
# Out:
# running loss : 3317.633229
# running loss : 3189.748018
# running loss : 2977.363971
# running loss : 2860.661377
# running loss : 2822.696303
# running loss : 2780.423139
# running loss : 2751.136159
# running loss : 2722.719396
# running loss : 2688.558824
# running loss : 2649.326172
# running loss : 2635.455552
# running loss : 2622.211986
# running loss : 2598.200066
# running loss : 2577.622372
# running loss : 2556.825684
# running loss : 2538.315200
# running loss : 2516.425767
# running loss : 2486.261633
# running loss : 2480.126436
# running loss : 2446.734231
# running loss : 2429.957103
# running loss : 2417.624411
# running loss : 2396.975414
# running loss : 2387.896915
# running loss : 2363.239387
# running loss : 2338.404541
# running loss : 2311.079935
# running loss : 2293.912698
# running loss : 2301.869399
# running loss : 2266.932560
# running loss : 2237.699506
# running loss : 2220.029642
# running loss : 2215.942756
# running loss : 2204.094023
# running loss : 2164.769172
# running loss : 2147.600572
# running loss : 2124.781990
# running loss : 2107.558536
# running loss : 2092.542236
# running loss : 2060.245943
# running loss : 2048.817828
# running loss : 2038.215066
# running loss : 2024.723511
# running loss : 1979.230756
# running loss : 1962.939934
# running loss : 1923.028507
# running loss : 1900.132181
# running loss : 1881.361824
# running loss : 1851.251781
# running loss : 1808.621237
# running loss : 1771.805887
# running loss : 1737.302483
# running loss : 1712.368387
# running loss : 1663.968793
# running loss : 1649.526583
# running loss : 1634.906853
# running loss : 1626.061789
# running loss : 1602.973898
# running loss : 1585.375905
# running loss : 1580.503468
# running loss : 1567.134450
# running loss : 1557.546380
# running loss : 1544.804766
# running loss : 1531.022798
# running loss : 1518.184628
# running loss : 1515.326423
# running loss : 1507.294089
# running loss : 1501.676183
# running loss : 1490.640955
# running loss : 1495.675580
# running loss : 1476.955552
# running loss : 1470.485732
# running loss : 1457.879459
# running loss : 1449.791030
# running loss : 1437.782578
# running loss : 1415.160724
# running loss : 1412.788079
# running loss : 1393.921976
# running loss : 1391.482199
# running loss : 1376.268469
# running loss : 1373.787009
# running loss : 1361.765718
# running loss : 1353.654268
# running loss : 1345.525922
# running loss : 1331.399967
# running loss : 1328.867812
# running loss : 1319.514885
# running loss : 1301.164386
# running loss : 1305.880134
# running loss : 1292.752090
# running loss : 1295.309915
# running loss : 1277.468441
# running loss : 1278.021427
# running loss : 1264.729765
# running loss : 1266.448120
# running loss : 1260.572036
# running loss : 1248.279397
# running loss : 1240.462417
# running loss : 1232.215899
# running loss : 1227.354097
# running loss : 1228.722003
# running loss : 1218.935274
# running loss : 1201.875129
# running loss : 1201.365680
# running loss : 1196.079295
# running loss : 1183.989409
# running loss : 1182.851110
# running loss : 1174.605020
# running loss : 1161.519506
# running loss : 1158.424769
# running loss : 1157.093147
# running loss : 1154.843140
# running loss : 1140.050487
# running loss : 1129.445208
# running loss : 1128.380511
# running loss : 1117.234784
# running loss : 1108.332792
# running loss : 1097.014139
# running loss : 1098.361454
# running loss : 1093.180578
# running loss : 1082.851764
# running loss : 1069.977058
# running loss : 1065.467422
# running loss : 1051.328107
# running loss : 1058.182308
# running loss : 1044.506168
# running loss : 1042.270928
# running loss : 1040.460482
# running loss : 1029.274245
# running loss : 1021.355731
# running loss : 1024.714571
# running loss : 1015.138535
# running loss : 1005.322460
# running loss : 999.946117
# running loss : 994.034564
# running loss : 989.687748
# running loss : 986.847803
# running loss : 975.400742
# running loss : 970.269510
# running loss : 967.575623
# running loss : 954.735316
# running loss : 953.028769
# running loss : 941.594885
# running loss : 938.172686
# running loss : 927.098708
# running loss : 934.505813
# running loss : 926.006674
# running loss : 917.332893
# running loss : 912.429619
# running loss : 909.072442
# running loss : 910.650602
# running loss : 898.981567
# running loss : 900.014871
# running loss : 899.335266
# running loss : 890.908828
# running loss : 887.032248
# running loss : 880.943036
# running loss : 878.277523
# running loss : 872.815652
# running loss : 869.247756
# running loss : 873.536837
# running loss : 860.927605
# running loss : 857.628651
# running loss : 853.941510
# running loss : 847.059750
# running loss : 845.157568
# running loss : 833.904817
# running loss : 837.179720
# running loss : 835.559922
# running loss : 836.019029
# running loss : 822.106478
# running loss : 824.469077
# running loss : 819.856449
# running loss : 812.447757
# running loss : 811.132856
# running loss : 803.543906
# running loss : 800.943104
# running loss : 804.591201
# running loss : 800.589607
# running loss : 791.668805
# running loss : 787.677663
# running loss : 792.301866
# running loss : 784.079737
# running loss : 782.082268
# running loss : 776.480088
# running loss : 776.983815
# running loss : 772.930280
# running loss : 770.269434
# running loss : 773.437748
# running loss : 771.380475
# running loss : 762.152444
# running loss : 758.841064
# running loss : 759.476099
# running loss : 756.400563
# running loss : 755.600661
# running loss : 754.722495
# running loss : 751.671351
# running loss : 747.619715
# running loss : 749.164429
# running loss : 744.763277
# running loss : 745.144811
# running loss : 741.916084
# running loss : 738.563782
# running loss : 736.295310
# running loss : 729.679063
# running loss : 728.981438
# running loss : 729.474258
# running loss : 727.728961
# running loss : 728.306020
# running loss : 718.644036
# running loss : 716.340443
# running loss : 723.365626
# running loss : 710.426349
# running loss : 714.134223
# running loss : 718.194849
# running loss : 710.019801
# running loss : 704.187522
# running loss : 703.164849
# running loss : 699.635333
# running loss : 695.815010
# running loss : 701.525229
# running loss : 691.294516
# running loss : 699.800889
# running loss : 690.434114
# running loss : 694.417699
# running loss : 684.727413
# running loss : 685.220567
# running loss : 688.054531
# running loss : 680.704737
# running loss : 675.478605
# running loss : 675.397834
# running loss : 673.925526
# running loss : 670.788955
# running loss : 671.423444
# running loss : 665.892916
# running loss : 667.952087
# running loss : 668.659955
# running loss : 664.099670
# running loss : 665.178219
# running loss : 659.804716
# running loss : 655.404078
# running loss : 653.561847
# running loss : 649.524138
# running loss : 651.136532
# running loss : 646.266415
# running loss : 644.480332
# running loss : 644.737876
# running loss : 639.740755
# running loss : 640.862122
# running loss : 640.482889
# running loss : 640.776148
# running loss : 635.513306
# running loss : 638.064485
# running loss : 631.198088
# running loss : 633.025865
# running loss : 634.060586
# running loss : 633.100726
# running loss : 625.626407
# running loss : 623.659503
# running loss : 626.209893
# running loss : 628.411461
# running loss : 617.259295
# running loss : 620.694866
# running loss : 626.124772
# running loss : 616.288919
# running loss : 618.776385
# running loss : 620.027606
# running loss : 618.762889
# running loss : 612.704475
# running loss : 610.359501
# running loss : 610.555143
# running loss : 615.761902
# running loss : 609.251109
# running loss : 607.345455
# running loss : 605.411122
# running loss : 603.874063
# running loss : 596.862140
# running loss : 600.309892
# running loss : 598.011144
# running loss : 595.418909
# running loss : 594.641436
# running loss : 596.932703
# running loss : 596.350949
# running loss : 587.338923
# running loss : 587.430371
# running loss : 586.689428
# running loss : 585.524260
# running loss : 589.100401
# running loss : 580.537267
# running loss : 582.562855
# running loss : 574.045561
# running loss : 579.186146
# running loss : 578.065604
# running loss : 576.138772
# running loss : 573.895321
# running loss : 577.542606
# running loss : 569.943812
# running loss : 570.728990
# running loss : 570.479557
# running loss : 568.402480
# running loss : 564.514289
# running loss : 566.901283
# running loss : 563.680594
# running loss : 569.195838
# running loss : 565.658681
# running loss : 561.573213
# running loss : 560.196858
# running loss : 558.788160
# running loss : 559.997101
# running loss : 556.305935
# running loss : 555.798965
# running loss : 553.166893
# running loss : 553.394835
# running loss : 553.499706
# running loss : 548.109635
# running loss : 551.307991
# running loss : 550.693611
# running loss : 543.484538
# running loss : 546.311904
# running loss : 544.745674
# running loss : 545.786278
# running loss : 545.702633
# running loss : 543.382281
# running loss : 544.203319
# running loss : 541.986789
# running loss : 539.322535
# running loss : 536.624485
# running loss : 533.657358
# running loss : 531.778265
# running loss : 532.696582
# running loss : 532.397798
# running loss : 534.866767
# running loss : 534.998803
# running loss : 531.752989
# running loss : 530.367642
# running loss : 531.213542
# running loss : 525.492509
# running loss : 526.498033
# running loss : 528.096217
# running loss : 522.560392
# running loss : 527.266874
# running loss : 522.322389
# running loss : 524.828080
# running loss : 519.066501
# running loss : 518.578175
# running loss : 520.422957
# running loss : 516.156557
# running loss : 515.212340
# running loss : 513.883613
# running loss : 508.809008
# running loss : 514.064010
# running loss : 510.801444
# running loss : 511.283144
# running loss : 508.161102
# running loss : 510.579190
# running loss : 503.429280
# running loss : 505.527127
# running loss : 508.501994
# running loss : 505.065203
# running loss : 501.969287
# running loss : 528.616744
# running loss : 555.014185
# running loss : 517.522263
# running loss : 508.813392
# running loss : 498.547954
# running loss : 501.436330
# running loss : 500.506032
# running loss : 498.242205
# running loss : 490.403108
# running loss : 495.271093
# running loss : 493.061339
# running loss : 491.773439
# running loss : 487.280338
# running loss : 491.546572
# running loss : 491.134049
# running loss : 490.175271
# running loss : 487.841750
# running loss : 484.326588
# running loss : 487.858330
# running loss : 479.796392
# running loss : 485.257983
# running loss : 481.429729
# running loss : 481.550657
# running loss : 482.958193
# running loss : 485.717213
# running loss : 478.261042
# running loss : 478.416283
# running loss : 476.892713
# running loss : 478.881757
# running loss : 481.038716
# running loss : 477.499503
# running loss : 470.972407
# running loss : 473.915380
# running loss : 469.773947
# running loss : 471.582392
# running loss : 473.271328
# running loss : 465.380136
# running loss : 468.808617
# running loss : 470.559701
# running loss : 466.168987
# running loss : 464.920162
# running loss : 462.585699
# running loss : 464.464628
# running loss : 463.107285
# running loss : 464.044198
# running loss : 463.032358
# running loss : 465.091477
# running loss : 457.951861
# running loss : 458.088950
# running loss : 457.292165
# running loss : 458.857544
# running loss : 457.412470
# running loss : 451.097606
# running loss : 453.209221
# running loss : 453.454161
# running loss : 452.216896
# running loss : 447.701430
# running loss : 454.291314
# running loss : 448.293407
# running loss : 447.599114
# running loss : 443.909849
# running loss : 450.895951
# running loss : 447.251740
# running loss : 439.526419
# running loss : 438.880434
# running loss : 443.579676
# running loss : 440.666946
# running loss : 438.872273
# running loss : 438.186252
# running loss : 439.564268
# running loss : 444.390866
# running loss : 436.862680
# running loss : 439.125515
# running loss : 433.118893
# running loss : 437.802397
# running loss : 434.991636
# running loss : 432.126603
# running loss : 432.567157
# running loss : 434.912716
# running loss : 430.945557
# running loss : 431.307450
# running loss : 431.059901
# running loss : 431.796083
# running loss : 430.609625
# running loss : 435.977234
# running loss : 426.426304
# running loss : 433.739624
# running loss : 429.155627
# running loss : 428.110621
# running loss : 427.050210
# running loss : 427.181075
# running loss : 427.052296
# running loss : 428.655401
# running loss : 427.237657
# running loss : 419.629281
# running loss : 422.629272
# running loss : 424.358345
# running loss : 421.022763
# running loss : 417.736913
# running loss : 416.875675
# running loss : 419.346010
# running loss : 423.660497
# running loss : 415.831204
# running loss : 418.864138
# running loss : 414.386232
# running loss : 417.692279
# running loss : 419.382051
# running loss : 414.727096
# running loss : 417.605108
# running loss : 407.415786
# running loss : 408.617462
# running loss : 411.200585
# running loss : 410.541312
# running loss : 411.922489
# running loss : 410.147870
# running loss : 410.962252
# running loss : 411.523064
# running loss : 408.592495
# running loss : 405.877350
# running loss : 403.053774
# running loss : 405.304804
# running loss : 407.868638
# running loss : 402.229526
# running loss : 404.756981
# running loss : 404.458843
# running loss : 400.037292
# running loss : 401.101807
# running loss : 403.265998
# running loss : 399.672074
# running loss : 396.354209
# running loss : 395.834308
# running loss : 395.765821
# running loss : 393.417872
# running loss : 398.529414
# running loss : 395.276768
# running loss : 393.391341
# running loss : 394.701346
# running loss : 388.897980
# running loss : 389.610353
# running loss : 392.752481
# running loss : 390.716664
# running loss : 390.554704
# running loss : 388.602026
# running loss : 389.552838
# running loss : 386.966660
# running loss : 388.131518
# running loss : 389.243660
# running loss : 386.781482
# running loss : 388.904331
# running loss : 388.364360
# running loss : 385.061100
# running loss : 384.123469
# running loss : 387.195724
# running loss : 388.727500
# running loss : 385.731420
# running loss : 381.468154
# running loss : 382.151159
# running loss : 381.344971
# running loss : 382.549787
# running loss : 381.649568
# running loss : 383.125208
# running loss : 380.855508
# running loss : 380.766745
# running loss : 380.809231
# running loss : 377.502937
# running loss : 377.029453
# running loss : 376.934499
# running loss : 381.802036
# running loss : 379.608632
# running loss : 378.567474
# running loss : 378.948994
# running loss : 376.085121
# running loss : 374.657749
# running loss : 377.844452
# running loss : 373.754802
# running loss : 374.497286
# running loss : 372.850570
# running loss : 370.848694
# running loss : 375.317925
# running loss : 371.877867
# running loss : 367.906410
# running loss : 370.982038
# running loss : 366.808012
# running loss : 365.987016
# running loss : 374.609951
# running loss : 369.468276
# running loss : 368.420116
# running loss : 366.248957
# running loss : 368.536743
# running loss : 365.334893
# running loss : 368.784682
# running loss : 365.267072
# running loss : 367.519677
# running loss : 360.059911
# running loss : 360.204812
# running loss : 364.178693
# running loss : 363.857855
# running loss : 357.947425
# running loss : 356.424559
# running loss : 358.466502
# running loss : 355.575982
# running loss : 359.229148
# running loss : 358.119579
# running loss : 358.717316
# running loss : 357.129434
# running loss : 355.170821
# running loss : 353.602918
# running loss : 354.292346
# running loss : 352.715021
# running loss : 354.590021
# running loss : 354.026710
# running loss : 352.736168
# running loss : 351.878291
# running loss : 354.203462
# running loss : 353.575310
# running loss : 351.815751
# running loss : 350.948632
# running loss : 351.921019
# running loss : 350.810769
# running loss : 350.187337
# running loss : 350.512749
# running loss : 345.893359
# running loss : 344.161964
# running loss : 342.930205
# running loss : 343.901518
# running loss : 343.928239
# running loss : 346.217379
# running loss : 342.431908
# running loss : 343.127395
# running loss : 344.094142
# running loss : 341.976327
# running loss : 339.460119
# running loss : 342.793637
# running loss : 341.011295
# running loss : 337.569984
# running loss : 335.188276
# running loss : 340.712702
# running loss : 337.397515
# running loss : 336.604939
# running loss : 338.080986
# running loss : 334.729537
# running loss : 335.413296
# running loss : 332.351008
# running loss : 334.651112
# running loss : 331.997815
# running loss : 331.852046
# running loss : 335.616997
# running loss : 329.166507
# running loss : 336.641862
# running loss : 330.234283
# running loss : 332.651191
# running loss : 327.987438
# running loss : 327.526928
# running loss : 326.808571
# running loss : 328.717508
# running loss : 328.285116
# running loss : 326.557861
# running loss : 327.098094
# running loss : 328.187746
# running loss : 325.311292
# running loss : 324.583668
# running loss : 324.249029
# running loss : 321.467145
# running loss : 325.930048
# running loss : 322.889420
# running loss : 322.499303
# running loss : 323.515033
# running loss : 320.619864
# running loss : 320.804126
# running loss : 320.311231
# running loss : 319.625002
# running loss : 319.557515
# running loss : 317.286618
# running loss : 318.807240
# running loss : 316.334550
# running loss : 318.985497
# running loss : 318.414709
# running loss : 313.830408
# running loss : 319.800735
# running loss : 317.494505
# running loss : 313.486064
# running loss : 318.637986
# running loss : 315.066476
# running loss : 315.471744
# running loss : 311.839770
# running loss : 311.946596
# running loss : 308.640887
# running loss : 312.052495
# running loss : 310.197999
# running loss : 311.801545
# running loss : 307.759310
# running loss : 309.891812
# running loss : 307.739531
# running loss : 303.676773
# running loss : 308.169786
# running loss : 306.512557
# running loss : 307.485316
# running loss : 306.420143
# running loss : 302.118294
# running loss : 305.698966
# running loss : 308.093447
# running loss : 301.116101
# running loss : 305.925052
# running loss : 303.997052
# running loss : 298.974888
# running loss : 302.814326
# running loss : 301.014598
# running loss : 302.267984
# running loss : 302.864371
# running loss : 300.983691
# running loss : 300.936264
# running loss : 298.865817
# running loss : 295.939731
# running loss : 293.691650
# running loss : 300.465670
# running loss : 295.984100
# running loss : 298.377803
# running loss : 296.566769
# running loss : 295.001025
# running loss : 294.635529
# running loss : 295.276442
# running loss : 294.034169
# running loss : 295.292334
# running loss : 292.776122
# running loss : 292.505479
# running loss : 293.474835
# running loss : 292.566486
# running loss : 294.117023
# running loss : 291.627820
# running loss : 291.688013
# running loss : 291.394604
# running loss : 291.147918
# running loss : 289.325971
# running loss : 294.698494
# running loss : 289.927164
# running loss : 287.900199
# running loss : 288.856708
# running loss : 286.863042
# running loss : 287.370240
# running loss : 287.717597
# running loss : 287.852119
# running loss : 286.532699
# running loss : 284.471573
# running loss : 280.029406
# running loss : 286.215408
# running loss : 284.105006
# running loss : 283.206956
# running loss : 281.097292
# running loss : 284.118864
# running loss : 279.642724
# running loss : 282.463383
# running loss : 281.123490
# running loss : 282.283479
# running loss : 281.511949
# running loss : 279.564172
# running loss : 279.330995
# running loss : 278.040850
# running loss : 275.399457
# running loss : 275.605304
# running loss : 273.585886
# running loss : 272.536017
# running loss : 275.298816
# running loss : 277.108406
# running loss : 276.550460
# running loss : 273.946539
# running loss : 271.920448
# running loss : 274.100173
# running loss : 272.929815
# running loss : 273.170138
# running loss : 275.597093
# running loss : 269.046611
# running loss : 268.372872
# running loss : 270.380400
# running loss : 271.537930
# running loss : 267.898318
# running loss : 273.209269
# running loss : 269.426414
# running loss : 266.716556
# running loss : 268.199065
# running loss : 268.574374
# running loss : 268.311923
# running loss : 268.771003
# running loss : 269.739078
# running loss : 270.020378
# running loss : 264.940715
# running loss : 268.219259
# running loss : 266.408427
# running loss : 267.590558
# running loss : 265.325790
# running loss : 264.873759
# running loss : 268.383947
# running loss : 266.765599
# running loss : 265.915745
# running loss : 264.181800
# running loss : 264.228839
# running loss : 260.972277
# running loss : 262.221737
# running loss : 264.005315
# running loss : 262.782803
# running loss : 261.625125
# running loss : 261.061781
# running loss : 260.514474
# running loss : 258.585992
# running loss : 263.538384
# running loss : 255.622445
# running loss : 260.461268
# running loss : 259.008793
# running loss : 257.684182
# running loss : 254.619688
# running loss : 257.678312
# running loss : 258.094095
# running loss : 255.197042
# running loss : 253.413366
# running loss : 254.208393
# running loss : 252.898176
# running loss : 253.823502
# running loss : 254.530325
# running loss : 253.246622
# running loss : 252.426933
# running loss : 251.741056
# running loss : 248.776902
# running loss : 250.321781
# running loss : 251.030448
# running loss : 248.723133
# running loss : 250.898516
# running loss : 247.616157
# running loss : 249.915348
# running loss : 248.934912
# running loss : 246.977993
# running loss : 245.592741
# running loss : 245.903939
# running loss : 245.374232
# running loss : 246.407197
# running loss : 246.502904
# running loss : 247.604898
# running loss : 247.551761
# running loss : 243.981303
# running loss : 245.389950
# running loss : 244.095595
# running loss : 245.179309
# running loss : 245.433907
# running loss : 246.966526
# running loss : 245.401726
# running loss : 242.336751
# running loss : 238.289555
# running loss : 241.992391
# running loss : 243.484486
# running loss : 240.531544
# running loss : 246.583019
# running loss : 241.102439
# running loss : 242.499295
# running loss : 242.481445
# running loss : 243.179170
# running loss : 237.198105
# running loss : 239.146508
# running loss : 240.631426
# running loss : 240.042242
# running loss : 240.203122
# running loss : 238.813712
# running loss : 235.978638
# running loss : 236.078725
# running loss : 234.036018
# running loss : 238.797818
# running loss : 236.951696
# running loss : 235.080657
# running loss : 236.463682
# running loss : 236.239965
# running loss : 237.708130
# running loss : 236.380092
# running loss : 234.887926
# running loss : 234.882740
# running loss : 232.410505
# running loss : 234.897490
# running loss : 232.771715
# running loss : 231.686936
# running loss : 228.455324
# running loss : 227.439521
# running loss : 233.005603
# running loss : 227.285995
# running loss : 228.394936
# running loss : 230.582190
# running loss : 229.621703
# running loss : 228.132278
# running loss : 227.684510
# running loss : 227.665615
# running loss : 227.548652
# running loss : 231.220782
# running loss : 227.227599
# running loss : 228.040848
# running loss : 225.733475
# running loss : 227.376044
# running loss : 228.002971
# running loss : 226.047571
# running loss : 225.911294
# running loss : 225.289592
# running loss : 222.774012
# running loss : 228.705280
# running loss : 224.477500
# running loss : 224.988148
# running loss : 223.361239
# running loss : 222.568605
# running loss : 225.332725
# running loss : 224.849089
# running loss : 223.261324
# running loss : 223.331828
# running loss : 220.852987
# running loss : 222.451509
# running loss : 220.746953
# running loss : 222.321777
# running loss : 222.292299
# running loss : 223.476151
# running loss : 221.312183
# running loss : 218.268910
# running loss : 222.236050
# running loss : 219.911587
# running loss : 218.734558
# running loss : 216.988076
# running loss : 223.437417
# running loss : 220.496105
# running loss : 219.954873
# running loss : 216.512825
# running loss : 219.561146
# running loss : 216.642836
# running loss : 215.109589
# running loss : 215.296652
# running loss : 217.581560
# running loss : 216.434698
# running loss : 216.864412
# running loss : 217.042164
# running loss : 215.269079
# running loss : 220.997682
# running loss : 214.812074
# running loss : 215.168297
# running loss : 212.080401
# running loss : 217.078343
# running loss : 213.787332
# running loss : 213.802906
# running loss : 209.765890
# running loss : 208.823472
# running loss : 214.369650
# running loss : 212.117816
# running loss : 213.166544
# running loss : 210.626801
# running loss : 210.722478
# running loss : 207.197453
# running loss : 213.261696
# running loss : 211.193270
# running loss : 209.617920
# running loss : 212.487915
# running loss : 210.175238
# running loss : 207.112252
# running loss : 206.844606
# running loss : 208.781228
# running loss : 208.049672
# running loss : 206.182691
# running loss : 206.807503
# running loss : 208.347456
# running loss : 206.465511
# running loss : 204.905215
# running loss : 206.032310
# running loss : 208.445972
# running loss : 207.699442
# running loss : 206.868473
# running loss : 205.768467
# running loss : 207.327677
# running loss : 204.988279
# running loss : 204.032639
# running loss : 203.592077
# running loss : 206.175472
# running loss : 203.596919
# running loss : 205.977489
# running loss : 205.208773
# running loss : 203.560035
# running loss : 203.653297
# running loss : 201.059902
# running loss : 203.552035
# running loss : 197.504919
# running loss : 202.967428
# running loss : 205.207899
# running loss : 202.451582
# running loss : 201.753528
# running loss : 200.370815
# running loss : 198.325755
# running loss : 200.836852
# running loss : 200.416442
# running loss : 199.512410
# running loss : 202.118373
# running loss : 197.791986
# running loss : 196.169776
# running loss : 198.993073
# running loss : 199.722063
# running loss : 197.670401
# running loss : 199.430840
# running loss : 196.031973
# running loss : 199.094626
# running loss : 193.721052
# running loss : 194.034067
# running loss : 193.301996
# running loss : 193.452837
# running loss : 193.057921
# running loss : 196.165879
# running loss : 193.407186
# running loss : 190.423354
# running loss : 196.642999
# running loss : 192.187890
# running loss : 190.653983
# running loss : 192.533656
# running loss : 193.088698
# running loss : 190.565128
# running loss : 192.133320
# running loss : 188.004699
# running loss : 195.866371
# running loss : 190.575984
# running loss : 192.057414
# running loss : 191.016509
# running loss : 189.478447
# running loss : 187.993409
# running loss : 193.006785
# running loss : 190.385162
# running loss : 186.820847
# running loss : 187.801178
# running loss : 188.249209
# running loss : 189.762884
# running loss : 189.288221
# running loss : 189.262006
# running loss : 189.559943
# running loss : 190.044589
# running loss : 187.866153
# running loss : 184.583167
# running loss : 184.179279
# running loss : 184.514194
# running loss : 185.338189
# running loss : 184.870164
# running loss : 184.528956
# running loss : 185.379716
# running loss : 185.922063
# running loss : 185.230517
# running loss : 185.010119
# running loss : 184.126971
# running loss : 185.068703
# running loss : 182.746967
# running loss : 185.349871
# running loss : 183.456894
# running loss : 179.694489
# running loss : 184.116881
# running loss : 182.214905
# running loss : 181.520944
# running loss : 182.304270
# running loss : 182.564096
# running loss : 180.016592
# running loss : 180.396871
# running loss : 176.120086
# running loss : 179.353986
# running loss : 181.583838
# running loss : 179.698838
# running loss : 177.158408
# running loss : 179.768807
# running loss : 176.915589
# running loss : 177.355913
# running loss : 179.074274
# running loss : 179.481622
# running loss : 180.319866
# running loss : 177.965213
# running loss : 177.437301
# running loss : 174.405232
# running loss : 176.690427
# running loss : 176.272684
# running loss : 175.706765
# running loss : 174.224687
# running loss : 173.783503
# running loss : 174.414495
# running loss : 175.369722
# running loss : 177.121152
# running loss : 173.983168
# running loss : 175.217590
# running loss : 175.701861
# running loss : 174.439090
# running loss : 173.662881
# running loss : 175.924973
# running loss : 174.073619
# running loss : 173.708784
# running loss : 175.364303
# running loss : 173.130684
# running loss : 172.862591
# running loss : 173.609677
# running loss : 170.631298
# running loss : 173.184616
# running loss : 171.464837
# running loss : 171.146533
# running loss : 171.604750
# running loss : 169.877797
# running loss : 172.127828
# running loss : 171.076894
# running loss : 173.922217
# running loss : 171.195523
# running loss : 171.958908
# running loss : 170.622954
# running loss : 171.795932
# running loss : 168.941800
# running loss : 169.009972
# running loss : 167.611910
# running loss : 167.932186
# running loss : 167.833113
# running loss : 169.392540
# running loss : 168.793607
# running loss : 164.735830
# running loss : 170.573791
# running loss : 167.033808
# running loss : 168.419030
# running loss : 167.273753
# running loss : 165.868674
# running loss : 167.718623
# running loss : 163.936324
# running loss : 166.881643
# running loss : 170.751207
# running loss : 166.849140
# running loss : 165.469288
# running loss : 165.325773
# running loss : 167.889005
# running loss : 166.289014
# running loss : 164.870809
# running loss : 166.393292
# running loss : 163.833484
# running loss : 164.852858
# running loss : 162.387158
# running loss : 164.739630
# running loss : 167.819381
# running loss : 163.766283
# running loss : 163.933146
# running loss : 165.168101
# running loss : 162.832684
# running loss : 163.163312
# running loss : 163.838679
# running loss : 161.329534
# running loss : 162.029795
# running loss : 161.674335
# running loss : 162.338149
# running loss : 165.088398
# running loss : 160.795438
# running loss : 161.378047
# running loss : 161.274860
# running loss : 158.126371
# running loss : 162.282503
# running loss : 159.182843
# running loss : 164.592427
# running loss : 158.526782
# running loss : 160.260069
# running loss : 161.515664
# running loss : 157.736870
# running loss : 161.610920
# running loss : 159.184726
# running loss : 182.399869
# running loss : 186.893522
# running loss : 169.580675
# running loss : 161.021347
# running loss : 159.218761
# running loss : 160.639953
# running loss : 157.224521
# running loss : 157.649833
# running loss : 157.640205
# running loss : 159.545870
# running loss : 156.865057
# running loss : 158.859031
# running loss : 156.818821
# running loss : 155.947015
# running loss : 158.768814
# running loss : 156.630470
# running loss : 155.128062
# running loss : 155.593540
# running loss : 157.819411
# running loss : 156.534260
# running loss : 155.968012
# running loss : 153.006446
# running loss : 156.556472
# running loss : 157.539435
# running loss : 157.446623
# running loss : 154.271680
# running loss : 155.358293
# running loss : 153.202820
# running loss : 153.686712
# running loss : 154.657507
# running loss : 155.072763
# running loss : 153.548608
# running loss : 152.101452
# running loss : 151.973484
# running loss : 153.974469
# running loss : 153.845488
# running loss : 152.667858
# running loss : 148.856258
# running loss : 152.473560
# running loss : 150.212688
# running loss : 150.656192
# running loss : 152.282704
# running loss : 150.853391
# running loss : 149.312770
# running loss : 151.079559
# running loss : 150.567437
# running loss : 151.367106
# running loss : 146.449260
# running loss : 151.112874
# running loss : 148.416156
# running loss : 148.196778
# running loss : 149.238985
# running loss : 149.667327
# running loss : 147.222946
# running loss : 147.608893
# running loss : 150.499912
# running loss : 147.294190
# running loss : 146.802944
# running loss : 148.435320
# running loss : 146.256664
# running loss : 147.428587
# running loss : 148.458960
# running loss : 147.357073
# running loss : 146.701855
# running loss : 148.662830
# running loss : 147.337258
# running loss : 147.215284
# running loss : 144.507211
# running loss : 145.520242
# running loss : 146.497668
# running loss : 146.009267
# running loss : 145.863971
# running loss : 142.524631
# running loss : 144.240583
# running loss : 145.601147
# running loss : 143.156206
# running loss : 143.296979
# running loss : 143.950366
# running loss : 141.735473
# running loss : 145.136904
# running loss : 141.538211
# running loss : 144.369652
# running loss : 142.413109
# running loss : 143.402093
# running loss : 142.814338
# running loss : 140.483826
# running loss : 140.397741
# running loss : 140.566837
# running loss : 139.976454
# running loss : 144.692690
# running loss : 137.907229
# running loss : 140.091030
# running loss : 139.984100
# running loss : 140.539080
# running loss : 139.084085
# running loss : 139.717434
# running loss : 137.186894
# running loss : 138.465140
# running loss : 139.468967
# running loss : 139.205543
# running loss : 138.917282
# running loss : 139.797628
# running loss : 140.051960
# running loss : 139.393377
# running loss : 137.726308
# running loss : 137.648006
# running loss : 137.753847
# running loss : 135.378925
# running loss : 141.253588
# running loss : 140.650257
# running loss : 138.225271
# running loss : 135.727597
# running loss : 135.646805
# running loss : 137.638320
# running loss : 137.268924
# running loss : 135.708709
# running loss : 136.734191
# running loss : 135.444479
# running loss : 137.923809
# running loss : 134.057414
# running loss : 135.701062
# running loss : 135.172623
# running loss : 136.963686
# running loss : 134.491656
# x after input block is nan tensor([[[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]],
#
#
#         [[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]],
#
#
#         [[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]],
#
#
#         ...,
#
#
#         [[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]],
#
#
#         [[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]],
#
#
#         [[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]]], device='cuda:0',
#        grad_fn=<ReluBackward0>)
# x after residual block 1 is nan tensor([[[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]],
#
#
#         [[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]],
#
#
#         [[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
# ...
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]],
#
#
#         ...,
#
#
#         [[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]],
#
#
#         [[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]],
#
#
#         [[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]]], device='cuda:0',
#        grad_fn=<MyClippingBackward>)
# integral u is nan tensor([[[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]],
#
#
#         [[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]],
#
#
#         [[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]],
#
#
#         ...,
#
#
#         [[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]],
#
#
#         [[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]],
#
#
#         [[[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]],
#
#          [[nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan],
#           [nan, nan, nan,  ..., nan, nan, nan]]]], device='cuda:0',
#        grad_fn=<MulBackward1>)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-beaeb894f837> in <module>
#      58                 break
#      59
# ---> 60         loss.backward()
#      61         #print("conv1.weights grad: ", params[0].grad)
#      62         #print(model.conv1.bias.grad)
#
# ~\anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# ~\anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     123         retain_graph = create_graph
#     124
# --> 125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
#     127         allow_unreachable=True)  # allow_unreachable flag
#
# RuntimeError: Index out of range
# Exception raised from should_compute_output at ..\torch/csrc/autograd/function.h:230 (most recent call first):
# 00007FFE4E7875A200007FFE4E787540 c10.dll!c10::Error::Error [<unknown file> @ <unknown line number>]
# 00007FFDCDFDB3F000007FFDCDFDB290 torch_cpu.dll!torch::autograd::Node::should_compute_output [<unknown file> @ <unknown line number>]
# 00007FFDCDF82A1600007FFDCDF82960 torch_cpu.dll!torch::autograd::generated::AsStridedBackward::apply [<unknown file> @ <unknown line number>]
# 00007FFDCDF77E9100007FFDCDF77B50 torch_cpu.dll!torch::autograd::Node::operator() [<unknown file> @ <unknown line number>]
# 00007FFDCE4DF9BA00007FFDCE4DF300 torch_cpu.dll!torch::autograd::Engine::add_thread_pool_task [<unknown file> @ <unknown line number>]
# 00007FFDCE4E03AD00007FFDCE4DFFD0 torch_cpu.dll!torch::autograd::Engine::evaluate_function [<unknown file> @ <unknown line number>]
# 00007FFDCE4E4FE200007FFDCE4E4CA0 torch_cpu.dll!torch::autograd::Engine::thread_main [<unknown file> @ <unknown line number>]
# 00007FFDCE4E4C4100007FFDCE4E4BC0 torch_cpu.dll!torch::autograd::Engine::thread_init [<unknown file> @ <unknown line number>]
# 00007FFD954B08F700007FFD95489F80 torch_python.dll!THPShortStorage_New [<unknown file> @ <unknown line number>]
# 00007FFDCE4DBF1400007FFDCE4DB780 torch_cpu.dll!torch::autograd::Engine::get_base_engine [<unknown file> @ <unknown line number>]
# 00007FFE5B8F1BB200007FFE5B8F1B20 ucrtbase.dll!configthreadlocale [<unknown file> @ <unknown line number>]
# 00007FFE5D25703400007FFE5D257020 KERNEL32.DLL!BaseThreadInitThunk [<unknown file> @ <unknown line number>]
# 00007FFE5E1DD24100007FFE5E1DD220 ntdll.dll!RtlUserThreadStart [<unknown file> @ <unknown line number>]

# %%
# save model parameters
torch.save(model.state_dict(), './model_parameters/mean_bit_ppx/lossy_comp_depthmap_beta001.pth')

# %%
model = LossyCompAutoencoder()
model.load_state_dict(torch.load('./model_parameters/mean_bit_ppx/lossy_comp_params_with_rate_beta005_incremental.pth'))
model.eval()
model.to(device)

# transfert du model au gpu
model.to(device)

# general update of coefficients    
    #define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
    # define loss function
distortion = nn.MSELoss().cuda()
    #Epochs
n_epochs = 600
beta = 0.05

    # Training the network
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
          
    #Training
    for i_batch, data in enumerate(dataloader):
        batch_images = data.to(device).float()
        [decoded_images, x_quantized] = model(batch_images, 1, True)
        optimizer.zero_grad()
        loss_dist = distortion(decoded_images, batch_images)
        loss_bit = mean_bit_per_px(x_quantized, model.phi, model.var)
        loss = beta * loss_dist + loss_bit
        #print(loss)
            
        loss.backward()
        #print("conv1.weights grad: ", params[0].grad)
        #print(model.conv1.bias.grad)
        #print(model.conv1.weight.grad)
        optimizer.step()
        running_loss += loss.item()

    running_loss = running_loss/len(dataloader)
    print('running loss : {:.06f}'.format(running_loss), )
# Out:
# running loss : 3.608064
# running loss : 3.595169
# running loss : 3.577811
# running loss : 3.565715
# running loss : 3.556746
# running loss : 3.551123
# running loss : 3.508999
# running loss : 3.493525
# running loss : 3.477084
# running loss : 3.480756
# running loss : 3.484556
# running loss : 3.470062
# running loss : 3.494472
# running loss : 3.480626
# running loss : 3.473711
# running loss : 3.469631
# running loss : 3.474533
# running loss : 3.457910
# running loss : 3.457608
# running loss : 3.463701
# running loss : 3.462066
# running loss : 3.455566
# running loss : 3.454701
# running loss : 3.452302
# running loss : 3.461875
# running loss : 3.440914
# running loss : 3.449169
# running loss : 3.461837
# running loss : 3.453840
# running loss : 3.431719
# running loss : 3.450540
# running loss : 3.444341
# running loss : 3.436081
# running loss : 3.438335
# running loss : 3.434041
# running loss : 3.437564
# running loss : 3.452365
# running loss : 3.440963
# running loss : 3.444202
# running loss : 3.428230
# running loss : 3.436434
# running loss : 3.443303
# running loss : 3.439506
# running loss : 3.427543
# running loss : 3.431219
# running loss : 3.448644
# running loss : 3.422745
# running loss : 3.433221
# running loss : 3.450936
# running loss : 3.433569
# running loss : 3.442692
# running loss : 3.429689
# running loss : 3.430512
# running loss : 3.426101
# running loss : 3.430047
# running loss : 3.432502
# running loss : 3.439135
# running loss : 3.429702
# running loss : 3.420823
# running loss : 3.431744
# running loss : 3.428611
# running loss : 3.433411
# running loss : 3.418620
# running loss : 3.420307
# running loss : 3.428004
# running loss : 3.420471
# running loss : 3.434505
# running loss : 3.439297
# running loss : 3.418552
# running loss : 3.423885
# running loss : 3.438213
# running loss : 3.421547
# running loss : 3.447951
# running loss : 3.426076
# running loss : 3.431946
# running loss : 3.421086
# running loss : 3.422254
# running loss : 3.434877
# running loss : 3.446865
# running loss : 3.416438
# running loss : 3.411806
# running loss : 3.418630
# running loss : 3.406292
# running loss : 3.428759
# running loss : 3.416834
# running loss : 3.421250
# running loss : 3.428968
# running loss : 3.419444
# running loss : 3.411746
# running loss : 3.431971
# running loss : 3.417159
# running loss : 3.417692
# running loss : 3.423909
# running loss : 3.426233
# running loss : 3.416708
# running loss : 3.409153
# running loss : 3.410394
# running loss : 3.412747
# running loss : 3.416086
# running loss : 3.417805
# running loss : 3.416933
# running loss : 3.418952
# running loss : 3.411268
# running loss : 3.418695
# running loss : 3.415554
# running loss : 3.407512
# running loss : 3.418305
# running loss : 3.417855
# running loss : 3.415935
# running loss : 3.404594
# running loss : 3.407119
# running loss : 3.408349
# running loss : 3.416635
# running loss : 3.411231
# running loss : 3.417814
# running loss : 3.407900
# running loss : 3.417695
# running loss : 3.410966
# running loss : 3.411711
# running loss : 3.405085
# running loss : 3.405621
# running loss : 3.403342
# running loss : 3.418212
# running loss : 3.418930
# running loss : 3.400970
# running loss : 3.425234
# running loss : 3.405430
# running loss : 3.414903
# running loss : 3.397287
# running loss : 3.409523
# running loss : 3.405635
# running loss : 3.404655
# running loss : 3.423258
# running loss : 3.418636
# running loss : 3.403312
# running loss : 3.402433
# running loss : 3.408503
# running loss : 3.411906
# running loss : 3.396481
# running loss : 3.413033
# running loss : 3.401829
# running loss : 3.399232
# running loss : 3.408765
# running loss : 3.413618
# running loss : 3.401739
# running loss : 3.393259
# running loss : 3.409699
# running loss : 3.405459
# running loss : 3.402204
# running loss : 3.401693
# running loss : 3.415576
# running loss : 3.393906
# running loss : 3.410737
# running loss : 3.409878
# running loss : 3.406994
# running loss : 3.402496
# running loss : 3.398531
# running loss : 3.406441
# running loss : 3.405680
# running loss : 3.404914
# running loss : 3.403816
# running loss : 3.415388
# running loss : 3.404948
# running loss : 3.404524
# running loss : 3.408215
# running loss : 3.397031
# running loss : 3.391528
# running loss : 3.394352
# running loss : 3.388567
# running loss : 3.402069
# running loss : 3.407573
# running loss : 3.401749
# running loss : 3.397013
# running loss : 3.380713
# running loss : 3.416723
# running loss : 3.395859
# running loss : 3.401124
# running loss : 3.395975
# running loss : 3.401524
# running loss : 3.397739
# running loss : 3.398284
# running loss : 3.397540
# running loss : 3.390580
# running loss : 3.395998
# running loss : 3.406830
# running loss : 3.400811
# running loss : 3.399028
# running loss : 3.391226
# running loss : 3.391155
# running loss : 3.403034
# running loss : 3.386472
# running loss : 3.391889
# running loss : 3.410040
# running loss : 3.396352
# running loss : 3.393411
# running loss : 3.392596
# running loss : 3.398096
# running loss : 3.419137
# running loss : 3.386801
# running loss : 3.393241
# running loss : 3.405118
# running loss : 3.401632
# running loss : 3.391891
# running loss : 3.387445
# running loss : 3.391386
# running loss : 3.387829
# running loss : 3.392365
# running loss : 3.400446
# running loss : 3.372927
# running loss : 3.404625
# running loss : 3.388007
# running loss : 3.395960
# running loss : 3.412260
# running loss : 3.404648
# running loss : 3.398713
# running loss : 3.397545
# running loss : 3.384526
# running loss : 3.385824
# running loss : 3.383352
# running loss : 3.393349
# running loss : 3.387968
# running loss : 3.382640
# running loss : 3.380239
# running loss : 3.384858
# running loss : 3.374717
# running loss : 3.409348
# running loss : 3.401197
# running loss : 3.389739
# running loss : 3.388080
# running loss : 3.392952
# running loss : 3.398019
# running loss : 3.404827
# running loss : 3.382396
# running loss : 3.380256
# running loss : 3.378441
# running loss : 3.373515
# running loss : 3.379723
# running loss : 3.386646
# running loss : 3.381797
# running loss : 3.386999
# running loss : 3.384829
# running loss : 3.369290
# running loss : 3.385859
# running loss : 3.388848
# running loss : 3.379311
# running loss : 3.373440
# running loss : 3.392347
# running loss : 3.382227
# running loss : 3.367000
# running loss : 3.378753
# running loss : 3.377418
# running loss : 3.396743
# running loss : 3.378321
# running loss : 3.384744
# running loss : 3.383695
# running loss : 3.388330
# running loss : 3.387338
# running loss : 3.391584
# running loss : 3.387342
# running loss : 3.375059
# running loss : 3.383311
# running loss : 3.387176
# running loss : 3.387320
# running loss : 3.379785
# running loss : 3.388733
# running loss : 3.375195
# running loss : 3.377278
# running loss : 3.381037
# running loss : 3.378940
# running loss : 3.377081
# running loss : 3.379055
# running loss : 3.384051
# running loss : 3.372547
# running loss : 3.359944
# running loss : 3.389396
# running loss : 3.377261
# running loss : 3.375371
# running loss : 3.374853
# running loss : 3.375038
# running loss : 3.371395
# running loss : 3.380230
# running loss : 3.374034
# running loss : 3.381019
# running loss : 3.379792
# running loss : 3.379630
# running loss : 3.375633
# running loss : 3.380527
# running loss : 3.374819
# running loss : 3.374065
# running loss : 3.376456
# running loss : 3.372698
# running loss : 3.376132
# running loss : 3.382859
# running loss : 3.361300
# running loss : 3.369921
# running loss : 3.382626
# running loss : 3.365912
# running loss : 3.374336
# running loss : 3.370419
# running loss : 3.375273
# running loss : 3.381060
# running loss : 3.368045
# running loss : 3.384040
# running loss : 3.379451
# running loss : 3.377281
# running loss : 3.376848
# running loss : 3.379195
# running loss : 3.377004
# running loss : 3.366520
# running loss : 3.369531
# running loss : 3.359590
# running loss : 3.379268
# running loss : 3.370147
# running loss : 3.380034
# running loss : 3.371945
# running loss : 3.378165
# running loss : 3.371639
# running loss : 3.365722
# running loss : 3.378202
# running loss : 3.383245
# running loss : 3.372720
# running loss : 3.357288
# running loss : 3.363374
# running loss : 3.380017
# running loss : 3.369098
# running loss : 3.370510
# running loss : 3.373468
# running loss : 3.365971
# running loss : 3.371524
# running loss : 3.371745
# running loss : 3.368102
# running loss : 3.368026
# running loss : 3.382858
# running loss : 3.381158
# running loss : 3.372145
# running loss : 3.366211
# running loss : 3.379800
# running loss : 3.365970
# running loss : 3.388563
# running loss : 3.364501
# running loss : 3.361850
# running loss : 3.367398
# running loss : 3.370314
# running loss : 3.377068
# running loss : 3.380413
# running loss : 3.369731
# running loss : 3.372108
# running loss : 3.373563
# running loss : 3.365202
# running loss : 3.375456
# running loss : 3.366879
# running loss : 3.364543
# running loss : 3.367663
# running loss : 3.371529
# running loss : 3.359032
# running loss : 3.364099
# running loss : 3.354579
# running loss : 3.367204
# running loss : 3.370713
# running loss : 3.366639
# running loss : 3.360884
# running loss : 3.353266
# running loss : 3.368702
# running loss : 3.359209
# running loss : 3.361315
# running loss : 3.372081
# running loss : 3.363859
# running loss : 3.356524
# running loss : 3.360332
# running loss : 3.353770
# running loss : 3.355852
# running loss : 3.365560
# running loss : 3.375980
# running loss : 3.351310
# running loss : 3.372552
# running loss : 3.356415
# running loss : 3.355415
# running loss : 3.359442
# running loss : 3.354993
# running loss : 3.353920
# running loss : 3.357007
# running loss : 3.347224
# running loss : 3.360047
# running loss : 3.356805
# running loss : 3.377442
# running loss : 3.360175
# running loss : 3.349696
# running loss : 3.370999
# running loss : 3.359068
# running loss : 3.362040
# running loss : 3.358622
# running loss : 3.352350
# running loss : 3.358476
# running loss : 3.346589
# running loss : 3.363932
# running loss : 3.356358
# running loss : 3.360231
# running loss : 3.361587
# running loss : 3.361075
# running loss : 3.363794
# running loss : 3.346298
# running loss : 3.363001
# running loss : 3.358429
# running loss : 3.357310
# running loss : 3.356154
# running loss : 3.360374
# running loss : 3.370111
# running loss : 3.365619
# running loss : 3.345095
# running loss : 3.357239
# running loss : 3.355625
# running loss : 3.357598
# running loss : 3.357125
# running loss : 3.355613
# running loss : 3.355986
# running loss : 3.368297
# running loss : 3.357122
# running loss : 3.355062
# running loss : 3.353528
# running loss : 3.369331
# running loss : 3.354843
# running loss : 3.371120
# running loss : 3.358374
# running loss : 3.369029
# running loss : 3.351763
# running loss : 3.356055
# running loss : 3.356574
# running loss : 3.353526
# running loss : 3.346547
# running loss : 3.355653
# running loss : 3.344817
# running loss : 3.366189
# running loss : 3.357121
# running loss : 3.355565
# running loss : 3.360159
# running loss : 3.346670
# running loss : 3.349266
# running loss : 3.361551
# running loss : 3.345708
# running loss : 3.346406
# running loss : 3.364660
# running loss : 3.348421
# running loss : 3.366565
# running loss : 3.357172
# running loss : 3.360273
# running loss : 3.361555
# running loss : 3.360843
# running loss : 3.364662
# running loss : 3.356550
# running loss : 3.346063
# running loss : 3.359142
# running loss : 3.352849
# running loss : 3.369623
# running loss : 3.360721
# running loss : 3.351882
# running loss : 3.359600
# running loss : 3.355730
# running loss : 3.353931
# running loss : 3.343998
# running loss : 3.359867
# running loss : 3.354931
# running loss : 3.346388
# running loss : 3.347316
# running loss : 3.372011
# running loss : 3.353952
# running loss : 3.336895
# running loss : 3.341002
# running loss : 3.344184
# running loss : 3.348712
# running loss : 3.357724
# running loss : 3.342228
# running loss : 3.339523
# running loss : 3.336710
# running loss : 3.359275
# running loss : 3.352273
# running loss : 3.355335
# running loss : 3.346686
# running loss : 3.351825
# running loss : 3.343329
# running loss : 3.353132
# running loss : 3.348568
# running loss : 3.349761
# running loss : 3.346203
# running loss : 3.345687
# running loss : 3.346822
# running loss : 3.359846
# running loss : 3.344461
# running loss : 3.347605
# running loss : 3.360306
# running loss : 3.349484
# running loss : 3.361984
# running loss : 3.345488
# running loss : 3.352357
# running loss : 3.350787
# running loss : 3.363186
# running loss : 3.358625
# running loss : 3.349598
# running loss : 3.350769
# running loss : 3.356160
# running loss : 3.355965
# running loss : 3.347878
# running loss : 3.362272
# running loss : 3.334891
# running loss : 3.350863
# running loss : 3.352918
# running loss : 3.351285
# running loss : 3.340953
# running loss : 3.351766
# running loss : 3.346930
# running loss : 3.345097
# running loss : 3.359069
# running loss : 3.344168
# running loss : 3.351817
# running loss : 3.335797
# running loss : 3.336338
# running loss : 3.369614
# running loss : 3.348467
# running loss : 3.338204
# running loss : 3.348724
# running loss : 3.343201
# running loss : 3.337590
# running loss : 3.345075
# running loss : 3.343137
# running loss : 3.342944
# running loss : 3.333315
# running loss : 3.359916
# running loss : 3.343439
# running loss : 3.348096
# running loss : 3.348777
# running loss : 3.342959
# running loss : 3.355742
# running loss : 3.344180
# running loss : 3.339853
# running loss : 3.346722
# running loss : 3.344836
# running loss : 3.338519
# running loss : 3.354768
# running loss : 3.354207
# running loss : 3.354161
# running loss : 3.350398
# running loss : 3.335574
# running loss : 3.339052
# running loss : 3.325654
# running loss : 3.346711
# running loss : 3.345718
# running loss : 3.342996
# running loss : 3.345942
# running loss : 3.340115
# running loss : 3.351426
# running loss : 3.335214
# running loss : 3.348179
# running loss : 3.339886
# running loss : 3.341955
# running loss : 3.343468
# running loss : 3.342511
# running loss : 3.339258
# running loss : 3.352079
# running loss : 3.351474
# running loss : 3.349672
# running loss : 3.326735
# running loss : 3.331779
# running loss : 3.332662
# running loss : 3.344620
# running loss : 3.342527
# running loss : 3.338769
# running loss : 3.329740
# running loss : 3.334696
# running loss : 3.349396
# running loss : 3.331655
# running loss : 3.343893
# running loss : 3.334330
# running loss : 3.341412
# running loss : 3.341261
# running loss : 3.342445
# running loss : 3.355054
# running loss : 3.342108
# running loss : 3.342142
# running loss : 3.333979
# running loss : 3.329740
# running loss : 3.330187
# running loss : 3.320707
# running loss : 3.337103
# running loss : 3.341556
# running loss : 3.334582
# running loss : 3.343184
# running loss : 3.342706
# running loss : 3.340070
# running loss : 3.344993
# running loss : 3.349691
# running loss : 3.340178
# running loss : 3.336386
# running loss : 3.342811
# running loss : 3.344449
# running loss : 3.357886
# running loss : 3.348683
# running loss : 3.346992
# running loss : 3.331960
# running loss : 3.348751
# running loss : 3.343655
# running loss : 3.350069

# %%
# test set 

#test_dataset = ImageDataset(root_dir='./data/kodac/', transform=transforms.Compose([RandomCrop(128), ToTensor()]))
test_dataset = ImageDataset(root_dir='D:/autoencoder_data/depthmaps/test', transform=transforms.Compose([ConvertDepthToColor(), ToTensor()]))
fig, axes = plt.subplots(nrows=4, ncols=6, sharex=True, sharey=True, figsize=(8,8))
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        if test_image.size(2)<test_image.size(3):
            test_image = test_image.permute(0, 1, 3, 2)
        
        reconstructed_image = model(test_image)
        h, w = reconstructed_image.size()[2:]
        ax = fig.add_subplot(4, 6, i+1, xticks=[], yticks=[])
        plt.imshow(torch.cat((torch.squeeze(reconstructed_image.int().cpu()), torch.zeros(1, h, w)), 0).permute(1, 2, 0))

# %%
# get back to original depthmaps
tsfm = ConvertColorToDepth()
fig, axes = plt.subplots(nrows=4, ncols=6, sharex=True, sharey=True, figsize=(8,8))
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        if test_image.size(2)<test_image.size(3):
            test_image = test_image.permute(0, 1, 3, 2)
        
        reconstructed_image = model(test_image)
        reconstructed_depthmap = tsfm(reconstructed_image)
        ax = fig.add_subplot(4, 6, i+1, xticks=[], yticks=[])
        plt.imshow(torch.squeeze((reconstructed_depthmap/torch.max(reconstructed_depthmap)).cpu(), 0))

# %%
# save results
import cv2
from torchvision.utils import save_image

with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        reconstructed_image = model(test_image)
        reconstructed_depthmap = np.squeeze((tsfm(reconstructed_image)).cpu()).numpy()
        cv2.imwrite("D:\\autoencoder_data\\depthmaps\\reconstructed\\beta_001\\" + "img" + str(i)+".png", reconstructed_depthmap.astype(np.uint16))
        #save_image(reconstructed_depthmap, "D:\\autoencoder_data\\depthmaps\\reconstructed\\beta_0001\\" + "img" + str(i)+".png", normalize=True)

# %%
# compute PSNR for each image of the test set and its reconstruction

def write_data(filepath , tensor_data):
    batch, channel, h, w = tensor_data.size()
    matrix = tensor_data.cpu().numpy()
    file = open(filepath, "w")
    for image in range(batch):
        np.savetxt(file, matrix[image, :, :, :].reshape(channel*h, w), fmt ='%.0f')

    file.close()
    
def compute_entropy(tensor_data):
    min_val = tensor_data.min()
    max_val = tensor_data.max()
    nb_bins = max_val - min_val + 1
    hist = torch.histc(tensor_data, bins=nb_bins.int(), min=min_val, max=max_val)
    hist_prob = hist/hist.sum()
    hist_prob[hist_prob == 0] = 1
    entropy = -(hist_prob*torch.log2(hist_prob)).sum()
    return entropy
    
        
    
    
def psnr(original, compressed, max_pixel): 
    mse = torch.mean((original - compressed) ** 2) 
    if(mse == 0):  # MSE is zero means no noise is present in the signal . 
                  # Therefore PSNR have no importance. 
        return 100
    psnr = 20 * np.log10(max_pixel / np.sqrt(mse)) 
    return psnr 


test_dataset = ImageDataset(root_dir='D:/autoencoder_data/depthmaps/test', transform=transforms.Compose([ConvertDepthToColor(), ToTensor()]))
psnr_sum = 0.0
bit_rate_sum = 0.0
tsfm = ConvertColorToDepth()
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        [reconstructed_image, im_quantized] = model(test_image, 1, True)
        #write_data('.\\reconstructed_data\\kodac\\loss_distortion_and_bitrate\\beta_2\\latent_vect\\' + 'vec' + str(i) +'.txt', im_quantized)
        nb_symbols = im_quantized.size(0)*im_quantized.size(1)*im_quantized.size(2)*im_quantized.size(3)
        entropy = compute_entropy(im_quantized)
        nbpp = nb_symbols*entropy/float(test_image.size(0)*test_image.size(2)*test_image.size(3))
        psnr_sum+= psnr(tsfm(test_image).cpu(), tsfm(reconstructed_image).cpu(), 2**16-1.0)
        bit_rate_sum += nbpp
        print("entropy : ", entropy)
        print( "nb bits per pixel : ", nbpp)
        print("psnr : " , psnr(tsfm(test_image).cpu(), tsfm(reconstructed_image).cpu(), 2**16-1.0))
print( "mean nb bits per pixel : ", bit_rate_sum/len(test_dataset))
print("psnr mean : ", psnr_sum/len(test_dataset) )
# Out:
# entropy :  tensor(0.658993, device='cuda:0')
# nb bits per pixel :  tensor(0.988489, device='cuda:0')
# psnr :  tensor(39.116608)
# entropy :  tensor(0.875205, device='cuda:0')
# nb bits per pixel :  tensor(1.312808, device='cuda:0')
# psnr :  tensor(38.140556)
# entropy :  tensor(0.588621, device='cuda:0')
# nb bits per pixel :  tensor(0.882931, device='cuda:0')
# psnr :  tensor(39.159363)
# entropy :  tensor(0.812552, device='cuda:0')
# nb bits per pixel :  tensor(1.218827, device='cuda:0')
# psnr :  tensor(37.686947)
# entropy :  tensor(0.822595, device='cuda:0')
# nb bits per pixel :  tensor(1.233893, device='cuda:0')
# psnr :  tensor(37.297016)
# entropy :  tensor(0.527693, device='cuda:0')
# nb bits per pixel :  tensor(0.791540, device='cuda:0')
# psnr :  tensor(39.868351)
# entropy :  tensor(0.799403, device='cuda:0')
# nb bits per pixel :  tensor(1.199105, device='cuda:0')
# psnr :  tensor(37.710098)
# entropy :  tensor(0.875558, device='cuda:0')
# nb bits per pixel :  tensor(1.313337, device='cuda:0')
# psnr :  tensor(36.952778)
# entropy :  tensor(0.587097, device='cuda:0')
# nb bits per pixel :  tensor(0.880645, device='cuda:0')
# psnr :  tensor(39.807220)
# entropy :  tensor(0.660854, device='cuda:0')
# nb bits per pixel :  tensor(0.991281, device='cuda:0')
# psnr :  tensor(38.408966)
# entropy :  tensor(0.762794, device='cuda:0')
# nb bits per pixel :  tensor(1.144191, device='cuda:0')
# psnr :  tensor(38.653831)
# entropy :  tensor(0.820578, device='cuda:0')
# nb bits per pixel :  tensor(1.230867, device='cuda:0')
# psnr :  tensor(37.375801)
# entropy :  tensor(0.629724, device='cuda:0')
# nb bits per pixel :  tensor(0.944586, device='cuda:0')
# psnr :  tensor(38.236958)
# entropy :  tensor(0.599068, device='cuda:0')
# nb bits per pixel :  tensor(0.898602, device='cuda:0')
# psnr :  tensor(38.892933)
# entropy :  tensor(0.563939, device='cuda:0')
# nb bits per pixel :  tensor(0.845908, device='cuda:0')
# psnr :  tensor(38.337982)
# entropy :  tensor(0.597507, device='cuda:0')
# nb bits per pixel :  tensor(0.896261, device='cuda:0')
# psnr :  tensor(39.048096)
# entropy :  tensor(0.719254, device='cuda:0')
# nb bits per pixel :  tensor(1.078882, device='cuda:0')
# psnr :  tensor(39.908676)
# entropy :  tensor(1.004510, device='cuda:0')
# nb bits per pixel :  tensor(1.506765, device='cuda:0')
# psnr :  tensor(35.880848)
# entropy :  tensor(1.036649, device='cuda:0')
# nb bits per pixel :  tensor(1.554973, device='cuda:0')
# psnr :  tensor(34.632507)
# entropy :  tensor(0.870264, device='cuda:0')
# nb bits per pixel :  tensor(1.305396, device='cuda:0')
# psnr :  tensor(32.328884)
# entropy :  tensor(1.014177, device='cuda:0')
# nb bits per pixel :  tensor(1.521266, device='cuda:0')
# psnr :  tensor(34.629162)
# entropy :  tensor(0.801203, device='cuda:0')
# nb bits per pixel :  tensor(1.201804, device='cuda:0')
# psnr :  tensor(37.907673)
# entropy :  tensor(0.678059, device='cuda:0')
# nb bits per pixel :  tensor(1.017088, device='cuda:0')
# psnr :  tensor(39.648022)
# entropy :  tensor(1.103430, device='cuda:0')
# nb bits per pixel :  tensor(1.655144, device='cuda:0')
# psnr :  tensor(35.110737)
# mean nb bits per pixel :  tensor(1.150608, device='cuda:0')
# psnr mean :  tensor(43.711575)

# %%
def compute_entropy(tensor_data):
    min_val = tensor_data.min()
    max_val = tensor_data.max()
    nb_bins = max_val - min_val + 1
    hist = torch.histc(tensor_data, bins=nb_bins.int(), min=min_val, max=max_val)
    hist_prob = hist/hist.sum()
    hist_prob[hist_prob == 0] = 1
    entropy = -(hist_prob*torch.log2(hist_prob)).sum()
    return entropy
    
        
    
    
def psnr(original, compressed, max_pixel): 
    mse = torch.mean((original - compressed) ** 2) 
    if(mse == 0):  # MSE is zero means no noise is present in the signal . 
                  # Therefore PSNR have no importance. 
        return 100
    psnr = 20 * np.log10(max_pixel / np.sqrt(mse)) 
    return psnr 


# Load previous model
model_prev = LossyCompAutoencoder()
model_prev.load_state_dict(torch.load('./model_parameters/lossy_comp_params_with_rate_beta2_incremental_2.pth'))
model_prev.eval()
model_prev.to(device)


# And run test 
test_dataset = ImageDataset(root_dir='./data/kodac/', transform=ToTensor())
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        [reconstructed_image, im_quantized] = model_prev(test_image,1, True)
        nb_symbols = im_quantized.size(0)*im_quantized.size(1)*im_quantized.size(2)*im_quantized.size(3)
        entropy = compute_entropy(im_quantized)
        nbpp = nb_symbols*entropy/float(test_image.size(0)*test_image.size(1)*test_image.size(2)*test_image.size(3))
        print("nb_symbols : ", nb_symbols)
        print("entropy : ", entropy)
        print( "nb bits per pixel : ", nbpp)
        print("psnr : " , psnr(test_image.cpu(), reconstructed_image.cpu(), 255.0))
    
# And print figures
fig, axes = plt.subplots(nrows=4, ncols=6, sharex=True, sharey=True, figsize=(8,8))
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        if test_image.size(2)<test_image.size(3):
            test_image = test_image.permute(0, 1, 3, 2)
        
        reconstructed_image = model_prev(test_image, 1,  False)
        ax = fig.add_subplot(4, 6, i+1, xticks=[], yticks=[])
        plt.imshow(np.squeeze(reconstructed_image.int().cpu()).permute(1, 2, 0))
        
# And save figures
from torchvision.utils import save_image

with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        reconstructed_image = np.squeeze(model_prev(test_image).cpu())
        print(reconstructed_image.type())
        save_image(reconstructed_image, ".\\reconstructed_data\\kodac\\loss_distortion_and_bitrate\\beta_2_incremental_bis\\" + "img" + str(i)+".png", normalize=True)
# Out:
# nb_symbols :  589824
# entropy :  tensor(5.433585, device='cuda:0')
# nb bits per pixel :  tensor(2.716793, device='cuda:0')
# psnr :  tensor(42.711697)
# nb_symbols :  589824
# entropy :  tensor(4.738198, device='cuda:0')
# nb bits per pixel :  tensor(2.369099, device='cuda:0')
# psnr :  tensor(44.366920)
# nb_symbols :  589824
# entropy :  tensor(5.278986, device='cuda:0')
# nb bits per pixel :  tensor(2.639493, device='cuda:0')
# psnr :  tensor(43.741898)
# nb_symbols :  589824
# entropy :  tensor(5.257313, device='cuda:0')
# nb bits per pixel :  tensor(2.628657, device='cuda:0')
# psnr :  tensor(44.050468)
# nb_symbols :  589824
# entropy :  tensor(5.570083, device='cuda:0')
# nb bits per pixel :  tensor(2.785042, device='cuda:0')
# psnr :  tensor(41.256756)
# nb_symbols :  589824
# entropy :  tensor(5.662136, device='cuda:0')
# nb bits per pixel :  tensor(2.831068, device='cuda:0')
# psnr :  tensor(43.080311)
# nb_symbols :  589824
# entropy :  tensor(5.116849, device='cuda:0')
# nb bits per pixel :  tensor(2.558424, device='cuda:0')
# psnr :  tensor(44.563042)
# nb_symbols :  589824
# entropy :  tensor(5.881482, device='cuda:0')
# nb bits per pixel :  tensor(2.940741, device='cuda:0')
# psnr :  tensor(40.955025)
# nb_symbols :  589824
# entropy :  tensor(5.085561, device='cuda:0')
# nb bits per pixel :  tensor(2.542780, device='cuda:0')
# psnr :  tensor(44.030388)
# nb_symbols :  589824
# entropy :  tensor(5.034587, device='cuda:0')
# nb bits per pixel :  tensor(2.517294, device='cuda:0')
# psnr :  tensor(44.090431)
# nb_symbols :  589824
# entropy :  tensor(5.315285, device='cuda:0')
# nb bits per pixel :  tensor(2.657643, device='cuda:0')
# psnr :  tensor(43.732460)
# nb_symbols :  589824
# entropy :  tensor(5.278862, device='cuda:0')
# nb bits per pixel :  tensor(2.639431, device='cuda:0')
# psnr :  tensor(44.424889)
# nb_symbols :  589824
# entropy :  tensor(5.721937, device='cuda:0')
# nb bits per pixel :  tensor(2.860968, device='cuda:0')
# psnr :  tensor(39.624790)
# nb_symbols :  589824
# entropy :  tensor(5.549026, device='cuda:0')
# nb bits per pixel :  tensor(2.774513, device='cuda:0')
# psnr :  tensor(41.797176)
# nb_symbols :  589824
# entropy :  tensor(5.991822, device='cuda:0')
# nb bits per pixel :  tensor(2.995911, device='cuda:0')
# psnr :  tensor(42.317528)
# nb_symbols :  589824
# entropy :  tensor(5.187307, device='cuda:0')
# nb bits per pixel :  tensor(2.593653, device='cuda:0')
# psnr :  tensor(45.182747)
# nb_symbols :  589824
# entropy :  tensor(5.300200, device='cuda:0')
# nb bits per pixel :  tensor(2.650100, device='cuda:0')
# psnr :  tensor(43.788574)
# nb_symbols :  589824
# entropy :  tensor(5.268565, device='cuda:0')
# nb bits per pixel :  tensor(2.634283, device='cuda:0')
# psnr :  tensor(41.059765)
# nb_symbols :  589824
# entropy :  tensor(5.418479, device='cuda:0')
# nb bits per pixel :  tensor(2.709240, device='cuda:0')
# psnr :  tensor(43.560848)
# nb_symbols :  589824
# entropy :  tensor(6.062364, device='cuda:0')
# nb bits per pixel :  tensor(3.031182, device='cuda:0')
# psnr :  tensor(42.766666)
# nb_symbols :  589824
# entropy :  tensor(5.341250, device='cuda:0')
# nb bits per pixel :  tensor(2.670625, device='cuda:0')
# psnr :  tensor(42.850250)
# nb_symbols :  589824
# entropy :  tensor(5.328340, device='cuda:0')
# nb bits per pixel :  tensor(2.664170, device='cuda:0')
# psnr :  tensor(42.178059)
# nb_symbols :  589824
# entropy :  tensor(5.568606, device='cuda:0')
# nb bits per pixel :  tensor(2.784303, device='cuda:0')
# psnr :  tensor(43.223347)
# nb_symbols :  589824
# entropy :  tensor(5.464958, device='cuda:0')
# nb bits per pixel :  tensor(2.732479, device='cuda:0')
# psnr :  tensor(39.438251)
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor
# torch.FloatTensor

# %%
def entropy_rate(x_quantized, phi, var):
    u = torch.arange(-0.5, 0.5+0.01, 0.01).cuda()        
    gsm_sum = torch.zeros(len(u)).cuda()
    for i in range(len(u)):
        x = x_quantized + u[i]
        gsm_sum_i = sum_gsm(x, var, phi, 6)
        gsm_sum[i] = gsm_sum_i

    entropy = torch.trapz(gsm_sum, u)
    
    return entropy


# Load incremental model
incremental_model = LossyCompAutoencoder()
incremental_model.load_state_dict(torch.load('./model_parameters/lossy_comp_params_with_rate_beta2_incremental.pth'))
incremental_model.eval()
incremental_model.to(device)

# train again the model starting form incremental-learned weights
    #define optimizer
optimizer = torch.optim.Adam(incremental_model.parameters(), lr=0.0001)

# define loss function
distortion = nn.MSELoss().cuda()


# define beta
beta = 2.0

#Epochs
n_epochs = 600


# Training the network
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
           
    #Training
    for i_batch, data in enumerate(dataloader):
        batch_images = data.to(device).float()
        [decoded_images, x_quantized] = incremental_model(batch_images, False, True)
        optimizer.zero_grad()
        entropy = entropy_rate(x_quantized, incremental_model.phi, incremental_model.var)
        print("entropy : ", entropy)
        dist = distortion(decoded_images, batch_images)
        print("distortion : ", dist)
        loss = beta * dist + entropy
        loss.backward()
        #print("conv1.weights grad: ", params[0].grad)
        #print(model.conv1.bias.grad)
        #print(model.conv1.weight.grad)
        optimizer.step()
        running_loss += loss.item()

    running_loss = running_loss/len(dataloader)
    print('running loss : {:.06f}'.format(running_loss), )
# Out:
# entropy :  tensor(4.992423, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3783.756348, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(35.316048, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3331.412354, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(33.194473, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3280.784668, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(16.982132, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3833.349854, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(6.236253, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(2998.021240, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(13.942085, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4020.668213, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(11.401224, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4049.084229, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.091653, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3914.844238, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(7.532864, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3699.531006, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(11.252965, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3502.669678, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(10.172251, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3233.638916, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(7.888332, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3444.639160, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.890505, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3758.968750, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(6.177967, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4241.679688, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(9.358366, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3220.504639, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(9.724493, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4545.562988, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(9.402671, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4369.997559, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(6.538430, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3352.075195, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.289365, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3834.843750, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(8.297033, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4144.026855, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(9.374476, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3154.157715, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(8.841386, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4223.809570, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(7.746368, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3535.041992, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(7.335207, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3648.764893, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.753038, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3968.517578, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.264740, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3936.420410, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(6.236658, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3609.426758, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(6.787442, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3621.904053, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.986058, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3584.592773, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.134099, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3085.294434, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.148417, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3078.743896, device='cuda:0', grad_fn=<MseLossBackward>)
# running loss : 7364.701818
# entropy :  tensor(4.213949, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3561.325195, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.420860, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4118.843750, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.712553, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3637.174072, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.181670, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3776.993408, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.715181, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3658.700684, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.026452, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3791.611328, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.472366, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4050.481445, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.867154, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3336.663330, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.950971, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3322.977051, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.643092, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4383.884766, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.033780, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3470.098389, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.374466, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3601.259033, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.418680, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3595.695068, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.429362, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3701.815430, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.102546, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3141.937500, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.463200, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3970.664551, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.480068, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3244.265625, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.471892, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(2789.662354, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.854553, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3421.625000, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.668358, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3847.244141, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.893020, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3640.884033, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.753895, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3621.660889, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.477390, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3783.617676, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.891545, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3746.264893, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.493074, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3678.192139, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.630400, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3549.524658, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.559849, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4365.400879, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.162018, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3316.888916, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.600066, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4416.073242, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.738790, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3471.339355, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.830067, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3463.139160, device='cuda:0', grad_fn=<MseLossBackward>)
# running loss : 7325.527312
# entropy :  tensor(4.101906, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3192.148926, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3
device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.253601, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3282.483643, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.040407, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(2838.232910, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.175869, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3185.782471, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.151800, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4109.848145, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.158847, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3655.943604, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.653343, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3582.857666, device='cuda:0', grad_fn=<MseLossBackward>)
# running loss : 7388.880544
# entropy :  tensor(4.078692, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4331.937500, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.303016, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3650.385498, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.910847, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3701.556152, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.063138, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3586.044678, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.186852, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3436.955322, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.935975, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3857.169678, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.243153, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4031.090088, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.233263, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3312.595947, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.272809, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3685.513916, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.544210, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3571.533936, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.963799, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3686.460693, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.587257, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3620.589844, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.902643, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3835.430908, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.706846, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3853.415283, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(5.016892, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3530.089355, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.708622, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3393.946533, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.012492, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3616.270264, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.857601, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3201.696533, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.309969, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3394.364746, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.094294, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4268.666504, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.429111, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3004.241211, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.262102, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3367.807373, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.463998, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3204.622803, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.628301, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3945.990479, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.638970, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4537.041016, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(3.390480, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4347.650391, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.352649, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(4050.649658, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.300420, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3470.998291, device='cuda:0', grad_fn=<MseLossBackward>)
# entropy :  tensor(4.867441, device='cuda:0', grad_fn=<DivBackward1>)
# distortion :  tensor(3542.787354, device='cuda:0', grad_fn=<MseLossBackward>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-17527ea6f60d> in <module>
#      47         print("distortion : ", dist)
#      48         loss = beta * dist + entropy
# ---> 49         loss.backward()
#      50         #print("conv1.weights grad: ", params[0].grad)
#      51         #print(model.conv1.bias.grad)
#
# ~\anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# ~\anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     123         retain_graph = create_graph
#     124
# --> 125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
#     127         allow_unreachable=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
from range_coder import RangeEncoder, RangeDecoder, prob_to_cum_freq
import os

# Load previous model
model = LossyCompAutoencoder()
model.load_state_dict(torch.load('./model_parameters/mean_bit_ppx/lossy_comp_params_with_rate_beta0005_incremental.pth'))
model.eval()
model.to(device)

nb_bits = 0.0
test_dataset = ImageDataset(root_dir='./data/kodac/', transform=ToTensor())
with torch.no_grad():  
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        [reconstructed_image, data_comp] = model(test_image, 1, True)
            # compute symbol probabilities
        min_val = data_comp.min()
        if min_val <0:
            data_comp -= min_val
            min_val = 0
        max_val = data_comp.max()
        nb_bins = max_val - min_val + 1
        hist = torch.histc(data_comp, bins=nb_bins.int(), min=min_val, max=max_val)
        prob = hist/hist.sum()
        #print("data comp : ", data_comp)
        #print(prob)
        
        """
        if len(torch.nonzero(prob)) != len(prob):
            zero_indices = ((prob == 0).nonzero())
            for j in reversed(range(0, len(zero_indices), 1)):
                data_comp[data_comp > int(zero_indices[j])+min_val] -=1
            min_val = data_comp.min()
            max_val = data_comp.max()
            nb_bins = max_val - min_val + 1
            hist = torch.histc(data_comp, bins=nb_bins.int(), min=min_val, max=max_val)
            prob = hist/hist.sum()
            print(min_val)
            print(max_val)
            print("data comp : ", data_comp)
            print(prob)
         """ 
            
            # convert probabilities to cumulative integer frequency table
        #cumFreq = prob_to_cum_freq(torch.clamp(prob, min=np.finfo(np.float32).eps).cpu(), resolution=128)
        cumFreq = prob_to_cum_freq(prob.cpu(), resolution=128)
        #print(cumFreq)
        
        # encode data
        filepath_to_write = "D:\\lossy_autoencoder\\latent_vect_encoded\\" + "img" + str(i) + ".bin"
        encoder = RangeEncoder(filepath_to_write)
        #print(torch.flatten(data_comp).cpu().tolist())
        encoder.encode(torch.flatten(data_comp.int()).cpu().tolist(), cumFreq)
        encoder.close()
        
        
        file_size = os.path.getsize(filepath_to_write)*8 #number of bits in the file
        print(file_size)
        nb_bits += file_size
        
    nb_bits_per_image = nb_bits/len(test_dataset)
    print(nb_bits_per_image)
    nb_bits_per_pixel = nb_bits_per_image/(512*768)
    print(nb_bits_per_pixel)
    
    
"""
    test_image = test_dataset[1].unsqueeze(0).to(device).float()
    [reconstructed_image, data_comp] = model(test_image, 1, True)
        # compute symbol probabilities
    min_val = data_comp.min()
    print(min_val)
    print(data_comp.max())
    if min_val <0:
        data_comp -= min_val
        min_val = 0
    max_val = data_comp.max()
    
    print(max_val)
    nb_bins = max_val - min_val + 1
    print(nb_bins)
    hist = torch.histc(data_comp, bins=nb_bins.int(), min=min_val, max=max_val)
    prob = hist/hist.sum()
    print(prob)
         # convert probabilities to cumulative integer frequency table
    cumFreq = prob_to_cum_freq(prob.cpu(), resolution=128)
    #print(cumFreq)

    print(torch.flatten(data_comp).cpu().tolist())
    
    
        # encode data
    filepath_to_write = "D:\\lossy_autoencoder\\latent_vect_encoded\\" + "img" + str(1) + ".bin"
    encoder = RangeEncoder(filepath_to_write)
    print(torch.flatten(data_comp).cpu().tolist())
    encoder.encode(torch.flatten(data_comp.int()).cpu().tolist(), cumFreq)
    encoder.close()   
"""
# Out:
# 619240
# 417832
# 381184
# 485040
# 681856
# 566208
# 438336
# 716840
# 393552
# 406752
# 519136
# 394736
# 786376
# 594720
# 470824
# 428256
# 399592
# 613760
# 510416
# 464416
# 540400
# 507440
# 400992
# 585792
# 513487.3333333333
# 1.3058658175998263
# '\n    test_image = test_dataset[1].unsqueeze(0).to(device).float()\n    [reconstructed_image, data_comp] = model(test_image, 1, True)\n        # compute symbol probabilities\n    min_val = data_comp.min()\n    print(min_val)\n    print(data_comp.max())\n    if min_val <0:\n        data_comp -= min_val\n        min_val = 0\n    max_val = data_comp.max()\n    \n    print(max_val)\n    nb_bins = max_val - min_val + 1\n    print(nb_bins)\n    hist = torch.histc(data_comp, bins=nb_bins.int(), min=min_val, max=max_val)\n    prob = hist/hist.sum()\n    print(prob)\n         # convert probabilities to cumulative integer frequency table\n    cumFreq = prob_to_cum_freq(prob.cpu(), resolution=128)\n    #print(cumFreq)\n\n    print(torch.flatten(data_comp).cpu().tolist())\n    \n    \n        # encode data\n    filepath_to_write = "D:\\lossy_autoencoder\\latent_vect_encoded\\" + "img" + str(1) + ".bin"\n    encoder = RangeEncoder(filepath_to_write)\n    print(torch.flatten(data_comp).cpu().tolist())\n    encoder.encode(torch.flatten(data_comp.int()).cpu().tolist(), cumFreq)\n    encoder.close()   \n'
