# %%
import numpy as np
import torch
import torch.nn as nn
import pandas as pd
from skimage import io, transform
import torch.autograd as ag
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import os
from scipy import signal
from sklearn.metrics import mean_squared_error
from torch.autograd import Variable
import time
from functools import reduce

torch.set_printoptions(precision=6)

# %%
class ImageDataset(Dataset):

    def __init__(self, root_dir, transform=None):
        """
        Args:
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        path, dirs, files = next(os.walk(self.root_dir))
        file_count = len(files)
        return file_count

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        path, dirs, files = next(os.walk(self.root_dir))
        img_name = os.path.join(self.root_dir, files[idx])
        image = io.imread(img_name)

        if self.transform:
            image = self.transform(image)

        return image


class RandomCrop(object):
    """Crop randomly the image

    Args:
        output_size (tuple or int): Desired output size. If int, square crop
            is made.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            assert len(output_size) == 2
            self.output_size = output_size

    def __call__(self, image):
        
        h, w = image.shape[:2]
        new_h, new_w = self.output_size
        
        if h!= new_h:
            top = np.random.randint(0, h - new_h)
        else:
            top = 0
        if w!= new_w:
            left = np.random.randint(0, w - new_w)
        else:
            left = 0
     
        image = image[top: top + new_h,
                      left: left + new_w]
        
        image = np.expand_dims(image, axis=2)

        return image
    
    
class Downsample(object):
    """Downsample the image

    Args:
        downsampling_factor (int or tuple): Desired downsampling factor for rows and columns.
        If the downsampling factor is an int, then both rows and columns are sampled by the same factor
    """

    def __init__(self, downsampling_factor):
        assert isinstance(downsampling_factor, (int, tuple))
        if isinstance(downsampling_factor, int):
            self.downsampling_factor = (downsampling_factor, downsampling_factor)
        else:
            assert len(downsampling_factor) == 2
            self.downsampling_factor = downsampling_factor

    def __call__(self, image):
        
        down_fact_h, down_fact_w = self.downsampling_factor
        image = image[::down_fact_h,
                      ::down_fact_w]

        return image
    
    
class ConvertDepthToColor(object):
    """ convert a 1xmxn 16-bits depthmap to a 2xmxn 8-bits colormap

    """

    def __call__(self, image):
        if len(image.shape[:]) <3:
            image = np.expand_dims(image, axis=2)
            
        h, w = image.shape[:2]
        image_r_color= np.zeros((h,w,1), dtype=int)
        image_g_color= np.zeros((h,w,1), dtype=int)
        image_g_color[(image > 2**8 - 1)] = image[(image > 2**8 - 1)] >> 8
        image_r_color = image - (image_g_color <<8)

        return np.concatenate((image_r_color, image_g_color), axis=2)
    

class ToTensor(object):
    """Convert ndarrays in images to Tensors."""

    def __call__(self, images):

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        images = images.transpose((2, 0, 1))
        images = images.astype(float)
        return torch.from_numpy(images)
    

    
class ConvertColorToDepth(object):
    """ convert a 2xmxn 8-bits colormap to a 1xmxn 16-bits depthmap

    """

    def __call__(self, color_image):
            
        depth_image = color_image[:, 0, :, :]
        depth_image += color_image[:, 1, :, :] << 8

        return depth_image

    
def show_image_batch(images_batch):
    """Show image for a batch of samples."""
    if images_batch.size(1) == 1:
        images_batch_normed = images_batch/torch.max(images_batch)
        grid = utils.make_grid(images_batch_normed)
        plt.imshow(grid.numpy().transpose((1, 2, 0)))

        plt.title('Batch from dataloader')
    else:
        print(images_batch.size())
        images_b_batch = torch.zeros(images_batch.size(0), 1, images_batch.size(2) , images_batch.size(3))
        images_color_batch = torch.cat((images_batch, images_b_batch), 1) 
        print(images_color_batch.size())
        grid = utils.make_grid(images_color_batch)
        plt.imshow(grid.numpy().transpose((1, 2, 0)))

        plt.title('Batch from dataloader')
    
    
    
    
# Load training dataset

#mirror_padding_transform = transforms.Compose([transforms.ToPILImage(), transforms.Pad(padding=12, padding_mode='reflect'), transforms.ToTensor()])
transformed_dataset = ImageDataset(root_dir='D:/autoencoder_data/depthmaps/training/dilated', 
                                           transform=transforms.Compose([
                                            RandomCrop((384, 640)), Downsample(( 3, 5)), ToTensor()])
                                  )
dataloader = DataLoader(transformed_dataset, batch_size=18, shuffle=True, num_workers=0)

for i_batch, batch_images in enumerate(dataloader):
    print(i_batch, batch_images.size())

    # observe 4th batch and stop.
    if i_batch == 2:
        plt.figure()
        show_image_batch(batch_images)
        plt.axis('off')
        plt.ioff()
        plt.show()
        break

"""
transform = transforms.Compose([
    transforms.Pad(12, padding_mode='reflect'),
    transforms.ToTensor()])

trainset = torchvision.datasets.Flickr8k(root='./data/flickr', ann_file = './data/flickr/file.csv', transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=2)
"""
# Out:
# 0 torch.Size([18, 1, 128, 128])
# 1 torch.Size([18, 1, 128, 128])
# 2 torch.Size([18, 1, 128, 128])
# "\ntransform = transforms.Compose([\n    transforms.Pad(12, padding_mode='reflect'),\n    transforms.ToTensor()])\n\ntrainset = torchvision.datasets.Flickr8k(root='./data/flickr', ann_file = './data/flickr/file.csv', transform=transform)\ntrainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=2)\n"

# %%
#Define additionnnal functions
def periodic_shuffling(T, C):
    T_copy = T.clone()
    batch_size = T.size()[0]
    H = T.size()[2]
    W = T.size()[3]
    T = T.view(batch_size, C, H*2, W*2)
    """
    for k in range(C):
        for i in range(2*H):
            for j in range(2*W):
                T[:, k, i, j] = T_copy[:, C*((j&1)<<1)+C*(i&1)+k, i>>1, j>>1]
    """
                
    T[:, :, ::2, ::2] = T_copy[:, 0:C, :, :]
    T[:, :, 1::2, ::2] = T_copy[:, C:2*C, :, :]
    T[:, :, ::2, 1::2] = T_copy[:, 2*C:3*C, :, :]
    T[:, :, 1::2, 1::2] = T_copy[:, 3*C:4*C, :, :]

    return T
    
    
def mirror_padding(x, padding_size):
    up_line = x[:, :, 0:padding_size, :].flip(2)
    left_col = x[:, :, :, 0:padding_size].flip(3)
    right_col = x[:, :, :, -padding_size:].flip(3)
    bottom_line = x[:, :, -padding_size:, :].flip(2)
    left_up_corner = left_col[:, :, 0:padding_size, :].flip(2)
    right_up_corner = right_col[:, :, 0:padding_size, :].flip(2)
    left_bottom_corner = left_col[:, :, -padding_size:, :].flip(2)
    right_bottom_corner = right_col[:, :, -padding_size:, :].flip(2)

    x_mirror_pad = torch.cat((torch.cat((left_up_corner, up_line, right_up_corner), 3), torch.cat((left_col, x, right_col), 3), torch.cat((left_bottom_corner, bottom_line, right_bottom_corner), 3)), 2)
    return x_mirror_pad


def get_zero_mask(x):
    return(x > 0)


def black_pixels_removal_by_dilatation(x, se):
    # se must be a rectangle element
    if x.is_cuda:
        se = se.cuda()
        zero_tensor = torch.zeros(1, dtype=torch.int64).cuda()
        one_tensor = torch.ones(1, dtype=torch.int64).cuda()
    else:
        zero_tensor = torch.zeros(1, dtype=torch.int64)
        one_tensor = torch.ones(1, dtype=torch.int64)
        
    se_height = se.size(0)
    se_width = se.size(1)
    zero_indices =  torch.nonzero((x == 0))
    row_ind = torch.stack([torch.max(zero_tensor, zero_indices[:, 2] - se_height//2), torch.min(one_tensor*x.size(2), zero_indices[:, 2] + se_height//2)], dim=1)
    col_ind = torch.stack([torch.max(zero_tensor, zero_indices[:, 3] - se_width//2), torch.min(one_tensor*x.size(3), zero_indices[:, 3] + se_width//2)], dim=1)
    x_with_reduced_black_px = x.clone().detach()
    for k in range(zero_indices.size(0)):
        x_with_reduced_black_px[tuple(zero_indices[k, :])] = torch.max(x[int(zero_indices[k, 0]), int(zero_indices[k, 1]), row_ind[k, 0]:row_ind[k, 1]+1:1, col_ind[k, 0]:col_ind[k, 1]+1:1])
        
    
    if torch.any(x_with_reduced_black_px==0):
        print("+1")
        x_with_reduced_black_px = black_pixels_removal_by_dilatation(x_with_reduced_black_px, se)
    
    return x_with_reduced_black_px

"""
def black_pixels_removal_by_dilatation(x):
    if x.is_cuda:
        kernel_tensor = torch.ones(1, 1, 109, 119).cuda()
    else:
        kernel_tensor = torch.ones(1, 1, 109, 119)
    mask_of_zero = (x==0)
    torch_result = torch.clamp(torch.nn.functional.conv2d(x, kernel_tensor, padding=(54, 59)), 0, 2**16-1)
    x_with_reduced_black_px = x.clone().detach()
    x_with_reduced_black_px[mask_of_zero] = torch_result[mask_of_zero]

    
    if torch.any(x_with_reduced_black_px==0):
        x_with_reduced_black_px = black_pixels_removal_by_dilatation(x_with_reduced_black_px)
    
    return x_with_reduced_black_px
   
"""
def normalize_input(x):
    mean_channels = torch.mean(1.0*x, [2,3])
    mean_channels_images = (mean_channels.repeat_interleave(x.size()[2]*x.size()[3])).view(x.size()[0], x.size()[1], x.size()[2], x.size()[3])
    x_centered = x - mean_channels_images
    max_value = torch.max(x)
    min_value = torch.min(x)
    radius = max(max_value, abs(min_value))
    x_centered_normalized = x_centered/radius
    return x_centered_normalized, radius, mean_channels

def standardize_input(x):
    mean_channels = torch.mean(1.0*x, [2,3])
    mean_channels_images = (mean_channels.repeat_interleave(x.size()[2]*x.size()[3])).view(x.size()[0], x.size()[1], x.size()[2], x.size()[3])
    x_centered = x - mean_channels_images
    var = torch.sum(x_centered**2, (2, 3))/(x.size()[2]*x.size()[3])
    x_standardized = x_centered / torch.sqrt(var.view(x_centered.size()[0], x_centered.size()[1], 1, 1))
    return x_standardized, mean_channels, var
    
def denormalize_output(x, radius, mean_channels):
    x_denormalized = x*radius
    mean_channels_images = (mean_channels.repeat_interleave(x.size()[2]*x.size()[3])).view(x.size()[0], x.size()[1], x.size()[2], x.size()[3])
    x_denormalized_centered = x_denormalized + mean_channels_images
    return x_denormalized_centered

def destandardize_output(x, mean_channels, var):
    x_rescaled = x*torch.sqrt(var.view(x.size()[0], x.size()[1], 1, 1))
    mean_channels_images = (mean_channels.repeat_interleave(x.size()[2]*x.size()[3])).view(x.size()[0], x.size()[1], x.size()[2], x.size()[3])
    x_destandardized = x_rescaled + mean_channels_images
    return x_destandardized



def compute_gsm(x, var, phi, nScale):
    gsm = 0.0
    
    phi = torch.abs(phi)
    var = torch.abs(var)
    phi_s_sum = torch.sum(phi, 0).unsqueeze(0)
    phi_norm = phi/phi_s_sum
    
    for s in range(nScale):
        var_s = var[s, :].view(1, -1, 1, 1)
        phi_s = phi_norm[s, :].view(1, -1, 1, 1)
        gaussian = phi_s*(1.0/(torch.sqrt(2*np.pi*var_s)))*torch.exp(-0.5*(x**2/var_s))
        gsm += gaussian
    return gsm


def sum_gsm(x, var, phi, nScale):
    gsm = 0.0
    
    phi = torch.abs(phi)
    var = torch.abs(var)
    phi_s_sum = torch.sum(phi, 0).unsqueeze(0)
    phi_norm = phi/phi_s_sum
    
    for s in range(nScale):
        var_s = var[s, :].view(1, -1, 1, 1)
        phi_s = phi_norm[s, :].view(1, -1, 1, 1)
        gaussian = phi_s*(1.0/(torch.sqrt(2*np.pi*var_s)))*torch.exp(-0.5*(x**2/var_s))
        gsm += gaussian
    #gsm_sum = (torch.log2(gsm)).sum()
    gsm_sum = gsm.sum()
    return gsm_sum
    
    
    """
    batch_size = x.size(0)
    h = x.size(-1)
    w = x.size(-2)
    #print("input : ", input)
    coeff = torch.sqrt(1.0 / (2 * np.pi * var))
    #print("coeff : ", coeff)
    x_resized = x.repeat((nScale, 1, 1, 1, 1))
    #print("input : ", input_resized)
    exponent = (-0.5*(x_resized ** 2)/var.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w))
    #print("exponent : ", exponent)
    coeffs_resized = coeff.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
    #print("coeffs : ", coeffs_resized)
    gaussian = coeffs_resized * torch.exp(exponent)
    #print("gaussian : ", gaussian)
    phi_resized = phi.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
    phi_gaussian = phi_resized*gaussian
    sum_phi_gaussian = phi_gaussian.sum(dim=0)
    #print("sum over scales : ", sum_phi_gaussian)
    result = -torch.log2(sum_phi_gaussian).sum()

    return result
    """
    
def compute_mask(nb_ones, dims):
    mask = torch.zeros(dims)
    indices = np.arange(nb_ones)
    mask_flatten = mask.view(-1, 1, 1, 1)
    mask_flatten[indices] = 1
    mask_reshaped = mask_flatten.view(dims)
    return mask_reshaped


def entropy_rate(x_quantized, phi, var):
    u = torch.arange(-0.5, 0.5+0.1, 0.1).cuda()        
    gsm_sum = torch.zeros(len(u)).cuda()
    for i in range(len(u)):
        x = x_quantized + u[i]
        gsm_sum_i = sum_gsm(x, var, phi, 6)
        gsm_sum[i] = gsm_sum_i

    integral_u = torch.trapz(gsm_sum, u)
    #print("gsm sum : ", gsm_sum)
    #print("integral over u : ", integral_u)
    entropy = -torch.log2(integral_u)
    
    return entropy



def mean_bit_per_px(x_quantized, phi, var):
    u = torch.arange(-0.5, 0.5+0.1, 0.1).cuda()   
    gsm_stacked = []
    #u_stacked = []
    for i in range(len(u)):
        x = x_quantized + u[i]
        gsm = compute_gsm(x, var, phi, 6)
        gsm_stacked.append(gsm)
        #u_stacked.append(torch.ones(gsm.size()).cuda()*u[i])
    
    gsms = torch.stack(gsm_stacked, dim=0)
    #us = torch.stack(u_stacked, dim=0)
    integral_u = torch.trapz(gsms, dx=0.1, dim=0)
    if torch.any(integral_u.isnan()):
        print("integral u is nan", integral_u)
        integral_u[integral_u.isnan()] = 1
    nb_bits = (-torch.log2(torch.clamp(integral_u, min=np.exp(-10**2), max=1))).sum()
    if nb_bits.isnan():
        print("nb bits is nan")
    if nb_bits < 0:
        #print("integral u : ", integral_u)
        print("nb_bits negative : ", nb_bits)
    return nb_bits/reduce(lambda x, y: x*y, list(x_quantized.size()))


def distortion_pc(x, x_reconstructed, focal_length, skew, scaling_factor, image_size, principal_point):
    # compute intrinsic matrix and its inverse
    K = torch.tensor([[focal_length, skew, principal_point[0]], [ 0.0, focal_length, principal_point[1]], [0.0, 0.0, 1.0]])
    K_ext = torch.eye(4)
    K_ext[0:3:1, 0:3:1] = K
    K_ext_inv = torch.inverse(K_ext).cuda()
    
    size_batch = x.size()[0]
    total_mse = 0.0
    for example in range(size_batch):
        # compute x,y,z coords from u,v coords and gray-level value
        z_reconstructed = x_reconstructed[example, :, :, :].view(image_size[0]*image_size[1])/scaling_factor
        z = x[example, :, :, :].view(image_size[0]*image_size[1])/scaling_factor
        bool_matrix = torch.logical_and(z_reconstructed != 0 , z != 0)
            # for reconstructed depthmap
        v_reconstructed = (torch.arange(1, image_size[0]+1)).repeat_interleave(image_size[1])
        v_reconstructed = v_reconstructed[bool_matrix].view(1, -1).cuda()
        u_reconstructed = (torch.arange(1, image_size[1]+1)).repeat(image_size[0])
        u_reconstructed = u_reconstructed[bool_matrix].view(1, -1).cuda()
        z_reconstructed = z_reconstructed[bool_matrix].view(1, -1)
        homogeneous_reconstructed_camera_points = torch.cat((u_reconstructed, v_reconstructed, torch.ones(1, u_reconstructed.size()[1]).cuda(), 1.0/z_reconstructed), 0)
        homogeneous_reconstructed_coords = z_reconstructed*(torch.mm(K_ext_inv,homogeneous_reconstructed_camera_points))
        coords_reconstructed = homogeneous_reconstructed_coords[0:3:1, :]
            # for original depthmap
        v = (torch.arange(1, image_size[0]+1)).repeat_interleave(image_size[1])
        v = v[bool_matrix].view(1, -1).cuda()
        u =  (torch.arange(1, image_size[1]+1)).repeat(image_size[0])
        u = u[bool_matrix].view(1, -1).cuda()    
        z = z[bool_matrix].view(1, -1)
        homogeneous_camera_points = torch.cat((u, v, torch.ones(1, u.size()[1]).cuda(), 1.0/z))
        homogeneous_coords = z*(torch.mm(K_ext_inv,homogeneous_camera_points))
        coords = homogeneous_coords[0:3:1, :]
        
        print(" x original : ", torch.squeeze(z)[10]*scaling_factor)
        print(" original coords : ", coords[:, 10])
        
        # compute MSE on points
        total_mse += torch.sum(torch.sqrt(torch.sum((coords_reconstructed - coords)**2, 0)))
    return total_mse
        

"""
def entropy_rate(x_quantized, phi, var):
    u = torch.arange(-0.5, 0.5+0.05, 0.05).cuda()   
    sum_log_gsm = torch.zeros(len(u)).cuda()
    for i in range(len(u)):
        x = x_quantized + u[i]
        gsm = compute_gsm(x, var, phi, 6)
        sum_log_gsm[i] = (-torch.log2(gsm)).sum()
    
    entropy = torch.trapz(sum_log_gsm, u)
    if entropy < 0:
        print("negative entropy")
    return entropy
"""

"""
def clip(x):
    x_n = (x - torch.min(x))/(torch.max(x) - torch.min(x))
    x_clipped = torch.round(255*x_n).float()
    return x_clipped
"""


class MyQuantization(torch.autograd.Function):
    """
    We can implement our own custom autograd Functions by subclassing
    torch.autograd.Function and implementing the forward and backward passes
    which operate on Tensors.
    """
    
    @staticmethod
    def forward(ctx, input):
        """
        In the forward pass we receive a Tensor containing the input and return
        a Tensor containing the output. ctx is a context object that can be used
        to stash information for backward computation. You can cache arbitrary
        objects for use in the backward pass using the ctx.save_for_backward method.
        """
        ctx.save_for_backward(input)
        return torch.round(input)
    
    @staticmethod
    def backward(ctx, grad_output):
        """
        In the backward pass we receive a Tensor containing the gradient of the loss
        with respect to the output, and we need to compute the gradient of the loss
        with respect to the input.
        """
        input, = ctx.saved_tensors
        return grad_output

        
        
class MyClipping(torch.autograd.Function):
  
    @staticmethod
    def forward(ctx, input):
        ctx.save_for_backward(input)
        return torch.round(input).clamp(min=0, max=2**16-1)
    
    @staticmethod
    def backward(ctx, grad_output):
        input = ctx.saved_tensors
        return grad_output

    
"""
class GaussianDistribution(torch.autograd.Function):
    @staticmethod
    def forward(ctx, input, var, phi, nScale, nChannel):
        batch_size = input.size(0)
        h = input.size(-1)
        w = input.size(-2)
        ctx.save_for_backward(input, var, phi)
        #print("input : ", input)
        coeff = torch.sqrt(1.0 / (2 * np.pi * var))
        #print("coeff : ", coeff)
        input_resized = input.repeat((nScale, 1, 1, 1, 1))
        #print("input : ", input_resized)
        exponent = (-0.5*(input_resized ** 2)/var.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w))
        #print("exponent : ", exponent)
        coeffs_resized = coeff.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
        #print("coeffs : ", coeffs_resized)
        gaussian = coeffs_resized * torch.exp(exponent)
        #print("gaussian : ", gaussian)
        phi_resized = phi.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
        phi_gaussian = phi_resized*gaussian
        sum_phi_gaussian = phi_gaussian.sum(dim=0)
        #print("sum over scales : ", sum_phi_gaussian)
        result = -torch.log2(sum_phi_gaussian).sum()

        return result

    @staticmethod
    def backward(ctx, grad_output):
        input, var, phi = ctx.saved_tensors
        batch_size = input.size(0)
        h = input.size(-1)
        w = input.size(-2)
        nChannel = var.size(1)
        nScale = var.size(0)
        
        
        var_resized = var.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
        phi_resized = phi.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)
        input_resized = input.repeat((nScale, 1, 1, 1, 1))
        
        d_phi = -torch.log2(1.0/torch.sqrt(2.0*np.pi*var_resized)*(torch.exp(-0.5*input_resized**2/var_resized))).sum(dim = [3, 4])
        d_var = -torch.log2(phi_resized*(1.0/(np.sqrt(2.0*np.pi)*var_resized)*torch.exp(-0.5*input_resized**2/var_resized))*(1.0 + input_resized**2/var_resized)).sum(dim = [3, 4])
        d_xq = -torch.log2((phi_resized*(-input_resized/torch.sqrt(2.0*np.pi*var_resized**3))*torch.exp(-0.5*input_resized**2/var_resized)).sum(dim=[0]))
        print("d_xq : ", (phi_resized*(-input_resized/torch.sqrt(2.0*np.pi*var_resized**3))*torch.exp(-0.5*input_resized**2/var_resized)).sum(dim=[0]))
        
        return grad_output*d_phi, grad_output*d_var, grad_output*d_xq
"""
# Out:
# '\nclass GaussianDistribution(torch.autograd.Function):\n    @staticmethod\n    def forward(ctx, input, var, phi, nScale, nChannel):\n        batch_size = input.size(0)\n        h = input.size(-1)\n        w = input.size(-2)\n        ctx.save_for_backward(input, var, phi)\n        #print("input : ", input)\n        coeff = torch.sqrt(1.0 / (2 * np.pi * var))\n        #print("coeff : ", coeff)\n        input_resized = input.repeat((nScale, 1, 1, 1, 1))\n        #print("input : ", input_resized)\n        exponent = (-0.5*(input_resized ** 2)/var.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w))\n        #print("exponent : ", exponent)\n        coeffs_resized = coeff.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)\n        #print("coeffs : ", coeffs_resized)\n        gaussian = coeffs_resized * torch.exp(exponent)\n        #print("gaussian : ", gaussian)\n        phi_resized = phi.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)\n        phi_gaussian = phi_resized*gaussian\n        sum_phi_gaussian = phi_gaussian.sum(dim=0)\n        #print("sum over scales : ", sum_phi_gaussian)\n        result = -torch.log2(sum_phi_gaussian).sum()\n\n        return result\n\n    @staticmethod\n    def backward(ctx, grad_output):\n        input, var, phi = ctx.saved_tensors\n        batch_size = input.size(0)\n        h = input.size(-1)\n        w = input.size(-2)\n        nChannel = var.size(1)\n        nScale = var.size(0)\n        \n        \n        var_resized = var.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)\n        phi_resized = phi.repeat_interleave(batch_size*h*w, 1).view(nScale, batch_size, nChannel, h, w)\n        input_resized = input.repeat((nScale, 1, 1, 1, 1))\n        \n        d_phi = -torch.log2(1.0/torch.sqrt(2.0*np.pi*var_resized)*(torch.exp(-0.5*input_resized**2/var_resized))).sum(dim = [3, 4])\n        d_var = -torch.log2(phi_resized*(1.0/(np.sqrt(2.0*np.pi)*var_resized)*torch.exp(-0.5*input_resized**2/var_resized))*(1.0 + input_resized**2/var_resized)).sum(dim = [3, 4])\n        d_xq = -torch.log2((phi_resized*(-input_resized/torch.sqrt(2.0*np.pi*var_resized**3))*torch.exp(-0.5*input_resized**2/var_resized)).sum(dim=[0]))\n        print("d_xq : ", (phi_resized*(-input_resized/torch.sqrt(2.0*np.pi*var_resized**3))*torch.exp(-0.5*input_resized**2/var_resized)).sum(dim=[0]))\n        \n        return grad_output*d_phi, grad_output*d_var, grad_output*d_xq\n'

# %%
#Define the Convolutional Autoencoder with integrated classifer
    #taille de l'image d'entrée : 128*128
class LossyCompAutoencoder(nn.Module):
    def __init__(self):
        super(LossyCompAutoencoder, self).__init__()
       
        #Encoder
            # input block
        self.conv1 = nn.Conv2d(1, 64, 5, stride=2, padding=0)  
        self.conv2 = nn.Conv2d(64, 128, 5, stride=2, padding=0)
            # residual block 1
        self.resConv1_1 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.resConv1_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
            # residual block 2
        self.resConv2_1 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.resConv2_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
            # residual block 3
        self.resConv3_1 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.resConv3_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
            # output block
        self.conv3 = nn.Conv2d(128, 96, 5, stride=2, padding=0)
        self.quantization = MyQuantization.apply
        #self.gaussian_distribution = GaussianDistribution.apply
        

       
        #Decoder
            # subpixel 1
        self.subpix1 = nn.Conv2d(96, 512, 3, stride=1, padding=1)
            #residual block 1
        self.deconv1_1 = nn.Conv2d(512//4, 128, 3, stride=1, padding=1)
        self.deconv1_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)    
            #residual block 2
        self.deconv2_1 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.deconv2_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
            #residual block 3
        self.deconv3_1 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.deconv3_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1) 
            # subpixel 2
        self.subpix2 = nn.Conv2d(128, 256, 3, stride=1, padding=1)
            # subpixel 3
        self.subpix3 = nn.Conv2d(256//4, 4, 3, stride=1, padding=1)
            # clipping
        self.clip = MyClipping.apply
        
        #Bit-rate      
        self.var = nn.Parameter(torch.Tensor(6, 96))
        self.phi = nn.Parameter(torch.Tensor(6, 96))
        self.var.data.uniform_(0, 1)
        self.phi.data.uniform_(0, 1)
        
        # lambda (variable bit-rate)
        self.lamb = nn.Parameter(torch.Tensor(96).view(1, 96, 1, 1))
        self.lamb.data.uniform_(0.985, 1.015)
        
        # batch norm
        self.batchNormed = nn.BatchNorm2d(96, momentum = False, affine=False)
        
        """
        self.gsm_pi = torch.nn.Parameter(torch.randn(6, 96))
        self.gsm_sigma = torch.nn.Parameter(torch.randn(6, 96))
        """
    
    
    
    def forward(self, x, mask= 1, return_xq=False, is_lambda = False):
        if not is_lambda:
            #encoder
                # get zero mask
            #dilatation_mask = (x>0)
                # removing black pixels
            #x = black_pixels_removal_by_dilatation(x)
            #if torch.any(x.isnan()):
                #print("x after dilatation is nan", x)
                # normalization
            x, mean_channels, var = standardize_input(x)
            #x, radius, mean_channels = normalize_input(x)
            if torch.any(x.isnan()):
                print("x after normalization is nan", x)
                # mirror padding
            x = mirror_padding(x, 14)
            if torch.any(x.isnan()):
                print("x after mirror padding is nan", x)
            """
            with torch.no_grad():
                x_copy = x.cpu()
                show_image_batch(x_copy)
            """
                # input blocks
            x = F.relu(self.conv1(x))
            x = F.relu(self.conv2(x))
            x_c1 = x.clone()
            if torch.any(x.isnan()):
                print("x after input block is nan", x)
                print("mean channels : ", mean_channels)
                print("standard deviation : ", torch.sqrt(var))
                print("input weights conv 1 gradient: ", self.conv1.weight.grad)
                print("input bias conv 1 gradient: ",  self.conv1.bias.grad)
                print("input weights conv 2 gradient: ", self.conv2.weight.grad)
                print("input bias conv 2 gradient: ",  self.conv2.bias.grad)
                # residual block 1
            x = F.relu(self.resConv1_1(x))
            x = self.resConv1_2(x)
            x += x_c1
            x_c2 = x.clone()
            if torch.any(x.isnan()):
                print("x after residual block 1 is nan", x)
                print("residual block 1 weights gradient: ", self.resConv1_1.weight.grad)
                print("residual block 1 bias gradient: ",  self.resConv1_1.bias.grad)
                print("residual block 2 weight gradients: ", self.resConv1_2.weight.grad)
                print("residual block 2 bias gradient: ",  self.resConv1_2.bias.grad)
                # residual block 2
            x = F.relu(self.resConv2_1(x))
            x = self.resConv2_2(x)
            x += x_c2
            x_c3 = x.clone()
            if torch.any(x.isnan()):
                print("x after residual block 2 is nan", x)
                print("residual block 1 weights gradient: ", self.resConv2_1.weight.grad)
                print("residual block 1 bias gradient: ",  self.resConv2_1.bias.grad)
                print("residual block 2 weights gradient: ", self.resConv2_2.weight.grad)
                print("residual block 2 bias gradient: ",  self.resConv2_2.bias.grad)
                # residual block 3
            x = F.relu(self.resConv3_1(x))
            x = self.resConv3_2(x)
            x += x_c3
            if torch.any(x.isnan()):
                print("x after residual block 3 is nan", x)
                print("residual block 1 weights gradient: ", self.resConv3_1.weight.grad)
                print("residual block 1 bias gradient: ",  self.resConv3_1.bias.grad)
                print("residual block 2 weights gradient: ", self.resConv3_2.weight.grad)
                print("residual block 2 bias gradient: ",  self.resConv3_2.bias.grad)
                # output block
            x = self.conv3(x)
            if torch.any(x.isnan()):
                print("x after output block is nan", x)
                print("output weights gradient: ", self.conv3.weight.grad)
                print("output bias gradient: ",  self.conv3.bias.grad)
                # quantization
            x = self.quantization(x)
            if torch.any(x.isnan()):
                print("x after quantization block is nan", x)
                # add mask for incremental training
            x = x*mask
            x_quantized = x
            if torch.any(x.isnan()):
                print("x after mask is nan", x)


            """
            w = x_quantized.size()[2]
            h = x_quantized.size()[3]
            gsm = 0.0
            for i in range(6)
                mi = torch.flatten(x_quantized),torch.diagonal(self.gsm_sigma[s, :].repeat(w*h, 1).squeeze(0))
                gsm += 
            """


            #decoder
                # subpixel 1
            x = self.subpix1(x)
            x = periodic_shuffling(x, 512//4)
            x_c4 = x.clone()
            if torch.any(x.isnan()):
                print("x after subpix 1 is nan", x)
                # residual block 1
            x = F.relu(self.deconv1_1(x))
            x = self.deconv1_2(x)
            x += x_c4
            x_c5 = x.clone()
            if torch.any(x.isnan()):
                print("x after residual block 1 is nan", x)
                   # residual block 2
            x = F.relu(self.deconv2_1(x))
            x = self.deconv2_2(x)
            x += x_c5
            x_c6 = x.clone()
            if torch.any(x.isnan()):
                print("x after residual block 2 is nan", x)
                   # residual block 3
            x = F.relu(self.deconv3_1(x))
            x = self.deconv3_2(x)
            x += x_c6
            if torch.any(x.isnan()):
                print("x after residual block 3 is nan", x)
                    # subpixel 2
            x = self.subpix2(x)
            x = F.relu(periodic_shuffling(x, 256//4))
            if torch.any(x.isnan()):
                print("x after subpix 2 is nan", x)
                    # subpixel 3
            x = self.subpix3(x)
            x = periodic_shuffling(x, 4//4)
            if torch.any(x.isnan()):
                print("x after subpix 3 is nan", x)
                    # denormalization
            x = destandardize_output(x, mean_channels, var)
            #x = denormalize_output(x, radius, mean_channels)
            if torch.any(x.isnan()):
                print("x after denormalization is nan", x)
                    # clipping
            x = self.clip(x)
            if torch.any(x.isnan()):
                print("x after clipping is nan", x)
                    # replace black pixels
           # x = x*dilatation_mask


            if return_xq:
                return x, x_quantized
            else:
                return x
            
        else:
            with torch.no_grad():
                #encoder
                    # normalization
                x, mean_channels, var = standardize_input(x)
                    # mirror padding
                x = mirror_padding(x, 14)
                    # input blocks
                x = F.relu(self.conv1(x))
                x = F.relu(self.conv2(x))
                x_c1 = x.clone()
                    # residual block 1
                x = F.relu(self.resConv1_1(x))
                x = self.resConv1_2(x)
                x += x_c1
                x_c2 = x.clone()
                    # residual block 2
                x = F.relu(self.resConv2_1(x))
                x = self.resConv2_2(x)
                x += x_c2
                x_c3 = x.clone()
                    # residual block 3
                x = F.relu(self.resConv3_1(x))
                x = self.resConv3_2(x)
                x += x_c3
                    # output block
                x = self.conv3(x)
            # quantization with bit-rate variation
            x = self.quantization(x / self.lamb)
            x_quantized = x
            
            #decoder
            x = x*self.lamb
            # batch normalization
            x = self.batchNormed(x)
            with torch.no_grad():
                    # subpixel 1
                x = self.subpix1(x)
                x = periodic_shuffling(x, 512//4)
                x_c4 = x.clone()
                if torch.any(x.isnan()):
                    print("x after subpix 1 is nan", x)
                    print("subpix 1 weights gradient: ", self.subpix1.weight.grad)
                    print("subpix 1 bias gradient: ",  self.subpix1.bias.grad)
                    # residual block 1
                x = F.relu(self.deconv1_1(x))
                x = self.deconv1_2(x)
                x += x_c4
                x_c5 = x.clone()
                if torch.any(x.isnan()):
                    print("x after residual block 1 is nan", x)
                    print("deconv 1 weights gradient: ", self.deconv1_1.weight.grad)
                    print("deconv 1 bias gradient: ",  self.deconv1_1.bias.grad)
                    print("deconv 2 weights gradient: ", self.deconv1_2.weight.grad)
                    print("deconv 2 bias gradient: ",  self.deconv1_2.bias.grad)
                       # residual block 2
                x = F.relu(self.deconv2_1(x))
                x = self.deconv2_2(x)
                x += x_c5
                x_c6 = x.clone()
                if torch.any(x.isnan()):
                    print("x after residual block 2 is nan", x)
                    print("deconv 1 weights gradient: ", self.deconv2_1.weight.grad)
                    print("deconv 1 bias gradient: ",  self.deconv2_1.bias.grad)
                    print("deconv 2 weights gradient: ", self.deconv2_2.weight.grad)
                    print("deconv 2 bias gradient: ",  self.deconv2_2.bias.grad)
                       # residual block 3
                x = F.relu(self.deconv3_1(x))
                x = self.deconv3_2(x)
                x += x_c6
                if torch.any(x.isnan()):
                    print("x after residual block 3 is nan", x)
                    print("deconv 1 weights gradient: ", self.deconv3_1.weight.grad)
                    print("deconv 1 bias gradient: ",  self.deconv3_1.bias.grad)
                    print("deconv 2 weights gradient: ", self.deconv3_2.weight.grad)
                    print("deconv 2 bias gradient: ",  self.deconv3_2.bias.grad)
                        # subpixel 2
                x = self.subpix2(x)
                x = F.relu(periodic_shuffling(x, 256//4))
                if torch.any(x.isnan()):
                    print("x after subpix 2 is nan", x)
                    print("subpix 2 weights gradient: ", self.subpix2.weight.grad)
                    print("subpix 2 bias gradient: ",  self.subpix2.bias.grad)
                        # subpixel 3
                x = self.subpix3(x)
                x = periodic_shuffling(x, 4//4)
                if torch.any(x.isnan()):
                    print("x after subpix 3 is nan", x)
                    print("subpix 3 weights gradient: ", self.subpix3.weight.grad)
                    print("subpix 3 bias gradient: ",  self.subpix3.bias.grad)
                        # denormalization
                x = destandardize_output(x, mean_channels, var)
                if torch.any(x.isnan()):
                    print("x after denormalization is nan", x)
                        # clipping
                x = self.clip(x)
                if torch.any(x.isnan()):
                    print("x after clipping is nan", x)


                if return_xq:
                    return x, x_quantized
                else:
                    return x

# %%
#Define the Convolutional Autoencoder with integrated classifer
    #taille de l'image d'entrée : 128*128
class LossyCompAutoencoder_bis(nn.Module):
    def __init__(self):
        super(LossyCompAutoencoder_bis, self).__init__()
       
        #Encoder
            # input block
        self.conv1 = nn.Conv2d(1, 64, 5, stride=2, padding=0)  
        self.conv2 = nn.Conv2d(64, 128, 5, stride=2, padding=0)
            # residual block 1
        self.resConv1_1 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.resConv1_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
            # residual block 2
        self.resConv2_1 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.resConv2_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
            # residual block 3
        self.resConv3_1 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.resConv3_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
            # output block
        self.conv3 = nn.Conv2d(128, 96, 5, stride=2, padding=0)
        self.quantization = MyQuantization.apply
        #self.gaussian_distribution = GaussianDistribution.apply
        

       
        #Decoder
            # subpixel 1
        self.subpix1 = nn.Conv2d(96, 512, 3, stride=1, padding=1)
            #residual block 1
        self.deconv1_1 = nn.Conv2d(512//4, 128, 3, stride=1, padding=1)
        self.deconv1_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)    
            #residual block 2
        self.deconv2_1 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.deconv2_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
            #residual block 3
        self.deconv3_1 = nn.Conv2d(128, 128, 3, stride=1, padding=1)
        self.deconv3_2 = nn.Conv2d(128, 128, 3, stride=1, padding=1) 
            # subpixel 2
        self.subpix2 = nn.Conv2d(128, 256, 3, stride=1, padding=1)
            # subpixel 3
        self.subpix3 = nn.Conv2d(256//4, 4, 3, stride=1, padding=1)
            # clipping
        self.clip = MyClipping.apply
        
        #Bit-rate      
        self.var = nn.Parameter(torch.Tensor(6, 96))
        self.phi = nn.Parameter(torch.Tensor(6, 96))
        self.var.data.uniform_(0, 1)
        self.phi.data.uniform_(0, 1)
        
        # lambda (variable bit-rate)
        self.lamb = nn.Parameter(torch.Tensor(96).view(1, 96, 1, 1))
        self.lamb.data.uniform_(0.985, 1.015)
    
        
        """
        self.gsm_pi = torch.nn.Parameter(torch.randn(6, 96))
        self.gsm_sigma = torch.nn.Parameter(torch.randn(6, 96))
        """
    
    
    
    def forward(self, x, mask= 1, return_xq=False, is_lambda = False):
        if not is_lambda:
            #encoder
                # normalization
            x, mean_channels, var = standardize_input(x)
            if torch.any(x.isnan()):
                print("x after normalization is nan", x)
                # mirror padding
            x = mirror_padding(x, 14)
            if torch.any(x.isnan()):
                print("x after mirror padding is nan", x)
            """
            with torch.no_grad():
                x_copy = x.cpu()
                show_image_batch(x_copy)
            """
                # input blocks
            x = F.relu(self.conv1(x))
            x = F.relu(self.conv2(x))
            x_c1 = x.clone()
            if torch.any(x.isnan()):
                print("x after input block is nan", x)
                print("input weights conv 1 gradient: ", self.conv1.weight.grad)
                print("input bias conv 1 gradient: ",  self.conv1.bias.grad)
                print("input weights conv 2 gradient: ", self.conv2.weight.grad)
                print("input bias conv 2 gradient: ",  self.conv2.bias.grad)
                # residual block 1
            x = F.relu(self.resConv1_1(x))
            x = self.resConv1_2(x)
            x += x_c1
            x_c2 = x.clone()
            if torch.any(x.isnan()):
                print("x after residual block 1 is nan", x)
                print("residual block 1 weights gradient: ", self.resConv1_1.weight.grad)
                print("residual block 1 bias gradient: ",  self.resConv1_1.bias.grad)
                print("residual block 2 weights gradient: ", self.resConv1_2.weight.grad)
                print("residual block 2 bias gradient: ",  self.resConv1_2.bias.grad)
                # residual block 2
            x = F.relu(self.resConv2_1(x))
            x = self.resConv2_2(x)
            x += x_c2
            x_c3 = x.clone()
            if torch.any(x.isnan()):
                print("x after residual block 2 is nan", x)
                print("residual block 1 weights gradient: ", self.resConv2_1.weight.grad)
                print("residual block 1 bias gradient: ",  self.resConv2_1.bias.grad)
                print("residual block 2 weights gradient: ", self.resConv2_2.weight.grad)
                print("residual block 2 bias gradient: ",  self.resConv2_2.bias.grad)
                # residual block 3
            x = F.relu(self.resConv3_1(x))
            x = self.resConv3_2(x)
            x += x_c3
            if torch.any(x.isnan()):
                print("x after residual block 3 is nan", x)
                print("residual block 1 weights gradient: ", self.resConv3_1.weight.grad)
                print("residual block 1 bias gradient: ",  self.resConv3_1.bias.grad)
                print("residual block 2 weights gradient: ", self.resConv3_2.weight.grad)
                print("residual block 2 bias gradient: ",  self.resConv3_2.bias.grad)
                # output block
            x = self.conv3(x)
            if torch.any(x.isnan()):
                print("x after output block is nan", x)
                print("output weights gradient: ", self.conv3.weight.grad)
                print("output bias gradient: ",  self.conv3.bias.grad)
                # quantization
            x = self.quantization(x)
            if torch.any(x.isnan()):
                print("x after quantization block is nan", x)
                # add mask for incremental training
            x = x*mask
            x_quantized = x
            if torch.any(x.isnan()):
                print("x after mask is nan", x)


            """
            w = x_quantized.size()[2]
            h = x_quantized.size()[3]
            gsm = 0.0
            for i in range(6)
                mi = torch.flatten(x_quantized),torch.diagonal(self.gsm_sigma[s, :].repeat(w*h, 1).squeeze(0))
                gsm += 
            """


            #decoder
                # subpixel 1
            x = self.subpix1(x)
            x = periodic_shuffling(x, 512//4)
            x_c4 = x.clone()
            if torch.any(x.isnan()):
                print("x after subpix 1 is nan", x)
                print("subpix 1 weights gradient: ", self.subpix1.weight.grad)
                print("subpix 1 bias gradient: ",  self.subpix1.bias.grad)
                # residual block 1
            x = F.relu(self.deconv1_1(x))
            x = self.deconv1_2(x)
            x += x_c4
            x_c5 = x.clone()
            if torch.any(x.isnan()):
                print("x after residual block 1 is nan", x)
                print("deconv 1 weights gradient: ", self.deconv1_1.weight.grad)
                print("deconv 1 bias gradient: ",  self.deconv1_1.bias.grad)
                print("deconv 2 weights gradient: ", self.deconv1_2.weight.grad)
                print("deconv 2 bias gradient: ",  self.deconv1_2.bias.grad)
                   # residual block 2
            x = F.relu(self.deconv2_1(x))
            x = self.deconv2_2(x)
            x += x_c5
            x_c6 = x.clone()
            if torch.any(x.isnan()):
                print("x after residual block 2 is nan", x)
                print("deconv 1 weights gradient: ", self.deconv2_1.weight.grad)
                print("deconv 1 bias gradient: ",  self.deconv2_1.bias.grad)
                print("deconv 2 weights gradient: ", self.deconv2_2.weight.grad)
                print("deconv 2 bias gradient: ",  self.deconv2_2.bias.grad)
                   # residual block 3
            x = F.relu(self.deconv3_1(x))
            x = self.deconv3_2(x)
            x += x_c6
            if torch.any(x.isnan()):
                print("x after residual block 3 is nan", x)
                print("deconv 1 weights gradient: ", self.deconv3_1.weight.grad)
                print("deconv 1 bias gradient: ",  self.deconv3_1.bias.grad)
                print("deconv 2 weights gradient: ", self.deconv3_2.weight.grad)
                print("deconv 2 bias gradient: ",  self.deconv3_2.bias.grad)
                    # subpixel 2
            x = self.subpix2(x)
            x = F.relu(periodic_shuffling(x, 256//4))
            if torch.any(x.isnan()):
                print("x after subpix 2 is nan", x)
                print("subpix 2 weights gradient: ", self.subpix2.weight.grad)
                print("subpix 2 bias gradient: ",  self.subpix2.bias.grad)
                    # subpixel 3
            x = self.subpix3(x)
            x = periodic_shuffling(x, 4//4)
            if torch.any(x.isnan()):
                print("x after subpix 3 is nan", x)
                print("subpix 3 weights gradient: ", self.subpix3.weight.grad)
                print("subpix 3 bias gradient: ",  self.subpix3.bias.grad)
                    # denormalization
            x = destandardize_output(x, mean_channels, var)
            if torch.any(x.isnan()):
                print("x after denormalization is nan", x)
                    # clipping
            x = self.clip(x)
            if torch.any(x.isnan()):
                print("x after clipping is nan", x)


            if return_xq:
                return x, x_quantized
            else:
                return x
            
        else:
            with torch.no_grad():
                #encoder
                    # normalization
                x, mean_channels, var = standardize_input(x)
                    # mirror padding
                x = mirror_padding(x, 14)
                    # input blocks
                x = F.relu(self.conv1(x))
                x = F.relu(self.conv2(x))
                x_c1 = x.clone()
                    # residual block 1
                x = F.relu(self.resConv1_1(x))
                x = self.resConv1_2(x)
                x += x_c1
                x_c2 = x.clone()
                    # residual block 2
                x = F.relu(self.resConv2_1(x))
                x = self.resConv2_2(x)
                x += x_c2
                x_c3 = x.clone()
                    # residual block 3
                x = F.relu(self.resConv3_1(x))
                x = self.resConv3_2(x)
                x += x_c3
                    # output block
                x = self.conv3(x)
            # quantization with bit-rate variation
            x = self.quantization(x / self.lamb)
            x_quantized = x

            #decoder
            x = x*self.lamb
            with torch.no_grad():
                    # subpixel 1
                x = self.subpix1(x)
                x = periodic_shuffling(x, 512//4)
                x_c4 = x.clone()
                if torch.any(x.isnan()):
                    print("x after subpix 1 is nan", x)
                    # residual block 1
                x = F.relu(self.deconv1_1(x))
                x = self.deconv1_2(x)
                x += x_c4
                x_c5 = x.clone()
                if torch.any(x.isnan()):
                    print("x after residual block 1 is nan", x)
                       # residual block 2
                x = F.relu(self.deconv2_1(x))
                x = self.deconv2_2(x)
                x += x_c5
                x_c6 = x.clone()
                if torch.any(x.isnan()):
                    print("x after residual block 2 is nan", x)
                       # residual block 3
                x = F.relu(self.deconv3_1(x))
                x = self.deconv3_2(x)
                x += x_c6
                if torch.any(x.isnan()):
                    print("x after residual block 3 is nan", x)
                        # subpixel 2
                x = self.subpix2(x)
                x = F.relu(periodic_shuffling(x, 256//4))
                if torch.any(x.isnan()):
                    print("x after subpix 2 is nan", x)
                        # subpixel 3
                x = self.subpix3(x)
                x = periodic_shuffling(x, 4//4)
                if torch.any(x.isnan()):
                    print("x after subpix 3 is nan", x)
                        # denormalization
                x = destandardize_output(x, mean_channels, var)
                if torch.any(x.isnan()):
                    print("x after denormalization is nan", x)
                        # clipping
                x = self.clip(x)
                if torch.any(x.isnan()):
                    print("x after clipping is nan", x)


                if return_xq:
                    return x, x_quantized
                else:
                    return x

# %%
# instanciate the model
model = LossyCompAutoencoder()
print(model)
params = list(model.parameters())
print(len(params))
#print(params)
# Out:
# LossyCompAutoencoder(
#   (conv1): Conv2d(1, 64, kernel_size=(5, 5), stride=(2, 2))
#   (conv2): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2))
#   (resConv1_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (resConv1_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (resConv2_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (resConv2_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (resConv3_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (resConv3_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(128, 96, kernel_size=(5, 5), stride=(2, 2))
#   (subpix1): Conv2d(96, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv1_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv1_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv2_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv2_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv3_1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (deconv3_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (subpix2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (subpix3): Conv2d(64, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchNormed): BatchNorm2d(96, eps=1e-05, momentum=False, affine=False, track_running_stats=True)
# )
# 39

# %%
def get_device():
    if torch.cuda.is_available():
        device = 'cuda:0'
    else:
        device = 'cpu'
    return device

device = get_device()
print(device)
# Out:
# cuda:0

# %%
# transfert du model au gpu
model.to(device)

#define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.000001)

# define loss function
distortion = nn.MSELoss().cuda()
        
# incremental update of coefficients        

# define beta
beta = 0.00001
#beta = 1000
# define threshold and loss_init
threshold = 0.95
loss_init = float("Inf")
nb_ones = 1
iteration = 0
mask=(compute_mask(1, (96, 16, 16)).unsqueeze(0)).cuda()
dim_latent = 16*16*96
output_flag = False

#Epochs
n_epochs = 6150


# Training the network
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
    
    """
    if epoch==100:
        # define a new learning rate and so a new optimizer
        optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)
    """
        
    #Training
    for i_batch, data in enumerate(dataloader):
        batch_images = data.to(device).float()
        [decoded_images, x_quantized] = model(batch_images, mask, True)
        optimizer.zero_grad()
        loss_dist = distortion(decoded_images, batch_images)
        #loss_dist = distortion_pc(batch_images, decoded_images, 525.0, 0, 1000.0, (128, 128), (319.5, 239.5))
        loss_bit = mean_bit_per_px(x_quantized, model.phi, model.var)
        #print(" loss distortion : ", loss_dist)
        #print("loss bit : ", loss_bit)
        #loss = loss_dist + beta*loss_bit
        loss = beta * loss_dist + loss_bit
        #print(loss)
        
        # check the value of the loss to see if another coefficient can be enabled
        if (loss.item() < loss_init*threshold or iteration > 5):
            if (nb_ones<dim_latent):
                nb_ones +=1
                loss_init = loss.item()
                iteration = 0
                mask = (compute_mask(nb_ones, tuple(x_quantized.size()[1:])).unsqueeze(0)).cuda()
            else:
                output_flag = True
                break
            
        loss.backward()
        #print("input weights conv 1 gradient: ", model.conv1.weight.grad)
        #print("input bias conv 1 gradient: ",  model.conv1.bias.grad)
        #print("conv1.weights grad: ", params[0].grad)
        #print(model.conv1.bias.grad)
        #print(model.conv1.weight.grad)
        optimizer.step()
        running_loss += loss.item()
        iteration += 1

    if output_flag:
        break
    running_loss = running_loss/len(dataloader)
    print('running loss : {:.06f}'.format(running_loss), )
# Out:
# running loss : 13.574186
# running loss : 13.545779
# running loss : 13.733607
# running loss : 13.507847
# running loss : 13.794653
# running loss : 14.155087
# running loss : 14.022519
# running loss : 13.591774
# running loss : 13.682420
# running loss : 13.867489
# running loss : 12.858099
# running loss : 13.071085
# running loss : 13.430161
# running loss : 13.191773
# running loss : 11.594570
# running loss : 11.311149
# running loss : 10.604638
# running loss : 9.789255
# running loss : 9.396698
# running loss : 9.501484
# running loss : 8.829032
# running loss : 8.515666
# running loss : 8.283163
# running loss : 8.032286
# running loss : 8.042659
# running loss : 7.739768
# running loss : 7.801652
# running loss : 8.191579
# running loss : 7.540001
# running loss : 7.549880
# running loss : 7.330161
# running loss : 7.016886
# running loss : 7.013660
# running loss : 7.112467
# running loss : 6.757724
# running loss : 6.309311
# running loss : 6.064420
# running loss : 5.787879
# running loss : 5.392809
# running loss : 4.970421
# running loss : 4.933261
# running loss : 4.661197
# running loss : 4.586731
# running loss : 4.497531
# running loss : 4.525174
# running loss : 4.414532
# running loss : 4.290733
# running loss : 4.244780
# running loss : 4.191707
# running loss : 4.089558
# running loss : 4.024294
# running loss : 4.083173
# running loss : 4.110531
# running loss : 3.919553
# running loss : 3.890827
# running loss : 3.856819
# running loss : 3.896404
# running loss : 3.734670
# running loss : 3.728320
# running loss : 3.659964
# running loss : 3.739755
# running loss : 3.669708
# running loss : 3.586171
# running loss : 3.614186
# running loss : 3.561293
# running loss : 3.514030
# running loss : 3.456508
# running loss : 3.510511
# running loss : 3.470893
# running loss : 3.493481
# running loss : 3.397975
# running loss : 3.320192
# running loss : 3.334195
# running loss : 3.335760
# running loss : 3.333567
# running loss : 3.289507
# running loss : 3.256030
# running loss : 3.262893
# running loss : 3.309298
# running loss : 3.129098
# running loss : 3.271649
# running loss : 3.140293
# running loss : 3.084030
# running loss : 3.080236
# running loss : 3.147198
# running loss : 3.095487
# running loss : 3.071485
# running loss : 3.022891
# running loss : 3.016481
# running loss : 3.077909
# running loss : 2.971448
# running loss : 2.939082
# running loss : 2.957189
# running loss : 3.010697
# running loss : 2.925434
# running loss : 2.976372
# running loss : 2.858246
# running loss : 2.916997
# running loss : 2.840281
# running loss : 2.861239
# running loss : 2.818287
# running loss : 2.833024
# running loss : 2.867198
# running loss : 2.747022
# running loss : 2.802659
# running loss : 2.770487
# running loss : 2.737240
# running loss : 2.825995
# running loss : 2.746669
# running loss : 2.715413
# running loss : 2.799102
# running loss : 2.708939
# running loss : 2.718435
# running loss : 2.655279
# running loss : 2.684665
# running loss : 2.630648
# running loss : 2.612709
# running loss : 2.583935
# running loss : 2.624246
# running loss : 2.586940
# running loss : 2.590278
# running loss : 2.572405
# running loss : 2.556391
# running loss : 2.620333
# running loss : 2.599614
# running loss : 2.566791
# running loss : 2.500832
# running loss : 2.537495
# running loss : 2.538381
# running loss : 2.539701
# running loss : 2.517512
# running loss : 2.505596
# running loss : 2.515452
# running loss : 2.505214
# running loss : 2.509743
# running loss : 2.561185
# running loss : 2.485588
# running loss : 2.466539
# running loss : 2.469581
# running loss : 2.454177
# running loss : 2.455761
# running loss : 2.453864
# running loss : 2.438339
# running loss : 2.396520
# running loss : 2.421881
# running loss : 2.470802
# running loss : 2.365222
# running loss : 2.349103
# running loss : 2.379943
# running loss : 2.355630
# running loss : 2.368229
# running loss : 2.379787
# running loss : 2.358695
# running loss : 2.369811
# running loss : 2.339563
# running loss : 2.403522
# running loss : 2.386931
# running loss : 2.295425
# running loss : 2.349980
# running loss : 2.311255
# running loss : 2.289734
# running loss : 2.371073
# running loss : 2.271774
# running loss : 2.364036
# running loss : 2.277105
# running loss : 2.278673
# running loss : 2.256168
# running loss : 2.240026
# running loss : 2.241133
# running loss : 2.255009
# running loss : 2.245285
# running loss : 2.311204
# running loss : 2.240960
# running loss : 2.223698
# running loss : 2.164323
# running loss : 2.221717
# running loss : 2.207101
# running loss : 2.176187
# running loss : 2.167700
# running loss : 2.132134
# running loss : 2.170579
# running loss : 2.264006
# running loss : 2.137141
# running loss : 2.167693
# running loss : 2.131471
# running loss : 2.167061
# running loss : 2.158620
# running loss : 2.167337
# running loss : 2.123321
# running loss : 2.128604
# running loss : 2.125625
# running loss : 2.118485
# running loss : 2.156926
# running loss : 2.130767
# running loss : 2.133588
# running loss : 2.096403
# running loss : 2.102753
# running loss : 2.107564
# running loss : 2.081940
# running loss : 2.040876
# running loss : 2.051576
# running loss : 2.069492
# running loss : 2.108091
# running loss : 2.065237
# running loss : 2.042806
# running loss : 2.083699
# running loss : 2.079287
# running loss : 2.074737
# running loss : 2.095794
# running loss : 2.033500
# running loss : 2.105451
# running loss : 2.060965
# running loss : 2.018206
# running loss : 2.102100
# running loss : 2.037679
# running loss : 2.005697
# running loss : 2.018153
# running loss : 2.029618
# running loss : 1.996931
# running loss : 1.992442
# running loss : 2.024745
# running loss : 2.033580
# running loss : 2.049335
# running loss : 2.022279
# running loss : 2.105610
# running loss : 2.028098
# running loss : 1.980502
# running loss : 1.964282
# running loss : 1.998783
# running loss : 1.979776
# running loss : 2.015872
# running loss : 1.962071
# running loss : 1.969565
# running loss : 1.977047
# running loss : 1.968564
# running loss : 1.990537
# running loss : 1.932322
# running loss : 1.976064
# running loss : 1.993312
# running loss : 1.975791
# running loss : 1.970098
# running loss : 1.933017
# running loss : 1.938629
# running loss : 1.989558
# running loss : 1.924922
# running loss : 2.047744
# running loss : 1.933295
# running loss : 1.951964
# running loss : 1.915869
# running loss : 1.926095
# running loss : 1.944371
# running loss : 1.926783
# running loss : 1.915524
# running loss : 1.928456
# running loss : 1.939900
# running loss : 1.927669
# running loss : 1.932599
# running loss : 1.892937
# running loss : 1.901645
# running loss : 1.896455
# running loss : 1.945839
# running loss : 1.918633
# running loss : 1.899104
# running loss : 1.932234
# running loss : 1.952352
# running loss : 1.892569
# running loss : 1.873740
# running loss : 1.895420
# running loss : 1.926992
# running loss : 1.885611
# running loss : 1.892556
# running loss : 1.885257
# running loss : 1.884638
# running loss : 1.867379
# running loss : 1.910610
# running loss : 1.878051
# running loss : 1.868922
# running loss : 1.841607
# running loss : 1.892261
# running loss : 1.875812
# running loss : 1.855192
# running loss : 1.883574
# running loss : 1.887441
# running loss : 1.861368
# running loss : 1.880326
# running loss : 1.849506
# running loss : 1.802306
# running loss : 1.826490
# running loss : 1.845749
# running loss : 1.861179
# running loss : 1.833251
# running loss : 1.833629
# running loss : 1.848551
# running loss : 1.811213
# running loss : 1.870925
# running loss : 1.842254
# running loss : 1.829227
# running loss : 1.829530
# running loss : 1.808206
# running loss : 1.848196
# running loss : 1.866173
# running loss : 1.828152
# running loss : 1.884741
# running loss : 1.814093
# running loss : 1.825234
# running loss : 1.796314
# running loss : 1.815374
# running loss : 1.832072
# running loss : 1.817269
# running loss : 1.780653
# running loss : 1.795754
# running loss : 1.807793
# running loss : 1.812010
# running loss : 1.816484
# running loss : 1.813496
# running loss : 1.804127
# running loss : 1.865090
# running loss : 1.820266
# running loss : 1.783911
# running loss : 1.831785
# running loss : 1.787129
# running loss : 1.792182
# running loss : 1.789199
# running loss : 1.791098
# running loss : 1.772521
# running loss : 1.791996
# running loss : 1.783888
# running loss : 1.792815
# running loss : 1.783856
# running loss : 1.828561
# running loss : 1.798510
# running loss : 1.794769
# running loss : 1.744136
# running loss : 1.785053
# running loss : 1.786679
# running loss : 1.762157
# running loss : 1.775924
# running loss : 1.795204
# running loss : 1.763240
# running loss : 1.736973
# running loss : 1.775398
# running loss : 1.761923
# running loss : 1.751032
# running loss : 1.741717
# running loss : 1.738177
# running loss : 1.773023
# running loss : 1.740909
# running loss : 1.763698
# running loss : 1.740855
# running loss : 1.770755
# running loss : 1.749994
# running loss : 1.736951
# running loss : 1.724627
# running loss : 1.744531
# running loss : 1.753459
# running loss : 1.722716
# running loss : 1.712643
# running loss : 1.731873
# running loss : 1.706943
# running loss : 1.741716
# running loss : 1.721772
# running loss : 1.718857
# running loss : 1.700231
# running loss : 1.706244
# running loss : 1.704129
# running loss : 1.717135
# running loss : 1.708837
# running loss : 1.726539
# running loss : 1.696447
# running loss : 1.697387
# running loss : 1.723122
# running loss : 1.688848
# running loss : 1.720312
# running loss : 1.690090
# running loss : 1.701344
# running loss : 1.690273
# running loss : 1.717976
# running loss : 1.692098
# running loss : 1.682328
# running loss : 1.676579
# running loss : 1.672790
# running loss : 1.758767
# running loss : 1.674210
# running loss : 1.703892
# running loss : 1.682086
# running loss : 1.676226
# running loss : 1.676795
# running loss : 1.723740
# running loss : 1.660899
# running loss : 1.692403
# running loss : 1.690308
# running loss : 1.687000
# running loss : 1.719613
# running loss : 1.662664
# running loss : 1.668562
# running loss : 1.698786
# running loss : 1.659017
# running loss : 1.687147
# running loss : 1.682113
# running loss : 1.676566
# running loss : 1.664392
# running loss : 1.654279
# running loss : 1.671221
# running loss : 1.690217
# running loss : 1.676587
# running loss : 1.683144
# running loss : 1.720774
# running loss : 1.706553
# running loss : 1.670628
# running loss : 1.664397
# running loss : 1.651225
# running loss : 1.662431
# running loss : 1.645278
# running loss : 1.637290
# running loss : 1.655248
# running loss : 1.644611
# running loss : 1.645602
# running loss : 1.645209
# running loss : 1.657763
# running loss : 1.651957
# running loss : 1.638473
# running loss : 1.649534
# running loss : 1.630957
# running loss : 1.677648
# running loss : 1.647873
# running loss : 1.633997
# running loss : 1.670814
# running loss : 1.638003
# running loss : 1.643951
# running loss : 1.672003
# running loss : 1.643365
# running loss : 1.612057
# running loss : 1.618942
# running loss : 1.635748
# running loss : 1.665522
# running loss : 1.644398
# running loss : 1.647706
# running loss : 1.683810
# running loss : 1.637437
# running loss : 1.632328
# running loss : 1.647131
# running loss : 1.621007
# running loss : 1.612657
# running loss : 1.614418
# running loss : 1.669754
# running loss : 1.660903
# running loss : 1.629449
# running loss : 1.625356
# running loss : 1.609000
# running loss : 1.598245
# running loss : 1.659637
# running loss : 1.625846
# running loss : 1.643398
# running loss : 1.610708
# running loss : 1.633744
# running loss : 1.598890
# running loss : 1.613819
# running loss : 1.622004
# running loss : 1.612618
# running loss : 1.619703
# running loss : 1.580595
# running loss : 1.605792
# running loss : 1.589878
# running loss : 1.604338
# running loss : 1.632817
# running loss : 1.597641
# running loss : 1.589217
# running loss : 1.583248
# running loss : 1.628285
# running loss : 1.596480
# running loss : 1.596418
# running loss : 1.591679
# running loss : 1.604235
# running loss : 1.604456
# running loss : 1.562247
# running loss : 1.573012
# running loss : 1.603835
# running loss : 1.576399
# running loss : 1.606750
# running loss : 1.582119
# running loss : 1.582572
# running loss : 1.579646
# running loss : 1.617778
# running loss : 1.564864
# running loss : 1.595097
# running loss : 1.611030
# running loss : 1.606870
# running loss : 1.591094
# running loss : 1.603150
# running loss : 1.591120
# running loss : 1.578633
# running loss : 1.571645
# running loss : 1.612396
# running loss : 1.596936
# running loss : 1.630525
# running loss : 1.578168
# running loss : 1.561416
# running loss : 1.609000
# running loss : 1.555578
# running loss : 1.576121
# running loss : 1.561295
# running loss : 1.554415
# running loss : 1.609108
# running loss : 1.582715
# running loss : 1.550652
# running loss : 1.556516
# running loss : 1.563046
# running loss : 1.572286
# running loss : 1.590683
# running loss : 1.545679
# running loss : 1.559169
# running loss : 1.562973
# running loss : 1.550113
# running loss : 1.580977
# running loss : 1.598475
# running loss : 1.551830
# running loss : 1.571786
# running loss : 1.553420
# running loss : 1.599196
# running loss : 1.527259
# running loss : 1.521815
# running loss : 1.565964
# running loss : 1.575127
# running loss : 1.565478
# running loss : 1.587959
# running loss : 1.584977
# running loss : 1.552218
# running loss : 1.548494
# running loss : 1.536938
# running loss : 1.608281
# running loss : 1.600564
# running loss : 1.543347
# running loss : 1.539382
# running loss : 1.544710
# running loss : 1.529996
# running loss : 1.545992
# running loss : 1.526106
# running loss : 1.534553
# running loss : 1.526778
# running loss : 1.533681
# running loss : 1.530602
# running loss : 1.525344
# running loss : 1.532860
# running loss : 1.522521
# running loss : 1.545475
# running loss : 1.529923
# running loss : 1.512330
# running loss : 1.534363
# running loss : 1.543824
# running loss : 1.563022
# running loss : 1.527611
# running loss : 1.547615
# running loss : 1.533814
# running loss : 1.576335
# running loss : 1.521777
# running loss : 1.524742
# running loss : 1.532582
# running loss : 1.514523
# running loss : 1.539132
# running loss : 1.504892
# running loss : 1.504345
# running loss : 1.511460
# running loss : 1.520127
# running loss : 1.534570
# running loss : 1.537750
# running loss : 1.528066
# running loss : 1.530288
# running loss : 1.524146
# running loss : 1.496730
# running loss : 1.545243
# running loss : 1.515914
# running loss : 1.494499
# running loss : 1.510369
# running loss : 1.509881
# running loss : 1.518665
# running loss : 1.525651
# running loss : 1.513417
# running loss : 1.526273
# running loss : 1.498657
# running loss : 1.486287
# running loss : 1.498933
# running loss : 1.504687
# running loss : 1.500070
# running loss : 1.496471
# running loss : 1.507161
# running loss : 1.543588
# running loss : 1.495997
# running loss : 1.517653
# running loss : 1.494390
# running loss : 1.515346
# running loss : 1.495900
# running loss : 1.491241
# running loss : 1.573176
# running loss : 1.492944
# running loss : 1.486785
# running loss : 1.506056
# running loss : 1.497770
# running loss : 1.533663
# running loss : 1.515169
# running loss : 1.518266
# running loss : 1.486819
# running loss : 1.501236
# running loss : 1.500037
# running loss : 1.492586
# running loss : 1.487124
# running loss : 1.518911
# running loss : 1.524140
# running loss : 1.461739
# running loss : 1.491404
# running loss : 1.474642
# running loss : 1.486212
# running loss : 1.475700
# running loss : 1.483974
# running loss : 1.510107
# running loss : 1.490304
# running loss : 1.479532
# running loss : 1.499649
# running loss : 1.499843
# running loss : 1.510967
# running loss : 1.467985
# running loss : 1.507945
# running loss : 1.509745
# running loss : 1.517806
# running loss : 1.516259
# running loss : 1.477083
# running loss : 1.459400
# running loss : 1.505076
# running loss : 1.476837
# running loss : 1.474953
# running loss : 1.476420
# running loss : 1.466813
# running loss : 1.490181
# running loss : 1.536965
# running loss : 1.453046
# running loss : 1.498054
# running loss : 1.434656
# running loss : 1.460069
# running loss : 1.468371
# running loss : 1.444579
# running loss : 1.447068
# running loss : 1.468663
# running loss : 1.455868
# running loss : 1.443121
# running loss : 1.475536
# running loss : 1.461900
# running loss : 1.497690
# running loss : 1.452212
# running loss : 1.454495
# running loss : 1.470810
# running loss : 1.431437
# running loss : 1.451063
# running loss : 1.439560
# running loss : 1.462950
# running loss : 1.456377
# running loss : 1.459306
# running loss : 1.461798
# running loss : 1.428648
# running loss : 1.458842
# running loss : 1.419171
# running loss : 1.459110
# running loss : 1.438253
# running loss : 1.437350
# running loss : 1.455885
# running loss : 1.441265
# running loss : 1.430888
# running loss : 1.441477
# running loss : 1.430399
# running loss : 1.465077
# running loss : 1.450128
# running loss : 1.430387
# running loss : 1.428135
# running loss : 1.441987
# running loss : 1.443976
# running loss : 1.446256
# running loss : 1.451901
# running loss : 1.453109
# running loss : 1.440362
# running loss : 1.469201
# running loss : 1.443643
# running loss : 1.431952
# running loss : 1.451390
# running loss : 1.440252
# running loss : 1.429209
# running loss : 1.485316
# running loss : 1.434734
# running loss : 1.454545
# running loss : 1.428285
# running loss : 1.465916
# running loss : 1.437756
# running loss : 1.418503
# running loss : 1.443361
# running loss : 1.425670
# running loss : 1.433091
# running loss : 1.449863
# running loss : 1.451078
# running loss : 1.433773
# running loss : 1.417011
# running loss : 1.452299
# running loss : 1.438386
# running loss : 1.455488
# running loss : 1.407141
# running loss : 1.431281
# running loss : 1.435046
# running loss : 1.435346
# running loss : 1.438339
# running loss : 1.422883
# running loss : 1.424456
# running loss : 1.437267
# running loss : 1.409109
# running loss : 1.436579
# running loss : 1.409181
# running loss : 1.469997
# running loss : 1.427489
# running loss : 1.407916
# running loss : 1.418234
# running loss : 1.405667
# running loss : 1.406292
# running loss : 1.450723
# running loss : 1.429960
# running loss : 1.430961
# running loss : 1.417276
# running loss : 1.432345
# running loss : 1.431230
# running loss : 1.429464
# running loss : 1.421528
# running loss : 1.435502
# running loss : 1.399812
# running loss : 1.428501
# running loss : 1.410603
# running loss : 1.443155
# running loss : 1.415945
# running loss : 1.408904
# running loss : 1.444070
# running loss : 1.417192
# running loss : 1.413440
# running loss : 1.419471
# running loss : 1.422705
# running loss : 1.395498
# running loss : 1.434043
# running loss : 1.399284
# running loss : 1.417591
# running loss : 1.404841
# running loss : 1.402203
# running loss : 1.384630
# running loss : 1.394090
# running loss : 1.396733
# running loss : 1.396417
# running loss : 1.392347
# running loss : 1.395676
# running loss : 1.393564
# running loss : 1.415059
# running loss : 1.421642
# running loss : 1.392205
# running loss : 1.398600
# running loss : 1.386844
# running loss : 1.454718
# running loss : 1.405695
# running loss : 1.406393
# running loss : 1.409439
# running loss : 1.418536
# running loss : 1.408668
# running loss : 1.379977
# running loss : 1.383284
# running loss : 1.393049
# running loss : 1.370427
# running loss : 1.392193
# running loss : 1.395736
# running loss : 1.385070
# running loss : 1.428751
# running loss : 1.413446
# running loss : 1.407945
# running loss : 1.397095
# running loss : 1.399177
# running loss : 1.408072
# running loss : 1.371136
# running loss : 1.405561
# running loss : 1.393962
# running loss : 1.398901
# running loss : 1.415824
# running loss : 1.381867
# running loss : 1.389988
# running loss : 1.384050
# running loss : 1.365861
# running loss : 1.390773
# running loss : 1.385161
# running loss : 1.376034
# running loss : 1.385278
# running loss : 1.392006
# running loss : 1.378093
# running loss : 1.399237
# running loss : 1.381189
# running loss : 1.385729
# running loss : 1.378098
# running loss : 1.366019
# running loss : 1.378023
# running loss : 1.416234
# running loss : 1.380578
# running loss : 1.411714
# running loss : 1.402161
# running loss : 1.383686
# running loss : 1.375816
# running loss : 1.365571
# running loss : 1.390040
# running loss : 1.369332
# running loss : 1.362981
# running loss : 1.361894
# running loss : 1.391678
# running loss : 1.376641
# running loss : 1.368002
# running loss : 1.383505
# running loss : 1.393691
# running loss : 1.361072
# running loss : 1.396127
# running loss : 1.385008
# running loss : 1.364012
# running loss : 1.365121
# running loss : 1.378291
# running loss : 1.372176
# running loss : 1.385514
# running loss : 1.380179
# running loss : 1.384242
# running loss : 1.361981
# running loss : 1.368147
# running loss : 1.380310
# running loss : 1.353637
# running loss : 1.358362
# running loss : 1.358164
# running loss : 1.388310
# running loss : 1.362627
# running loss : 1.348096
# running loss : 1.352870
# running loss : 1.386163
# running loss : 1.365669
# running loss : 1.353905
# running loss : 1.373692
# running loss : 1.363005
# running loss : 1.351961
# running loss : 1.372111
# running loss : 1.346810
# running loss : 1.360010
# running loss : 1.363969
# running loss : 1.382763
# running loss : 1.369124
# running loss : 1.383966
# running loss : 1.385725
# running loss : 1.354049
# running loss : 1.360107
# running loss : 1.335608
# running loss : 1.355234
# running loss : 1.370716
# running loss : 1.366463
# running loss : 1.371955
# running loss : 1.354019
# running loss : 1.385824
# running loss : 1.350539
# running loss : 1.367395
# running loss : 1.357162
# running loss : 1.360495
# running loss : 1.375157
# running loss : 1.366977
# running loss : 1.342680
# running loss : 1.348914
# running loss : 1.367173
# running loss : 1.375342
# running loss : 1.336439
# running loss : 1.362499
# running loss : 1.338961
# running loss : 1.351320
# running loss : 1.347163
# running loss : 1.335197
# running loss : 1.329173
# running loss : 1.364634
# running loss : 1.325610
# running loss : 1.335111
# running loss : 1.351706
# running loss : 1.366787
# running loss : 1.332311
# running loss : 1.360826
# running loss : 1.332347
# running loss : 1.382490
# running loss : 1.363342
# running loss : 1.352658
# running loss : 1.368274
# running loss : 1.340336
# running loss : 1.337825
# running loss : 1.346927
# running loss : 1.341091
# running loss : 1.332642
# running loss : 1.339029
# running loss : 1.353251
# running loss : 1.323598
# running loss : 1.343791
# running loss : 1.355662
# running loss : 1.354322
# running loss : 1.364466
# running loss : 1.318971
# running loss : 1.312209
# running loss : 1.347330
# running loss : 1.321276
# running loss : 1.327569
# running loss : 1.357486
# running loss : 1.330124
# running loss : 1.339739
# running loss : 1.347894
# running loss : 1.326829
# running loss : 1.339182
# running loss : 1.323636
# running loss : 1.320818
# running loss : 1.349121
# running loss : 1.352560
# running loss : 1.333679
# running loss : 1.327594
# running loss : 1.332963
# running loss : 1.319655
# running loss : 1.326930
# running loss : 1.312350
# running loss : 1.356722
# running loss : 1.325409
# running loss : 1.319569
# running loss : 1.359156
# running loss : 1.336954
# running loss : 1.317330
# running loss : 1.334322
# running loss : 1.330305
# running loss : 1.325814
# running loss : 1.324556
# running loss : 1.311979
# running loss : 1.326276
# running loss : 1.331235
# running loss : 1.328039
# running loss : 1.319792
# running loss : 1.289757
# running loss : 1.326296
# running loss : 1.312775
# running loss : 1.305041
# running loss : 1.352892
# running loss : 1.320602
# running loss : 1.336955
# running loss : 1.313926
# running loss : 1.315833
# running loss : 1.318396
# running loss : 1.343640
# running loss : 1.371504
# running loss : 1.313775
# running loss : 1.313246
# running loss : 1.318093
# running loss : 1.336896
# running loss : 1.309169
# running loss : 1.317737
# running loss : 1.337715
# running loss : 1.316491
# running loss : 1.358855
# running loss : 1.329099
# running loss : 1.319845
# running loss : 1.319528
# running loss : 1.308978
# running loss : 1.312475
# running loss : 1.350956
# running loss : 1.316269
# running loss : 1.312210
# running loss : 1.311062
# running loss : 1.325650
# running loss : 1.311938
# running loss : 1.305346
# running loss : 1.304185
# running loss : 1.317313
# running loss : 1.336732
# running loss : 1.300825
# running loss : 1.306281
# running loss : 1.348239
# running loss : 1.317017
# running loss : 1.334070
# running loss : 1.301955
# running loss : 1.333499
# running loss : 1.293446
# running loss : 1.336404
# running loss : 1.322636
# running loss : 1.312505
# running loss : 1.307659
# running loss : 1.300682
# running loss : 1.333481
# running loss : 1.316483
# running loss : 1.310219
# running loss : 1.306891
# running loss : 1.293658
# running loss : 1.302843
# running loss : 1.306074
# running loss : 1.303313
# running loss : 1.317383
# running loss : 1.298017
# running loss : 1.299868
# running loss : 1.319848
# running loss : 1.335732
# running loss : 1.299292
# running loss : 1.322806
# running loss : 1.343057
# running loss : 1.326660
# running loss : 1.295825
# running loss : 1.302488
# running loss : 1.305835
# running loss : 1.311599
# running loss : 1.298647
# running loss : 1.280093
# running loss : 1.326825
# running loss : 1.296578
# running loss : 1.315441
# running loss : 1.299382
# running loss : 1.300586
# running loss : 1.326242
# running loss : 1.287782
# running loss : 1.295218
# running loss : 1.311392
# running loss : 1.299364
# running loss : 1.319422
# running loss : 1.302364
# running loss : 1.295740
# running loss : 1.288361
# running loss : 1.312828
# running loss : 1.301463
# running loss : 1.325542
# running loss : 1.299768
# running loss : 1.296153
# running loss : 1.308865
# running loss : 1.284571
# running loss : 1.310820
# running loss : 1.284614
# running loss : 1.290469
# running loss : 1.295038
# running loss : 1.314131
# running loss : 1.303092
# running loss : 1.302422
# running loss : 1.292444
# running loss : 1.300419
# running loss : 1.292881
# running loss : 1.285974
# running loss : 1.300803
# running loss : 1.287285
# running loss : 1.289642
# running loss : 1.298346
# running loss : 1.278335
# running loss : 1.294458
# running loss : 1.281099
# running loss : 1.300352
# running loss : 1.292358
# running loss : 1.286851
# running loss : 1.303225
# running loss : 1.295207
# running loss : 1.327620
# running loss : 1.291641
# running loss : 1.311726
# running loss : 1.311022
# running loss : 1.304955
# running loss : 1.290507
# running loss : 1.289830
# running loss : 1.320137
# running loss : 1.271374
# running loss : 1.333773
# running loss : 1.321831
# running loss : 1.307758
# running loss : 1.288431
# running loss : 1.268058
# running loss : 1.266073
# running loss : 1.293754
# running loss : 1.301272
# running loss : 1.285482
# running loss : 1.302818
# running loss : 1.287294
# running loss : 1.276935
# running loss : 1.273188
# running loss : 1.273002
# running loss : 1.267417
# running loss : 1.268825
# running loss : 1.295824
# running loss : 1.297121
# running loss : 1.297296
# running loss : 1.285539
# running loss : 1.278420
# running loss : 1.277419
# running loss : 1.275397
# running loss : 1.310258
# running loss : 1.308703
# running loss : 1.303557
# running loss : 1.287998
# running loss : 1.278987
# running loss : 1.284931
# running loss : 1.277646
# running loss : 1.303887
# running loss : 1.299875
# running loss : 1.290088
# running loss : 1.282375
# running loss : 1.270917
# running loss : 1.267962
# running loss : 1.278629
# running loss : 1.298007
# running loss : 1.290371
# running loss : 1.284715
# running loss : 1.274395
# running loss : 1.307441
# running loss : 1.276329
# running loss : 1.316053
# running loss : 1.289430
# running loss : 1.283882
# running loss : 1.266002
# running loss : 1.276998
# running loss : 1.288429
# running loss : 1.292282
# running loss : 1.274795
# running loss : 1.299108
# running loss : 1.281244
# running loss : 1.290223
# running loss : 1.313794
# running loss : 1.272452
# running loss : 1.267938
# running loss : 1.281972
# running loss : 1.263402
# running loss : 1.289712
# running loss : 1.292731
# running loss : 1.312650
# running loss : 1.259936
# running loss : 1.276153
# running loss : 1.276969
# running loss : 1.292054
# running loss : 1.285142
# running loss : 1.264694
# running loss : 1.269210
# running loss : 1.291379
# running loss : 1.270086
# running loss : 1.268603
# running loss : 1.313299
# running loss : 1.261297
# running loss : 1.277849
# running loss : 1.285378
# running loss : 1.271242
# running loss : 1.264169
# running loss : 1.289815
# running loss : 1.259993
# running loss : 1.314420
# running loss : 1.269354
# running loss : 1.276782
# running loss : 1.273200
# running loss : 1.262964
# running loss : 1.258760
# running loss : 1.273869
# running loss : 1.289448
# running loss : 1.291003
# running loss : 1.263952
# running loss : 1.272811
# running loss : 1.258879
# running loss : 1.276777
# running loss : 1.260521
# running loss : 1.277313
# running loss : 1.281645
# running loss : 1.277988
# running loss : 1.267665
# running loss : 1.272724
# running loss : 1.264944
# running loss : 1.275185
# running loss : 1.269700
# running loss : 1.253398
# running loss : 1.265678
# running loss : 1.270194
# running loss : 1.255767
# running loss : 1.257306
# running loss : 1.252402
# running loss : 1.279786
# running loss : 1.255487
# running loss : 1.270508
# running loss : 1.265760
# running loss : 1.253036
# running loss : 1.268728
# running loss : 1.265967
# running loss : 1.265903
# running loss : 1.252706
# running loss : 1.266187
# running loss : 1.243035
# running loss : 1.248388
# running loss : 1.263143
# running loss : 1.264283
# running loss : 1.261289
# running loss : 1.245262
# running loss : 1.265106
# running loss : 1.249220
# running loss : 1.261097
# running loss : 1.271731
# running loss : 1.257102
# running loss : 1.258415
# running loss : 1.270594
# running loss : 1.245004
# running loss : 1.284445
# running loss : 1.257665
# running loss : 1.268193
# running loss : 1.263508
# running loss : 1.269299
# running loss : 1.264935
# running loss : 1.240564
# running loss : 1.266963
# running loss : 1.246210
# running loss : 1.255548
# running loss : 1.275484
# running loss : 1.258761
# running loss : 1.259536
# running loss : 1.251867
# running loss : 1.278804
# running loss : 1.285130
# running loss : 1.246765
# running loss : 1.258920
# running loss : 1.261240
# running loss : 1.249492
# running loss : 1.276400
# running loss : 1.252837
# running loss : 1.276071
# running loss : 1.255484
# running loss : 1.242823
# running loss : 1.247395
# running loss : 1.260551
# running loss : 1.266795
# running loss : 1.272306
# running loss : 1.266411
# running loss : 1.235151
# running loss : 1.248862
# running loss : 1.250813
# running loss : 1.245502
# running loss : 1.264622
# running loss : 1.246857
# running loss : 1.246407
# running loss : 1.238510
# running loss : 1.254485
# running loss : 1.250911
# running loss : 1.275781
# running loss : 1.252906
# running loss : 1.244187
# running loss : 1.268841
# running loss : 1.235271
# running loss : 1.240663
# running loss : 1.258387
# running loss : 1.236634
# running loss : 1.254957
# running loss : 1.243893
# running loss : 1.268562
# running loss : 1.260191
# running loss : 1.248004
# running loss : 1.247051
# running loss : 1.269006
# running loss : 1.254977
# running loss : 1.250358
# running loss : 1.260495
# running loss : 1.245548
# running loss : 1.256144
# running loss : 1.242070
# running loss : 1.252927
# running loss : 1.240523
# running loss : 1.265039
# running loss : 1.230232
# running loss : 1.273221
# running loss : 1.233802
# running loss : 1.259594
# running loss : 1.237762
# running loss : 1.242523
# running loss : 1.250196
# running loss : 1.232120
# running loss : 1.240395
# running loss : 1.229852
# running loss : 1.239377
# running loss : 1.253075
# running loss : 1.222090
# running loss : 1.240807
# running loss : 1.238299
# running loss : 1.230665
# running loss : 1.234092
# running loss : 1.232690
# running loss : 1.246706
# running loss : 1.236324
# running loss : 1.276388
# running loss : 1.256019
# running loss : 1.225461
# running loss : 1.237220
# running loss : 1.244209
# running loss : 1.231949
# running loss : 1.245609
# running loss : 1.220571
# running loss : 1.247085
# running loss : 1.246748
# running loss : 1.220580
# running loss : 1.222484
# running loss : 1.250210
# running loss : 1.233166
# running loss : 1.232493
# running loss : 1.242871
# running loss : 1.228149
# running loss : 1.252293
# running loss : 1.229720
# running loss : 1.229690
# running loss : 1.234284
# running loss : 1.249870
# running loss : 1.232417
# running loss : 1.236034
# running loss : 1.216337
# running loss : 1.237461
# running loss : 1.217933
# running loss : 1.229813
# running loss : 1.221777
# running loss : 1.241348
# running loss : 1.233992
# running loss : 1.220831
# running loss : 1.248021
# running loss : 1.235881
# running loss : 1.219519
# running loss : 1.239492
# running loss : 1.224113
# running loss : 1.225602
# running loss : 1.223700
# running loss : 1.241296
# running loss : 1.234523
# running loss : 1.222374
# running loss : 1.238627
# running loss : 1.212267
# running loss : 1.222935
# running loss : 1.232226
# running loss : 1.213729
# running loss : 1.217171
# running loss : 1.230615
# running loss : 1.228060
# running loss : 1.217491
# running loss : 1.216998
# running loss : 1.254720
# running loss : 1.221859
# running loss : 1.212595
# running loss : 1.215651
# running loss : 1.207751
# running loss : 1.222195
# running loss : 1.230467
# running loss : 1.214811
# running loss : 1.234639
# running loss : 1.218311
# running loss : 1.229156
# running loss : 1.213488
# running loss : 1.200281
# running loss : 1.245642
# running loss : 1.216046
# running loss : 1.221882
# running loss : 1.207302
# running loss : 1.211114
# running loss : 1.228551
# running loss : 1.214306
# running loss : 1.202891
# running loss : 1.211553
# running loss : 1.217932
# running loss : 1.240122
# running loss : 1.212059
# running loss : 1.232652
# running loss : 1.209442
# running loss : 1.215293
# running loss : 1.225951
# running loss : 1.236224
# running loss : 1.223600
# running loss : 1.224285
# running loss : 1.219609
# running loss : 1.226290
# running loss : 1.203901
# running loss : 1.219571
# running loss : 1.223701
# running loss : 1.213821
# running loss : 1.207994
# running loss : 1.236013
# running loss : 1.218452
# running loss : 1.223172
# running loss : 1.222098
# running loss : 1.231651
# running loss : 1.218840
# running loss : 1.205077
# running loss : 1.204919
# running loss : 1.201649
# running loss : 1.218584
# running loss : 1.230733
# running loss : 1.220221
# running loss : 1.191019
# running loss : 1.185268
# running loss : 1.214523
# running loss : 1.221164
# running loss : 1.201769
# running loss : 1.221911
# running loss : 1.216890
# running loss : 1.197899
# running loss : 1.222366
# running loss : 1.196162
# running loss : 1.222124
# running loss : 1.195972
# running loss : 1.193031
# running loss : 1.218734
# running loss : 1.212877
# running loss : 1.203296
# running loss : 1.219620
# running loss : 1.191349
# running loss : 1.194188
# running loss : 1.218531
# running loss : 1.193846
# running loss : 1.210699
# running loss : 1.197321
# running loss : 1.195502
# running loss : 1.186920
# running loss : 1.217884
# running loss : 1.214616
# running loss : 1.224892
# running loss : 1.200037
# running loss : 1.199264
# running loss : 1.199409
# running loss : 1.206560
# running loss : 1.188112
# running loss : 1.206828
# running loss : 1.216155
# running loss : 1.203082
# running loss : 1.188386
# running loss : 1.203729
# running loss : 1.208467
# running loss : 1.188718
# running loss : 1.200558
# running loss : 1.189649
# running loss : 1.200848
# running loss : 1.201699
# running loss : 1.194863
# running loss : 1.211865
# running loss : 1.210423
# running loss : 1.190652
# running loss : 1.235723
# running loss : 1.214330
# running loss : 1.203396
# running loss : 1.210526
# running loss : 1.181340
# running loss : 1.191547
# running loss : 1.195951
# running loss : 1.211410
# running loss : 1.192342
# running loss : 1.204404
# running loss : 1.200850
# running loss : 1.187261
# running loss : 1.215830
# running loss : 1.193611
# running loss : 1.222930
# running loss : 1.198329
# running loss : 1.194773
# running loss : 1.200439
# running loss : 1.193500
# running loss : 1.203358
# running loss : 1.203643
# running loss : 1.220463
# running loss : 1.213748
# running loss : 1.183725
# running loss : 1.204729
# running loss : 1.201050
# running loss : 1.199420
# running loss : 1.225334
# running loss : 1.195552
# running loss : 1.191047
# running loss : 1.205371
# running loss : 1.196514
# running loss : 1.196666
# running loss : 1.194168
# running loss : 1.197061
# running loss : 1.205923
# running loss : 1.200497
# running loss : 1.193384
# running loss : 1.227021
# running loss : 1.178802
# running loss : 1.193303
# running loss : 1.188198
# running loss : 1.184553
# running loss : 1.204858
# running loss : 1.202908
# running loss : 1.192082
# running loss : 1.188680
# running loss : 1.197306
# running loss : 1.190667
# running loss : 1.212224
# running loss : 1.194992
# running loss : 1.205589
# running loss : 1.185266
# running loss : 1.180347
# running loss : 1.192181
# running loss : 1.179463
# running loss : 1.185095
# running loss : 1.197748
# running loss : 1.177140
# running loss : 1.163682
# running loss : 1.224611
# running loss : 1.188388
# running loss : 1.243246
# running loss : 1.177195
# running loss : 1.198710
# running loss : 1.192519
# running loss : 1.192350
# running loss : 1.185799
# running loss : 1.185552
# running loss : 1.192167
# running loss : 1.189036
# running loss : 1.204524
# running loss : 1.189819
# running loss : 1.177281
# running loss : 1.189125
# running loss : 1.183257
# running loss : 1.174992
# running loss : 1.203450
# running loss : 1.177596
# running loss : 1.177660
# running loss : 1.181942
# running loss : 1.219916
# running loss : 1.184973
# running loss : 1.207326
# running loss : 1.190128
# running loss : 1.185224
# running loss : 1.176643
# running loss : 1.174314
# running loss : 1.188376
# running loss : 1.180600
# running loss : 1.174730
# running loss : 1.186868
# running loss : 1.182106
# running loss : 1.171825
# running loss : 1.190551
# running loss : 1.198188
# running loss : 1.164070
# running loss : 1.169712
# running loss : 1.187804
# running loss : 1.185147
# running loss : 1.164930
# running loss : 1.173116
# running loss : 1.179055
# running loss : 1.174300
# running loss : 1.186790
# running loss : 1.160739
# running loss : 1.187457
# running loss : 1.180724
# running loss : 1.169067
# running loss : 1.170918
# running loss : 1.172852
# running loss : 1.169747
# running loss : 1.181707
# running loss : 1.180253
# running loss : 1.158911
# running loss : 1.159335
# running loss : 1.161114
# running loss : 1.159453
# running loss : 1.151578
# running loss : 1.157555
# running loss : 1.172256
# running loss : 1.189982
# running loss : 1.164747
# running loss : 1.155646
# running loss : 1.160565
# running loss : 1.154796
# running loss : 1.166836
# running loss : 1.167981
# running loss : 1.156907
# running loss : 1.172049
# running loss : 1.178709
# running loss : 1.152785
# running loss : 1.156245
# running loss : 1.156669
# running loss : 1.196488
# running loss : 1.162047
# running loss : 1.176079
# running loss : 1.161050
# running loss : 1.155215
# running loss : 1.147313
# running loss : 1.140534
# running loss : 1.178691
# running loss : 1.152016
# running loss : 1.152314
# running loss : 1.182738
# running loss : 1.151409
# running loss : 1.160758
# running loss : 1.162960
# running loss : 1.180125
# running loss : 1.147722
# running loss : 1.151614
# running loss : 1.163148
# running loss : 1.168160
# running loss : 1.165095
# running loss : 1.146003
# running loss : 1.172094
# running loss : 1.148089
# running loss : 1.153839
# running loss : 1.165426
# running loss : 1.153196
# running loss : 1.164610
# running loss : 1.179792
# running loss : 1.163723
# running loss : 1.155775
# running loss : 1.184651
# running loss : 1.169129
# running loss : 1.156432
# running loss : 1.152394
# running loss : 1.147678
# running loss : 1.158670
# running loss : 1.177971
# running loss : 1.144672
# running loss : 1.150413
# running loss : 1.132501
# running loss : 1.150841
# running loss : 1.136093
# running loss : 1.134035
# running loss : 1.141620
# running loss : 1.135355
# running loss : 1.135601
# running loss : 1.141807
# running loss : 1.155793
# running loss : 1.163740
# running loss : 1.181326
# running loss : 1.151173
# running loss : 1.145168
# running loss : 1.162098
# running loss : 1.158124
# running loss : 1.152038
# running loss : 1.160710
# running loss : 1.144570
# running loss : 1.134810
# running loss : 1.146724
# running loss : 1.141616
# running loss : 1.132342
# running loss : 1.140257
# running loss : 1.149807
# running loss : 1.147070
# running loss : 1.138178
# running loss : 1.165262
# running loss : 1.138114
# running loss : 1.133676
# running loss : 1.165618
# running loss : 1.134357
# running loss : 1.171346
# running loss : 1.136518
# running loss : 1.144854
# running loss : 1.150424
# running loss : 1.132630
# running loss : 1.144519
# running loss : 1.143012
# running loss : 1.143266
# running loss : 1.125134
# running loss : 1.142032
# running loss : 1.128779
# running loss : 1.131644
# running loss : 1.155294
# running loss : 1.157117
# running loss : 1.134291
# running loss : 1.172259
# running loss : 1.143300
# running loss : 1.130861
# running loss : 1.132745
# running loss : 1.148546
# running loss : 1.152013
# running loss : 1.145191
# running loss : 1.130155
# running loss : 1.146948
# running loss : 1.146492
# running loss : 1.129821
# running loss : 1.144072
# running loss : 1.141200
# running loss : 1.128655
# running loss : 1.130682
# running loss : 1.148216
# running loss : 1.139565
# running loss : 1.142797
# running loss : 1.146455
# running loss : 1.128976
# running loss : 1.136234
# running loss : 1.141511
# running loss : 1.123825
# running loss : 1.148491
# running loss : 1.132650
# running loss : 1.132978
# running loss : 1.133218
# running loss : 1.127482
# running loss : 1.131395
# running loss : 1.134338
# running loss : 1.127098
# running loss : 1.133702
# running loss : 1.142131
# running loss : 1.146915
# running loss : 1.148885
# running loss : 1.117337
# running loss : 1.145732
# running loss : 1.124459
# running loss : 1.135248
# running loss : 1.133408
# running loss : 1.123593
# running loss : 1.133690
# running loss : 1.131512
# running loss : 1.130834
# running loss : 1.127960
# running loss : 1.123925
# running loss : 1.136068
# running loss : 1.119331
# running loss : 1.128712
# running loss : 1.143308
# running loss : 1.140718
# running loss : 1.139003
# running loss : 1.141348
# running loss : 1.123024
# running loss : 1.133342
# running loss : 1.119566
# running loss : 1.128415
# running loss : 1.141027
# running loss : 1.117824
# running loss : 1.129003
# running loss : 1.114894
# running loss : 1.155891
# running loss : 1.138864
# running loss : 1.115752
# running loss : 1.144873
# running loss : 1.136459
# running loss : 1.113113
# running loss : 1.145606
# running loss : 1.116853
# running loss : 1.129267
# running loss : 1.139674
# running loss : 1.144641
# running loss : 1.136670
# running loss : 1.130272
# running loss : 1.131763
# running loss : 1.122309
# running loss : 1.134731
# running loss : 1.130685
# running loss : 1.112762
# running loss : 1.119227
# running loss : 1.119110
# running loss : 1.120323
# running loss : 1.115597
# running loss : 1.135387
# running loss : 1.154738
# running loss : 1.120519
# running loss : 1.138655
# running loss : 1.125824
# running loss : 1.115340
# running loss : 1.130306
# running loss : 1.119970
# running loss : 1.119808
# running loss : 1.132210
# running loss : 1.134114
# running loss : 1.131696
# running loss : 1.107795
# running loss : 1.147336
# running loss : 1.129460
# running loss : 1.115037
# running loss : 1.126238
# running loss : 1.153057
# running loss : 1.127973
# running loss : 1.142183
# running loss : 1.120263
# running loss : 1.116586
# running loss : 1.138366
# running loss : 1.126464
# running loss : 1.143295
# running loss : 1.147110
# running loss : 1.119264
# running loss : 1.131331
# running loss : 1.128189
# running loss : 1.125312
# running loss : 1.135566
# running loss : 1.146481
# running loss : 1.128062
# running loss : 1.122641
# running loss : 1.153336
# running loss : 1.130195
# running loss : 1.121398
# running loss : 1.124239
# running loss : 1.131696
# running loss : 1.159095
# running loss : 1.131714
# running loss : 1.117096
# running loss : 1.130882
# running loss : 1.116453
# running loss : 1.123765
# running loss : 1.128579
# running loss : 1.116153
# running loss : 1.124442
# running loss : 1.123334
# running loss : 1.117118
# running loss : 1.129645
# running loss : 1.112485
# running loss : 1.119552
# running loss : 1.131290
# running loss : 1.123942
# running loss : 1.134575
# running loss : 1.132220
# running loss : 1.146554
# running loss : 1.131742
# running loss : 1.114523
# running loss : 1.124779
# running loss : 1.127680
# running loss : 1.124841
# running loss : 1.106490
# running loss : 1.129919
# running loss : 1.113327
# running loss : 1.138798
# running loss : 1.127348
# running loss : 1.108486
# running loss : 1.123371
# running loss : 1.110355
# running loss : 1.153990
# running loss : 1.132043
# running loss : 1.164572
# running loss : 1.111080
# running loss : 1.129576
# running loss : 1.119218
# running loss : 1.124569
# running loss : 1.108700
# running loss : 1.127014
# running loss : 1.112862
# running loss : 1.112798
# running loss : 1.114230
# running loss : 1.126372
# running loss : 1.128866
# running loss : 1.128224
# running loss : 1.124478
# running loss : 1.126821
# running loss : 1.120568
# running loss : 1.119566
# running loss : 1.104061
# running loss : 1.146500
# running loss : 1.122314
# running loss : 1.128881
# running loss : 1.125130
# running loss : 1.111888
# running loss : 1.101561
# running loss : 1.118865
# running loss : 1.119146
# running loss : 1.104488
# running loss : 1.137652
# running loss : 1.154475
# running loss : 1.106399
# running loss : 1.119988
# running loss : 1.125354
# running loss : 1.135806
# running loss : 1.114457
# running loss : 1.110499
# running loss : 1.135797
# running loss : 1.106118
# running loss : 1.098687
# running loss : 1.105286
# running loss : 1.108304
# running loss : 1.108216
# running loss : 1.105491
# running loss : 1.109497
# running loss : 1.107064
# running loss : 1.121167
# running loss : 1.101563
# running loss : 1.108891
# running loss : 1.103727
# running loss : 1.113980
# running loss : 1.111470
# running loss : 1.107838
# running loss : 1.116203
# running loss : 1.093251
# running loss : 1.106023
# running loss : 1.104643
# running loss : 1.112780
# running loss : 1.122529
# running loss : 1.101717
# running loss : 1.126030
# running loss : 1.126947
# running loss : 1.110428
# running loss : 1.093987
# running loss : 1.122325
# running loss : 1.100172
# running loss : 1.128566
# running loss : 1.091934
# running loss : 1.095027
# running loss : 1.098241
# running loss : 1.131715
# running loss : 1.120658
# running loss : 1.122372
# running loss : 1.109786
# running loss : 1.100067
# running loss : 1.103213
# running loss : 1.111316
# running loss : 1.102858
# running loss : 1.096339
# running loss : 1.108074
# running loss : 1.101649
# running loss : 1.094768
# running loss : 1.114876
# running loss : 1.125910
# running loss : 1.118624
# running loss : 1.127620
# running loss : 1.099574
# running loss : 1.108794
# running loss : 1.114343
# running loss : 1.097086
# running loss : 1.103612
# running loss : 1.112299
# running loss : 1.114834
# running loss : 1.101931
# running loss : 1.099808
# running loss : 1.090388
# running loss : 1.121260
# running loss : 1.099250
# running loss : 1.095619
# running loss : 1.098963
# running loss : 1.094663
# running loss : 1.092304
# running loss : 1.094488
# running loss : 1.086758
# running loss : 1.111568
# running loss : 1.105377
# running loss : 1.103548
# running loss : 1.101038
# running loss : 1.098287
# running loss : 1.099042
# running loss : 1.101476
# running loss : 1.090994
# running loss : 1.113949
# running loss : 1.111600
# running loss : 1.103155
# running loss : 1.090784
# running loss : 1.085529
# running loss : 1.080182
# running loss : 1.096264
# running loss : 1.108028
# running loss : 1.104337
# running loss : 1.095390
# running loss : 1.105973
# running loss : 1.097786
# running loss : 1.103651
# running loss : 1.101748
# running loss : 1.119259
# running loss : 1.090492
# running loss : 1.104688
# running loss : 1.105224
# running loss : 1.109636
# running loss : 1.101725
# running loss : 1.095688
# running loss : 1.120004
# running loss : 1.099233
# running loss : 1.076559
# running loss : 1.093564
# running loss : 1.071759
# running loss : 1.068593
# running loss : 1.098736
# running loss : 1.069380
# running loss : 1.069493
# running loss : 1.107486
# running loss : 1.083439
# running loss : 1.084732
# running loss : 1.100867
# running loss : 1.080521
# running loss : 1.090890
# running loss : 1.089196
# running loss : 1.075678
# running loss : 1.085336
# running loss : 1.079716
# running loss : 1.086632
# running loss : 1.081114
# running loss : 1.079329
# running loss : 1.084942
# running loss : 1.078740
# running loss : 1.076904
# running loss : 1.091506
# running loss : 1.091677
# running loss : 1.072796
# running loss : 1.074600
# running loss : 1.082139
# running loss : 1.087497
# running loss : 1.083020
# running loss : 1.078690
# running loss : 1.087676
# running loss : 1.093991
# running loss : 1.085101
# running loss : 1.082570
# running loss : 1.074764
# running loss : 1.115499
# running loss : 1.081889
# running loss : 1.088602
# running loss : 1.084883
# running loss : 1.076787
# running loss : 1.072929
# running loss : 1.081270
# running loss : 1.074642
# running loss : 1.092482
# running loss : 1.077719
# running loss : 1.080542
# running loss : 1.079391
# running loss : 1.062746
# running loss : 1.099079
# running loss : 1.055145
# running loss : 1.083528
# running loss : 1.077377
# running loss : 1.084185
# running loss : 1.073835
# running loss : 1.073007
# running loss : 1.065107
# running loss : 1.074255
# running loss : 1.071573
# running loss : 1.065554
# running loss : 1.070703
# running loss : 1.075465
# running loss : 1.078744
# running loss : 1.060903
# running loss : 1.076594
# running loss : 1.056573
# running loss : 1.071008
# running loss : 1.066175
# ...
# running loss : 0.930404
# running loss : 0.909344
# running loss : 0.911901
# running loss : 0.930034
# running loss : 0.907693
# running loss : 0.915930
# running loss : 0.919119
# running loss : 0.902653
# running loss : 0.933586
# running loss : 0.916577
# running loss : 0.940421
# running loss : 0.914286
# running loss : 0.906169
# running loss : 0.920298
# running loss : 0.933255
# running loss : 0.916829
# running loss : 0.917650
# running loss : 0.920359
# running loss : 0.903991
# running loss : 0.930017
# running loss : 0.899793
# running loss : 0.918015
# running loss : 0.898239
# running loss : 0.901180
# running loss : 0.916808
# running loss : 0.913059
# running loss : 0.906518
# running loss : 0.916312
# running loss : 0.912340
# running loss : 0.910764
# running loss : 0.917308
# running loss : 0.909528
# running loss : 0.920142
# running loss : 0.911524
# running loss : 0.928599
# running loss : 0.905827
# running loss : 0.893559
# running loss : 0.915412
# running loss : 0.915507
# running loss : 0.909107
# running loss : 0.915741
# running loss : 0.901940
# running loss : 0.914980
# running loss : 0.910466
# running loss : 0.905359
# running loss : 0.903308
# running loss : 0.907841
# running loss : 0.913136
# running loss : 0.918938
# running loss : 0.907490
# running loss : 0.908431
# running loss : 0.920978
# running loss : 0.913771
# running loss : 0.914631
# running loss : 0.902159
# running loss : 0.913185
# running loss : 0.905790
# running loss : 0.904455
# running loss : 0.899317
# running loss : 0.922094
# running loss : 0.907965
# running loss : 0.895221
# running loss : 0.919707
# running loss : 0.908540
# running loss : 0.910272
# running loss : 0.919696
# running loss : 0.909427
# running loss : 0.906907
# running loss : 0.901834
# running loss : 0.895062
# running loss : 0.926166
# running loss : 0.911047
# running loss : 0.920530
# running loss : 0.888158
# running loss : 0.900561
# running loss : 0.901625
# running loss : 0.895138
# running loss : 0.933793
# running loss : 0.910896
# running loss : 0.905402
# running loss : 0.916081
# running loss : 0.912371
# running loss : 0.893459
# running loss : 0.899121
# running loss : 0.905052
# running loss : 0.893837
# running loss : 0.897911
# running loss : 0.906012
# running loss : 0.896443
# running loss : 0.900838
# running loss : 0.896696
# running loss : 0.937035
# running loss : 0.891556
# running loss : 0.902840
# running loss : 0.892554
# running loss : 0.914584
# running loss : 0.898906
# running loss : 0.897157
# running loss : 0.895135
# running loss : 0.908307
# running loss : 0.918773
# running loss : 0.911161
# running loss : 0.900198
# running loss : 0.893621
# running loss : 0.900462
# running loss : 0.921243
# running loss : 0.890139
# running loss : 0.896533
# running loss : 0.898686
# running loss : 0.894970
# running loss : 0.901962
# running loss : 0.916359
# running loss : 0.902929
# running loss : 0.903069
# running loss : 0.902987
# running loss : 0.895637
# running loss : 0.891671
# running loss : 0.908178
# running loss : 0.903961
# running loss : 0.920831
# running loss : 0.903126
# running loss : 0.903523
# running loss : 0.899283
# running loss : 0.901564
# running loss : 0.899604
# running loss : 0.898850
# running loss : 0.893086
# running loss : 0.916403
# running loss : 0.902098
# running loss : 0.909998
# running loss : 0.890126
# running loss : 0.910016
# running loss : 0.896363
# running loss : 0.917351
# running loss : 0.907861
# running loss : 0.890675
# running loss : 0.904016
# running loss : 0.893060
# running loss : 0.899986
# running loss : 0.907631
# running loss : 0.913161
# running loss : 0.906976
# running loss : 0.896852
# running loss : 0.908946
# running loss : 0.890772
# running loss : 0.904858
# running loss : 0.902373
# running loss : 0.889920
# running loss : 0.889717
# running loss : 0.890657
# running loss : 0.892300
# running loss : 0.895600
# running loss : 0.907249
# running loss : 0.899800
# running loss : 0.886515
# running loss : 0.895054
# running loss : 0.910738
# running loss : 0.890260
# running loss : 0.907143
# running loss : 0.886626
# running loss : 0.894748
# running loss : 0.892220
# running loss : 0.890248
# running loss : 0.908372
# running loss : 0.891497
# running loss : 0.893764
# running loss : 0.895609
# running loss : 0.896516
# running loss : 0.886517
# running loss : 0.884247
# running loss : 0.894781
# running loss : 0.889991
# running loss : 0.885803
# running loss : 0.895169
# running loss : 0.899558
# running loss : 0.887390
# running loss : 0.904158
# running loss : 0.901054
# running loss : 0.901356
# running loss : 0.892937
# running loss : 0.901888
# running loss : 0.883763
# running loss : 0.889189
# running loss : 0.879662
# running loss : 0.879654
# running loss : 0.889692
# running loss : 0.881433
# running loss : 0.905332
# running loss : 0.881444
# running loss : 0.892542
# running loss : 0.899410
# running loss : 0.886976
# running loss : 0.896015
# running loss : 0.939558
# running loss : 0.893658
# running loss : 0.904645
# running loss : 0.894781
# running loss : 0.875676
# running loss : 0.894434
# running loss : 0.882880
# running loss : 0.899301
# running loss : 0.897730
# running loss : 0.890153
# running loss : 0.892690
# running loss : 0.888432
# running loss : 0.900199
# running loss : 0.887515
# running loss : 0.889246
# running loss : 0.874570
# running loss : 0.901136
# running loss : 0.893607
# running loss : 0.891614
# running loss : 0.890977
# running loss : 0.886065
# running loss : 0.883575
# running loss : 0.883858
# running loss : 0.882349
# running loss : 0.900603
# running loss : 0.889884
# running loss : 0.906565
# running loss : 0.890911
# running loss : 0.879605
# running loss : 0.888929
# running loss : 0.880233
# running loss : 0.887517
# running loss : 0.879773
# running loss : 0.900390
# running loss : 0.910868
# running loss : 0.895800
# running loss : 0.885813
# running loss : 0.876253
# running loss : 0.884493
# running loss : 0.889402
# running loss : 0.883580
# running loss : 0.879795
# running loss : 0.879124
# running loss : 0.880666
# running loss : 0.888192
# running loss : 0.889533
# running loss : 0.881985
# running loss : 0.886188
# running loss : 0.880670
# running loss : 0.896774
# running loss : 0.877685
# running loss : 0.881712
# running loss : 0.879521
# running loss : 0.887046
# running loss : 0.900815
# running loss : 0.881995
# running loss : 0.898607
# running loss : 0.883552
# running loss : 0.884959
# running loss : 0.895825
# running loss : 0.892233
# running loss : 0.877429
# running loss : 0.879698
# running loss : 0.902164
# running loss : 0.880009
# running loss : 0.877965
# running loss : 0.893130
# running loss : 0.888912
# running loss : 0.868769
# running loss : 0.896390
# running loss : 0.934512
# running loss : 0.911628
# running loss : 0.915346
# running loss : 0.880796
# running loss : 0.886666
# running loss : 0.894593
# running loss : 0.878323
# running loss : 0.877508
# running loss : 0.885618
# running loss : 0.904156
# running loss : 0.898083
# running loss : 0.874172
# running loss : 0.885016
# running loss : 0.890989
# running loss : 0.873518
# running loss : 0.880810
# running loss : 0.873630
# running loss : 0.883013
# running loss : 0.877039
# running loss : 0.901434
# running loss : 0.863800
# running loss : 0.872598
# running loss : 0.883932
# running loss : 0.882010
# running loss : 0.865971
# running loss : 0.884333
# running loss : 0.887502
# running loss : 0.880367
# running loss : 0.866851
# running loss : 0.885694
# running loss : 0.879685
# running loss : 0.886565
# running loss : 0.893670
# running loss : 0.882386
# running loss : 0.891116
# running loss : 0.880218
# running loss : 0.895314
# running loss : 0.904714
# running loss : 0.871695
# running loss : 0.874772
# running loss : 0.884359
# running loss : 0.878985
# running loss : 0.884790
# running loss : 0.887124
# running loss : 0.877119
# running loss : 0.881020
# running loss : 0.886310
# running loss : 0.908337
# running loss : 0.889140
# running loss : 0.885785
# running loss : 0.870979
# running loss : 0.867202
# running loss : 0.885963
# running loss : 0.869314
# running loss : 0.877707
# running loss : 0.874997
# running loss : 0.878658
# running loss : 0.869365
# running loss : 0.880780
# running loss : 0.870932
# running loss : 0.881686
# running loss : 0.871085
# running loss : 0.875590
# running loss : 0.880330
# running loss : 0.878462
# running loss : 0.880973
# running loss : 0.892782
# running loss : 0.869961
# running loss : 0.880782
# running loss : 0.872773
# running loss : 0.870442
# running loss : 0.870801
# running loss : 0.879088
# running loss : 0.869668
# running loss : 0.879317
# running loss : 0.866440
# running loss : 0.868120
# running loss : 0.881930
# running loss : 0.865800
# running loss : 0.865179
# running loss : 0.871163
# running loss : 0.864993
# running loss : 0.874320
# running loss : 0.866574
# running loss : 0.872189
# running loss : 0.875289
# running loss : 0.881361
# running loss : 0.887368
# running loss : 0.864964
# running loss : 0.869140
# running loss : 0.886216
# running loss : 0.880936
# running loss : 0.874622
# running loss : 0.887245
# running loss : 0.882646
# running loss : 0.879774
# running loss : 0.870417
# running loss : 0.887543
# running loss : 0.889451
# running loss : 0.867953
# running loss : 0.871515
# running loss : 0.867737
# running loss : 0.871592
# running loss : 0.868141
# running loss : 0.876133
# running loss : 0.869681
# running loss : 0.874193
# running loss : 0.866001
# running loss : 0.871826
# running loss : 0.869842
# running loss : 0.886887
# running loss : 0.870325
# running loss : 0.880667
# running loss : 0.871434
# running loss : 0.909168
# running loss : 0.865646
# running loss : 0.879470
# running loss : 0.890747
# running loss : 0.892343
# running loss : 0.893325
# running loss : 0.872622
# running loss : 0.856447
# running loss : 0.877736
# running loss : 0.854435
# running loss : 0.877383
# running loss : 0.863402
# running loss : 0.869864
# running loss : 0.870971
# running loss : 0.863107
# running loss : 0.868560
# running loss : 0.870679
# running loss : 0.868997
# running loss : 0.880763
# running loss : 0.869783
# running loss : 0.868154
# running loss : 0.874048
# running loss : 0.861441
# running loss : 0.860841
# running loss : 0.870923
# running loss : 0.870750
# running loss : 0.859800
# running loss : 0.895199
# running loss : 0.864663
# running loss : 0.867815
# running loss : 0.875589
# running loss : 0.877249
# running loss : 0.891404
# running loss : 0.869079
# running loss : 0.872401
# running loss : 0.872175
# running loss : 0.866474
# running loss : 0.883760
# running loss : 0.866169
# running loss : 0.870225
# running loss : 0.882080
# running loss : 0.866066
# running loss : 0.874219
# running loss : 0.864899
# running loss : 0.865070
# running loss : 0.891896
# running loss : 0.869277
# running loss : 0.864316
# running loss : 0.864534
# running loss : 0.868354
# running loss : 0.867539
# running loss : 0.865087
# running loss : 0.868389
# running loss : 0.864357
# running loss : 0.882197
# running loss : 0.874934
# running loss : 0.894696
# running loss : 0.872145
# running loss : 0.892641
# running loss : 0.870567
# running loss : 0.865522
# running loss : 0.896790
# running loss : 0.876790
# running loss : 0.869847
# running loss : 0.879645
# running loss : 0.879563
# running loss : 0.866959
# running loss : 0.862774
# running loss : 0.860153
# running loss : 0.871583
# running loss : 0.871064
# running loss : 0.872761
# running loss : 0.869754
# running loss : 0.872161
# running loss : 0.859022
# running loss : 0.863717
# running loss : 0.872366
# running loss : 0.864781
# running loss : 0.880034
# running loss : 0.864805
# running loss : 0.862385
# running loss : 0.859579
# running loss : 0.872355
# running loss : 0.863293
# running loss : 0.858884
# running loss : 0.878997
# running loss : 0.871279
# running loss : 0.866986
# running loss : 0.880697
# running loss : 0.876322
# running loss : 0.855797
# running loss : 0.867639
# running loss : 0.873091
# running loss : 0.873540
# running loss : 0.857956
# running loss : 0.864401
# running loss : 0.878044
# running loss : 0.879831
# running loss : 0.857095
# running loss : 0.870504
# running loss : 0.879468
# running loss : 0.875775
# running loss : 0.858115
# running loss : 0.879505
# running loss : 0.855472
# running loss : 0.878624
# running loss : 0.863743
# running loss : 0.874000
# running loss : 0.865812
# running loss : 0.865746
# running loss : 0.868064
# running loss : 0.880061
# running loss : 0.881310
# running loss : 0.856048
# running loss : 0.870465
# running loss : 0.866334
# running loss : 0.875430
# running loss : 0.856677
# running loss : 0.859542
# running loss : 0.871764
# running loss : 0.854036
# running loss : 0.863338
# running loss : 0.861732
# running loss : 0.847938
# running loss : 0.863573
# running loss : 0.875962
# running loss : 0.866145
# running loss : 0.860468
# running loss : 0.860101
# running loss : 0.854264
# running loss : 0.849782
# running loss : 0.875650
# running loss : 0.880424
# running loss : 0.861183
# running loss : 0.860602
# running loss : 0.864006
# running loss : 0.862336
# running loss : 0.862503
# running loss : 0.849530
# running loss : 0.857452
# running loss : 0.855260
# running loss : 0.852045
# running loss : 0.864614
# running loss : 0.856598
# running loss : 0.849560
# running loss : 0.861797
# running loss : 0.901036
# running loss : 0.876531
# running loss : 0.856893
# running loss : 0.887778
# running loss : 0.863686
# running loss : 0.877234
# running loss : 0.883301
# running loss : 0.899134
# running loss : 0.869435
# running loss : 0.859639
# running loss : 0.878384
# running loss : 0.870135
# running loss : 0.864838
# running loss : 0.866420
# running loss : 0.878815
# running loss : 0.868964
# running loss : 0.860506
# running loss : 0.865913
# running loss : 0.861841
# running loss : 0.871846
# running loss : 0.871422
# running loss : 0.847997
# running loss : 0.871702
# running loss : 0.882493
# running loss : 0.867396
# running loss : 0.871174
# running loss : 0.883650
# running loss : 0.866909
# running loss : 0.867651
# running loss : 0.863149
# running loss : 0.879406
# running loss : 0.858335
# running loss : 0.892006
# running loss : 0.870448
# running loss : 0.866554
# running loss : 0.870150
# running loss : 0.881155
# running loss : 0.851349
# running loss : 0.881733
# running loss : 0.866928
# running loss : 0.871750
# running loss : 0.857524
# running loss : 0.874921
# running loss : 0.867286
# running loss : 0.869520
# running loss : 0.855579
# running loss : 0.853603
# running loss : 0.876271
# running loss : 0.869179
# running loss : 0.852665
# running loss : 0.873819
# running loss : 0.862232
# running loss : 0.859272
# running loss : 0.860800
# running loss : 0.869162
# running loss : 0.887196
# running loss : 0.866840
# running loss : 0.856831
# running loss : 0.852026
# running loss : 0.860009
# running loss : 0.869533
# running loss : 0.861166
# running loss : 0.867809
# running loss : 0.848142
# running loss : 0.853339
# running loss : 0.861052
# running loss : 0.875606
# running loss : 0.851786
# running loss : 0.867217
# running loss : 0.855561
# running loss : 0.862845
# running loss : 0.845832
# running loss : 0.862744
# running loss : 0.869999
# running loss : 0.850623
# running loss : 0.849238
# running loss : 0.863937
# running loss : 0.863141
# running loss : 0.860791
# running loss : 0.861094
# running loss : 0.869315
# running loss : 0.854373
# running loss : 0.850094
# running loss : 0.844927
# running loss : 0.871413
# running loss : 0.852072
# running loss : 0.843997
# running loss : 0.861769
# running loss : 0.854839
# running loss : 0.849963
# running loss : 0.845113
# running loss : 0.861281
# running loss : 0.851354
# running loss : 0.860069
# running loss : 0.869050
# running loss : 0.843362
# running loss : 0.864837
# running loss : 0.864753
# running loss : 0.853396
# running loss : 0.849424
# running loss : 0.844144
# running loss : 0.874883
# running loss : 0.860429
# running loss : 0.846989
# running loss : 0.853570
# running loss : 0.871509
# running loss : 0.853591
# running loss : 0.838358
# running loss : 0.863210
# running loss : 0.851404
# running loss : 0.844459
# running loss : 0.893911
# running loss : 0.857910
# running loss : 0.849239
# running loss : 0.847136
# running loss : 0.856696
# running loss : 0.847167
# running loss : 0.865459
# running loss : 0.836719
# running loss : 0.863312
# running loss : 0.861453
# running loss : 0.856514
# running loss : 0.860692
# running loss : 0.854702
# running loss : 0.837141
# running loss : 0.845071
# running loss : 0.844875
# running loss : 0.854507
# running loss : 0.860871
# running loss : 0.842190
# running loss : 0.844512
# running loss : 0.856713
# running loss : 0.856948
# running loss : 0.852492
# running loss : 0.859256
# running loss : 0.852231
# running loss : 0.846977
# running loss : 0.832851
# running loss : 0.840811
# running loss : 0.864508
# running loss : 0.844780
# running loss : 0.840719
# running loss : 0.857757

# %%
# save model parameters
torch.save(model.state_dict(), './model_parameters/mean_bit_ppx/lossy_comp_depthmap3_beta000001_without_black_px_bis.pth')

# %%
# variable bit rate
    # get back network parameters obtained by first training (eg for a fixed value of beta and no lambda)
    # these parameters are used to initialize the new network and won't be changed after. 
    # The only parameter that is optimized in the new network is lambda 
    # The new network is trained each time we want to change the rate-distortion tradeoff beta
    
"""
model = LossyCompAutoencoder()
model.load_state_dict(torch.load('./model_parameters/mean_bit_ppx/lossy_comp_depthmap3_beta000001.pth'))
model.eval()
model.to(device)
"""

# transfert du model au gpu
model_bis.to(device)

# general update of coefficients    
    #define optimizer
optimizer = torch.optim.Adam(model_bis.parameters(), lr=0.00001)
    # define loss function
distortion = nn.MSELoss().cuda()
    #Epochs
n_epochs = 420
beta = 0.00001
nb_updates = 0
learning_rate = 0.0001
tau = 10000
kappa = 0.8

    # Training the network
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
          
    #Training
    for i_batch, data in enumerate(dataloader):
        learning_rate *= tau**kappa/(tau + nb_updates)**kappa
        print("learning_ rate : ", learning_rate)
        optimizer = torch.optim.Adam(model_bis.parameters(), lr=learning_rate)
        batch_images = data.to(device).float()
        [decoded_images, x_quantized] = model_bis(batch_images, 1, True, True)
        optimizer.zero_grad()
        loss_dist = distortion(decoded_images, batch_images)
        loss_bit = mean_bit_per_px(x_quantized, model_bis.phi, model_bis.var)
        loss = beta * loss_dist + loss_bit
        #print(loss)
            
        loss.backward()
        #print("conv1.weights grad: ", params[0].grad)
        #print(model.conv1.bias.grad)
        #print(model.conv1.weight.grad)
        optimizer.step()
        running_loss += loss.item()
        nb_updates += 1

    running_loss = running_loss/len(dataloader)
    print('running loss : {:.06f}'.format(running_loss), )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-94555e69bfd5> in <module>
#      13
#      14 # transfert du model au gpu
# ---> 15 model_bis.to(device)
#      16
#      17 # general update of coefficients
#
# NameError: name 'model_bis' is not defined

# %%
# variable bit rate
    # get back network parameters obtained by first training (eg for a fixed value of beta and no lambda)
    # these parameters are used to initialize the new network and won't be changed after. 
    # The only parameter that is optimized in the new network is lambda 
    # The new network is trained each time we want to change the rate-distortion tradeoff beta

model_bis = LossyCompAutoencoder_bis()
model_bis.load_state_dict(torch.load('./model_parameters/mean_bit_ppx/lossy_comp_depthmap3_beta000001.pth'))
model_bis.train()
model_bis.to(device)


weights_model_bis = list(model_bis.parameters())
print("nb parameters of the model : ", len(weights_model_bis))
for (name_bis, parameter_bis), (name, parameter) in zip(model_bis.named_parameters(), model.named_parameters()) :
    """
    if name_bis == "lamb":
        print("lamb parameter : ", parameter_bis)
        parameter_bis.data = torch.FloatTensor(1, 96, 1, 1).uniform_(0.9, 1.1)
        print("lamb new parameter : ", parameter_bis)
    """
    print("name of user-defined parameters : ", name_bis)
    print("size of user-defined parameters : ", parameter_bis.size())
    parameter.data = parameter_bis.data

for name_bis, parameter_bis in model_bis.named_parameters():
    if name_bis == "lamb":
        print("check lamb parameter : ", parameter_bis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c27b05dcba91> in <module>
#       5     # The new network is trained each time we want to change the rate-distortion tradeoff beta
#       6
# ----> 7 model_bis = LossyCompAutoencoder_bis()
#       8 model_bis.load_state_dict(torch.load('./model_parameters/mean_bit_ppx/lossy_comp_depthmap3_beta000001.pth'))
#       9 model_bis.train()
#
# NameError: name 'LossyCompAutoencoder_bis' is not defined

# %%
weights_model = list(model.parameters())
for i in range(0, 39, 1):
    weights_model[i] = weights_model_bis[i]
    print("size of user-defined parameters : ", weights_model_bis[i].size())
    print("weights model: " ,weights_model_bis[i])
model.train()    
#weights_model[39] = torch.FloatTensor(96).uniform_(0, 1)
#weights_model[40] = torch.FloatTensor(96).uniform_(0, 1)


for name, parameter in model.named_parameters():
    """
    if name == "lamb":
        print("lamb parameter : ", parameter)
        parameter.data = torch.FloatTensor(1, 96, 1, 1).uniform_(1, 1)
        print("lamb new parameter : ", parameter)
    """
    print("name of user-defined parameters : ", name)
    print("size of user-defined parameters : ", parameter.size())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9d7010c95117> in <module>
# ----> 1 weights_model = list(model.parameters())
#       2 for i in range(0, 39, 1):
#       3     weights_model[i] = weights_model_bis[i]
#       4     print("size of user-defined parameters : ", weights_model_bis[i].size())
#       5     print("weights model: " ,weights_model_bis[i])
#
# NameError: name 'model' is not defined

# %%
# test set 
"""
model = LossyCompAutoencoder()
model.load_state_dict(torch.load('./model_parameters/mean_bit_ppx/lossy_comp_depthmap3_beta000001.pth'))
model.eval()
model.to(device)
"""

#test_dataset = ImageDataset(root_dir='./data/kodac/', transform=transforms.Compose([RandomCrop(128), ToTensor()]))
test_dataset = ImageDataset(root_dir='D:/autoencoder_data/depthmaps/test/dilated', transform=transforms.Compose([RandomCrop((480, 640)), ToTensor()]))
fig, axes = plt.subplots(nrows=4, ncols=6, sharex=True, sharey=True, figsize=(8,8))
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        if test_image.size(2)>test_image.size(3):
            test_image = test_image.permute(0, 1, 3, 2)
        
        [reconstructed_image, vec_latent] = model(test_image, 1, True)
        print("min vec latent : ", torch.min(vec_latent))
        print("max vec latent : ", torch.max(vec_latent))
        
        ax = fig.add_subplot(4, 6, i+1, xticks=[], yticks=[])
        plt.imshow(torch.squeeze(reconstructed_image.int().cpu()))
        
        """
        # We can set the number of bins with the `bins` kwarg
        bins_list = [-6.5, -5.5, -4.5, -3.5, -2.5, -1.5, -0.5, 0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5]
        for k in range(96):
            # plot histograms
            fig, ax = plt.subplots(1, 1, sharey=True, tight_layout=True)
            ax.hist((vec_latent[:, k, :, :]).view(-1).cpu(), bins=bins_list)
            plt.savefig("D:\\autoencoder_data\\histograms\\depthmap\\" + "img" + str(i)+ "hist" + str(k) + ".png")
        """
# Out:
# min vec latent :  tensor(-7., device='cuda:0')
# max vec latent :  tensor(5., device='cuda:0')
# min vec latent :  tensor(-6., device='cuda:0')
# max vec latent :  tensor(3., device='cuda:0')
# min vec latent :  tensor(-6., device='cuda:0')
# max vec latent :  tensor(4., device='cuda:0')
# min vec latent :  tensor(-4., device='cuda:0')
# max vec latent :  tensor(3., device='cuda:0')
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(3., device='cuda:0')
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(5., device='cuda:0')
# min vec latent :  tensor(-4., device='cuda:0')
# max vec latent :  tensor(3., device='cuda:0')
# min vec latent :  tensor(-3., device='cuda:0')
# max vec latent :  tensor(4., device='cuda:0')
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(4., device='cuda:0')
# min vec latent :  tensor(-4., device='cuda:0')
# max vec latent :  tensor(3., device='cuda:0')
# min vec latent :  tensor(-7., device='cuda:0')
# max vec latent :  tensor(4., device='cuda:0')
# min vec latent :  tensor(-6., device='cuda:0')
# max vec latent :  tensor(4., device='cuda:0')
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(4., device='cuda:0')
# min vec latent :  tensor(-7., device='cuda:0')
# max vec latent :  tensor(7., device='cuda:0')
# min vec latent :  tensor(-6., device='cuda:0')
# max vec latent :  tensor(4., device='cuda:0')
# min vec latent :  tensor(-7., device='cuda:0')
# max vec latent :  tensor(4., device='cuda:0')
# min vec latent :  tensor(-6., device='cuda:0')
# max vec latent :  tensor(6., device='cuda:0')
# min vec latent :  tensor(-10., device='cuda:0')
# max vec latent :  tensor(5., device='cuda:0')
# min vec latent :  tensor(-7., device='cuda:0')
# max vec latent :  tensor(5., device='cuda:0')
# min vec latent :  tensor(-7., device='cuda:0')
# max vec latent :  tensor(4., device='cuda:0')
# min vec latent :  tensor(-6., device='cuda:0')
# max vec latent :  tensor(4., device='cuda:0')
# min vec latent :  tensor(-5., device='cuda:0')
# max vec latent :  tensor(5., device='cuda:0')
# min vec latent :  tensor(-8., device='cuda:0')
# max vec latent :  tensor(5., device='cuda:0')
# min vec latent :  tensor(-7., device='cuda:0')
# max vec latent :  tensor(7., device='cuda:0')

# %%
# save results
import cv2
from torchvision.utils import save_image

with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        reconstructed_image = model(test_image)
        reconstructed_depthmap = np.squeeze(reconstructed_image.cpu()).numpy()
        cv2.imwrite("D:\\autoencoder_data\\depthmaps2\\reconstructed\\beta_000001_dilated\\" + "img" + str(i)+".png", reconstructed_depthmap.astype(np.uint16))
        #save_image(reconstructed_depthmap, "D:\\autoencoder_data\\depthmaps\\reconstructed\\beta_0001\\" + "img" + str(i)+".png", normalize=True)

# %%
# compute PSNR for each image of the test set and its reconstruction

def write_data(filepath , tensor_data):
    batch, channel, h, w = tensor_data.size()
    matrix = tensor_data.cpu().numpy()
    file = open(filepath, "w")
    for image in range(batch):
        np.savetxt(file, matrix[image, :, :, :].reshape(channel*h, w), fmt ='%.0f')

    file.close()
    
def compute_entropy(tensor_data):
    min_val = tensor_data.min()
    max_val = tensor_data.max()
    nb_bins = max_val - min_val + 1
    hist = torch.histc(tensor_data, bins=nb_bins.int(), min=min_val, max=max_val)
    hist_prob = hist/hist.sum()
    hist_prob[hist_prob == 0] = 1
    entropy = -(hist_prob*torch.log2(hist_prob)).sum()
    return entropy
    
        
    
    
def psnr(original, compressed, max_pixel): 
    mse = torch.mean((original - compressed) ** 2) 
    if(mse == 0):  # MSE is zero means no noise is present in the signal . 
                  # Therefore PSNR have no importance. 
        return 100
    psnr = 20 * np.log10(max_pixel / np.sqrt(mse)) 
    return psnr 


test_dataset = ImageDataset(root_dir='D:/autoencoder_data/depthmaps/test/dilated', transform=transforms.Compose([RandomCrop((480, 640)), ToTensor()]))
psnr_sum = 0.0
bit_rate_sum = 0.0
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        [reconstructed_image, im_quantized] = model(test_image, 1, True)
        #write_data('.\\reconstructed_data\\kodac\\loss_distortion_and_bitrate\\beta_2\\latent_vect\\' + 'vec' + str(i) +'.txt', im_quantized)
        nb_symbols = im_quantized.size(0)*im_quantized.size(1)*im_quantized.size(2)*im_quantized.size(3)
        entropy = compute_entropy(im_quantized)
        nbpp = nb_symbols*entropy/float(test_image.size(0)*test_image.size(2)*test_image.size(3))
        psnr_sum+= psnr(test_image.cpu(), reconstructed_image.cpu(), 2**16-1.0)
        bit_rate_sum += nbpp
        print("entropy : ", entropy)
        print( "nb bits per pixel : ", nbpp)
        print("psnr : " , psnr(test_image.cpu(), reconstructed_image.cpu(), 2**16-1.0))
print( "mean nb bits per pixel : ", bit_rate_sum/len(test_dataset))
print("psnr mean : ", psnr_sum/len(test_dataset) )
# Out:
# entropy :  tensor(0.299682, device='cuda:0')
# nb bits per pixel :  tensor(0.449523, device='cuda:0')
# psnr :  tensor(59.911148)
# entropy :  tensor(0.280624, device='cuda:0')
# nb bits per pixel :  tensor(0.420936, device='cuda:0')
# psnr :  tensor(58.645592)
# entropy :  tensor(0.279606, device='cuda:0')
# nb bits per pixel :  tensor(0.419409, device='cuda:0')
# psnr :  tensor(62.470928)
# entropy :  tensor(0.264995, device='cuda:0')
# nb bits per pixel :  tensor(0.397493, device='cuda:0')
# psnr :  tensor(56.918236)
# entropy :  tensor(0.321478, device='cuda:0')
# nb bits per pixel :  tensor(0.482218, device='cuda:0')
# psnr :  tensor(56.003670)
# entropy :  tensor(0.303443, device='cuda:0')
# nb bits per pixel :  tensor(0.455164, device='cuda:0')
# psnr :  tensor(63.269012)
# entropy :  tensor(0.251661, device='cuda:0')
# nb bits per pixel :  tensor(0.377492, device='cuda:0')
# psnr :  tensor(58.613136)
# entropy :  tensor(0.267232, device='cuda:0')
# nb bits per pixel :  tensor(0.400848, device='cuda:0')
# psnr :  tensor(55.555897)
# entropy :  tensor(0.284949, device='cuda:0')
# nb bits per pixel :  tensor(0.427424, device='cuda:0')
# psnr :  tensor(62.742439)
# entropy :  tensor(0.285615, device='cuda:0')
# nb bits per pixel :  tensor(0.428423, device='cuda:0')
# psnr :  tensor(61.013199)
# entropy :  tensor(0.280314, device='cuda:0')
# nb bits per pixel :  tensor(0.420471, device='cuda:0')
# psnr :  tensor(58.584518)
# entropy :  tensor(0.310857, device='cuda:0')
# nb bits per pixel :  tensor(0.466286, device='cuda:0')
# psnr :  tensor(57.064495)
# entropy :  tensor(0.342531, device='cuda:0')
# nb bits per pixel :  tensor(0.513796, device='cuda:0')
# psnr :  tensor(60.719322)
# entropy :  tensor(0.357145, device='cuda:0')
# nb bits per pixel :  tensor(0.535717, device='cuda:0')
# psnr :  tensor(60.914539)
# entropy :  tensor(0.319701, device='cuda:0')
# nb bits per pixel :  tensor(0.479551, device='cuda:0')
# psnr :  tensor(61.570465)
# entropy :  tensor(0.308953, device='cuda:0')
# nb bits per pixel :  tensor(0.463430, device='cuda:0')
# psnr :  tensor(60.828457)
# entropy :  tensor(0.365580, device='cuda:0')
# nb bits per pixel :  tensor(0.548370, device='cuda:0')
# psnr :  tensor(58.830700)
# entropy :  tensor(0.377138, device='cuda:0')
# nb bits per pixel :  tensor(0.565707, device='cuda:0')
# psnr :  tensor(51.517021)
# entropy :  tensor(0.259791, device='cuda:0')
# nb bits per pixel :  tensor(0.389687, device='cuda:0')
# psnr :  tensor(48.712620)
# entropy :  tensor(0.325927, device='cuda:0')
# nb bits per pixel :  tensor(0.488891, device='cuda:0')
# psnr :  tensor(45.384995)
# entropy :  tensor(0.303327, device='cuda:0')
# nb bits per pixel :  tensor(0.454990, device='cuda:0')
# psnr :  tensor(47.058735)
# entropy :  tensor(0.470700, device='cuda:0')
# nb bits per pixel :  tensor(0.706050, device='cuda:0')
# psnr :  tensor(56.556961)
# entropy :  tensor(0.363664, device='cuda:0')
# nb bits per pixel :  tensor(0.545496, device='cuda:0')
# psnr :  tensor(56.634617)
# entropy :  tensor(0.342370, device='cuda:0')
# nb bits per pixel :  tensor(0.513554, device='cuda:0')
# psnr :  tensor(49.479210)
# mean nb bits per pixel :  tensor(0.472955, device='cuda:0')
# psnr mean :  tensor(57.041668)

# %%
def compute_entropy(tensor_data):
    min_val = tensor_data.min()
    max_val = tensor_data.max()
    nb_bins = max_val - min_val + 1
    hist = torch.histc(tensor_data, bins=nb_bins.int(), min=min_val, max=max_val)
    hist_prob = hist/hist.sum()
    hist_prob[hist_prob == 0] = 1
    entropy = -(hist_prob*torch.log2(hist_prob)).sum()
    return entropy
       
    
    
def psnr(original, compressed, max_pixel): 
    mse = torch.mean((original - compressed) ** 2) 
    if(mse == 0):  # MSE is zero means no noise is present in the signal . 
                  # Therefore PSNR have no importance. 
        return 100
    psnr = 20 * np.log10(max_pixel / np.sqrt(mse)) 
    return psnr 


# Load previous model
model_prev = LossyCompAutoencoder()
model_prev.load_state_dict(torch.load('./model_parameters/lossy_comp_params_with_rate_beta2_incremental_2.pth'))
model_prev.eval()
model_prev.to(device)


# And run test 
test_dataset = ImageDataset(root_dir='./data/kodac/', transform=ToTensor())
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        [reconstructed_image, im_quantized] = model_prev(test_image,1, True)
        nb_symbols = im_quantized.size(0)*im_quantized.size(1)*im_quantized.size(2)*im_quantized.size(3)
        entropy = compute_entropy(im_quantized)
        nbpp = nb_symbols*entropy/float(test_image.size(0)*test_image.size(1)*test_image.size(2)*test_image.size(3))
        print("nb_symbols : ", nb_symbols)
        print("entropy : ", entropy)
        print( "nb bits per pixel : ", nbpp)
        print("psnr : " , psnr(test_image.cpu(), reconstructed_image.cpu(), 255.0))
    
# And print figures
fig, axes = plt.subplots(nrows=4, ncols=6, sharex=True, sharey=True, figsize=(8,8))
with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        if test_image.size(2)<test_image.size(3):
            test_image = test_image.permute(0, 1, 3, 2)
        
        reconstructed_image = model_prev(test_image, 1,  False)
        ax = fig.add_subplot(4, 6, i+1, xticks=[], yticks=[])
        plt.imshow(np.squeeze(reconstructed_image.int().cpu()).permute(1, 2, 0))
        
# And save figures
from torchvision.utils import save_image

with torch.no_grad():
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        
        reconstructed_image = np.squeeze(model_prev(test_image).cpu())
        print(reconstructed_image.type())
        save_image(reconstructed_image, ".\\reconstructed_data\\kodac\\loss_distortion_and_bitrate\\beta_2_incremental_bis\\" + "img" + str(i)+".png", normalize=True)

# %%
"""
def entropy_rate(x_quantized, phi, var):
    u = torch.arange(-0.5, 0.5+0.01, 0.01).cuda()        
    gsm_sum = torch.zeros(len(u)).cuda()
    for i in range(len(u)):
        x = x_quantized + u[i]
        gsm_sum_i = sum_gsm(x, var, phi, 6)
        gsm_sum[i] = gsm_sum_i

    entropy = torch.trapz(gsm_sum, u)
    
    return entropy
"""

# Load incremental model
incremental_model = LossyCompAutoencoder()
incremental_model.load_state_dict(torch.load('./model_parameters/mean_bit_ppx/lossy_comp_depthmap3_beta1_without_bitrate.pth'))
incremental_model.train()
incremental_model.to(device)

# train again the model starting form incremental-learned weights
    #define optimizer
optimizer = torch.optim.Adam(incremental_model.parameters(), lr=0.00001)

# define loss function
distortion = nn.MSELoss().cuda()


# define beta
beta = 1.0

#Epochs
n_epochs = 800


# Training the network
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
           
    #Training
    for i_batch, data in enumerate(dataloader):
        batch_images = data.to(device).float()
        [decoded_images, x_quantized] = incremental_model(batch_images, 1, True, False)
        optimizer.zero_grad()
        #entropy = entropy_rate(x_quantized, incremental_model.phi, incremental_model.var)
        #print("entropy : ", entropy)
        dist = distortion(decoded_images, batch_images)
        #print("distortion : ", dist)
        #loss = beta * dist + entropy
        loss = beta*dist
        loss.backward()
        #print("conv1.weights grad: ", params[0].grad)
        #print(model.conv1.bias.grad)
        #print(model.conv1.weight.grad)
        optimizer.step()
        running_loss += loss.item()

    running_loss = running_loss/len(dataloader)
    print('running loss : {:.06f}'.format(running_loss), )
# Out:
# running loss : 90881.718424
# running loss : 80767.381022
# running loss : 81141.024251
# running loss : 82880.777669
# running loss : 82961.080566
# running loss : 80102.377279
# running loss : 78891.135254
# running loss : 81277.776530
# running loss : 85981.076497
# running loss : 79330.397786
# running loss : 81722.521647
# running loss : 81752.704427
# running loss : 80582.047445
# running loss : 79124.916667
# running loss : 77118.216146
# running loss : 80098.077311
# running loss : 80323.040690
# running loss : 77555.702474
# running loss : 81157.973796
# running loss : 83483.012695
# running loss : 81039.977051
# running loss : 80674.319661
# running loss : 78851.218424
# running loss : 79257.480469
# running loss : 81489.141927
# running loss : 78403.699056
# running loss : 77935.420654
# running loss : 75854.299316
# running loss : 77985.073893
# running loss : 79333.242025
# running loss : 78887.763672
# running loss : 76951.318522
# running loss : 74481.261230
# running loss : 76596.198730
# running loss : 80668.370605
# running loss : 78486.251790
# running loss : 79721.607747
# running loss : 81922.940918
# running loss : 74783.033040
# running loss : 76995.726074
# running loss : 75828.042806
# running loss : 75566.468831
# running loss : 77649.646891
# running loss : 75448.314860
# running loss : 80816.064128
# running loss : 78636.360352
# running loss : 79527.605794
# running loss : 79126.900879
# running loss : 78015.188965
# running loss : 74594.386637
# running loss : 77053.531820
# running loss : 75672.388346
# running loss : 76516.456706
# running loss : 74747.424805
# running loss : 78134.740234
# running loss : 76639.831543
# running loss : 78095.943848
# running loss : 76729.708659
# running loss : 75958.247721
# running loss : 76754.540853
# running loss : 74499.404785
# running loss : 76064.408447
# running loss : 74957.913411
# running loss : 74683.286133
# running loss : 76095.526449
# running loss : 74837.771810
# running loss : 78134.862467
# running loss : 73558.099772
# running loss : 73238.178223
# running loss : 73542.956380
# running loss : 71541.253743
# running loss : 76337.736003
# running loss : 77145.011230
# running loss : 82591.630697
# running loss : 74320.608724
# running loss : 75400.365723
# running loss : 76297.754720
# running loss : 73032.168457
# running loss : 72223.773275
# running loss : 77493.298340
# running loss : 74394.108236
# running loss : 73023.217041
# running loss : 76107.315267
# running loss : 74056.746582
# running loss : 74171.511719
# running loss : 74653.592773
# running loss : 73351.820312
# running loss : 78821.387044
# running loss : 75447.558757
# running loss : 72967.428385
# running loss : 72232.532227
# running loss : 71519.714762
# running loss : 72271.118571
# running loss : 75045.665039
# running loss : 71788.911540
# running loss : 71587.612956
# running loss : 75326.343424
# running loss : 72893.089844
# running loss : 72551.791504
# running loss : 72402.118164
# running loss : 72482.847819
# running loss : 70326.353027
# running loss : 72497.148438
# running loss : 71030.833252
# running loss : 72834.551188
# running loss : 69049.243978
# running loss : 72041.862793
# running loss : 73895.796224
# running loss : 71108.629639
# running loss : 70673.523600
# running loss : 70563.469645
# running loss : 71669.611491
# running loss : 71572.809570
# running loss : 73207.610026
# running loss : 70289.937988
# running loss : 73608.363932
# running loss : 69644.988770
# running loss : 70632.329346
# running loss : 72060.336344
# running loss : 74013.411377
# running loss : 72037.394206
# running loss : 70665.166341
# running loss : 68599.423014
# running loss : 69972.512858
# running loss : 71346.927246
# running loss : 71016.819010
# running loss : 66559.967692
# running loss : 71759.971680
# running loss : 68208.039225
# running loss : 68988.021159
# running loss : 72319.526855
# running loss : 66640.239339
# running loss : 71162.450195
# running loss : 73307.329427
# running loss : 72013.509603
# running loss : 67888.399577
# running loss : 67838.267253
# running loss : 67403.818359
# running loss : 66424.451579
# running loss : 68155.833171
# running loss : 66552.755371
# running loss : 69753.739746
# running loss : 68499.088460
# running loss : 67558.430339
# running loss : 68600.804281
# running loss : 69922.785156
# running loss : 66757.889730
# running loss : 68707.454753
# running loss : 68183.697591
# running loss : 65835.472493
# running loss : 67034.937663
# running loss : 68011.588867
# running loss : 66190.742350
# running loss : 72201.026693
# running loss : 67558.470052
# running loss : 67204.678711
# running loss : 66466.527100
# running loss : 67778.593913
# running loss : 66149.158854
# running loss : 66644.091553
# running loss : 66531.372070
# running loss : 68879.133464
# running loss : 65883.524577
# running loss : 65989.712565
# running loss : 64777.686930
# running loss : 66744.919027
# running loss : 64951.270345
# running loss : 69847.909180
# running loss : 68170.651530
# running loss : 63616.576986
# running loss : 65671.874756
# running loss : 64878.045410
# running loss : 65433.097087
# running loss : 65687.117350
# running loss : 64973.419434
# running loss : 65977.335938
# running loss : 64862.483317
# running loss : 65343.246257
# running loss : 67058.325602
# running loss : 67467.834310
# running loss : 64426.727458
# running loss : 68849.332194
# running loss : 66362.670898
# running loss : 63499.920329
# running loss : 66428.607096
# running loss : 67124.953776
# running loss : 65019.662923
# running loss : 65982.241211
# running loss : 63719.047689
# running loss : 64204.582194
# running loss : 63478.442708
# running loss : 64878.372762
# running loss : 65296.317139
# running loss : 63436.056803
# running loss : 63702.435954
# running loss : 64820.618083
# running loss : 65014.929769
# running loss : 64328.333496
# running loss : 64518.002686
# running loss : 64876.278076
# running loss : 64833.586426
# running loss : 64939.841471
# running loss : 64190.499349
# running loss : 64012.215088
# running loss : 61040.502197
# running loss : 62624.248454
# running loss : 62617.131836
# running loss : 62997.559082
# running loss : 62796.240641
# running loss : 65386.404297
# running loss : 68609.843750
# running loss : 63262.989665
# running loss : 62988.893962
# running loss : 63351.589111
# running loss : 63487.382894
# running loss : 66367.378581
# running loss : 63156.476888
# running loss : 62550.610352
# running loss : 65799.342611
# running loss : 63506.818115
# running loss : 62989.610189
# running loss : 61707.131022
# running loss : 62448.594889
# running loss : 62532.534831
# running loss : 62570.916667
# running loss : 63322.117188
# running loss : 63918.275391
# running loss : 66068.375326
# running loss : 62895.030762
# running loss : 62117.057861
# running loss : 62043.133626
# running loss : 61570.696777
# running loss : 64902.429688
# running loss : 63346.717041
# running loss : 62140.927083
# running loss : 61786.596354
# running loss : 63687.006266
# running loss : 60424.630615
# running loss : 61077.136312
# running loss : 60420.428792
# running loss : 61147.024740
# running loss : 61320.482666
# running loss : 61779.270508
# running loss : 62446.612386
# running loss : 60744.679688
# running loss : 64975.457031
# running loss : 60987.298096
# running loss : 62643.756917
# running loss : 61548.540039
# running loss : 59826.493164
# running loss : 61498.732747
# running loss : 60646.932699
# running loss : 59577.069255
# running loss : 60038.006673
# running loss : 62109.148600
# running loss : 59153.445231
# running loss : 58757.138184
# running loss : 61034.308431
# running loss : 59519.460612
# running loss : 59256.192546
# running loss : 58871.865234
# running loss : 61170.366292
# running loss : 61147.690348
# running loss : 59543.365397
# running loss : 60917.224854
# running loss : 60962.057292
# running loss : 59510.192546
# running loss : 59751.641846
# running loss : 60623.890299
# running loss : 57572.010905
# running loss : 59270.081380
# running loss : 57685.983358
# running loss : 58103.847575
# running loss : 59411.888184
# running loss : 60618.824870
# running loss : 57591.052327
# running loss : 60389.428467
# running loss : 59656.430827
# running loss : 58223.061849
# running loss : 56892.443359
# running loss : 59637.031576
# running loss : 56824.380127
# running loss : 57407.539795
# running loss : 59503.296224
# running loss : 59686.411865
# running loss : 56967.001302
# running loss : 57625.842855
# running loss : 58739.717041
# running loss : 59640.992676
# running loss : 56245.007812
# running loss : 56935.122396
# running loss : 56973.031494
# running loss : 57224.989176
# running loss : 56330.414144
# running loss : 59217.237142
# running loss : 56974.153239
# running loss : 57221.444499
# running loss : 59008.677165
# running loss : 57119.617513
# running loss : 55305.609049
# running loss : 57673.525716
# running loss : 56229.853027
# running loss : 59675.997640
# running loss : 55790.359294
# running loss : 57322.470052
# running loss : 56106.875407
# running loss : 60872.270020
# running loss : 56010.167318
# running loss : 57382.687419
# running loss : 58415.753255
# running loss : 56892.956543
# running loss : 55117.039795
# running loss : 55409.036784
# running loss : 56686.735514
# running loss : 53838.631673
# running loss : 56824.481038
# running loss : 55640.784505
# running loss : 58160.728841
# running loss : 57626.534668
# running loss : 58323.094727
# running loss : 53920.407064
# running loss : 55168.505452
# running loss : 55127.270671
# running loss : 54881.633057
# running loss : 54211.694743
# running loss : 54501.730794
# running loss : 56947.436442
# running loss : 56152.468913
# running loss : 55613.786621
# running loss : 55751.203613
# running loss : 56320.617106
# running loss : 55469.636556
# running loss : 58944.215576
# running loss : 55151.181234
# running loss : 54784.307699
# running loss : 53933.224284
# running loss : 53722.103516
# running loss : 55022.672526
# running loss : 55112.404785
# running loss : 56338.940511
# running loss : 54212.332845
# running loss : 58285.784668
# running loss : 53848.245280
# running loss : 53618.175374
# running loss : 60219.200602
# running loss : 56293.832357
# running loss : 53725.534993
# running loss : 53165.360514
# running loss : 55134.238932
# running loss : 52998.208496
# running loss : 56099.515462
# running loss : 53734.485921
# running loss : 53228.031657
# running loss : 55388.830322
# running loss : 52846.800618
# running loss : 53111.263590
# running loss : 52534.631673
# running loss : 52801.039388
# running loss : 53641.130859
# running loss : 53582.857992
# running loss : 52399.858398
# running loss : 56638.229818
# running loss : 52979.531006
# running loss : 54271.182373
# running loss : 52913.174805
# running loss : 55493.278646
# running loss : 55342.254557
# running loss : 57968.763753
# running loss : 52760.720785
# running loss : 52599.817790
# running loss : 52585.163493
# running loss : 53373.625977
# running loss : 52442.100586
# running loss : 53891.315267
# running loss : 50547.944987
# running loss : 51661.942057
# running loss : 53970.030111
# running loss : 53986.946533
# running loss : 52550.642578
# running loss : 52293.479980
# running loss : 51929.335938
# running loss : 52587.779541
# running loss : 53295.073893
# running loss : 53681.895915
# running loss : 52964.613241
# running loss : 52228.323975
# running loss : 52873.979980
# running loss : 53320.415853
# running loss : 53423.901449
# running loss : 50707.938558
# running loss : 54250.009359
# running loss : 52043.060221
# running loss : 52570.794678
# running loss : 50841.515544
# running loss : 52653.602702
# running loss : 50633.415283
# running loss : 53026.918864
# running loss : 53763.368083
# running loss : 52898.638509
# running loss : 51744.891317
# running loss : 49307.681885
# running loss : 51092.994548
# running loss : 52226.794352
# running loss : 50100.759684
# running loss : 51270.523682
# running loss : 52272.166585
# running loss : 52876.253988
# running loss : 53089.156820
# running loss : 54536.442790
# running loss : 51735.277018
# running loss : 51833.324219
# running loss : 49773.806722
# running loss : 51504.332845
# running loss : 51773.265869
# running loss : 49764.508464
# running loss : 49225.610514
# running loss : 49575.354899
# running loss : 49936.283854
# running loss : 48218.027507
# running loss : 50748.913330
# running loss : 49324.360840
# running loss : 50701.173747
# running loss : 49849.854736
# running loss : 51438.284261
# running loss : 50187.976644
# running loss : 50680.334391
# running loss : 50702.315674
# running loss : 53446.914551
# running loss : 50960.229045
# running loss : 50184.661214
# running loss : 50461.203532
# running loss : 50077.770833
# running loss : 50244.267741
# running loss : 49254.449544
# running loss : 48433.246501
# running loss : 49656.638509
# running loss : 48824.016520
# running loss : 49076.353923
# running loss : 50104.597453
# running loss : 50265.500488
# running loss : 50032.427246
# running loss : 49624.999512
# running loss : 50925.185954
# running loss : 48534.235921
# running loss : 50662.632568
# running loss : 48193.469889
# running loss : 48474.606852
# running loss : 49389.584473
# running loss : 49591.266439
# running loss : 51075.706055
# running loss : 47004.641195
# running loss : 49832.155762
# running loss : 48841.529948
# running loss : 48364.793050
# running loss : 49087.891032
# running loss : 49919.277507
# running loss : 50339.088623
# running loss : 48497.556234
# running loss : 48887.618652
# running loss : 49891.339193
# running loss : 50234.233073
# running loss : 49169.051351
# running loss : 47015.986491
# running loss : 48219.990153
# running loss : 47937.049316
# running loss : 47478.959554
# running loss : 47636.843750
# running loss : 48866.298258
# running loss : 47756.621826
# running loss : 48210.740072
# running loss : 47783.646322
# running loss : 48204.722738
# running loss : 47461.079508
# running loss : 49181.149658
# running loss : 49097.230957
# running loss : 50193.783366
# running loss : 49531.762288
# running loss : 50378.979818
# running loss : 48356.587484
# running loss : 48787.566243
# running loss : 48377.106934
# running loss : 48516.516927
# running loss : 46364.435872
# running loss : 47041.051025
# running loss : 47239.184001
# running loss : 46649.845540
# running loss : 45625.941976
# running loss : 48156.247965
# running loss : 46817.323812
# running loss : 46268.982544
# running loss : 45899.153646
# running loss : 46552.740560
# running loss : 47220.430013
# running loss : 47627.274089
# running loss : 47222.320475
# running loss : 45934.450358
# running loss : 47653.203451
# running loss : 47547.944092
# running loss : 47703.819173
# running loss : 46692.880778
# running loss : 45628.091960
# running loss : 45902.782715
# running loss : 46425.142415
# running loss : 45972.709961
# running loss : 46971.066650
# running loss : 46530.842041
# running loss : 44901.349935
# running loss : 45541.446289
# running loss : 44867.612305
# running loss : 47857.843750
# running loss : 46523.240641
# running loss : 47989.493245
# running loss : 48226.034831
# running loss : 49315.416585
# running loss : 46795.908040
# running loss : 46138.067424
# running loss : 47623.291016
# running loss : 46836.219076
# running loss : 45712.408285
# running loss : 46073.073893
# running loss : 47835.127360
# running loss : 44855.554850
# running loss : 44278.727946
# running loss : 44724.735758
# running loss : 44922.763590
# running loss : 47036.272542
# running loss : 45472.129232
# running loss : 44592.049967
# running loss : 46900.262044
# running loss : 45040.774577
# running loss : 44863.964193
# running loss : 44892.395020
# running loss : 50270.711344
# running loss : 47854.146647
# running loss : 45389.122803
# running loss : 44142.645589
# running loss : 46900.283854
# running loss : 45170.434408
# running loss : 44071.296387
# running loss : 47352.829834
# running loss : 44197.769775
# running loss : 47417.472331
# running loss : 47880.432129
# running loss : 45117.166829
# running loss : 43656.764567
# running loss : 44177.691569
# running loss : 44232.839600
# running loss : 48167.512044
# running loss : 46936.025635
# running loss : 46363.481201
# running loss : 45062.203451
# running loss : 44512.832357
# running loss : 44358.731445
# running loss : 44597.669637
# running loss : 44642.365641
# running loss : 44932.551676
# running loss : 46019.332682
# running loss : 46495.985189
# running loss : 44827.285238
# running loss : 45363.432048
# running loss : 44987.661865
# running loss : 44964.790446
# running loss : 47934.064046
# running loss : 44326.019531
# running loss : 44429.802327
# running loss : 43404.033936
# running loss : 42733.738118
# running loss : 42979.190999
# running loss : 43090.233480
# running loss : 42178.195231
# running loss : 44282.277262
# running loss : 43237.059408
# running loss : 43080.399984
# running loss : 44342.421956
# running loss : 45713.942220
# running loss : 45192.666016
# running loss : 44188.002686
# running loss : 43359.221354
# running loss : 42526.843750
# running loss : 42504.014079
# running loss : 44542.493408
# running loss : 43413.537598
# running loss : 42975.689697
# running loss : 41882.025798
# running loss : 45173.108561
# running loss : 43113.059163
# running loss : 42049.697184
# running loss : 43533.153076
# running loss : 44885.608317
# running loss : 41994.284668
# running loss : 42707.935465
# running loss : 43617.561401
# running loss : 43501.439535
# running loss : 45306.684977
# running loss : 42371.569499
# running loss : 42649.004028
# running loss : 42970.214600
# running loss : 43877.583211
# running loss : 45055.379883
# running loss : 47416.100423
# running loss : 44013.671549
# running loss : 41930.735921
# running loss : 42926.273356
# running loss : 42976.764323
# running loss : 42344.595866
# running loss : 45141.950684
# running loss : 41748.728271
# running loss : 40846.569661
# running loss : 40846.616211
# running loss : 42071.263021
# running loss : 42872.596273
# running loss : 41079.228597
# running loss : 43009.363444
# running loss : 41749.715007
# running loss : 43407.815430
# running loss : 41383.585124
# running loss : 42660.203613
# running loss : 39532.865723
# running loss : 42471.631836
# running loss : 41117.482422
# running loss : 42307.607259
# running loss : 43086.586670
# running loss : 41912.858398
# running loss : 40667.849447
# running loss : 40378.923360
# running loss : 42101.007955
# running loss : 43457.886882
# running loss : 42638.267253
# running loss : 40191.221517
# running loss : 42054.164632
# running loss : 42710.465576
# running loss : 41776.853027
# running loss : 40840.724528
# running loss : 41981.012533
# running loss : 41827.223470
# running loss : 42626.150553
# running loss : 41102.608724
# running loss : 42965.730469
# running loss : 40813.096680
# running loss : 42967.378255
# running loss : 40754.357422
# running loss : 43311.801514
# running loss : 43746.010010
# running loss : 45314.289225
# running loss : 44185.326742
# running loss : 41368.289469
# running loss : 42592.260905
# running loss : 42177.947917
# running loss : 39440.786865
# running loss : 41175.631348
# running loss : 40673.101237
# running loss : 41260.341309
# running loss : 39842.173096
# running loss : 39610.854655
# running loss : 40011.491252
# running loss : 41294.312744
# running loss : 40743.686686
# running loss : 40808.694580
# running loss : 40922.118083
# running loss : 41300.705566
# running loss : 39272.987427
# running loss : 39944.322591
# running loss : 40927.354818
# running loss : 41713.333903
# running loss : 41205.771159
# running loss : 40223.961263
# running loss : 40055.026204
# running loss : 42504.890137
# running loss : 38472.325480
# running loss : 39715.286133
# running loss : 40104.106201
# running loss : 39906.485270
# running loss : 39945.331217
# running loss : 40454.727132
# running loss : 40127.358480
# running loss : 40601.440552
# running loss : 39349.564697
# running loss : 39965.462565
# running loss : 39061.080078
# running loss : 39247.757243
# running loss : 40323.256266
# running loss : 39330.027995
# running loss : 40946.892822
# running loss : 39579.459066
# running loss : 40141.127523
# running loss : 37958.996094
# running loss : 38565.373617
# running loss : 39442.689250
# running loss : 37960.278198
# running loss : 40197.711995
# running loss : 38318.272054
# running loss : 38624.005941
# running loss : 39791.647135
# running loss : 40296.829346
# running loss : 38651.548828
# running loss : 39517.404378
# running loss : 39225.887451
# running loss : 40284.003174
# running loss : 39523.394084
# running loss : 39864.496908
# running loss : 40773.883952
# running loss : 40279.895996
# running loss : 38176.749430
# running loss : 39640.435221
# running loss : 40695.060954
# running loss : 38564.190186
# running loss : 38240.065918
# running loss : 39776.977295
# running loss : 39240.485107
# running loss : 39634.348633
# running loss : 39527.217855
# running loss : 38991.980387
# running loss : 40660.052409
# running loss : 39328.340251
# running loss : 37052.416667
# running loss : 37462.157878
# running loss : 36517.768880
# running loss : 37817.378174
# running loss : 37819.425456
# running loss : 39793.552816
# running loss : 39935.727580
# running loss : 37920.915934
# running loss : 39468.699219
# running loss : 40378.190267
# running loss : 42313.413981
# running loss : 41549.432536
# running loss : 40742.347575
# running loss : 38147.835856
# running loss : 37041.001465
# running loss : 38509.685872
# running loss : 39745.657308
# running loss : 39248.717041
# running loss : 37695.092529
# running loss : 37377.616374
# running loss : 37953.819417
# running loss : 36682.688721
# running loss : 36722.831787
# running loss : 37717.070312
# running loss : 37457.493571
# running loss : 37760.280558
# running loss : 38268.555990
# running loss : 39532.212484
# running loss : 38873.700765
# running loss : 37996.628255
# running loss : 36304.407104
# running loss : 35136.636841
# running loss : 36975.792847
# running loss : 36151.441610
# running loss : 37569.448730
# running loss : 37302.001546
# running loss : 36688.678345
# running loss : 36615.930908
# running loss : 36540.654948
# running loss : 36370.960327
# running loss : 36948.654378
# running loss : 36589.127238
# running loss : 35811.934977
# running loss : 36479.235596
# running loss : 37382.861694
# running loss : 36323.645264
# running loss : 37198.983073
# running loss : 36736.359049
# running loss : 36496.441162
# running loss : 36162.318237
# running loss : 37526.738851
# running loss : 37927.038574
# running loss : 36195.593913
# running loss : 35435.948975
# running loss : 36975.531901
# running loss : 37372.103190
# running loss : 35218.944051
# running loss : 37129.270345
# running loss : 36393.042765
# running loss : 36152.630452
# running loss : 36788.343424
# running loss : 37108.506755
# running loss : 37676.685059
# running loss : 36886.631999
# running loss : 36423.447673
# running loss : 35939.713257
# running loss : 37843.852376
# running loss : 36102.163167
# running loss : 36574.401855
# running loss : 38166.099121
# running loss : 36151.078857
# running loss : 37152.074951
# running loss : 38201.656169
# running loss : 35700.944499
# running loss : 37860.992025
# running loss : 36248.929606
# running loss : 36788.438558
# running loss : 36701.525553
# running loss : 36676.227783
# running loss : 35208.483602
# running loss : 36152.297363
# running loss : 35524.565104
# running loss : 35788.688883
# running loss : 36025.366781
# running loss : 35683.189372
# running loss : 35550.561117

# %%
from range_coder import RangeEncoder, RangeDecoder, prob_to_cum_freq
import os

# Load previous model
model = LossyCompAutoencoder()
model.load_state_dict(torch.load('./model_parameters/mean_bit_ppx/lossy_comp_params_with_rate_beta0005_incremental.pth'))
model.eval()
model.to(device)

nb_bits = 0.0
test_dataset = ImageDataset(root_dir='./data/kodac/', transform=ToTensor())
with torch.no_grad():  
    for i in range(len(test_dataset)):
        test_image = test_dataset[i].unsqueeze(0).to(device).float()
        [reconstructed_image, data_comp] = model(test_image, 1, True)
            # compute symbol probabilities
        min_val = data_comp.min()
        if min_val <0:
            data_comp -= min_val
            min_val = 0
        max_val = data_comp.max()
        nb_bins = max_val - min_val + 1
        hist = torch.histc(data_comp, bins=nb_bins.int(), min=min_val, max=max_val)
        prob = hist/hist.sum()
        #print("data comp : ", data_comp)
        #print(prob)
        
        """
        if len(torch.nonzero(prob)) != len(prob):
            zero_indices = ((prob == 0).nonzero())
            for j in reversed(range(0, len(zero_indices), 1)):
                data_comp[data_comp > int(zero_indices[j])+min_val] -=1
            min_val = data_comp.min()
            max_val = data_comp.max()
            nb_bins = max_val - min_val + 1
            hist = torch.histc(data_comp, bins=nb_bins.int(), min=min_val, max=max_val)
            prob = hist/hist.sum()
            print(min_val)
            print(max_val)
            print("data comp : ", data_comp)
            print(prob)
         """ 
            
            # convert probabilities to cumulative integer frequency table
        #cumFreq = prob_to_cum_freq(torch.clamp(prob, min=np.finfo(np.float32).eps).cpu(), resolution=128)
        cumFreq = prob_to_cum_freq(prob.cpu(), resolution=128)
        #print(cumFreq)
        
        # encode data
        filepath_to_write = "D:\\lossy_autoencoder\\latent_vect_encoded\\" + "img" + str(i) + ".bin"
        encoder = RangeEncoder(filepath_to_write)
        #print(torch.flatten(data_comp).cpu().tolist())
        encoder.encode(torch.flatten(data_comp.int()).cpu().tolist(), cumFreq)
        encoder.close()
        
        
        file_size = os.path.getsize(filepath_to_write)*8 #number of bits in the file
        print(file_size)
        nb_bits += file_size
        
    nb_bits_per_image = nb_bits/len(test_dataset)
    print(nb_bits_per_image)
    nb_bits_per_pixel = nb_bits_per_image/(512*768)
    print(nb_bits_per_pixel)
    
    
"""
    test_image = test_dataset[1].unsqueeze(0).to(device).float()
    [reconstructed_image, data_comp] = model(test_image, 1, True)
        # compute symbol probabilities
    min_val = data_comp.min()
    print(min_val)
    print(data_comp.max())
    if min_val <0:
        data_comp -= min_val
        min_val = 0
    max_val = data_comp.max()
    
    print(max_val)
    nb_bins = max_val - min_val + 1
    print(nb_bins)
    hist = torch.histc(data_comp, bins=nb_bins.int(), min=min_val, max=max_val)
    prob = hist/hist.sum()
    print(prob)
         # convert probabilities to cumulative integer frequency table
    cumFreq = prob_to_cum_freq(prob.cpu(), resolution=128)
    #print(cumFreq)

    print(torch.flatten(data_comp).cpu().tolist())
    
    
        # encode data
    filepath_to_write = "D:\\lossy_autoencoder\\latent_vect_encoded\\" + "img" + str(1) + ".bin"
    encoder = RangeEncoder(filepath_to_write)
    print(torch.flatten(data_comp).cpu().tolist())
    encoder.encode(torch.flatten(data_comp.int()).cpu().tolist(), cumFreq)
    encoder.close()   
"""

# %%
import cv2
from torchvision.utils import save_image

test_dataset = ImageDataset(root_dir='D:/autoencoder_data/depthmaps/test', transform=transforms.Compose([RandomCrop((480, 640)), ToTensor()]))
#fig, axes = plt.subplots(nrows=4, ncols=6, sharex=True, sharey=True, figsize=(8,8))

for i in range(len(test_dataset)):
    test_image = test_dataset[i].unsqueeze(0).float().cuda()

    #test_image_without_black_px = black_pixels_removal_by_dilatation(test_image, torch.ones(3, 5))
    test_image_without_black_px = black_pixels_removal_by_dilatation(test_image)
    cv2.imwrite("D:\\autoencoder_data\\depthmaps2\\dilated\\" + "img" + str(i)+".png", np.squeeze(test_image_without_black_px.cpu().numpy()).astype(np.uint16))
    #ax = fig.add_subplot(4, 6, i+1, xticks=[], yticks=[])
    #plt.imshow(torch.squeeze(test_image_without_black_px).cpu())

"""    
i = 0
test_image = test_dataset[i].unsqueeze(0).float()

#test_image_without_black_px = black_pixels_removal_by_dilatation(test_image, torch.ones(3, 5))
test_image_without_black_px = black_pixels_removal_by_dilatation(test_image)
ax = fig.add_subplot(4, 6, i+1, xticks=[], yticks=[])
plt.imshow(torch.squeeze(test_image_without_black_px))
"""
# Out:
# '    \ni = 0\ntest_image = test_dataset[i].unsqueeze(0).float()\n\n#test_image_without_black_px = black_pixels_removal_by_dilatation(test_image, torch.ones(3, 5))\ntest_image_without_black_px = black_pixels_removal_by_dilatation(test_image)\nax = fig.add_subplot(4, 6, i+1, xticks=[], yticks=[])\nplt.imshow(torch.squeeze(test_image_without_black_px))\n'
